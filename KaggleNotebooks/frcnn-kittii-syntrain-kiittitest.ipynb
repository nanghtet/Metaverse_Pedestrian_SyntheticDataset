# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Download TorchVision repo to use some files from
# references/detection
# !pip install pycocotools --quiet
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 531476, done.
# remote: Counting objects: 100% (45086/45086), done.
# remote: Compressing objects: 100% (2076/2076), done.
# remote: Total 531476 (delta 43041), reused 44919 (delta 42937), pack-reused 486390
# Receiving objects: 100% (531476/531476), 1.00 GiB | 23.59 MiB/s, done.
# Resolving deltas: 100% (496285/496285), done.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
from torch.utils.data import ConcatDataset

import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
# defining the files directory and testing directory
train_dir = '/kaggle/input/kitti-train-test-selection/Train_Test_Selection/Train'
test_dir  = '/kaggle/input/kitti-train-test-selection/Train_Test_Selection/Test'

# %%
add_train_dir = '/kaggle/input/pedestriansyntheticdataset/train/train'

# %%
#for txt-annotatation dataset
class KittiDataset(torch.utils.data.Dataset):
    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        self.classes = ['background', 'Pedestrian']

    def __getitem__(self, idx):
        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # Reading the images and converting them to correct size and color
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        img_res /= 255.0

        # Annotation file
        annot_filename = img_name[:-4] + '.txt'
        annot_file_path = os.path.join(self.files_dir, annot_filename)

        boxes = []
        labels = []

           # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        # Read annotation data from text file
        with open(annot_file_path, 'r') as file:
            for line in file:
                parts = line.strip().split(' ')
                label_text = parts[0].lower()

                if label_text in ['pedestrian', 'person']:
                    labels.append(self.classes.index('Pedestrian'))

                    # Bounding box coordinates
                    xmin = float(parts[4])
                    ymin = float(parts[5])
                    xmax = float(parts[6])
                    ymax = float(parts[7])

                    # Normalize coordinates
                    xmin_corr = (xmin/wt)*self.width
                    xmax_corr = (xmax/wt)*self.width
                    ymin_corr = (ymin/ht)*self.height
                    ymax_corr = (ymax/ht)*self.height

                    boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])

        # Convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        #print("boxes shape: ", boxes.size(), "at index",idx, img_name)
       
      
           

        # Calculate areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # Suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)

        labels = torch.as_tensor(labels, dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd

        # image_id
        #image_id = torch.tensor([idx])
        image_id = idx
        target["image_id"] = image_id

        if self.transforms:
            sample = self.transforms(image=img_res, bboxes=target['boxes'], labels=labels)
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
        return img_res, target
    
    

    def __len__(self):
        return len(self.imgs)

# %%
class ImagesDataset(torch.utils.data.Dataset):

    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
            
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        
        
        # classes: 0 index is reserved for background
        self.classes = ['background','Pedestrian']

    def __getitem__(self, idx):

        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # reading the images and converting them to correct size and color    
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        # diving by 255
        img_res /= 255.0
        
        # annotation file
        annot_filename = img_name[:-4] + '.xml'
        annot_file_path = os.path.join(self.files_dir, annot_filename)
        
        boxes = []
        labels = []
        tree = et.parse(annot_file_path)
        root = tree.getroot()
        
        # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        
        # box coordinates for xml files are extracted and corrected for image size given
        for member in root.findall('object'):
            label_text = member.find('name').text.lower()
            if label_text in ['ped', 'pedestrian','person']:
                labels.append(self.classes.index('Pedestrian')) 
            
            # bounding box
                xmin = int(member.find('bndbox').find('xmin').text)
                xmax = int(member.find('bndbox').find('xmax').text)
            
                ymin = int(member.find('bndbox').find('ymin').text)
                ymax = int(member.find('bndbox').find('ymax').text)
            
            
                xmin_corr = (xmin/wt)*self.width
                xmax_corr = (xmax/wt)*self.width
                ymin_corr = (ymin/ht)*self.height
                ymax_corr = (ymax/ht)*self.height
            
                boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
        
        # convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        # getting the areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
        
        labels = torch.as_tensor(labels, dtype=torch.int64)


        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        # image_id
        image_id = idx
        target["image_id"] = image_id
        
  


        if self.transforms:
            
            sample = self.transforms(image = img_res,
                                     bboxes = target['boxes'],
                                     labels = labels)
            
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
            
            
            
        return img_res, target

    def __len__(self):
        return len(self.imgs)

# %%
def get_object_detection_model(num_classes):

    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 

    return model

# %%
# Send train=True fro training transforms and False for val/test transforms
def get_transform(train):
    
    if train:
        return A.Compose([
            A.HorizontalFlip(0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
            A.Rotate(limit=15, p=0.5),
            ToTensorV2(p=1.0)
        ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']))
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
# use our dataset and defined transformations
train_dataset     = KittiDataset(train_dir, 1920, 1080, transforms= get_transform(train=True))
add_train_dataset = ImagesDataset(add_train_dir, 1920, 1080, transforms= get_transform(train=True))
combined_dataset = ConcatDataset([train_dataset, add_train_dataset])

test_dataset = KittiDataset(test_dir, 1920, 1080, transforms= get_transform(train=False))


# define training and validation data loaders
combined_data_loader_train = torch.utils.data.DataLoader(
    combined_dataset, batch_size=4, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

# # define training and validation data loaders
# data_loader_train = torch.utils.data.DataLoader(
#     train_dataset, batch_size=4, shuffle=True, num_workers=4,
#     collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    test_dataset, batch_size=4, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')


num_classes = 2

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:02<00:00, 60.0MB/s]

# %%
# # training for 5 epochs
# num_epochs = 5
# for epoch in range(num_epochs):
#     # training for one epoch
#     train_one_epoch(model, optimizer, data_loader_train, device, epoch, print_freq=10)
#     # update the learning rate
#     lr_scheduler.step()
#     # evaluate on the test dataset
#     evaluate(model, data_loader_test, device=device)

# %%
# training for 10 epochs (additional training)
num_epochs = 10
for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, combined_data_loader_train, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [  0/149]  eta: 0:11:38  lr: 0.000039  loss: 1.0147 (1.0147)  loss_classifier: 0.6439 (0.6439)  loss_box_reg: 0.2174 (0.2174)  loss_objectness: 0.0704 (0.0704)  loss_rpn_box_reg: 0.0830 (0.0830)  time: 4.6874  data: 1.5895  max mem: 4799
# Epoch: [0]  [ 10/149]  eta: 0:02:20  lr: 0.000376  loss: 0.8645 (0.8139)  loss_classifier: 0.5553 (0.5048)  loss_box_reg: 0.2000 (0.2137)  loss_objectness: 0.0222 (0.0632)  loss_rpn_box_reg: 0.0216 (0.0322)  time: 1.0117  data: 0.1688  max mem: 4958
# Epoch: [0]  [ 20/149]  eta: 0:01:48  lr: 0.000714  loss: 0.4853 (0.6177)  loss_classifier: 0.2436 (0.3421)  loss_box_reg: 0.1800 (0.2014)  loss_objectness: 0.0244 (0.0485)  loss_rpn_box_reg: 0.0140 (0.0257)  time: 0.6449  data: 0.0282  max mem: 4959
# Epoch: [0]  [ 30/149]  eta: 0:01:32  lr: 0.001051  loss: 0.4353 (0.5808)  loss_classifier: 0.1914 (0.2957)  loss_box_reg: 0.2069 (0.2056)  loss_objectness: 0.0244 (0.0529)  loss_rpn_box_reg: 0.0127 (0.0266)  time: 0.6548  data: 0.0321  max mem: 4959
# Epoch: [0]  [ 40/149]  eta: 0:01:21  lr: 0.001389  loss: 0.3594 (0.5170)  loss_classifier: 0.1094 (0.2458)  loss_box_reg: 0.2069 (0.1964)  loss_objectness: 0.0214 (0.0494)  loss_rpn_box_reg: 0.0127 (0.0254)  time: 0.6555  data: 0.0317  max mem: 4959
# Epoch: [0]  [ 50/149]  eta: 0:01:12  lr: 0.001726  loss: 0.3266 (0.4887)  loss_classifier: 0.0911 (0.2166)  loss_box_reg: 0.2058 (0.2020)  loss_objectness: 0.0192 (0.0464)  loss_rpn_box_reg: 0.0088 (0.0237)  time: 0.6537  data: 0.0329  max mem: 4959
# Epoch: [0]  [ 60/149]  eta: 0:01:03  lr: 0.002064  loss: 0.3331 (0.4732)  loss_classifier: 0.0907 (0.1976)  loss_box_reg: 0.2217 (0.2096)  loss_objectness: 0.0181 (0.0428)  loss_rpn_box_reg: 0.0088 (0.0233)  time: 0.6551  data: 0.0334  max mem: 4959
# Epoch: [0]  [ 70/149]  eta: 0:00:56  lr: 0.002401  loss: 0.3265 (0.4585)  loss_classifier: 0.0835 (0.1823)  loss_box_reg: 0.1898 (0.2118)  loss_objectness: 0.0267 (0.0407)  loss_rpn_box_reg: 0.0142 (0.0236)  time: 0.6521  data: 0.0308  max mem: 4959
# Epoch: [0]  [ 80/149]  eta: 0:00:48  lr: 0.002739  loss: 0.2643 (0.4315)  loss_classifier: 0.0727 (0.1679)  loss_box_reg: 0.1643 (0.2046)  loss_objectness: 0.0156 (0.0375)  loss_rpn_box_reg: 0.0091 (0.0216)  time: 0.6543  data: 0.0319  max mem: 4959
# Epoch: [0]  [ 90/149]  eta: 0:00:41  lr: 0.003076  loss: 0.2053 (0.4076)  loss_classifier: 0.0584 (0.1558)  loss_box_reg: 0.1250 (0.1949)  loss_objectness: 0.0132 (0.0361)  loss_rpn_box_reg: 0.0081 (0.0209)  time: 0.6548  data: 0.0320  max mem: 4959
# Epoch: [0]  [100/149]  eta: 0:00:33  lr: 0.003414  loss: 0.2037 (0.3907)  loss_classifier: 0.0622 (0.1474)  loss_box_reg: 0.1203 (0.1884)  loss_objectness: 0.0102 (0.0341)  loss_rpn_box_reg: 0.0112 (0.0207)  time: 0.6553  data: 0.0320  max mem: 4959
# Epoch: [0]  [110/149]  eta: 0:00:26  lr: 0.003751  loss: 0.2165 (0.3762)  loss_classifier: 0.0738 (0.1405)  loss_box_reg: 0.1349 (0.1838)  loss_objectness: 0.0095 (0.0321)  loss_rpn_box_reg: 0.0079 (0.0198)  time: 0.6528  data: 0.0318  max mem: 4959
# Epoch: [0]  [120/149]  eta: 0:00:19  lr: 0.004089  loss: 0.2127 (0.3733)  loss_classifier: 0.0583 (0.1346)  loss_box_reg: 0.1272 (0.1801)  loss_objectness: 0.0117 (0.0352)  loss_rpn_box_reg: 0.0065 (0.0233)  time: 0.6496  data: 0.0314  max mem: 4959
# Epoch: [0]  [130/149]  eta: 0:00:12  lr: 0.004426  loss: 0.2172 (0.3623)  loss_classifier: 0.0561 (0.1293)  loss_box_reg: 0.1254 (0.1763)  loss_objectness: 0.0139 (0.0339)  loss_rpn_box_reg: 0.0112 (0.0228)  time: 0.6541  data: 0.0316  max mem: 4959
# Epoch: [0]  [140/149]  eta: 0:00:06  lr: 0.004764  loss: 0.2206 (0.3563)  loss_classifier: 0.0643 (0.1256)  loss_box_reg: 0.1202 (0.1733)  loss_objectness: 0.0225 (0.0343)  loss_rpn_box_reg: 0.0168 (0.0232)  time: 0.6575  data: 0.0325  max mem: 4959
# Epoch: [0]  [148/149]  eta: 0:00:00  lr: 0.005000  loss: 0.2033 (0.3489)  loss_classifier: 0.0665 (0.1225)  loss_box_reg: 0.1085 (0.1700)  loss_objectness: 0.0167 (0.0333)  loss_rpn_box_reg: 0.0188 (0.0231)  time: 0.6289  data: 0.0300  max mem: 4959
# Epoch: [0] Total time: 0:01:40 (0.6772 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2843 (0.2843)  evaluator_time: 0.0061 (0.0061)  time: 0.9969  data: 0.6181  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2558 (0.2573)  evaluator_time: 0.0073 (0.0102)  time: 0.3596  data: 0.0595  max mem: 4959
# Test: Total time: 0:00:07 (0.3613 s / it)
# Averaged stats: model_time: 0.2558 (0.2573)  evaluator_time: 0.0073 (0.0102)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.321
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.634
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.396
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.514
# Epoch: [1]  [  0/149]  eta: 0:04:43  lr: 0.005000  loss: 0.1194 (0.1194)  loss_classifier: 0.0346 (0.0346)  loss_box_reg: 0.0595 (0.0595)  loss_objectness: 0.0180 (0.0180)  loss_rpn_box_reg: 0.0073 (0.0073)  time: 1.9022  data: 1.1356  max mem: 4959
# Epoch: [1]  [ 10/149]  eta: 0:01:48  lr: 0.005000  loss: 0.2028 (0.2311)  loss_classifier: 0.0511 (0.0641)  loss_box_reg: 0.1032 (0.1167)  loss_objectness: 0.0180 (0.0253)  loss_rpn_box_reg: 0.0257 (0.0249)  time: 0.7793  data: 0.1395  max mem: 4959
# Epoch: [1]  [ 20/149]  eta: 0:01:32  lr: 0.005000  loss: 0.2403 (0.2436)  loss_classifier: 0.0708 (0.0702)  loss_box_reg: 0.1183 (0.1309)  loss_objectness: 0.0151 (0.0226)  loss_rpn_box_reg: 0.0100 (0.0199)  time: 0.6587  data: 0.0370  max mem: 4959
# Epoch: [1]  [ 30/149]  eta: 0:01:23  lr: 0.005000  loss: 0.2325 (0.2408)  loss_classifier: 0.0681 (0.0697)  loss_box_reg: 0.1355 (0.1356)  loss_objectness: 0.0120 (0.0189)  loss_rpn_box_reg: 0.0069 (0.0166)  time: 0.6532  data: 0.0337  max mem: 4959
# Epoch: [1]  [ 40/149]  eta: 0:01:14  lr: 0.005000  loss: 0.2243 (0.2470)  loss_classifier: 0.0658 (0.0727)  loss_box_reg: 0.1369 (0.1403)  loss_objectness: 0.0094 (0.0171)  loss_rpn_box_reg: 0.0076 (0.0169)  time: 0.6502  data: 0.0319  max mem: 4959
# Epoch: [1]  [ 50/149]  eta: 0:01:07  lr: 0.005000  loss: 0.2290 (0.2488)  loss_classifier: 0.0598 (0.0713)  loss_box_reg: 0.1374 (0.1438)  loss_objectness: 0.0066 (0.0155)  loss_rpn_box_reg: 0.0077 (0.0181)  time: 0.6452  data: 0.0310  max mem: 4959
# Epoch: [1]  [ 60/149]  eta: 0:00:59  lr: 0.005000  loss: 0.2290 (0.2592)  loss_classifier: 0.0596 (0.0699)  loss_box_reg: 0.1300 (0.1386)  loss_objectness: 0.0075 (0.0284)  loss_rpn_box_reg: 0.0117 (0.0222)  time: 0.6482  data: 0.0315  max mem: 4959
# Epoch: [1]  [ 70/149]  eta: 0:00:52  lr: 0.005000  loss: 0.2159 (0.2504)  loss_classifier: 0.0531 (0.0670)  loss_box_reg: 0.0946 (0.1327)  loss_objectness: 0.0246 (0.0301)  loss_rpn_box_reg: 0.0137 (0.0206)  time: 0.6494  data: 0.0325  max mem: 4959
# Epoch: [1]  [ 80/149]  eta: 0:00:46  lr: 0.005000  loss: 0.2179 (0.2487)  loss_classifier: 0.0531 (0.0666)  loss_box_reg: 0.1057 (0.1331)  loss_objectness: 0.0256 (0.0289)  loss_rpn_box_reg: 0.0091 (0.0201)  time: 0.6484  data: 0.0336  max mem: 4959
# Epoch: [1]  [ 90/149]  eta: 0:00:39  lr: 0.005000  loss: 0.2506 (0.2503)  loss_classifier: 0.0628 (0.0679)  loss_box_reg: 0.1497 (0.1348)  loss_objectness: 0.0135 (0.0275)  loss_rpn_box_reg: 0.0094 (0.0201)  time: 0.6520  data: 0.0345  max mem: 4959
# Epoch: [1]  [100/149]  eta: 0:00:32  lr: 0.005000  loss: 0.1875 (0.2453)  loss_classifier: 0.0594 (0.0668)  loss_box_reg: 0.1136 (0.1329)  loss_objectness: 0.0106 (0.0260)  loss_rpn_box_reg: 0.0096 (0.0195)  time: 0.6537  data: 0.0343  max mem: 4959
# Epoch: [1]  [110/149]  eta: 0:00:25  lr: 0.005000  loss: 0.1793 (0.2404)  loss_classifier: 0.0594 (0.0660)  loss_box_reg: 0.1084 (0.1314)  loss_objectness: 0.0073 (0.0245)  loss_rpn_box_reg: 0.0078 (0.0185)  time: 0.6518  data: 0.0334  max mem: 4959
# Epoch: [1]  [120/149]  eta: 0:00:19  lr: 0.005000  loss: 0.2047 (0.2405)  loss_classifier: 0.0654 (0.0661)  loss_box_reg: 0.1123 (0.1315)  loss_objectness: 0.0080 (0.0243)  loss_rpn_box_reg: 0.0078 (0.0186)  time: 0.6533  data: 0.0341  max mem: 4959
# Epoch: [1]  [130/149]  eta: 0:00:12  lr: 0.005000  loss: 0.1888 (0.2369)  loss_classifier: 0.0491 (0.0655)  loss_box_reg: 0.1097 (0.1304)  loss_objectness: 0.0082 (0.0231)  loss_rpn_box_reg: 0.0073 (0.0180)  time: 0.6528  data: 0.0340  max mem: 4959
# Epoch: [1]  [140/149]  eta: 0:00:05  lr: 0.005000  loss: 0.1998 (0.2377)  loss_classifier: 0.0532 (0.0658)  loss_box_reg: 0.1314 (0.1320)  loss_objectness: 0.0091 (0.0223)  loss_rpn_box_reg: 0.0073 (0.0175)  time: 0.6497  data: 0.0325  max mem: 4959
# Epoch: [1]  [148/149]  eta: 0:00:00  lr: 0.005000  loss: 0.2226 (0.2373)  loss_classifier: 0.0655 (0.0661)  loss_box_reg: 0.1401 (0.1323)  loss_objectness: 0.0058 (0.0217)  loss_rpn_box_reg: 0.0083 (0.0172)  time: 0.6194  data: 0.0291  max mem: 4959
# Epoch: [1] Total time: 0:01:37 (0.6565 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2773 (0.2773)  evaluator_time: 0.0059 (0.0059)  time: 0.9924  data: 0.6352  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2569 (0.2579)  evaluator_time: 0.0109 (0.0146)  time: 0.3635  data: 0.0602  max mem: 4959
# Test: Total time: 0:00:07 (0.3653 s / it)
# Averaged stats: model_time: 0.2569 (0.2579)  evaluator_time: 0.0109 (0.0146)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.282
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.707
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.132
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.155
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.185
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.363
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.416
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.476
# Epoch: [2]  [  0/149]  eta: 0:04:46  lr: 0.005000  loss: 0.1485 (0.1485)  loss_classifier: 0.0599 (0.0599)  loss_box_reg: 0.0664 (0.0664)  loss_objectness: 0.0166 (0.0166)  loss_rpn_box_reg: 0.0057 (0.0057)  time: 1.9210  data: 1.2726  max mem: 4959
# Epoch: [2]  [ 10/149]  eta: 0:01:46  lr: 0.005000  loss: 0.1480 (0.1718)  loss_classifier: 0.0468 (0.0541)  loss_box_reg: 0.0725 (0.0883)  loss_objectness: 0.0138 (0.0133)  loss_rpn_box_reg: 0.0100 (0.0161)  time: 0.7668  data: 0.1443  max mem: 4959
# Epoch: [2]  [ 20/149]  eta: 0:01:31  lr: 0.005000  loss: 0.1539 (0.1890)  loss_classifier: 0.0473 (0.0575)  loss_box_reg: 0.0875 (0.1104)  loss_objectness: 0.0071 (0.0093)  loss_rpn_box_reg: 0.0068 (0.0118)  time: 0.6468  data: 0.0303  max mem: 4959
# Epoch: [2]  [ 30/149]  eta: 0:01:21  lr: 0.005000  loss: 0.1720 (0.1861)  loss_classifier: 0.0478 (0.0571)  loss_box_reg: 0.1005 (0.1081)  loss_objectness: 0.0052 (0.0102)  loss_rpn_box_reg: 0.0068 (0.0107)  time: 0.6430  data: 0.0301  max mem: 4959
# Epoch: [2]  [ 40/149]  eta: 0:01:13  lr: 0.005000  loss: 0.1496 (0.1886)  loss_classifier: 0.0478 (0.0591)  loss_box_reg: 0.0903 (0.1085)  loss_objectness: 0.0078 (0.0102)  loss_rpn_box_reg: 0.0070 (0.0108)  time: 0.6454  data: 0.0306  max mem: 4959
# Epoch: [2]  [ 50/149]  eta: 0:01:06  lr: 0.005000  loss: 0.1600 (0.1925)  loss_classifier: 0.0585 (0.0595)  loss_box_reg: 0.0872 (0.1088)  loss_objectness: 0.0076 (0.0126)  loss_rpn_box_reg: 0.0079 (0.0116)  time: 0.6479  data: 0.0313  max mem: 4959
# Epoch: [2]  [ 60/149]  eta: 0:00:59  lr: 0.005000  loss: 0.1890 (0.1952)  loss_classifier: 0.0570 (0.0595)  loss_box_reg: 0.1129 (0.1116)  loss_objectness: 0.0059 (0.0119)  loss_rpn_box_reg: 0.0106 (0.0122)  time: 0.6497  data: 0.0318  max mem: 4959
# Epoch: [2]  [ 70/149]  eta: 0:00:52  lr: 0.005000  loss: 0.2158 (0.1997)  loss_classifier: 0.0570 (0.0596)  loss_box_reg: 0.1409 (0.1173)  loss_objectness: 0.0048 (0.0112)  loss_rpn_box_reg: 0.0056 (0.0116)  time: 0.6481  data: 0.0316  max mem: 4959
# Epoch: [2]  [ 80/149]  eta: 0:00:45  lr: 0.005000  loss: 0.2405 (0.2102)  loss_classifier: 0.0588 (0.0620)  loss_box_reg: 0.1447 (0.1224)  loss_objectness: 0.0065 (0.0120)  loss_rpn_box_reg: 0.0084 (0.0138)  time: 0.6474  data: 0.0314  max mem: 4959
# Epoch: [2]  [ 90/149]  eta: 0:00:39  lr: 0.005000  loss: 0.2863 (0.2202)  loss_classifier: 0.0759 (0.0642)  loss_box_reg: 0.1472 (0.1297)  loss_objectness: 0.0098 (0.0118)  loss_rpn_box_reg: 0.0107 (0.0145)  time: 0.6540  data: 0.0331  max mem: 4959
# Epoch: [2]  [100/149]  eta: 0:00:32  lr: 0.005000  loss: 0.2321 (0.2198)  loss_classifier: 0.0658 (0.0637)  loss_box_reg: 0.1383 (0.1301)  loss_objectness: 0.0082 (0.0118)  loss_rpn_box_reg: 0.0087 (0.0143)  time: 0.6546  data: 0.0340  max mem: 4959
# Epoch: [2]  [110/149]  eta: 0:00:25  lr: 0.005000  loss: 0.1978 (0.2158)  loss_classifier: 0.0437 (0.0622)  loss_box_reg: 0.1092 (0.1275)  loss_objectness: 0.0049 (0.0119)  loss_rpn_box_reg: 0.0080 (0.0142)  time: 0.6494  data: 0.0328  max mem: 4959
# Epoch: [2]  [120/149]  eta: 0:00:19  lr: 0.005000  loss: 0.1300 (0.2112)  loss_classifier: 0.0368 (0.0609)  loss_box_reg: 0.0837 (0.1245)  loss_objectness: 0.0049 (0.0118)  loss_rpn_box_reg: 0.0057 (0.0141)  time: 0.6525  data: 0.0340  max mem: 4959
# Epoch: [2]  [130/149]  eta: 0:00:12  lr: 0.005000  loss: 0.1619 (0.2121)  loss_classifier: 0.0452 (0.0613)  loss_box_reg: 0.0909 (0.1255)  loss_objectness: 0.0065 (0.0114)  loss_rpn_box_reg: 0.0076 (0.0139)  time: 0.6518  data: 0.0328  max mem: 4959
# Epoch: [2]  [140/149]  eta: 0:00:05  lr: 0.005000  loss: 0.2063 (0.2126)  loss_classifier: 0.0596 (0.0612)  loss_box_reg: 0.1253 (0.1267)  loss_objectness: 0.0056 (0.0110)  loss_rpn_box_reg: 0.0101 (0.0136)  time: 0.6491  data: 0.0323  max mem: 4959
# Epoch: [2]  [148/149]  eta: 0:00:00  lr: 0.005000  loss: 0.1925 (0.2130)  loss_classifier: 0.0506 (0.0613)  loss_box_reg: 0.1247 (0.1271)  loss_objectness: 0.0056 (0.0110)  loss_rpn_box_reg: 0.0088 (0.0136)  time: 0.6216  data: 0.0305  max mem: 4959
# Epoch: [2] Total time: 0:01:37 (0.6546 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2743 (0.2743)  evaluator_time: 0.0065 (0.0065)  time: 0.9575  data: 0.6273  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2565 (0.2578)  evaluator_time: 0.0089 (0.0117)  time: 0.3585  data: 0.0594  max mem: 4959
# Test: Total time: 0:00:07 (0.3606 s / it)
# Averaged stats: model_time: 0.2565 (0.2578)  evaluator_time: 0.0089 (0.0117)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.315
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.720
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.399
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.196
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.413
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.482
# Epoch: [3]  [  0/149]  eta: 0:06:04  lr: 0.000500  loss: 0.2268 (0.2268)  loss_classifier: 0.0706 (0.0706)  loss_box_reg: 0.1335 (0.1335)  loss_objectness: 0.0117 (0.0117)  loss_rpn_box_reg: 0.0110 (0.0110)  time: 2.4468  data: 1.7595  max mem: 4959
# Epoch: [3]  [ 10/149]  eta: 0:01:53  lr: 0.000500  loss: 0.2075 (0.1898)  loss_classifier: 0.0652 (0.0606)  loss_box_reg: 0.1335 (0.1160)  loss_objectness: 0.0039 (0.0059)  loss_rpn_box_reg: 0.0087 (0.0073)  time: 0.8157  data: 0.1868  max mem: 4959
# Epoch: [3]  [ 20/149]  eta: 0:01:35  lr: 0.000500  loss: 0.1866 (0.1990)  loss_classifier: 0.0528 (0.0591)  loss_box_reg: 0.1131 (0.1250)  loss_objectness: 0.0031 (0.0062)  loss_rpn_box_reg: 0.0054 (0.0087)  time: 0.6521  data: 0.0310  max mem: 4959
# Epoch: [3]  [ 30/149]  eta: 0:01:24  lr: 0.000500  loss: 0.1926 (0.2005)  loss_classifier: 0.0528 (0.0592)  loss_box_reg: 0.1339 (0.1268)  loss_objectness: 0.0026 (0.0054)  loss_rpn_box_reg: 0.0064 (0.0091)  time: 0.6551  data: 0.0341  max mem: 4959
# Epoch: [3]  [ 40/149]  eta: 0:01:15  lr: 0.000500  loss: 0.2056 (0.2064)  loss_classifier: 0.0614 (0.0602)  loss_box_reg: 0.1339 (0.1307)  loss_objectness: 0.0035 (0.0057)  loss_rpn_box_reg: 0.0067 (0.0098)  time: 0.6538  data: 0.0336  max mem: 4959
# Epoch: [3]  [ 50/149]  eta: 0:01:08  lr: 0.000500  loss: 0.1537 (0.2012)  loss_classifier: 0.0468 (0.0598)  loss_box_reg: 0.0986 (0.1259)  loss_objectness: 0.0048 (0.0057)  loss_rpn_box_reg: 0.0055 (0.0097)  time: 0.6483  data: 0.0322  max mem: 4959
# Epoch: [3]  [ 60/149]  eta: 0:01:00  lr: 0.000500  loss: 0.1778 (0.2006)  loss_classifier: 0.0545 (0.0600)  loss_box_reg: 0.0986 (0.1239)  loss_objectness: 0.0050 (0.0065)  loss_rpn_box_reg: 0.0087 (0.0102)  time: 0.6517  data: 0.0341  max mem: 4959
# Epoch: [3]  [ 70/149]  eta: 0:00:53  lr: 0.000500  loss: 0.1778 (0.1962)  loss_classifier: 0.0545 (0.0581)  loss_box_reg: 0.0902 (0.1203)  loss_objectness: 0.0054 (0.0066)  loss_rpn_box_reg: 0.0087 (0.0112)  time: 0.6543  data: 0.0351  max mem: 4959
# Epoch: [3]  [ 80/149]  eta: 0:00:46  lr: 0.000500  loss: 0.1431 (0.1920)  loss_classifier: 0.0437 (0.0568)  loss_box_reg: 0.0811 (0.1174)  loss_objectness: 0.0050 (0.0066)  loss_rpn_box_reg: 0.0055 (0.0112)  time: 0.6533  data: 0.0342  max mem: 4959
# Epoch: [3]  [ 90/149]  eta: 0:00:39  lr: 0.000500  loss: 0.1431 (0.1862)  loss_classifier: 0.0426 (0.0552)  loss_box_reg: 0.0812 (0.1141)  loss_objectness: 0.0046 (0.0063)  loss_rpn_box_reg: 0.0055 (0.0107)  time: 0.6500  data: 0.0323  max mem: 4959
# Epoch: [3]  [100/149]  eta: 0:00:32  lr: 0.000500  loss: 0.1435 (0.1933)  loss_classifier: 0.0428 (0.0561)  loss_box_reg: 0.0821 (0.1165)  loss_objectness: 0.0035 (0.0076)  loss_rpn_box_reg: 0.0046 (0.0130)  time: 0.6469  data: 0.0316  max mem: 4959
# Epoch: [3]  [110/149]  eta: 0:00:26  lr: 0.000500  loss: 0.2015 (0.1949)  loss_classifier: 0.0538 (0.0564)  loss_box_reg: 0.1195 (0.1171)  loss_objectness: 0.0047 (0.0078)  loss_rpn_box_reg: 0.0096 (0.0136)  time: 0.6477  data: 0.0321  max mem: 4959
# Epoch: [3]  [120/149]  eta: 0:00:19  lr: 0.000500  loss: 0.2015 (0.1981)  loss_classifier: 0.0538 (0.0572)  loss_box_reg: 0.1195 (0.1200)  loss_objectness: 0.0049 (0.0076)  loss_rpn_box_reg: 0.0091 (0.0133)  time: 0.6528  data: 0.0332  max mem: 4959
# Epoch: [3]  [130/149]  eta: 0:00:12  lr: 0.000500  loss: 0.1624 (0.1944)  loss_classifier: 0.0465 (0.0560)  loss_box_reg: 0.1019 (0.1185)  loss_objectness: 0.0028 (0.0072)  loss_rpn_box_reg: 0.0053 (0.0127)  time: 0.6523  data: 0.0322  max mem: 4959
# Epoch: [3]  [140/149]  eta: 0:00:05  lr: 0.000500  loss: 0.1640 (0.1950)  loss_classifier: 0.0455 (0.0560)  loss_box_reg: 0.1028 (0.1183)  loss_objectness: 0.0028 (0.0074)  loss_rpn_box_reg: 0.0054 (0.0132)  time: 0.6498  data: 0.0317  max mem: 4959
# Epoch: [3]  [148/149]  eta: 0:00:00  lr: 0.000500  loss: 0.1395 (0.1929)  loss_classifier: 0.0463 (0.0559)  loss_box_reg: 0.1003 (0.1170)  loss_objectness: 0.0051 (0.0072)  loss_rpn_box_reg: 0.0068 (0.0129)  time: 0.6215  data: 0.0297  max mem: 4959
# Epoch: [3] Total time: 0:01:38 (0.6600 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:18  model_time: 0.2720 (0.2720)  evaluator_time: 0.0070 (0.0070)  time: 0.9199  data: 0.6041  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2574 (0.2581)  evaluator_time: 0.0086 (0.0119)  time: 0.3542  data: 0.0561  max mem: 4959
# Test: Total time: 0:00:07 (0.3561 s / it)
# Averaged stats: model_time: 0.2574 (0.2581)  evaluator_time: 0.0086 (0.0119)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.726
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.133
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.418
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.453
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.521
# Epoch: [4]  [  0/149]  eta: 0:05:26  lr: 0.000500  loss: 0.2575 (0.2575)  loss_classifier: 0.0650 (0.0650)  loss_box_reg: 0.1656 (0.1656)  loss_objectness: 0.0047 (0.0047)  loss_rpn_box_reg: 0.0223 (0.0223)  time: 2.1933  data: 1.4759  max mem: 4959
# Epoch: [4]  [ 10/149]  eta: 0:01:51  lr: 0.000500  loss: 0.1640 (0.1861)  loss_classifier: 0.0548 (0.0567)  loss_box_reg: 0.1149 (0.1142)  loss_objectness: 0.0047 (0.0057)  loss_rpn_box_reg: 0.0057 (0.0095)  time: 0.8048  data: 0.1662  max mem: 4959
# Epoch: [4]  [ 20/149]  eta: 0:01:34  lr: 0.000500  loss: 0.1610 (0.1851)  loss_classifier: 0.0447 (0.0534)  loss_box_reg: 0.0909 (0.1149)  loss_objectness: 0.0040 (0.0051)  loss_rpn_box_reg: 0.0057 (0.0117)  time: 0.6604  data: 0.0345  max mem: 4959
# Epoch: [4]  [ 30/149]  eta: 0:01:24  lr: 0.000500  loss: 0.1518 (0.1867)  loss_classifier: 0.0448 (0.0562)  loss_box_reg: 0.0943 (0.1135)  loss_objectness: 0.0056 (0.0065)  loss_rpn_box_reg: 0.0058 (0.0105)  time: 0.6554  data: 0.0331  max mem: 4959
# Epoch: [4]  [ 40/149]  eta: 0:01:15  lr: 0.000500  loss: 0.1588 (0.1842)  loss_classifier: 0.0481 (0.0549)  loss_box_reg: 0.0980 (0.1128)  loss_objectness: 0.0056 (0.0058)  loss_rpn_box_reg: 0.0059 (0.0108)  time: 0.6523  data: 0.0321  max mem: 4959
# Epoch: [4]  [ 50/149]  eta: 0:01:07  lr: 0.000500  loss: 0.1805 (0.1815)  loss_classifier: 0.0483 (0.0529)  loss_box_reg: 0.1255 (0.1130)  loss_objectness: 0.0019 (0.0055)  loss_rpn_box_reg: 0.0062 (0.0100)  time: 0.6492  data: 0.0333  max mem: 4959
# Epoch: [4]  [ 60/149]  eta: 0:01:00  lr: 0.000500  loss: 0.1823 (0.1905)  loss_classifier: 0.0502 (0.0559)  loss_box_reg: 0.1195 (0.1179)  loss_objectness: 0.0034 (0.0054)  loss_rpn_box_reg: 0.0085 (0.0113)  time: 0.6518  data: 0.0338  max mem: 4959
# Epoch: [4]  [ 70/149]  eta: 0:00:53  lr: 0.000500  loss: 0.2228 (0.1961)  loss_classifier: 0.0698 (0.0577)  loss_box_reg: 0.1295 (0.1217)  loss_objectness: 0.0048 (0.0055)  loss_rpn_box_reg: 0.0088 (0.0112)  time: 0.6519  data: 0.0326  max mem: 4959
# Epoch: [4]  [ 80/149]  eta: 0:00:46  lr: 0.000500  loss: 0.2023 (0.1933)  loss_classifier: 0.0542 (0.0566)  loss_box_reg: 0.1292 (0.1195)  loss_objectness: 0.0042 (0.0057)  loss_rpn_box_reg: 0.0093 (0.0115)  time: 0.6475  data: 0.0311  max mem: 4959
# Epoch: [4]  [ 90/149]  eta: 0:00:39  lr: 0.000500  loss: 0.1671 (0.1939)  loss_classifier: 0.0518 (0.0569)  loss_box_reg: 0.1045 (0.1192)  loss_objectness: 0.0049 (0.0061)  loss_rpn_box_reg: 0.0098 (0.0118)  time: 0.6477  data: 0.0319  max mem: 4959
# Epoch: [4]  [100/149]  eta: 0:00:32  lr: 0.000500  loss: 0.1791 (0.1930)  loss_classifier: 0.0490 (0.0563)  loss_box_reg: 0.1016 (0.1192)  loss_objectness: 0.0050 (0.0062)  loss_rpn_box_reg: 0.0062 (0.0114)  time: 0.6518  data: 0.0343  max mem: 4959
# Epoch: [4]  [110/149]  eta: 0:00:26  lr: 0.000500  loss: 0.1820 (0.1953)  loss_classifier: 0.0468 (0.0570)  loss_box_reg: 0.1033 (0.1197)  loss_objectness: 0.0043 (0.0071)  loss_rpn_box_reg: 0.0057 (0.0116)  time: 0.6560  data: 0.0352  max mem: 4959
# Epoch: [4]  [120/149]  eta: 0:00:19  lr: 0.000500  loss: 0.1694 (0.1922)  loss_classifier: 0.0455 (0.0561)  loss_box_reg: 0.1019 (0.1174)  loss_objectness: 0.0048 (0.0073)  loss_rpn_box_reg: 0.0057 (0.0114)  time: 0.6557  data: 0.0352  max mem: 4959
# Epoch: [4]  [130/149]  eta: 0:00:12  lr: 0.000500  loss: 0.1643 (0.1918)  loss_classifier: 0.0466 (0.0561)  loss_box_reg: 0.0915 (0.1172)  loss_objectness: 0.0060 (0.0072)  loss_rpn_box_reg: 0.0054 (0.0113)  time: 0.6497  data: 0.0338  max mem: 4959
# Epoch: [4]  [140/149]  eta: 0:00:05  lr: 0.000500  loss: 0.1725 (0.1912)  loss_classifier: 0.0493 (0.0561)  loss_box_reg: 0.1095 (0.1168)  loss_objectness: 0.0050 (0.0070)  loss_rpn_box_reg: 0.0077 (0.0113)  time: 0.6481  data: 0.0335  max mem: 4959
# Epoch: [4]  [148/149]  eta: 0:00:00  lr: 0.000500  loss: 0.1464 (0.1906)  loss_classifier: 0.0493 (0.0558)  loss_box_reg: 0.0958 (0.1162)  loss_objectness: 0.0048 (0.0070)  loss_rpn_box_reg: 0.0078 (0.0115)  time: 0.6198  data: 0.0304  max mem: 4959
# Epoch: [4] Total time: 0:01:38 (0.6592 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:22  model_time: 0.2871 (0.2871)  evaluator_time: 0.0096 (0.0096)  time: 1.1220  data: 0.7532  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2575 (0.2588)  evaluator_time: 0.0096 (0.0131)  time: 0.3674  data: 0.0645  max mem: 4959
# Test: Total time: 0:00:07 (0.3692 s / it)
# Averaged stats: model_time: 0.2575 (0.2588)  evaluator_time: 0.0096 (0.0131)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.345
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.727
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.270
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.176
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.413
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.524
# Epoch: [5]  [  0/149]  eta: 0:05:39  lr: 0.000500  loss: 0.2595 (0.2595)  loss_classifier: 0.0713 (0.0713)  loss_box_reg: 0.1611 (0.1611)  loss_objectness: 0.0100 (0.0100)  loss_rpn_box_reg: 0.0171 (0.0171)  time: 2.2797  data: 1.5602  max mem: 4959
# Epoch: [5]  [ 10/149]  eta: 0:01:53  lr: 0.000500  loss: 0.2073 (0.2188)  loss_classifier: 0.0539 (0.0602)  loss_box_reg: 0.1440 (0.1422)  loss_objectness: 0.0046 (0.0061)  loss_rpn_box_reg: 0.0085 (0.0104)  time: 0.8137  data: 0.1791  max mem: 4959
# Epoch: [5]  [ 20/149]  eta: 0:01:34  lr: 0.000500  loss: 0.1782 (0.1921)  loss_classifier: 0.0469 (0.0558)  loss_box_reg: 0.1047 (0.1211)  loss_objectness: 0.0029 (0.0062)  loss_rpn_box_reg: 0.0071 (0.0090)  time: 0.6577  data: 0.0368  max mem: 4959
# Epoch: [5]  [ 30/149]  eta: 0:01:24  lr: 0.000500  loss: 0.1440 (0.1828)  loss_classifier: 0.0460 (0.0535)  loss_box_reg: 0.0948 (0.1162)  loss_objectness: 0.0017 (0.0051)  loss_rpn_box_reg: 0.0049 (0.0079)  time: 0.6484  data: 0.0332  max mem: 4959
# Epoch: [5]  [ 40/149]  eta: 0:01:15  lr: 0.000500  loss: 0.1899 (0.1915)  loss_classifier: 0.0622 (0.0566)  loss_box_reg: 0.1176 (0.1175)  loss_objectness: 0.0043 (0.0066)  loss_rpn_box_reg: 0.0091 (0.0107)  time: 0.6499  data: 0.0341  max mem: 4959
# Epoch: [5]  [ 50/149]  eta: 0:01:07  lr: 0.000500  loss: 0.2207 (0.1996)  loss_classifier: 0.0648 (0.0586)  loss_box_reg: 0.1218 (0.1229)  loss_objectness: 0.0051 (0.0062)  loss_rpn_box_reg: 0.0141 (0.0119)  time: 0.6508  data: 0.0326  max mem: 4959
# Epoch: [5]  [ 60/149]  eta: 0:01:00  lr: 0.000500  loss: 0.2039 (0.2021)  loss_classifier: 0.0566 (0.0597)  loss_box_reg: 0.1387 (0.1252)  loss_objectness: 0.0030 (0.0058)  loss_rpn_box_reg: 0.0089 (0.0114)  time: 0.6475  data: 0.0304  max mem: 4959
# Epoch: [5]  [ 70/149]  eta: 0:00:53  lr: 0.000500  loss: 0.1504 (0.1967)  loss_classifier: 0.0449 (0.0581)  loss_box_reg: 0.1021 (0.1218)  loss_objectness: 0.0030 (0.0056)  loss_rpn_box_reg: 0.0063 (0.0111)  time: 0.6476  data: 0.0306  max mem: 4959
# Epoch: [5]  [ 80/149]  eta: 0:00:46  lr: 0.000500  loss: 0.1429 (0.1931)  loss_classifier: 0.0379 (0.0567)  loss_box_reg: 0.1016 (0.1200)  loss_objectness: 0.0036 (0.0055)  loss_rpn_box_reg: 0.0054 (0.0109)  time: 0.6491  data: 0.0322  max mem: 4959
# Epoch: [5]  [ 90/149]  eta: 0:00:39  lr: 0.000500  loss: 0.1556 (0.1878)  loss_classifier: 0.0432 (0.0552)  loss_box_reg: 0.1007 (0.1165)  loss_objectness: 0.0036 (0.0056)  loss_rpn_box_reg: 0.0058 (0.0106)  time: 0.6492  data: 0.0331  max mem: 4959
# Epoch: [5]  [100/149]  eta: 0:00:32  lr: 0.000500  loss: 0.1493 (0.1891)  loss_classifier: 0.0446 (0.0555)  loss_box_reg: 0.0986 (0.1175)  loss_objectness: 0.0040 (0.0054)  loss_rpn_box_reg: 0.0069 (0.0107)  time: 0.6496  data: 0.0328  max mem: 4959
# Epoch: [5]  [110/149]  eta: 0:00:25  lr: 0.000500  loss: 0.1449 (0.1890)  loss_classifier: 0.0421 (0.0547)  loss_box_reg: 0.0856 (0.1150)  loss_objectness: 0.0040 (0.0056)  loss_rpn_box_reg: 0.0045 (0.0137)  time: 0.6482  data: 0.0320  max mem: 4959
# Epoch: [5]  [120/149]  eta: 0:00:19  lr: 0.000500  loss: 0.1438 (0.1874)  loss_classifier: 0.0421 (0.0543)  loss_box_reg: 0.0856 (0.1142)  loss_objectness: 0.0027 (0.0054)  loss_rpn_box_reg: 0.0045 (0.0134)  time: 0.6462  data: 0.0312  max mem: 4959
# Epoch: [5]  [130/149]  eta: 0:00:12  lr: 0.000500  loss: 0.1461 (0.1851)  loss_classifier: 0.0462 (0.0538)  loss_box_reg: 0.0868 (0.1130)  loss_objectness: 0.0026 (0.0053)  loss_rpn_box_reg: 0.0056 (0.0130)  time: 0.6442  data: 0.0307  max mem: 4959
# Epoch: [5]  [140/149]  eta: 0:00:05  lr: 0.000500  loss: 0.1548 (0.1875)  loss_classifier: 0.0487 (0.0543)  loss_box_reg: 0.0958 (0.1140)  loss_objectness: 0.0026 (0.0058)  loss_rpn_box_reg: 0.0066 (0.0133)  time: 0.6451  data: 0.0314  max mem: 4959
# Epoch: [5]  [148/149]  eta: 0:00:00  lr: 0.000500  loss: 0.1828 (0.1858)  loss_classifier: 0.0495 (0.0538)  loss_box_reg: 0.1087 (0.1135)  loss_objectness: 0.0022 (0.0057)  loss_rpn_box_reg: 0.0050 (0.0128)  time: 0.6172  data: 0.0293  max mem: 4959
# Epoch: [5] Total time: 0:01:37 (0.6567 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:16  model_time: 0.2696 (0.2696)  evaluator_time: 0.0063 (0.0063)  time: 0.8420  data: 0.5060  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2575 (0.2587)  evaluator_time: 0.0083 (0.0115)  time: 0.3514  data: 0.0520  max mem: 4959
# Test: Total time: 0:00:07 (0.3533 s / it)
# Averaged stats: model_time: 0.2575 (0.2587)  evaluator_time: 0.0083 (0.0115)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.360
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.747
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.305
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.456
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.438
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.540
# Epoch: [6]  [  0/149]  eta: 0:05:25  lr: 0.000050  loss: 0.1647 (0.1647)  loss_classifier: 0.0390 (0.0390)  loss_box_reg: 0.1171 (0.1171)  loss_objectness: 0.0053 (0.0053)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 2.1817  data: 1.5387  max mem: 4959
# Epoch: [6]  [ 10/149]  eta: 0:01:50  lr: 0.000050  loss: 0.2387 (0.2433)  loss_classifier: 0.0763 (0.0720)  loss_box_reg: 0.1548 (0.1512)  loss_objectness: 0.0044 (0.0058)  loss_rpn_box_reg: 0.0057 (0.0144)  time: 0.7977  data: 0.1678  max mem: 4959
# Epoch: [6]  [ 20/149]  eta: 0:01:34  lr: 0.000050  loss: 0.2072 (0.2015)  loss_classifier: 0.0542 (0.0577)  loss_box_reg: 0.1219 (0.1265)  loss_objectness: 0.0030 (0.0047)  loss_rpn_box_reg: 0.0056 (0.0127)  time: 0.6589  data: 0.0325  max mem: 4959
# Epoch: [6]  [ 30/149]  eta: 0:01:23  lr: 0.000050  loss: 0.1165 (0.1981)  loss_classifier: 0.0347 (0.0546)  loss_box_reg: 0.0755 (0.1193)  loss_objectness: 0.0031 (0.0067)  loss_rpn_box_reg: 0.0064 (0.0175)  time: 0.6533  data: 0.0335  max mem: 4959
# Epoch: [6]  [ 40/149]  eta: 0:01:15  lr: 0.000050  loss: 0.1887 (0.1921)  loss_classifier: 0.0467 (0.0533)  loss_box_reg: 0.0970 (0.1164)  loss_objectness: 0.0042 (0.0063)  loss_rpn_box_reg: 0.0082 (0.0161)  time: 0.6464  data: 0.0321  max mem: 4959
# Epoch: [6]  [ 50/149]  eta: 0:01:07  lr: 0.000050  loss: 0.1802 (0.1877)  loss_classifier: 0.0471 (0.0520)  loss_box_reg: 0.1075 (0.1164)  loss_objectness: 0.0029 (0.0056)  loss_rpn_box_reg: 0.0043 (0.0137)  time: 0.6511  data: 0.0328  max mem: 4959
# Epoch: [6]  [ 60/149]  eta: 0:01:00  lr: 0.000050  loss: 0.1691 (0.1851)  loss_classifier: 0.0477 (0.0524)  loss_box_reg: 0.1042 (0.1149)  loss_objectness: 0.0031 (0.0053)  loss_rpn_box_reg: 0.0040 (0.0126)  time: 0.6537  data: 0.0337  max mem: 4959
# Epoch: [6]  [ 70/149]  eta: 0:00:53  lr: 0.000050  loss: 0.1607 (0.1857)  loss_classifier: 0.0549 (0.0535)  loss_box_reg: 0.0970 (0.1145)  loss_objectness: 0.0031 (0.0053)  loss_rpn_box_reg: 0.0056 (0.0123)  time: 0.6501  data: 0.0336  max mem: 4959
# Epoch: [6]  [ 80/149]  eta: 0:00:46  lr: 0.000050  loss: 0.1702 (0.1816)  loss_classifier: 0.0420 (0.0523)  loss_box_reg: 0.1009 (0.1128)  loss_objectness: 0.0026 (0.0051)  loss_rpn_box_reg: 0.0054 (0.0115)  time: 0.6537  data: 0.0352  max mem: 4959
# Epoch: [6]  [ 90/149]  eta: 0:00:39  lr: 0.000050  loss: 0.1515 (0.1850)  loss_classifier: 0.0413 (0.0534)  loss_box_reg: 0.1017 (0.1136)  loss_objectness: 0.0046 (0.0060)  loss_rpn_box_reg: 0.0059 (0.0119)  time: 0.6532  data: 0.0345  max mem: 4959
# Epoch: [6]  [100/149]  eta: 0:00:32  lr: 0.000050  loss: 0.1515 (0.1833)  loss_classifier: 0.0413 (0.0531)  loss_box_reg: 0.0938 (0.1127)  loss_objectness: 0.0050 (0.0059)  loss_rpn_box_reg: 0.0060 (0.0116)  time: 0.6526  data: 0.0335  max mem: 4959
# Epoch: [6]  [110/149]  eta: 0:00:25  lr: 0.000050  loss: 0.1505 (0.1799)  loss_classifier: 0.0387 (0.0520)  loss_box_reg: 0.0933 (0.1109)  loss_objectness: 0.0029 (0.0058)  loss_rpn_box_reg: 0.0056 (0.0112)  time: 0.6526  data: 0.0346  max mem: 4959
# Epoch: [6]  [120/149]  eta: 0:00:19  lr: 0.000050  loss: 0.1546 (0.1799)  loss_classifier: 0.0425 (0.0520)  loss_box_reg: 0.1007 (0.1109)  loss_objectness: 0.0025 (0.0058)  loss_rpn_box_reg: 0.0059 (0.0113)  time: 0.6552  data: 0.0354  max mem: 4959
# Epoch: [6]  [130/149]  eta: 0:00:12  lr: 0.000050  loss: 0.1861 (0.1840)  loss_classifier: 0.0535 (0.0531)  loss_box_reg: 0.1162 (0.1141)  loss_objectness: 0.0028 (0.0056)  loss_rpn_box_reg: 0.0086 (0.0111)  time: 0.6573  data: 0.0354  max mem: 4959
# Epoch: [6]  [140/149]  eta: 0:00:05  lr: 0.000050  loss: 0.1738 (0.1843)  loss_classifier: 0.0572 (0.0535)  loss_box_reg: 0.1162 (0.1140)  loss_objectness: 0.0044 (0.0058)  loss_rpn_box_reg: 0.0052 (0.0110)  time: 0.6490  data: 0.0335  max mem: 4959
# Epoch: [6]  [148/149]  eta: 0:00:00  lr: 0.000050  loss: 0.1646 (0.1834)  loss_classifier: 0.0467 (0.0529)  loss_box_reg: 0.1029 (0.1135)  loss_objectness: 0.0046 (0.0058)  loss_rpn_box_reg: 0.0065 (0.0111)  time: 0.6197  data: 0.0308  max mem: 4959
# Epoch: [6] Total time: 0:01:38 (0.6596 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.2734 (0.2734)  evaluator_time: 0.0061 (0.0061)  time: 1.0118  data: 0.6957  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2569 (0.2582)  evaluator_time: 0.0082 (0.0109)  time: 0.3582  data: 0.0604  max mem: 4959
# Test: Total time: 0:00:07 (0.3599 s / it)
# Averaged stats: model_time: 0.2569 (0.2582)  evaluator_time: 0.0082 (0.0109)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.749
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.298
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.444
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.456
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.524
# Epoch: [7]  [  0/149]  eta: 0:04:16  lr: 0.000050  loss: 0.1526 (0.1526)  loss_classifier: 0.0418 (0.0418)  loss_box_reg: 0.1045 (0.1045)  loss_objectness: 0.0035 (0.0035)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 1.7245  data: 0.9704  max mem: 4959
# Epoch: [7]  [ 10/149]  eta: 0:01:48  lr: 0.000050  loss: 0.1573 (0.1589)  loss_classifier: 0.0475 (0.0447)  loss_box_reg: 0.1045 (0.1008)  loss_objectness: 0.0063 (0.0053)  loss_rpn_box_reg: 0.0043 (0.0081)  time: 0.7810  data: 0.1262  max mem: 4959
# Epoch: [7]  [ 20/149]  eta: 0:01:32  lr: 0.000050  loss: 0.1775 (0.1851)  loss_classifier: 0.0511 (0.0550)  loss_box_reg: 0.1072 (0.1150)  loss_objectness: 0.0044 (0.0047)  loss_rpn_box_reg: 0.0065 (0.0104)  time: 0.6651  data: 0.0355  max mem: 4959
# Epoch: [7]  [ 30/149]  eta: 0:01:22  lr: 0.000050  loss: 0.1900 (0.1851)  loss_classifier: 0.0503 (0.0554)  loss_box_reg: 0.1228 (0.1158)  loss_objectness: 0.0025 (0.0044)  loss_rpn_box_reg: 0.0076 (0.0096)  time: 0.6481  data: 0.0313  max mem: 4959
# Epoch: [7]  [ 40/149]  eta: 0:01:14  lr: 0.000050  loss: 0.1279 (0.1741)  loss_classifier: 0.0398 (0.0518)  loss_box_reg: 0.0819 (0.1097)  loss_objectness: 0.0021 (0.0040)  loss_rpn_box_reg: 0.0036 (0.0086)  time: 0.6510  data: 0.0336  max mem: 4959
# Epoch: [7]  [ 50/149]  eta: 0:01:07  lr: 0.000050  loss: 0.1279 (0.1775)  loss_classifier: 0.0387 (0.0521)  loss_box_reg: 0.0813 (0.1129)  loss_objectness: 0.0017 (0.0042)  loss_rpn_box_reg: 0.0031 (0.0083)  time: 0.6505  data: 0.0337  max mem: 4959
# Epoch: [7]  [ 60/149]  eta: 0:00:59  lr: 0.000050  loss: 0.1459 (0.1768)  loss_classifier: 0.0462 (0.0521)  loss_box_reg: 0.1008 (0.1130)  loss_objectness: 0.0012 (0.0039)  loss_rpn_box_reg: 0.0048 (0.0078)  time: 0.6520  data: 0.0331  max mem: 4959
# Epoch: [7]  [ 70/149]  eta: 0:00:52  lr: 0.000050  loss: 0.1662 (0.1783)  loss_classifier: 0.0446 (0.0519)  loss_box_reg: 0.1042 (0.1143)  loss_objectness: 0.0017 (0.0039)  loss_rpn_box_reg: 0.0052 (0.0082)  time: 0.6512  data: 0.0332  max mem: 4959
# Epoch: [7]  [ 80/149]  eta: 0:00:45  lr: 0.000050  loss: 0.1505 (0.1794)  loss_classifier: 0.0448 (0.0523)  loss_box_reg: 0.0961 (0.1145)  loss_objectness: 0.0043 (0.0041)  loss_rpn_box_reg: 0.0071 (0.0085)  time: 0.6450  data: 0.0316  max mem: 4959
# Epoch: [7]  [ 90/149]  eta: 0:00:39  lr: 0.000050  loss: 0.1674 (0.1818)  loss_classifier: 0.0512 (0.0534)  loss_box_reg: 0.1026 (0.1157)  loss_objectness: 0.0048 (0.0042)  loss_rpn_box_reg: 0.0070 (0.0086)  time: 0.6477  data: 0.0322  max mem: 4959
# Epoch: [7]  [100/149]  eta: 0:00:32  lr: 0.000050  loss: 0.1684 (0.1843)  loss_classifier: 0.0574 (0.0540)  loss_box_reg: 0.1096 (0.1174)  loss_objectness: 0.0043 (0.0043)  loss_rpn_box_reg: 0.0067 (0.0088)  time: 0.6510  data: 0.0329  max mem: 4959
# Epoch: [7]  [110/149]  eta: 0:00:25  lr: 0.000050  loss: 0.1640 (0.1835)  loss_classifier: 0.0570 (0.0540)  loss_box_reg: 0.1078 (0.1165)  loss_objectness: 0.0037 (0.0042)  loss_rpn_box_reg: 0.0046 (0.0088)  time: 0.6460  data: 0.0311  max mem: 4959
# Epoch: [7]  [120/149]  eta: 0:00:19  lr: 0.000050  loss: 0.1715 (0.1846)  loss_classifier: 0.0498 (0.0542)  loss_box_reg: 0.1078 (0.1170)  loss_objectness: 0.0031 (0.0044)  loss_rpn_box_reg: 0.0046 (0.0090)  time: 0.6501  data: 0.0331  max mem: 4959
# Epoch: [7]  [130/149]  eta: 0:00:12  lr: 0.000050  loss: 0.1800 (0.1838)  loss_classifier: 0.0466 (0.0542)  loss_box_reg: 0.1075 (0.1161)  loss_objectness: 0.0036 (0.0044)  loss_rpn_box_reg: 0.0066 (0.0092)  time: 0.6514  data: 0.0338  max mem: 4959
# Epoch: [7]  [140/149]  eta: 0:00:05  lr: 0.000050  loss: 0.1506 (0.1810)  loss_classifier: 0.0414 (0.0535)  loss_box_reg: 0.0891 (0.1137)  loss_objectness: 0.0039 (0.0046)  loss_rpn_box_reg: 0.0060 (0.0093)  time: 0.6453  data: 0.0311  max mem: 4959
# Epoch: [7]  [148/149]  eta: 0:00:00  lr: 0.000050  loss: 0.1506 (0.1819)  loss_classifier: 0.0420 (0.0541)  loss_box_reg: 0.1004 (0.1139)  loss_objectness: 0.0042 (0.0046)  loss_rpn_box_reg: 0.0066 (0.0092)  time: 0.6193  data: 0.0296  max mem: 4959
# Epoch: [7] Total time: 0:01:37 (0.6552 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:17  model_time: 0.2971 (0.2971)  evaluator_time: 0.0063 (0.0063)  time: 0.8547  data: 0.4879  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2566 (0.2587)  evaluator_time: 0.0082 (0.0103)  time: 0.3496  data: 0.0508  max mem: 4959
# Test: Total time: 0:00:07 (0.3515 s / it)
# Averaged stats: model_time: 0.2566 (0.2587)  evaluator_time: 0.0082 (0.0103)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.751
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.445
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.456
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.524
# Epoch: [8]  [  0/149]  eta: 0:05:10  lr: 0.000050  loss: 0.1314 (0.1314)  loss_classifier: 0.0413 (0.0413)  loss_box_reg: 0.0749 (0.0749)  loss_objectness: 0.0047 (0.0047)  loss_rpn_box_reg: 0.0105 (0.0105)  time: 2.0858  data: 1.3680  max mem: 4959
# Epoch: [8]  [ 10/149]  eta: 0:01:49  lr: 0.000050  loss: 0.2094 (0.2422)  loss_classifier: 0.0604 (0.0667)  loss_box_reg: 0.1404 (0.1571)  loss_objectness: 0.0048 (0.0052)  loss_rpn_box_reg: 0.0067 (0.0132)  time: 0.7860  data: 0.1531  max mem: 4959
# Epoch: [8]  [ 20/149]  eta: 0:01:33  lr: 0.000050  loss: 0.2006 (0.2194)  loss_classifier: 0.0516 (0.0611)  loss_box_reg: 0.1273 (0.1364)  loss_objectness: 0.0048 (0.0066)  loss_rpn_box_reg: 0.0060 (0.0153)  time: 0.6537  data: 0.0321  max mem: 4959
# Epoch: [8]  [ 30/149]  eta: 0:01:23  lr: 0.000050  loss: 0.1991 (0.2101)  loss_classifier: 0.0516 (0.0600)  loss_box_reg: 0.1155 (0.1304)  loss_objectness: 0.0036 (0.0063)  loss_rpn_box_reg: 0.0060 (0.0135)  time: 0.6518  data: 0.0329  max mem: 4959
# Epoch: [8]  [ 40/149]  eta: 0:01:15  lr: 0.000050  loss: 0.2015 (0.2246)  loss_classifier: 0.0582 (0.0631)  loss_box_reg: 0.1256 (0.1397)  loss_objectness: 0.0042 (0.0063)  loss_rpn_box_reg: 0.0136 (0.0155)  time: 0.6537  data: 0.0332  max mem: 4959
# Epoch: [8]  [ 50/149]  eta: 0:01:07  lr: 0.000050  loss: 0.1669 (0.2117)  loss_classifier: 0.0465 (0.0603)  loss_box_reg: 0.1106 (0.1312)  loss_objectness: 0.0042 (0.0058)  loss_rpn_box_reg: 0.0128 (0.0144)  time: 0.6527  data: 0.0330  max mem: 4959
# Epoch: [8]  [ 60/149]  eta: 0:01:00  lr: 0.000050  loss: 0.1556 (0.2118)  loss_classifier: 0.0460 (0.0588)  loss_box_reg: 0.0965 (0.1278)  loss_objectness: 0.0042 (0.0060)  loss_rpn_box_reg: 0.0085 (0.0192)  time: 0.6488  data: 0.0328  max mem: 4959
# Epoch: [8]  [ 70/149]  eta: 0:00:53  lr: 0.000050  loss: 0.1552 (0.2028)  loss_classifier: 0.0431 (0.0569)  loss_box_reg: 0.0985 (0.1228)  loss_objectness: 0.0032 (0.0056)  loss_rpn_box_reg: 0.0072 (0.0175)  time: 0.6483  data: 0.0328  max mem: 4959
# Epoch: [8]  [ 80/149]  eta: 0:00:46  lr: 0.000050  loss: 0.1552 (0.1969)  loss_classifier: 0.0447 (0.0555)  loss_box_reg: 0.0985 (0.1195)  loss_objectness: 0.0029 (0.0054)  loss_rpn_box_reg: 0.0072 (0.0166)  time: 0.6490  data: 0.0324  max mem: 4959
# Epoch: [8]  [ 90/149]  eta: 0:00:39  lr: 0.000050  loss: 0.1245 (0.1891)  loss_classifier: 0.0387 (0.0534)  loss_box_reg: 0.0773 (0.1151)  loss_objectness: 0.0029 (0.0051)  loss_rpn_box_reg: 0.0071 (0.0155)  time: 0.6505  data: 0.0333  max mem: 4959
# Epoch: [8]  [100/149]  eta: 0:00:32  lr: 0.000050  loss: 0.1385 (0.1885)  loss_classifier: 0.0387 (0.0534)  loss_box_reg: 0.0899 (0.1147)  loss_objectness: 0.0027 (0.0051)  loss_rpn_box_reg: 0.0050 (0.0153)  time: 0.6484  data: 0.0325  max mem: 4959
# Epoch: [8]  [110/149]  eta: 0:00:25  lr: 0.000050  loss: 0.1904 (0.1901)  loss_classifier: 0.0556 (0.0539)  loss_box_reg: 0.1059 (0.1158)  loss_objectness: 0.0045 (0.0054)  loss_rpn_box_reg: 0.0078 (0.0150)  time: 0.6451  data: 0.0309  max mem: 4959
# Epoch: [8]  [120/149]  eta: 0:00:19  lr: 0.000050  loss: 0.1739 (0.1873)  loss_classifier: 0.0521 (0.0533)  loss_box_reg: 0.0939 (0.1144)  loss_objectness: 0.0037 (0.0052)  loss_rpn_box_reg: 0.0058 (0.0143)  time: 0.6463  data: 0.0320  max mem: 4959
# Epoch: [8]  [130/149]  eta: 0:00:12  lr: 0.000050  loss: 0.1388 (0.1850)  loss_classifier: 0.0449 (0.0529)  loss_box_reg: 0.0863 (0.1126)  loss_objectness: 0.0028 (0.0053)  loss_rpn_box_reg: 0.0053 (0.0142)  time: 0.6464  data: 0.0320  max mem: 4959
# Epoch: [8]  [140/149]  eta: 0:00:05  lr: 0.000050  loss: 0.1388 (0.1824)  loss_classifier: 0.0429 (0.0522)  loss_box_reg: 0.0873 (0.1111)  loss_objectness: 0.0021 (0.0054)  loss_rpn_box_reg: 0.0046 (0.0137)  time: 0.6470  data: 0.0329  max mem: 4959
# Epoch: [8]  [148/149]  eta: 0:00:00  lr: 0.000050  loss: 0.1450 (0.1814)  loss_classifier: 0.0429 (0.0523)  loss_box_reg: 0.0924 (0.1105)  loss_objectness: 0.0018 (0.0052)  loss_rpn_box_reg: 0.0043 (0.0133)  time: 0.6208  data: 0.0317  max mem: 4959
# Epoch: [8] Total time: 0:01:37 (0.6558 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:17  model_time: 0.2757 (0.2757)  evaluator_time: 0.0067 (0.0067)  time: 0.8944  data: 0.5598  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2575 (0.2582)  evaluator_time: 0.0082 (0.0108)  time: 0.3525  data: 0.0542  max mem: 4959
# Test: Total time: 0:00:07 (0.3542 s / it)
# Averaged stats: model_time: 0.2575 (0.2582)  evaluator_time: 0.0082 (0.0108)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.743
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.452
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.529
# Epoch: [9]  [  0/149]  eta: 0:05:00  lr: 0.000005  loss: 0.2043 (0.2043)  loss_classifier: 0.0707 (0.0707)  loss_box_reg: 0.0728 (0.0728)  loss_objectness: 0.0084 (0.0084)  loss_rpn_box_reg: 0.0524 (0.0524)  time: 2.0137  data: 1.3319  max mem: 4959
# Epoch: [9]  [ 10/149]  eta: 0:01:48  lr: 0.000005  loss: 0.1453 (0.1445)  loss_classifier: 0.0401 (0.0450)  loss_box_reg: 0.0709 (0.0791)  loss_objectness: 0.0050 (0.0075)  loss_rpn_box_reg: 0.0076 (0.0130)  time: 0.7837  data: 0.1534  max mem: 4959
# Epoch: [9]  [ 20/149]  eta: 0:01:33  lr: 0.000005  loss: 0.1453 (0.1714)  loss_classifier: 0.0377 (0.0470)  loss_box_reg: 0.0795 (0.0919)  loss_objectness: 0.0039 (0.0069)  loss_rpn_box_reg: 0.0053 (0.0256)  time: 0.6586  data: 0.0354  max mem: 4959
# Epoch: [9]  [ 30/149]  eta: 0:01:23  lr: 0.000005  loss: 0.1542 (0.1713)  loss_classifier: 0.0377 (0.0481)  loss_box_reg: 0.0932 (0.0946)  loss_objectness: 0.0032 (0.0071)  loss_rpn_box_reg: 0.0038 (0.0216)  time: 0.6515  data: 0.0334  max mem: 4959
# Epoch: [9]  [ 40/149]  eta: 0:01:14  lr: 0.000005  loss: 0.1542 (0.1819)  loss_classifier: 0.0469 (0.0513)  loss_box_reg: 0.0918 (0.1040)  loss_objectness: 0.0041 (0.0067)  loss_rpn_box_reg: 0.0040 (0.0198)  time: 0.6483  data: 0.0313  max mem: 4959
# Epoch: [9]  [ 50/149]  eta: 0:01:07  lr: 0.000005  loss: 0.1460 (0.1795)  loss_classifier: 0.0392 (0.0498)  loss_box_reg: 0.0890 (0.1024)  loss_objectness: 0.0034 (0.0071)  loss_rpn_box_reg: 0.0055 (0.0201)  time: 0.6494  data: 0.0324  max mem: 4959
# Epoch: [9]  [ 60/149]  eta: 0:00:59  lr: 0.000005  loss: 0.1477 (0.1863)  loss_classifier: 0.0427 (0.0523)  loss_box_reg: 0.0890 (0.1082)  loss_objectness: 0.0031 (0.0070)  loss_rpn_box_reg: 0.0067 (0.0188)  time: 0.6458  data: 0.0326  max mem: 4959
# Epoch: [9]  [ 70/149]  eta: 0:00:52  lr: 0.000005  loss: 0.1240 (0.1739)  loss_classifier: 0.0367 (0.0491)  loss_box_reg: 0.0721 (0.1010)  loss_objectness: 0.0031 (0.0063)  loss_rpn_box_reg: 0.0064 (0.0175)  time: 0.6469  data: 0.0325  max mem: 4959
# Epoch: [9]  [ 80/149]  eta: 0:00:46  lr: 0.000005  loss: 0.1120 (0.1763)  loss_classifier: 0.0323 (0.0499)  loss_box_reg: 0.0697 (0.1034)  loss_objectness: 0.0030 (0.0062)  loss_rpn_box_reg: 0.0064 (0.0168)  time: 0.6492  data: 0.0324  max mem: 4959
# Epoch: [9]  [ 90/149]  eta: 0:00:39  lr: 0.000005  loss: 0.1757 (0.1764)  loss_classifier: 0.0512 (0.0503)  loss_box_reg: 0.1101 (0.1037)  loss_objectness: 0.0051 (0.0063)  loss_rpn_box_reg: 0.0069 (0.0160)  time: 0.6463  data: 0.0313  max mem: 4959
# Epoch: [9]  [100/149]  eta: 0:00:32  lr: 0.000005  loss: 0.1539 (0.1761)  loss_classifier: 0.0478 (0.0505)  loss_box_reg: 0.0931 (0.1044)  loss_objectness: 0.0025 (0.0060)  loss_rpn_box_reg: 0.0066 (0.0151)  time: 0.6469  data: 0.0322  max mem: 4959
# Epoch: [9]  [110/149]  eta: 0:00:25  lr: 0.000005  loss: 0.1468 (0.1757)  loss_classifier: 0.0478 (0.0507)  loss_box_reg: 0.0931 (0.1045)  loss_objectness: 0.0025 (0.0059)  loss_rpn_box_reg: 0.0076 (0.0147)  time: 0.6462  data: 0.0319  max mem: 4959
# Epoch: [9]  [120/149]  eta: 0:00:19  lr: 0.000005  loss: 0.1659 (0.1793)  loss_classifier: 0.0485 (0.0517)  loss_box_reg: 0.1057 (0.1072)  loss_objectness: 0.0041 (0.0059)  loss_rpn_box_reg: 0.0078 (0.0145)  time: 0.6461  data: 0.0308  max mem: 4959
# Epoch: [9]  [130/149]  eta: 0:00:12  lr: 0.000005  loss: 0.1659 (0.1797)  loss_classifier: 0.0483 (0.0519)  loss_box_reg: 0.1057 (0.1078)  loss_objectness: 0.0045 (0.0059)  loss_rpn_box_reg: 0.0084 (0.0141)  time: 0.6496  data: 0.0322  max mem: 4959
# Epoch: [9]  [140/149]  eta: 0:00:05  lr: 0.000005  loss: 0.1643 (0.1812)  loss_classifier: 0.0480 (0.0524)  loss_box_reg: 0.1115 (0.1091)  loss_objectness: 0.0045 (0.0058)  loss_rpn_box_reg: 0.0087 (0.0140)  time: 0.6507  data: 0.0329  max mem: 4959
# Epoch: [9]  [148/149]  eta: 0:00:00  lr: 0.000005  loss: 0.2084 (0.1846)  loss_classifier: 0.0626 (0.0535)  loss_box_reg: 0.1260 (0.1114)  loss_objectness: 0.0034 (0.0059)  loss_rpn_box_reg: 0.0088 (0.0139)  time: 0.6223  data: 0.0302  max mem: 4959
# Epoch: [9] Total time: 0:01:37 (0.6551 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.2733 (0.2733)  evaluator_time: 0.0061 (0.0061)  time: 1.0259  data: 0.6798  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2585 (0.2592)  evaluator_time: 0.0075 (0.0107)  time: 0.3725  data: 0.0720  max mem: 4959
# Test: Total time: 0:00:07 (0.3751 s / it)
# Averaged stats: model_time: 0.2585 (0.2592)  evaluator_time: 0.0075 (0.0107)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.750
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.298
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.450
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.355
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.529
