# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Download TorchVision repo to use some files from
# references/detection
# !pip install pycocotools --quiet
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 531475, done.
# remote: Counting objects: 100% (45085/45085), done.
# remote: Compressing objects: 100% (2107/2107), done.
# remote: Total 531475 (delta 43040), reused 44881 (delta 42905), pack-reused 486390
# Receiving objects: 100% (531475/531475), 1022.60 MiB | 24.81 MiB/s, done.
# Resolving deltas: 100% (496275/496275), done.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
# defining the files directory and testing directory
train_dir = '/kaggle/input/citypersons-testselection/NewTest'
test_dir = '/kaggle/input/citypersons-testselection/NewTest'

# %%
class ImagesDataset(torch.utils.data.Dataset):

    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
        
        # sorting the images for consistency
        # To get images, the extension of the filename is checked to be jpg
       # self.imgs = [image for image in sorted(os.listdir(files_dir))
                       # if image[-4:]=='.jpg']
        
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        
        
        
        # classes: 0 index is reserved for background
        self.classes = ['background','pedestrian']

    def __getitem__(self, idx):

        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # reading the images and converting them to correct size and color    
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        # diving by 255
        img_res /= 255.0
        
        # annotation file
        annot_filename = img_name[:-4] + '.xml'
        annot_file_path = os.path.join(self.files_dir, annot_filename)
        
        boxes = []
        labels = []
        tree = et.parse(annot_file_path)
        root = tree.getroot()
        
        # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        
        # box coordinates for xml files are extracted and corrected for image size given
        for member in root.findall('object'):
            label_text = member.find('name').text.lower()
            if label_text in ['ped', 'pedestrian']:
                labels.append(self.classes.index('pedestrian')) 
            
            # bounding box
            xmin = int(member.find('bndbox').find('xmin').text)
            xmax = int(member.find('bndbox').find('xmax').text)
            
            ymin = int(member.find('bndbox').find('ymin').text)
            ymax = int(member.find('bndbox').find('ymax').text)
            
            
            xmin_corr = (xmin/wt)*self.width
            xmax_corr = (xmax/wt)*self.width
            ymin_corr = (ymin/ht)*self.height
            ymax_corr = (ymax/ht)*self.height
            
            boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
        
        # convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        # getting the areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
        
        labels = torch.as_tensor(labels, dtype=torch.int64)


        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        # image_id
        image_id = idx
        target["image_id"] = image_id
        
  


        if self.transforms:
            
            sample = self.transforms(image = img_res,
                                     bboxes = target['boxes'],
                                     labels = labels)
            
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
            
            
            
        return img_res, target

    def __len__(self):
        return len(self.imgs)

# %%
def get_object_detection_model(num_classes):

    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 

    return model

# %%
# Send train=True fro training transforms and False for val/test transforms
def get_transform(train):
    
    if train:
        return A.Compose([
            A.HorizontalFlip(0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
            A.Rotate(limit=15, p=0.5),
            ToTensorV2(p=1.0)
        ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']))
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
# use our dataset and defined transformations
train_dataset = ImagesDataset(train_dir, 1920, 1080, transforms= get_transform(train=True))
test_dataset = ImagesDataset(test_dir, 1920, 1080, transforms= get_transform(train=False))

# split the dataset in train and test set
torch.manual_seed(1)
indices = torch.randperm(len(train_dataset)).tolist()

# train test split
test_split = 0.2
tsize = int(len(train_dataset)*test_split)
dataset = torch.utils.data.Subset(train_dataset, indices[:-tsize])
dataset_test = torch.utils.data.Subset(test_dataset, indices[-tsize:])

# define training and validation data loaders
data_loader_train= torch.utils.data.DataLoader(
    train_dataset, batch_size=4, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    test_dataset, batch_size=4, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')


num_classes = 2

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:01<00:00, 148MB/s]

# %%
# training for 10 epochs
num_epochs = 20

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, data_loader_train, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [ 0/19]  eta: 0:01:24  lr: 0.000282  loss: 1.1206 (1.1206)  loss_classifier: 0.5981 (0.5981)  loss_box_reg: 0.3469 (0.3469)  loss_objectness: 0.1279 (0.1279)  loss_rpn_box_reg: 0.0478 (0.0478)  time: 4.4310  data: 1.5310  max mem: 4799
# Epoch: [0]  [10/19]  eta: 0:00:08  lr: 0.003058  loss: 1.1206 (1.0578)  loss_classifier: 0.3311 (0.3893)  loss_box_reg: 0.4213 (0.4224)  loss_objectness: 0.0975 (0.1166)  loss_rpn_box_reg: 0.1318 (0.1294)  time: 0.9944  data: 0.1684  max mem: 4957
# Epoch: [0]  [18/19]  eta: 0:00:00  lr: 0.005000  loss: 0.8853 (0.9280)  loss_classifier: 0.2678 (0.3197)  loss_box_reg: 0.3469 (0.3802)  loss_objectness: 0.0884 (0.1006)  loss_rpn_box_reg: 0.1318 (0.1275)  time: 0.8341  data: 0.1085  max mem: 4959
# Epoch: [0] Total time: 0:00:15 (0.8358 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:19  model_time: 0.2750 (0.2750)  evaluator_time: 0.0831 (0.0831)  time: 1.0242  data: 0.5934  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2530 (0.2512)  evaluator_time: 0.0946 (0.1282)  time: 0.4645  data: 0.0555  max mem: 4959
# Test: Total time: 0:00:08 (0.4668 s / it)
# Averaged stats: model_time: 0.2530 (0.2512)  evaluator_time: 0.0946 (0.1282)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.461
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.095
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.147
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.494
# Epoch: [1]  [ 0/19]  eta: 0:00:32  lr: 0.005000  loss: 0.5712 (0.5712)  loss_classifier: 0.1571 (0.1571)  loss_box_reg: 0.3175 (0.3175)  loss_objectness: 0.0519 (0.0519)  loss_rpn_box_reg: 0.0448 (0.0448)  time: 1.7086  data: 1.0204  max mem: 4959
# Epoch: [1]  [10/19]  eta: 0:00:06  lr: 0.005000  loss: 0.6248 (0.6334)  loss_classifier: 0.1571 (0.1715)  loss_box_reg: 0.3368 (0.3375)  loss_objectness: 0.0462 (0.0502)  loss_rpn_box_reg: 0.0570 (0.0743)  time: 0.7485  data: 0.1238  max mem: 4959
# Epoch: [1]  [18/19]  eta: 0:00:00  lr: 0.005000  loss: 0.6064 (0.6211)  loss_classifier: 0.1571 (0.1644)  loss_box_reg: 0.3175 (0.3096)  loss_objectness: 0.0455 (0.0481)  loss_rpn_box_reg: 0.0835 (0.0990)  time: 0.6907  data: 0.0828  max mem: 4959
# Epoch: [1] Total time: 0:00:13 (0.6928 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:16  model_time: 0.2886 (0.2886)  evaluator_time: 0.0839 (0.0839)  time: 0.8806  data: 0.4483  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2526 (0.2515)  evaluator_time: 0.0993 (0.1146)  time: 0.4475  data: 0.0510  max mem: 4959
# Test: Total time: 0:00:08 (0.4494 s / it)
# Averaged stats: model_time: 0.2526 (0.2515)  evaluator_time: 0.0993 (0.1146)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.265
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.579
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.471
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.276
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.237
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.403
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.531
# Epoch: [2]  [ 0/19]  eta: 0:00:30  lr: 0.005000  loss: 0.7308 (0.7308)  loss_classifier: 0.2071 (0.2071)  loss_box_reg: 0.3971 (0.3971)  loss_objectness: 0.0337 (0.0337)  loss_rpn_box_reg: 0.0929 (0.0929)  time: 1.6239  data: 0.9281  max mem: 4959
# Epoch: [2]  [10/19]  eta: 0:00:06  lr: 0.005000  loss: 0.5765 (0.5963)  loss_classifier: 0.1592 (0.1642)  loss_box_reg: 0.3053 (0.3260)  loss_objectness: 0.0296 (0.0297)  loss_rpn_box_reg: 0.0717 (0.0764)  time: 0.7449  data: 0.1199  max mem: 4959
# Epoch: [2]  [18/19]  eta: 0:00:00  lr: 0.005000  loss: 0.5260 (0.5772)  loss_classifier: 0.1476 (0.1548)  loss_box_reg: 0.3021 (0.3099)  loss_objectness: 0.0296 (0.0311)  loss_rpn_box_reg: 0.0865 (0.0814)  time: 0.6902  data: 0.0811  max mem: 4959
# Epoch: [2] Total time: 0:00:13 (0.6925 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:18  model_time: 0.2751 (0.2751)  evaluator_time: 0.0472 (0.0472)  time: 0.9871  data: 0.5940  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2526 (0.2506)  evaluator_time: 0.0472 (0.0717)  time: 0.4096  data: 0.0578  max mem: 4959
# Test: Total time: 0:00:07 (0.4113 s / it)
# Averaged stats: model_time: 0.2526 (0.2506)  evaluator_time: 0.0472 (0.0717)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.613
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.246
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.322
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.380
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.232
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.409
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.538
# Epoch: [3]  [ 0/19]  eta: 0:00:37  lr: 0.000500  loss: 0.5257 (0.5257)  loss_classifier: 0.1427 (0.1427)  loss_box_reg: 0.2899 (0.2899)  loss_objectness: 0.0182 (0.0182)  loss_rpn_box_reg: 0.0750 (0.0750)  time: 1.9608  data: 1.2308  max mem: 4959
# Epoch: [3]  [10/19]  eta: 0:00:06  lr: 0.000500  loss: 0.5070 (0.5281)  loss_classifier: 0.1427 (0.1486)  loss_box_reg: 0.2378 (0.2765)  loss_objectness: 0.0219 (0.0246)  loss_rpn_box_reg: 0.0750 (0.0784)  time: 0.7765  data: 0.1458  max mem: 4959
# Epoch: [3]  [18/19]  eta: 0:00:00  lr: 0.000500  loss: 0.4851 (0.5283)  loss_classifier: 0.1257 (0.1450)  loss_box_reg: 0.2588 (0.2856)  loss_objectness: 0.0191 (0.0251)  loss_rpn_box_reg: 0.0713 (0.0726)  time: 0.7077  data: 0.0957  max mem: 4959
# Epoch: [3] Total time: 0:00:13 (0.7097 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:19  model_time: 0.2808 (0.2808)  evaluator_time: 0.0700 (0.0700)  time: 1.0240  data: 0.5916  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2549 (0.2527)  evaluator_time: 0.0700 (0.0922)  time: 0.4338  data: 0.0581  max mem: 4959
# Test: Total time: 0:00:08 (0.4357 s / it)
# Averaged stats: model_time: 0.2549 (0.2527)  evaluator_time: 0.0700 (0.0922)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.615
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.251
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.326
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.531
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.574
# Epoch: [4]  [ 0/19]  eta: 0:00:26  lr: 0.000500  loss: 0.2075 (0.2075)  loss_classifier: 0.0566 (0.0566)  loss_box_reg: 0.1206 (0.1206)  loss_objectness: 0.0226 (0.0226)  loss_rpn_box_reg: 0.0077 (0.0077)  time: 1.3955  data: 0.7043  max mem: 4959
# Epoch: [4]  [10/19]  eta: 0:00:06  lr: 0.000500  loss: 0.5030 (0.4683)  loss_classifier: 0.1392 (0.1332)  loss_box_reg: 0.2549 (0.2498)  loss_objectness: 0.0247 (0.0233)  loss_rpn_box_reg: 0.0561 (0.0620)  time: 0.7244  data: 0.0977  max mem: 4960
# Epoch: [4]  [18/19]  eta: 0:00:00  lr: 0.000500  loss: 0.5087 (0.5045)  loss_classifier: 0.1404 (0.1367)  loss_box_reg: 0.2709 (0.2749)  loss_objectness: 0.0226 (0.0235)  loss_rpn_box_reg: 0.0561 (0.0695)  time: 0.6787  data: 0.0681  max mem: 4960
# Epoch: [4] Total time: 0:00:12 (0.6808 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:18  model_time: 0.2700 (0.2700)  evaluator_time: 0.0603 (0.0603)  time: 0.9712  data: 0.5598  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2542 (0.2520)  evaluator_time: 0.0603 (0.0862)  time: 0.4244  data: 0.0555  max mem: 4960
# Test: Total time: 0:00:08 (0.4265 s / it)
# Averaged stats: model_time: 0.2542 (0.2520)  evaluator_time: 0.0603 (0.0862)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.333
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.632
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.105
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.362
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.433
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.275
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.462
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.603
# Epoch: [5]  [ 0/19]  eta: 0:00:45  lr: 0.000500  loss: 0.6418 (0.6418)  loss_classifier: 0.1624 (0.1624)  loss_box_reg: 0.3796 (0.3796)  loss_objectness: 0.0337 (0.0337)  loss_rpn_box_reg: 0.0662 (0.0662)  time: 2.4085  data: 1.7021  max mem: 4960
# Epoch: [5]  [10/19]  eta: 0:00:07  lr: 0.000500  loss: 0.5369 (0.5066)  loss_classifier: 0.1368 (0.1377)  loss_box_reg: 0.3100 (0.2861)  loss_objectness: 0.0205 (0.0225)  loss_rpn_box_reg: 0.0550 (0.0603)  time: 0.8078  data: 0.1831  max mem: 4960
# Epoch: [5]  [18/19]  eta: 0:00:00  lr: 0.000500  loss: 0.4788 (0.5147)  loss_classifier: 0.1358 (0.1418)  loss_box_reg: 0.2841 (0.2919)  loss_objectness: 0.0208 (0.0218)  loss_rpn_box_reg: 0.0545 (0.0592)  time: 0.7255  data: 0.1169  max mem: 4960
# Epoch: [5] Total time: 0:00:13 (0.7275 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2756 (0.2756)  evaluator_time: 0.0523 (0.0523)  time: 0.9057  data: 0.4941  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2540 (0.2523)  evaluator_time: 0.0563 (0.0840)  time: 0.4195  data: 0.0525  max mem: 4960
# Test: Total time: 0:00:08 (0.4212 s / it)
# Averaged stats: model_time: 0.2540 (0.2523)  evaluator_time: 0.0563 (0.0840)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.327
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.307
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.354
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.282
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.457
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.588
# Epoch: [6]  [ 0/19]  eta: 0:00:30  lr: 0.000050  loss: 0.1956 (0.1956)  loss_classifier: 0.0546 (0.0546)  loss_box_reg: 0.0649 (0.0649)  loss_objectness: 0.0158 (0.0158)  loss_rpn_box_reg: 0.0602 (0.0602)  time: 1.5911  data: 0.9163  max mem: 4960
# Epoch: [6]  [10/19]  eta: 0:00:06  lr: 0.000050  loss: 0.5769 (0.5156)  loss_classifier: 0.1399 (0.1424)  loss_box_reg: 0.3244 (0.2920)  loss_objectness: 0.0202 (0.0212)  loss_rpn_box_reg: 0.0553 (0.0600)  time: 0.7485  data: 0.1165  max mem: 4960
# Epoch: [6]  [18/19]  eta: 0:00:00  lr: 0.000050  loss: 0.5660 (0.5157)  loss_classifier: 0.1399 (0.1431)  loss_box_reg: 0.3244 (0.2927)  loss_objectness: 0.0190 (0.0207)  loss_rpn_box_reg: 0.0553 (0.0592)  time: 0.6920  data: 0.0785  max mem: 4960
# Epoch: [6] Total time: 0:00:13 (0.6942 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:18  model_time: 0.2790 (0.2790)  evaluator_time: 0.0538 (0.0538)  time: 0.9778  data: 0.5949  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2547 (0.2532)  evaluator_time: 0.0559 (0.0826)  time: 0.4209  data: 0.0568  max mem: 4960
# Test: Total time: 0:00:08 (0.4227 s / it)
# Averaged stats: model_time: 0.2547 (0.2532)  evaluator_time: 0.0559 (0.0826)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.327
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.638
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.308
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.354
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.275
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.457
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.590
# Epoch: [7]  [ 0/19]  eta: 0:00:31  lr: 0.000050  loss: 0.7793 (0.7793)  loss_classifier: 0.2252 (0.2252)  loss_box_reg: 0.3929 (0.3929)  loss_objectness: 0.0299 (0.0299)  loss_rpn_box_reg: 0.1313 (0.1313)  time: 1.6606  data: 0.9566  max mem: 4960
# Epoch: [7]  [10/19]  eta: 0:00:06  lr: 0.000050  loss: 0.5410 (0.5457)  loss_classifier: 0.1524 (0.1501)  loss_box_reg: 0.3216 (0.3059)  loss_objectness: 0.0208 (0.0237)  loss_rpn_box_reg: 0.0585 (0.0660)  time: 0.7448  data: 0.1215  max mem: 4960
# Epoch: [7]  [18/19]  eta: 0:00:00  lr: 0.000050  loss: 0.5125 (0.4924)  loss_classifier: 0.1397 (0.1349)  loss_box_reg: 0.2805 (0.2763)  loss_objectness: 0.0183 (0.0213)  loss_rpn_box_reg: 0.0505 (0.0599)  time: 0.6908  data: 0.0820  max mem: 4960
# Epoch: [7] Total time: 0:00:13 (0.6927 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:18  model_time: 0.2734 (0.2734)  evaluator_time: 0.0532 (0.0532)  time: 0.9800  data: 0.5883  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2546 (0.2529)  evaluator_time: 0.0552 (0.0824)  time: 0.4219  data: 0.0574  max mem: 4960
# Test: Total time: 0:00:08 (0.4238 s / it)
# Averaged stats: model_time: 0.2546 (0.2529)  evaluator_time: 0.0552 (0.0824)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.634
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.312
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.431
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.278
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.461
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [8]  [ 0/19]  eta: 0:00:33  lr: 0.000050  loss: 0.6063 (0.6063)  loss_classifier: 0.1745 (0.1745)  loss_box_reg: 0.3429 (0.3429)  loss_objectness: 0.0179 (0.0179)  loss_rpn_box_reg: 0.0710 (0.0710)  time: 1.7688  data: 1.0872  max mem: 4960
# Epoch: [8]  [10/19]  eta: 0:00:06  lr: 0.000050  loss: 0.5680 (0.5390)  loss_classifier: 0.1633 (0.1485)  loss_box_reg: 0.3222 (0.3044)  loss_objectness: 0.0162 (0.0163)  loss_rpn_box_reg: 0.0715 (0.0698)  time: 0.7579  data: 0.1318  max mem: 4960
# Epoch: [8]  [18/19]  eta: 0:00:00  lr: 0.000050  loss: 0.5625 (0.5046)  loss_classifier: 0.1593 (0.1399)  loss_box_reg: 0.3033 (0.2873)  loss_objectness: 0.0162 (0.0165)  loss_rpn_box_reg: 0.0635 (0.0609)  time: 0.6984  data: 0.0878  max mem: 4960
# Epoch: [8] Total time: 0:00:13 (0.7003 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:18  model_time: 0.2713 (0.2713)  evaluator_time: 0.0535 (0.0535)  time: 0.9566  data: 0.5636  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2546 (0.2522)  evaluator_time: 0.0546 (0.0814)  time: 0.4180  data: 0.0548  max mem: 4960
# Test: Total time: 0:00:07 (0.4198 s / it)
# Averaged stats: model_time: 0.2546 (0.2522)  evaluator_time: 0.0546 (0.0814)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.633
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.310
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.270
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [9]  [ 0/19]  eta: 0:00:32  lr: 0.000005  loss: 0.4811 (0.4811)  loss_classifier: 0.1372 (0.1372)  loss_box_reg: 0.2352 (0.2352)  loss_objectness: 0.0214 (0.0214)  loss_rpn_box_reg: 0.0873 (0.0873)  time: 1.7199  data: 1.0391  max mem: 4960
# Epoch: [9]  [10/19]  eta: 0:00:06  lr: 0.000005  loss: 0.4931 (0.5065)  loss_classifier: 0.1372 (0.1361)  loss_box_reg: 0.2779 (0.2864)  loss_objectness: 0.0239 (0.0232)  loss_rpn_box_reg: 0.0621 (0.0609)  time: 0.7611  data: 0.1299  max mem: 4960
# Epoch: [9]  [18/19]  eta: 0:00:00  lr: 0.000005  loss: 0.5391 (0.5064)  loss_classifier: 0.1462 (0.1402)  loss_box_reg: 0.2894 (0.2853)  loss_objectness: 0.0214 (0.0218)  loss_rpn_box_reg: 0.0581 (0.0590)  time: 0.6998  data: 0.0863  max mem: 4960
# Epoch: [9] Total time: 0:00:13 (0.7018 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:16  model_time: 0.2679 (0.2679)  evaluator_time: 0.0524 (0.0524)  time: 0.8882  data: 0.5230  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2541 (0.2524)  evaluator_time: 0.0587 (0.0862)  time: 0.4215  data: 0.0544  max mem: 4960
# Test: Total time: 0:00:08 (0.4233 s / it)
# Averaged stats: model_time: 0.2541 (0.2524)  evaluator_time: 0.0587 (0.0862)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.634
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.273
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [10]  [ 0/19]  eta: 0:00:30  lr: 0.000005  loss: 0.4539 (0.4539)  loss_classifier: 0.1228 (0.1228)  loss_box_reg: 0.2791 (0.2791)  loss_objectness: 0.0181 (0.0181)  loss_rpn_box_reg: 0.0338 (0.0338)  time: 1.6177  data: 0.9594  max mem: 4960
# Epoch: [10]  [10/19]  eta: 0:00:06  lr: 0.000005  loss: 0.4539 (0.5146)  loss_classifier: 0.1228 (0.1366)  loss_box_reg: 0.2791 (0.2891)  loss_objectness: 0.0181 (0.0204)  loss_rpn_box_reg: 0.0504 (0.0686)  time: 0.7404  data: 0.1182  max mem: 4960
# Epoch: [10]  [18/19]  eta: 0:00:00  lr: 0.000005  loss: 0.4729 (0.5085)  loss_classifier: 0.1328 (0.1413)  loss_box_reg: 0.2791 (0.2833)  loss_objectness: 0.0181 (0.0199)  loss_rpn_box_reg: 0.0532 (0.0639)  time: 0.6881  data: 0.0792  max mem: 4960
# Epoch: [10] Total time: 0:00:13 (0.6901 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2631 (0.2631)  evaluator_time: 0.0559 (0.0559)  time: 0.9256  data: 0.5447  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2556 (0.2534)  evaluator_time: 0.0559 (0.0834)  time: 0.4216  data: 0.0554  max mem: 4960
# Test: Total time: 0:00:08 (0.4235 s / it)
# Averaged stats: model_time: 0.2556 (0.2534)  evaluator_time: 0.0559 (0.0834)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.634
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.273
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [11]  [ 0/19]  eta: 0:00:38  lr: 0.000005  loss: 0.5274 (0.5274)  loss_classifier: 0.1432 (0.1432)  loss_box_reg: 0.3127 (0.3127)  loss_objectness: 0.0131 (0.0131)  loss_rpn_box_reg: 0.0584 (0.0584)  time: 2.0155  data: 1.3490  max mem: 4960
# Epoch: [11]  [10/19]  eta: 0:00:07  lr: 0.000005  loss: 0.6055 (0.5927)  loss_classifier: 0.1784 (0.1605)  loss_box_reg: 0.3181 (0.3353)  loss_objectness: 0.0194 (0.0191)  loss_rpn_box_reg: 0.0656 (0.0779)  time: 0.7850  data: 0.1559  max mem: 4960
# Epoch: [11]  [18/19]  eta: 0:00:00  lr: 0.000005  loss: 0.5056 (0.5108)  loss_classifier: 0.1432 (0.1401)  loss_box_reg: 0.3127 (0.2927)  loss_objectness: 0.0148 (0.0171)  loss_rpn_box_reg: 0.0552 (0.0609)  time: 0.7130  data: 0.1016  max mem: 4960
# Epoch: [11] Total time: 0:00:13 (0.7151 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:18  model_time: 0.2593 (0.2593)  evaluator_time: 0.0517 (0.0517)  time: 0.9549  data: 0.5875  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2545 (0.2526)  evaluator_time: 0.0571 (0.0855)  time: 0.4284  data: 0.0604  max mem: 4960
# Test: Total time: 0:00:08 (0.4309 s / it)
# Averaged stats: model_time: 0.2545 (0.2526)  evaluator_time: 0.0571 (0.0855)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.275
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [12]  [ 0/19]  eta: 0:00:32  lr: 0.000001  loss: 0.7582 (0.7582)  loss_classifier: 0.1951 (0.1951)  loss_box_reg: 0.4197 (0.4197)  loss_objectness: 0.0210 (0.0210)  loss_rpn_box_reg: 0.1224 (0.1224)  time: 1.7003  data: 1.0513  max mem: 4960
# Epoch: [12]  [10/19]  eta: 0:00:06  lr: 0.000001  loss: 0.4918 (0.5298)  loss_classifier: 0.1472 (0.1452)  loss_box_reg: 0.3174 (0.2913)  loss_objectness: 0.0174 (0.0204)  loss_rpn_box_reg: 0.0541 (0.0730)  time: 0.7543  data: 0.1228  max mem: 4960
# Epoch: [12]  [18/19]  eta: 0:00:00  lr: 0.000001  loss: 0.4832 (0.5207)  loss_classifier: 0.1376 (0.1434)  loss_box_reg: 0.2725 (0.2958)  loss_objectness: 0.0187 (0.0208)  loss_rpn_box_reg: 0.0471 (0.0606)  time: 0.6964  data: 0.0828  max mem: 4960
# Epoch: [12] Total time: 0:00:13 (0.6983 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2600 (0.2600)  evaluator_time: 0.0523 (0.0523)  time: 0.9121  data: 0.5360  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2548 (0.2525)  evaluator_time: 0.0576 (0.0838)  time: 0.4205  data: 0.0546  max mem: 4960
# Test: Total time: 0:00:08 (0.4223 s / it)
# Averaged stats: model_time: 0.2548 (0.2525)  evaluator_time: 0.0576 (0.0838)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.275
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [13]  [ 0/19]  eta: 0:00:33  lr: 0.000001  loss: 0.4844 (0.4844)  loss_classifier: 0.1458 (0.1458)  loss_box_reg: 0.2836 (0.2836)  loss_objectness: 0.0156 (0.0156)  loss_rpn_box_reg: 0.0394 (0.0394)  time: 1.7765  data: 1.0899  max mem: 4960
# Epoch: [13]  [10/19]  eta: 0:00:06  lr: 0.000001  loss: 0.4844 (0.4812)  loss_classifier: 0.1458 (0.1392)  loss_box_reg: 0.2777 (0.2755)  loss_objectness: 0.0160 (0.0173)  loss_rpn_box_reg: 0.0539 (0.0491)  time: 0.7513  data: 0.1258  max mem: 4960
# Epoch: [13]  [18/19]  eta: 0:00:00  lr: 0.000001  loss: 0.4844 (0.4964)  loss_classifier: 0.1330 (0.1382)  loss_box_reg: 0.2777 (0.2824)  loss_objectness: 0.0165 (0.0186)  loss_rpn_box_reg: 0.0574 (0.0573)  time: 0.6934  data: 0.0836  max mem: 4960
# Epoch: [13] Total time: 0:00:13 (0.6955 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:16  model_time: 0.2782 (0.2782)  evaluator_time: 0.0557 (0.0557)  time: 0.8779  data: 0.4636  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2553 (0.2537)  evaluator_time: 0.0557 (0.0838)  time: 0.4188  data: 0.0510  max mem: 4960
# Test: Total time: 0:00:07 (0.4207 s / it)
# Averaged stats: model_time: 0.2553 (0.2537)  evaluator_time: 0.0557 (0.0838)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [14]  [ 0/19]  eta: 0:00:38  lr: 0.000001  loss: 0.2693 (0.2693)  loss_classifier: 0.0814 (0.0814)  loss_box_reg: 0.1657 (0.1657)  loss_objectness: 0.0075 (0.0075)  loss_rpn_box_reg: 0.0147 (0.0147)  time: 2.0080  data: 1.3715  max mem: 4960
# Epoch: [14]  [10/19]  eta: 0:00:06  lr: 0.000001  loss: 0.4471 (0.4517)  loss_classifier: 0.1240 (0.1260)  loss_box_reg: 0.2488 (0.2456)  loss_objectness: 0.0168 (0.0202)  loss_rpn_box_reg: 0.0477 (0.0599)  time: 0.7692  data: 0.1507  max mem: 4960
# Epoch: [14]  [18/19]  eta: 0:00:00  lr: 0.000001  loss: 0.4763 (0.5038)  loss_classifier: 0.1287 (0.1405)  loss_box_reg: 0.2623 (0.2822)  loss_objectness: 0.0182 (0.0216)  loss_rpn_box_reg: 0.0526 (0.0594)  time: 0.7041  data: 0.0980  max mem: 4960
# Epoch: [14] Total time: 0:00:13 (0.7062 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:18  model_time: 0.2671 (0.2671)  evaluator_time: 0.0518 (0.0518)  time: 0.9816  data: 0.5769  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2546 (0.2526)  evaluator_time: 0.0554 (0.0829)  time: 0.4259  data: 0.0581  max mem: 4960
# Test: Total time: 0:00:08 (0.4277 s / it)
# Averaged stats: model_time: 0.2546 (0.2526)  evaluator_time: 0.0554 (0.0829)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [15]  [ 0/19]  eta: 0:00:38  lr: 0.000000  loss: 0.6711 (0.6711)  loss_classifier: 0.1740 (0.1740)  loss_box_reg: 0.3972 (0.3972)  loss_objectness: 0.0458 (0.0458)  loss_rpn_box_reg: 0.0541 (0.0541)  time: 2.0494  data: 1.3806  max mem: 4960
# Epoch: [15]  [10/19]  eta: 0:00:06  lr: 0.000000  loss: 0.4547 (0.4967)  loss_classifier: 0.1250 (0.1324)  loss_box_reg: 0.2823 (0.2758)  loss_objectness: 0.0208 (0.0244)  loss_rpn_box_reg: 0.0551 (0.0641)  time: 0.7765  data: 0.1531  max mem: 4960
# Epoch: [15]  [18/19]  eta: 0:00:00  lr: 0.000000  loss: 0.5184 (0.5084)  loss_classifier: 0.1283 (0.1418)  loss_box_reg: 0.2760 (0.2820)  loss_objectness: 0.0204 (0.0239)  loss_rpn_box_reg: 0.0589 (0.0607)  time: 0.7091  data: 0.0998  max mem: 4960
# Epoch: [15] Total time: 0:00:13 (0.7112 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:18  model_time: 0.2595 (0.2595)  evaluator_time: 0.0551 (0.0551)  time: 0.9518  data: 0.5993  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2546 (0.2521)  evaluator_time: 0.0555 (0.0843)  time: 0.4196  data: 0.0555  max mem: 4960
# Test: Total time: 0:00:08 (0.4216 s / it)
# Averaged stats: model_time: 0.2546 (0.2521)  evaluator_time: 0.0555 (0.0843)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [16]  [ 0/19]  eta: 0:00:34  lr: 0.000000  loss: 0.2123 (0.2123)  loss_classifier: 0.0747 (0.0747)  loss_box_reg: 0.0979 (0.0979)  loss_objectness: 0.0056 (0.0056)  loss_rpn_box_reg: 0.0341 (0.0341)  time: 1.8046  data: 1.1339  max mem: 4960
# Epoch: [16]  [10/19]  eta: 0:00:06  lr: 0.000000  loss: 0.4649 (0.4569)  loss_classifier: 0.1232 (0.1291)  loss_box_reg: 0.2531 (0.2520)  loss_objectness: 0.0153 (0.0183)  loss_rpn_box_reg: 0.0406 (0.0575)  time: 0.7667  data: 0.1402  max mem: 4960
# Epoch: [16]  [18/19]  eta: 0:00:00  lr: 0.000000  loss: 0.4649 (0.4937)  loss_classifier: 0.1232 (0.1376)  loss_box_reg: 0.2531 (0.2774)  loss_objectness: 0.0170 (0.0206)  loss_rpn_box_reg: 0.0559 (0.0581)  time: 0.7037  data: 0.0921  max mem: 4960
# Epoch: [16] Total time: 0:00:13 (0.7058 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:19  model_time: 0.2605 (0.2605)  evaluator_time: 0.0538 (0.0538)  time: 1.0011  data: 0.6237  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2539 (0.2521)  evaluator_time: 0.0552 (0.0834)  time: 0.4234  data: 0.0588  max mem: 4960
# Test: Total time: 0:00:08 (0.4253 s / it)
# Averaged stats: model_time: 0.2539 (0.2521)  evaluator_time: 0.0552 (0.0834)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [17]  [ 0/19]  eta: 0:00:38  lr: 0.000000  loss: 0.2366 (0.2366)  loss_classifier: 0.0623 (0.0623)  loss_box_reg: 0.0998 (0.0998)  loss_objectness: 0.0165 (0.0165)  loss_rpn_box_reg: 0.0580 (0.0580)  time: 2.0073  data: 1.3240  max mem: 4960
# Epoch: [17]  [10/19]  eta: 0:00:06  lr: 0.000000  loss: 0.3985 (0.4813)  loss_classifier: 0.1057 (0.1334)  loss_box_reg: 0.2136 (0.2589)  loss_objectness: 0.0196 (0.0231)  loss_rpn_box_reg: 0.0600 (0.0661)  time: 0.7745  data: 0.1477  max mem: 4960
# Epoch: [17]  [18/19]  eta: 0:00:00  lr: 0.000000  loss: 0.4788 (0.5004)  loss_classifier: 0.1385 (0.1380)  loss_box_reg: 0.2677 (0.2786)  loss_objectness: 0.0175 (0.0217)  loss_rpn_box_reg: 0.0600 (0.0620)  time: 0.7084  data: 0.0968  max mem: 4960
# Epoch: [17] Total time: 0:00:13 (0.7104 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2588 (0.2588)  evaluator_time: 0.0584 (0.0584)  time: 0.9171  data: 0.5281  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2548 (0.2525)  evaluator_time: 0.0584 (0.0851)  time: 0.4225  data: 0.0545  max mem: 4960
# Test: Total time: 0:00:08 (0.4244 s / it)
# Averaged stats: model_time: 0.2548 (0.2525)  evaluator_time: 0.0584 (0.0851)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [18]  [ 0/19]  eta: 0:00:28  lr: 0.000000  loss: 0.1712 (0.1712)  loss_classifier: 0.0548 (0.0548)  loss_box_reg: 0.0949 (0.0949)  loss_objectness: 0.0135 (0.0135)  loss_rpn_box_reg: 0.0080 (0.0080)  time: 1.5182  data: 0.8193  max mem: 4960
# Epoch: [18]  [10/19]  eta: 0:00:06  lr: 0.000000  loss: 0.6065 (0.5698)  loss_classifier: 0.1637 (0.1540)  loss_box_reg: 0.3408 (0.3156)  loss_objectness: 0.0193 (0.0221)  loss_rpn_box_reg: 0.0807 (0.0780)  time: 0.7379  data: 0.1066  max mem: 4960
# Epoch: [18]  [18/19]  eta: 0:00:00  lr: 0.000000  loss: 0.5457 (0.5047)  loss_classifier: 0.1341 (0.1407)  loss_box_reg: 0.3035 (0.2850)  loss_objectness: 0.0164 (0.0187)  loss_rpn_box_reg: 0.0518 (0.0602)  time: 0.6856  data: 0.0726  max mem: 4960
# Epoch: [18] Total time: 0:00:13 (0.6877 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2788 (0.2788)  evaluator_time: 0.0580 (0.0580)  time: 0.9332  data: 0.5222  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2545 (0.2531)  evaluator_time: 0.0580 (0.0834)  time: 0.4203  data: 0.0535  max mem: 4960
# Test: Total time: 0:00:08 (0.4222 s / it)
# Averaged stats: model_time: 0.2545 (0.2531)  evaluator_time: 0.0580 (0.0834)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
# Epoch: [19]  [ 0/19]  eta: 0:00:37  lr: 0.000000  loss: 0.6128 (0.6128)  loss_classifier: 0.1396 (0.1396)  loss_box_reg: 0.3633 (0.3633)  loss_objectness: 0.0613 (0.0613)  loss_rpn_box_reg: 0.0487 (0.0487)  time: 1.9651  data: 1.2951  max mem: 4960
# Epoch: [19]  [10/19]  eta: 0:00:07  lr: 0.000000  loss: 0.6046 (0.5797)  loss_classifier: 0.1615 (0.1624)  loss_box_reg: 0.3602 (0.3260)  loss_objectness: 0.0219 (0.0243)  loss_rpn_box_reg: 0.0625 (0.0671)  time: 0.7779  data: 0.1506  max mem: 4960
# Epoch: [19]  [18/19]  eta: 0:00:00  lr: 0.000000  loss: 0.5426 (0.5223)  loss_classifier: 0.1396 (0.1436)  loss_box_reg: 0.3081 (0.2954)  loss_objectness: 0.0219 (0.0224)  loss_rpn_box_reg: 0.0503 (0.0609)  time: 0.7092  data: 0.0983  max mem: 4960
# Epoch: [19] Total time: 0:00:13 (0.7112 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2590 (0.2590)  evaluator_time: 0.0514 (0.0514)  time: 0.9295  data: 0.5653  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2540 (0.2518)  evaluator_time: 0.0550 (0.0818)  time: 0.4165  data: 0.0544  max mem: 4960
# Test: Total time: 0:00:07 (0.4183 s / it)
# Averaged stats: model_time: 0.2540 (0.2518)  evaluator_time: 0.0550 (0.0818)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.591
