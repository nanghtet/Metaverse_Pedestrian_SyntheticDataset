# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Download TorchVision repo to use some files from
# references/detection
# !pip install pycocotools --quiet
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 531472, done.
# remote: Counting objects: 100% (45082/45082), done.
# remote: Compressing objects: 100% (2106/2106), done.
# remote: Total 531472 (delta 43038), reused 44878 (delta 42903), pack-reused 486390
# Receiving objects: 100% (531472/531472), 1022.60 MiB | 24.79 MiB/s, done.
# Resolving deltas: 100% (496273/496273), done.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
from torch.utils.data import Subset
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
# defining the files directory and testing directory
train_dir = '/kaggle/input/pedestriansyntheticdataset/train/train'
test_dir = '/kaggle/input/kitti-train-test-selection/Train_Test_Selection/Test'

# %%
#for xml-annotatation dataset
class ImagesDataset(torch.utils.data.Dataset):

    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
            
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        
        
        # classes: 0 index is reserved for background
        self.classes = ['background','Pedestrian']

    def __getitem__(self, idx):

        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # reading the images and converting them to correct size and color    
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        # diving by 255
        img_res /= 255.0
        
        # annotation file
        annot_filename = img_name[:-4] + '.xml'
        annot_file_path = os.path.join(self.files_dir, annot_filename)
        
        boxes = []
        labels = []
        tree = et.parse(annot_file_path)
        root = tree.getroot()
        
        # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        
        # box coordinates for xml files are extracted and corrected for image size given
        for member in root.findall('object'):
            label_text = member.find('name').text.lower()
            if label_text in ['ped', 'pedestrian','person']:
                labels.append(self.classes.index('Pedestrian')) 
            
            # bounding box
            xmin = int(member.find('bndbox').find('xmin').text)
            xmax = int(member.find('bndbox').find('xmax').text)
            
            ymin = int(member.find('bndbox').find('ymin').text)
            ymax = int(member.find('bndbox').find('ymax').text)
            
            
            xmin_corr = (xmin/wt)*self.width
            xmax_corr = (xmax/wt)*self.width
            ymin_corr = (ymin/ht)*self.height
            ymax_corr = (ymax/ht)*self.height
            
            boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
          
        
        # convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        
        # getting the areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
        
        labels = torch.as_tensor(labels, dtype=torch.int64)


        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        # image_id
        image_id = idx
        target["image_id"] = image_id
        
  


        if self.transforms:
            
            sample = self.transforms(image = img_res,
                                     bboxes = target['boxes'],
                                     labels = labels)
            
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
            
            
            
        return img_res, target

    def __len__(self):
        return len(self.imgs)

# %%
#for txt-annotatation dataset
class KittiDataset(torch.utils.data.Dataset):
    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        self.classes = ['background', 'Pedestrian']

    def __getitem__(self, idx):
        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # Reading the images and converting them to correct size and color
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        img_res /= 255.0

        # Annotation file
        annot_filename = img_name[:-4] + '.txt'
        annot_file_path = os.path.join(self.files_dir, annot_filename)

        boxes = []
        labels = []

           # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        # Read annotation data from text file
        with open(annot_file_path, 'r') as file:
            for line in file:
                parts = line.strip().split(' ')
                label_text = parts[0].lower()

                if label_text in ['pedestrian', 'person']:
                    labels.append(self.classes.index('Pedestrian'))

                    # Bounding box coordinates
                    xmin = float(parts[4])
                    ymin = float(parts[5])
                    xmax = float(parts[6])
                    ymax = float(parts[7])

                    # Normalize coordinates
                    xmin_corr = (xmin/wt)*self.width
                    xmax_corr = (xmax/wt)*self.width
                    ymin_corr = (ymin/ht)*self.height
                    ymax_corr = (ymax/ht)*self.height

                    boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])

        # Convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        #print("boxes shape: ", boxes.size(), "at index",idx, img_name)
       
      
           

        # Calculate areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # Suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)

        labels = torch.as_tensor(labels, dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd

        # image_id
        #image_id = torch.tensor([idx])
        image_id = idx
        target["image_id"] = image_id

        if self.transforms:
            sample = self.transforms(image=img_res, bboxes=target['boxes'], labels=labels)
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
        return img_res, target
    
    

    def __len__(self):
        return len(self.imgs)

# %%
# check train dataset
train_dataset = ImagesDataset(train_dir, 1920, 1080)
print('length of dataset = ', len(train_dataset), '\n')

# getting the image and target for a test index.  Feel free to change the index.
img, target = train_dataset[7]
print(img.shape, '\n',target)
# Out:
# length of dataset =  293
#
# (1080, 1920, 3)
#  {'boxes': tensor([[ 236.,  505.,  334.,  750.],
#         [ 359.,  685.,  430.,  755.],
#         [1639.,  127., 1753.,  227.],
#         [1836.,  199., 1908.,  346.]]), 'labels': tensor([1, 1, 1, 1]), 'area': tensor([24010.,  4970., 11400., 10584.]), 'iscrowd': tensor([0, 0, 0, 0]), 'image_id': 7}

# %%
# # check test dataset
test_dataset = KittiDataset(test_dir, 1920, 1080)
print('length of dataset = ', len(test_dataset), '\n')

# getting the image and target for a test index.  Feel free to change the index.
img, target = test_dataset[7]
print(img.shape, '\n',target)
# Out:
# length of dataset =  80
#
# (1080, 1920, 3)
#  {'boxes': tensor([[1128.2241,  475.8912, 1165.2483,  649.4400]]), 'labels': tensor([1]), 'area': tensor([6425.5000]), 'iscrowd': tensor([0]), 'image_id': 7}

# %%
def get_object_detection_model(num_classes):

    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 

    return model

# %%
# Send train=True fro training transforms and False for val/test transforms
def get_transform(train):
    
    if train:
        return A.Compose([
            A.HorizontalFlip(0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
            A.Rotate(limit=15, p=0.5),
            ToTensorV2(p=1.0)
        ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']))
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
# use our dataset and defined transformations
train_dataset = ImagesDataset(train_dir, 1920, 1080, transforms= get_transform(train=True))
test_dataset = KittiDataset(test_dir, 1920, 1080, transforms= get_transform(train=False))

# define training and validation data loaders
data_loader_train = torch.utils.data.DataLoader(
    train_dataset, batch_size=4, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    test_dataset, batch_size=4, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')


num_classes = 2

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:02<00:00, 76.9MB/s]

# %%
# training for 10 epochs
num_epochs = 10
for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, data_loader_train, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [ 0/74]  eta: 0:05:22  lr: 0.000073  loss: 1.3514 (1.3514)  loss_classifier: 1.1547 (1.1547)  loss_box_reg: 0.1739 (0.1739)  loss_objectness: 0.0111 (0.0111)  loss_rpn_box_reg: 0.0117 (0.0117)  time: 4.3638  data: 1.5328  max mem: 4799
# Epoch: [0]  [10/74]  eta: 0:01:03  lr: 0.000758  loss: 0.9542 (0.8884)  loss_classifier: 0.5754 (0.6397)  loss_box_reg: 0.2139 (0.2220)  loss_objectness: 0.0141 (0.0162)  loss_rpn_box_reg: 0.0093 (0.0106)  time: 0.9858  data: 0.1675  max mem: 4958
# Epoch: [0]  [20/74]  eta: 0:00:44  lr: 0.001442  loss: 0.6036 (0.7470)  loss_classifier: 0.2868 (0.4676)  loss_box_reg: 0.2378 (0.2506)  loss_objectness: 0.0145 (0.0169)  loss_rpn_box_reg: 0.0101 (0.0119)  time: 0.6473  data: 0.0300  max mem: 4959
# Epoch: [0]  [30/74]  eta: 0:00:33  lr: 0.002126  loss: 0.4931 (0.6428)  loss_classifier: 0.1715 (0.3605)  loss_box_reg: 0.2601 (0.2541)  loss_objectness: 0.0161 (0.0166)  loss_rpn_box_reg: 0.0075 (0.0116)  time: 0.6464  data: 0.0303  max mem: 4959
# Epoch: [0]  [40/74]  eta: 0:00:25  lr: 0.002810  loss: 0.3761 (0.5717)  loss_classifier: 0.0986 (0.2917)  loss_box_reg: 0.2437 (0.2534)  loss_objectness: 0.0101 (0.0157)  loss_rpn_box_reg: 0.0059 (0.0109)  time: 0.6448  data: 0.0312  max mem: 4959
# Epoch: [0]  [50/74]  eta: 0:00:17  lr: 0.003495  loss: 0.3334 (0.5205)  loss_classifier: 0.0752 (0.2491)  loss_box_reg: 0.2335 (0.2473)  loss_objectness: 0.0062 (0.0141)  loss_rpn_box_reg: 0.0057 (0.0101)  time: 0.6444  data: 0.0300  max mem: 4959
# Epoch: [0]  [60/74]  eta: 0:00:09  lr: 0.004179  loss: 0.2531 (0.4745)  loss_classifier: 0.0590 (0.2178)  loss_box_reg: 0.1804 (0.2354)  loss_objectness: 0.0020 (0.0122)  loss_rpn_box_reg: 0.0045 (0.0091)  time: 0.6448  data: 0.0297  max mem: 4959
# Epoch: [0]  [70/74]  eta: 0:00:02  lr: 0.004863  loss: 0.2377 (0.4550)  loss_classifier: 0.0587 (0.1963)  loss_box_reg: 0.1699 (0.2300)  loss_objectness: 0.0020 (0.0193)  loss_rpn_box_reg: 0.0050 (0.0094)  time: 0.6410  data: 0.0296  max mem: 4959
# Epoch: [0]  [73/74]  eta: 0:00:00  lr: 0.005000  loss: 0.2297 (0.4450)  loss_classifier: 0.0579 (0.1904)  loss_box_reg: 0.1584 (0.2263)  loss_objectness: 0.0020 (0.0190)  loss_rpn_box_reg: 0.0053 (0.0093)  time: 0.6227  data: 0.0290  max mem: 4959
# Epoch: [0] Total time: 0:00:51 (0.6903 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:16  model_time: 0.2998 (0.2998)  evaluator_time: 0.0126 (0.0126)  time: 0.8434  data: 0.4943  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2553 (0.2578)  evaluator_time: 0.0141 (0.0186)  time: 0.3567  data: 0.0524  max mem: 4959
# Test: Total time: 0:00:07 (0.3585 s / it)
# Averaged stats: model_time: 0.2553 (0.2578)  evaluator_time: 0.0141 (0.0186)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.528
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.054
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.359
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.450
# Epoch: [1]  [ 0/74]  eta: 0:02:43  lr: 0.005000  loss: 0.2228 (0.2228)  loss_classifier: 0.0512 (0.0512)  loss_box_reg: 0.1632 (0.1632)  loss_objectness: 0.0029 (0.0029)  loss_rpn_box_reg: 0.0055 (0.0055)  time: 2.2103  data: 1.5119  max mem: 4959
# Epoch: [1]  [10/74]  eta: 0:00:51  lr: 0.005000  loss: 0.2153 (0.2271)  loss_classifier: 0.0512 (0.0574)  loss_box_reg: 0.1489 (0.1588)  loss_objectness: 0.0041 (0.0047)  loss_rpn_box_reg: 0.0060 (0.0063)  time: 0.8021  data: 0.1682  max mem: 4959
# Epoch: [1]  [20/74]  eta: 0:00:39  lr: 0.005000  loss: 0.1940 (0.2026)  loss_classifier: 0.0504 (0.0501)  loss_box_reg: 0.1326 (0.1437)  loss_objectness: 0.0025 (0.0036)  loss_rpn_box_reg: 0.0052 (0.0052)  time: 0.6516  data: 0.0319  max mem: 4959
# Epoch: [1]  [30/74]  eta: 0:00:30  lr: 0.005000  loss: 0.1609 (0.1962)  loss_classifier: 0.0419 (0.0497)  loss_box_reg: 0.1041 (0.1379)  loss_objectness: 0.0020 (0.0036)  loss_rpn_box_reg: 0.0044 (0.0051)  time: 0.6471  data: 0.0324  max mem: 4959
# Epoch: [1]  [40/74]  eta: 0:00:23  lr: 0.005000  loss: 0.1747 (0.1979)  loss_classifier: 0.0473 (0.0504)  loss_box_reg: 0.1221 (0.1390)  loss_objectness: 0.0016 (0.0031)  loss_rpn_box_reg: 0.0044 (0.0054)  time: 0.6474  data: 0.0332  max mem: 4959
# Epoch: [1]  [50/74]  eta: 0:00:16  lr: 0.005000  loss: 0.1957 (0.1950)  loss_classifier: 0.0483 (0.0499)  loss_box_reg: 0.1396 (0.1370)  loss_objectness: 0.0011 (0.0029)  loss_rpn_box_reg: 0.0040 (0.0053)  time: 0.6429  data: 0.0314  max mem: 4959
# Epoch: [1]  [60/74]  eta: 0:00:09  lr: 0.005000  loss: 0.1885 (0.1957)  loss_classifier: 0.0447 (0.0493)  loss_box_reg: 0.1214 (0.1385)  loss_objectness: 0.0018 (0.0029)  loss_rpn_box_reg: 0.0036 (0.0051)  time: 0.6442  data: 0.0312  max mem: 4959
# Epoch: [1]  [70/74]  eta: 0:00:02  lr: 0.005000  loss: 0.1786 (0.1961)  loss_classifier: 0.0445 (0.0493)  loss_box_reg: 0.1368 (0.1389)  loss_objectness: 0.0014 (0.0029)  loss_rpn_box_reg: 0.0034 (0.0050)  time: 0.6422  data: 0.0311  max mem: 4959
# Epoch: [1]  [73/74]  eta: 0:00:00  lr: 0.005000  loss: 0.1786 (0.1944)  loss_classifier: 0.0446 (0.0489)  loss_box_reg: 0.1368 (0.1375)  loss_objectness: 0.0013 (0.0029)  loss_rpn_box_reg: 0.0036 (0.0050)  time: 0.6176  data: 0.0302  max mem: 4959
# Epoch: [1] Total time: 0:00:48 (0.6616 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.3034 (0.3034)  evaluator_time: 0.0125 (0.0125)  time: 1.0288  data: 0.6790  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2564 (0.2592)  evaluator_time: 0.0124 (0.0167)  time: 0.3670  data: 0.0616  max mem: 4959
# Test: Total time: 0:00:07 (0.3689 s / it)
# Averaged stats: model_time: 0.2564 (0.2592)  evaluator_time: 0.0124 (0.0167)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.246
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.582
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.157
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.086
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.372
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.466
# Epoch: [2]  [ 0/74]  eta: 0:02:37  lr: 0.005000  loss: 0.2551 (0.2551)  loss_classifier: 0.0587 (0.0587)  loss_box_reg: 0.1880 (0.1880)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0075 (0.0075)  time: 2.1261  data: 1.4818  max mem: 4959
# Epoch: [2]  [10/74]  eta: 0:00:50  lr: 0.005000  loss: 0.1391 (0.1458)  loss_classifier: 0.0408 (0.0412)  loss_box_reg: 0.0957 (0.0977)  loss_objectness: 0.0021 (0.0029)  loss_rpn_box_reg: 0.0033 (0.0040)  time: 0.7893  data: 0.1647  max mem: 4959
# Epoch: [2]  [20/74]  eta: 0:00:38  lr: 0.005000  loss: 0.1522 (0.1760)  loss_classifier: 0.0408 (0.0450)  loss_box_reg: 0.1040 (0.1237)  loss_objectness: 0.0021 (0.0030)  loss_rpn_box_reg: 0.0033 (0.0044)  time: 0.6515  data: 0.0330  max mem: 4959
# Epoch: [2]  [30/74]  eta: 0:00:30  lr: 0.005000  loss: 0.1804 (0.1793)  loss_classifier: 0.0466 (0.0460)  loss_box_reg: 0.1221 (0.1248)  loss_objectness: 0.0017 (0.0037)  loss_rpn_box_reg: 0.0041 (0.0048)  time: 0.6525  data: 0.0341  max mem: 4959
# Epoch: [2]  [40/74]  eta: 0:00:23  lr: 0.005000  loss: 0.1752 (0.1810)  loss_classifier: 0.0463 (0.0466)  loss_box_reg: 0.1221 (0.1264)  loss_objectness: 0.0015 (0.0033)  loss_rpn_box_reg: 0.0037 (0.0047)  time: 0.6527  data: 0.0333  max mem: 4959
# Epoch: [2]  [50/74]  eta: 0:00:16  lr: 0.005000  loss: 0.2230 (0.1892)  loss_classifier: 0.0538 (0.0484)  loss_box_reg: 0.1496 (0.1326)  loss_objectness: 0.0017 (0.0031)  loss_rpn_box_reg: 0.0044 (0.0050)  time: 0.6471  data: 0.0314  max mem: 4959
# Epoch: [2]  [60/74]  eta: 0:00:09  lr: 0.005000  loss: 0.1813 (0.1807)  loss_classifier: 0.0392 (0.0459)  loss_box_reg: 0.1356 (0.1273)  loss_objectness: 0.0011 (0.0027)  loss_rpn_box_reg: 0.0047 (0.0047)  time: 0.6435  data: 0.0303  max mem: 4959
# Epoch: [2]  [70/74]  eta: 0:00:02  lr: 0.005000  loss: 0.1813 (0.1822)  loss_classifier: 0.0392 (0.0462)  loss_box_reg: 0.1293 (0.1287)  loss_objectness: 0.0011 (0.0027)  loss_rpn_box_reg: 0.0040 (0.0047)  time: 0.6398  data: 0.0297  max mem: 4959
# Epoch: [2]  [73/74]  eta: 0:00:00  lr: 0.005000  loss: 0.1813 (0.1807)  loss_classifier: 0.0392 (0.0458)  loss_box_reg: 0.1293 (0.1276)  loss_objectness: 0.0011 (0.0026)  loss_rpn_box_reg: 0.0040 (0.0046)  time: 0.6156  data: 0.0282  max mem: 4959
# Epoch: [2] Total time: 0:00:48 (0.6617 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2890 (0.2890)  evaluator_time: 0.0057 (0.0057)  time: 0.9990  data: 0.6326  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2566 (0.2588)  evaluator_time: 0.0087 (0.0121)  time: 0.3599  data: 0.0583  max mem: 4959
# Test: Total time: 0:00:07 (0.3616 s / it)
# Averaged stats: model_time: 0.2566 (0.2588)  evaluator_time: 0.0087 (0.0121)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.550
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.136
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.077
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.427
# Epoch: [3]  [ 0/74]  eta: 0:02:34  lr: 0.000500  loss: 0.1375 (0.1375)  loss_classifier: 0.0369 (0.0369)  loss_box_reg: 0.0979 (0.0979)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 2.0913  data: 1.4174  max mem: 4959
# Epoch: [3]  [10/74]  eta: 0:00:50  lr: 0.000500  loss: 0.1393 (0.1511)  loss_classifier: 0.0369 (0.0382)  loss_box_reg: 0.1028 (0.1076)  loss_objectness: 0.0017 (0.0019)  loss_rpn_box_reg: 0.0027 (0.0034)  time: 0.7880  data: 0.1589  max mem: 4959
# Epoch: [3]  [20/74]  eta: 0:00:38  lr: 0.000500  loss: 0.1546 (0.1639)  loss_classifier: 0.0406 (0.0430)  loss_box_reg: 0.1082 (0.1149)  loss_objectness: 0.0016 (0.0017)  loss_rpn_box_reg: 0.0032 (0.0042)  time: 0.6531  data: 0.0321  max mem: 4959
# Epoch: [3]  [30/74]  eta: 0:00:30  lr: 0.000500  loss: 0.1762 (0.1719)  loss_classifier: 0.0419 (0.0448)  loss_box_reg: 0.1238 (0.1210)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0039 (0.0046)  time: 0.6494  data: 0.0309  max mem: 4959
# Epoch: [3]  [40/74]  eta: 0:00:23  lr: 0.000500  loss: 0.1650 (0.1676)  loss_classifier: 0.0407 (0.0434)  loss_box_reg: 0.1206 (0.1184)  loss_objectness: 0.0006 (0.0014)  loss_rpn_box_reg: 0.0034 (0.0045)  time: 0.6486  data: 0.0313  max mem: 4959
# Epoch: [3]  [50/74]  eta: 0:00:16  lr: 0.000500  loss: 0.1283 (0.1630)  loss_classifier: 0.0336 (0.0423)  loss_box_reg: 0.0914 (0.1152)  loss_objectness: 0.0007 (0.0012)  loss_rpn_box_reg: 0.0030 (0.0042)  time: 0.6524  data: 0.0341  max mem: 4959
# Epoch: [3]  [60/74]  eta: 0:00:09  lr: 0.000500  loss: 0.1375 (0.1628)  loss_classifier: 0.0354 (0.0422)  loss_box_reg: 0.0986 (0.1152)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0030 (0.0041)  time: 0.6521  data: 0.0348  max mem: 4959
# Epoch: [3]  [70/74]  eta: 0:00:02  lr: 0.000500  loss: 0.1449 (0.1623)  loss_classifier: 0.0353 (0.0413)  loss_box_reg: 0.1028 (0.1136)  loss_objectness: 0.0009 (0.0030)  loss_rpn_box_reg: 0.0030 (0.0043)  time: 0.6420  data: 0.0310  max mem: 4959
# Epoch: [3]  [73/74]  eta: 0:00:00  lr: 0.000500  loss: 0.1449 (0.1625)  loss_classifier: 0.0347 (0.0412)  loss_box_reg: 0.1028 (0.1140)  loss_objectness: 0.0011 (0.0030)  loss_rpn_box_reg: 0.0034 (0.0043)  time: 0.6182  data: 0.0300  max mem: 4959
# Epoch: [3] Total time: 0:00:49 (0.6627 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:18  model_time: 0.2843 (0.2843)  evaluator_time: 0.0061 (0.0061)  time: 0.9366  data: 0.6019  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2563 (0.2579)  evaluator_time: 0.0098 (0.0121)  time: 0.3558  data: 0.0567  max mem: 4959
# Test: Total time: 0:00:07 (0.3577 s / it)
# Averaged stats: model_time: 0.2563 (0.2579)  evaluator_time: 0.0098 (0.0121)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.554
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.314
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.423
# Epoch: [4]  [ 0/74]  eta: 0:02:41  lr: 0.000500  loss: 0.2640 (0.2640)  loss_classifier: 0.0634 (0.0634)  loss_box_reg: 0.1924 (0.1924)  loss_objectness: 0.0016 (0.0016)  loss_rpn_box_reg: 0.0066 (0.0066)  time: 2.1848  data: 1.5283  max mem: 4959
# Epoch: [4]  [10/74]  eta: 0:00:51  lr: 0.000500  loss: 0.1552 (0.1662)  loss_classifier: 0.0399 (0.0460)  loss_box_reg: 0.1127 (0.1126)  loss_objectness: 0.0009 (0.0029)  loss_rpn_box_reg: 0.0026 (0.0047)  time: 0.8053  data: 0.1698  max mem: 4959
# Epoch: [4]  [20/74]  eta: 0:00:39  lr: 0.000500  loss: 0.1552 (0.1704)  loss_classifier: 0.0399 (0.0449)  loss_box_reg: 0.1127 (0.1190)  loss_objectness: 0.0009 (0.0024)  loss_rpn_box_reg: 0.0026 (0.0041)  time: 0.6571  data: 0.0325  max mem: 4959
# Epoch: [4]  [30/74]  eta: 0:00:30  lr: 0.000500  loss: 0.1556 (0.1652)  loss_classifier: 0.0380 (0.0425)  loss_box_reg: 0.1158 (0.1165)  loss_objectness: 0.0008 (0.0021)  loss_rpn_box_reg: 0.0027 (0.0040)  time: 0.6488  data: 0.0323  max mem: 4959
# Epoch: [4]  [40/74]  eta: 0:00:23  lr: 0.000500  loss: 0.1556 (0.1644)  loss_classifier: 0.0396 (0.0425)  loss_box_reg: 0.1114 (0.1138)  loss_objectness: 0.0009 (0.0035)  loss_rpn_box_reg: 0.0031 (0.0046)  time: 0.6472  data: 0.0328  max mem: 4959
# Epoch: [4]  [50/74]  eta: 0:00:16  lr: 0.000500  loss: 0.1425 (0.1590)  loss_classifier: 0.0407 (0.0414)  loss_box_reg: 0.0932 (0.1103)  loss_objectness: 0.0006 (0.0029)  loss_rpn_box_reg: 0.0028 (0.0044)  time: 0.6466  data: 0.0320  max mem: 4959
# Epoch: [4]  [60/74]  eta: 0:00:09  lr: 0.000500  loss: 0.1155 (0.1524)  loss_classifier: 0.0358 (0.0400)  loss_box_reg: 0.0818 (0.1058)  loss_objectness: 0.0005 (0.0027)  loss_rpn_box_reg: 0.0019 (0.0040)  time: 0.6521  data: 0.0322  max mem: 4959
# Epoch: [4]  [70/74]  eta: 0:00:02  lr: 0.000500  loss: 0.1413 (0.1569)  loss_classifier: 0.0366 (0.0412)  loss_box_reg: 0.0948 (0.1083)  loss_objectness: 0.0005 (0.0029)  loss_rpn_box_reg: 0.0023 (0.0045)  time: 0.6493  data: 0.0313  max mem: 4959
# Epoch: [4]  [73/74]  eta: 0:00:00  lr: 0.000500  loss: 0.1413 (0.1566)  loss_classifier: 0.0366 (0.0414)  loss_box_reg: 0.0948 (0.1078)  loss_objectness: 0.0005 (0.0028)  loss_rpn_box_reg: 0.0028 (0.0046)  time: 0.6224  data: 0.0298  max mem: 4959
# Epoch: [4] Total time: 0:00:49 (0.6658 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2766 (0.2766)  evaluator_time: 0.0062 (0.0062)  time: 0.9948  data: 0.6303  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2574 (0.2581)  evaluator_time: 0.0104 (0.0131)  time: 0.3592  data: 0.0572  max mem: 4959
# Test: Total time: 0:00:07 (0.3610 s / it)
# Averaged stats: model_time: 0.2574 (0.2581)  evaluator_time: 0.0104 (0.0131)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.587
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.347
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.434
# Epoch: [5]  [ 0/74]  eta: 0:02:52  lr: 0.000500  loss: 0.1954 (0.1954)  loss_classifier: 0.0491 (0.0491)  loss_box_reg: 0.1436 (0.1436)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 2.3267  data: 1.6579  max mem: 4959
# Epoch: [5]  [10/74]  eta: 0:00:51  lr: 0.000500  loss: 0.1477 (0.1625)  loss_classifier: 0.0388 (0.0423)  loss_box_reg: 0.1045 (0.1163)  loss_objectness: 0.0004 (0.0007)  loss_rpn_box_reg: 0.0028 (0.0032)  time: 0.8079  data: 0.1800  max mem: 4959
# Epoch: [5]  [20/74]  eta: 0:00:39  lr: 0.000500  loss: 0.1477 (0.1618)  loss_classifier: 0.0359 (0.0422)  loss_box_reg: 0.1045 (0.1154)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0028 (0.0033)  time: 0.6552  data: 0.0337  max mem: 4959
# Epoch: [5]  [30/74]  eta: 0:00:31  lr: 0.000500  loss: 0.1387 (0.1547)  loss_classifier: 0.0344 (0.0409)  loss_box_reg: 0.1036 (0.1095)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0031 (0.0033)  time: 0.6498  data: 0.0334  max mem: 4959
# Epoch: [5]  [40/74]  eta: 0:00:23  lr: 0.000500  loss: 0.1289 (0.1599)  loss_classifier: 0.0370 (0.0424)  loss_box_reg: 0.0936 (0.1126)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0031 (0.0037)  time: 0.6470  data: 0.0325  max mem: 4959
# Epoch: [5]  [50/74]  eta: 0:00:16  lr: 0.000500  loss: 0.1506 (0.1609)  loss_classifier: 0.0373 (0.0424)  loss_box_reg: 0.1021 (0.1130)  loss_objectness: 0.0016 (0.0017)  loss_rpn_box_reg: 0.0031 (0.0038)  time: 0.6481  data: 0.0325  max mem: 4959
# Epoch: [5]  [60/74]  eta: 0:00:09  lr: 0.000500  loss: 0.1445 (0.1553)  loss_classifier: 0.0373 (0.0409)  loss_box_reg: 0.0911 (0.1092)  loss_objectness: 0.0010 (0.0016)  loss_rpn_box_reg: 0.0029 (0.0036)  time: 0.6512  data: 0.0337  max mem: 4959
# Epoch: [5]  [70/74]  eta: 0:00:02  lr: 0.000500  loss: 0.1218 (0.1561)  loss_classifier: 0.0341 (0.0413)  loss_box_reg: 0.0901 (0.1095)  loss_objectness: 0.0006 (0.0016)  loss_rpn_box_reg: 0.0028 (0.0037)  time: 0.6489  data: 0.0326  max mem: 4959
# Epoch: [5]  [73/74]  eta: 0:00:00  lr: 0.000500  loss: 0.1346 (0.1566)  loss_classifier: 0.0379 (0.0415)  loss_box_reg: 0.0911 (0.1099)  loss_objectness: 0.0006 (0.0016)  loss_rpn_box_reg: 0.0028 (0.0036)  time: 0.6233  data: 0.0309  max mem: 4959
# Epoch: [5] Total time: 0:00:49 (0.6666 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:21  model_time: 0.2914 (0.2914)  evaluator_time: 0.0063 (0.0063)  time: 1.0539  data: 0.6884  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2557 (0.2578)  evaluator_time: 0.0093 (0.0119)  time: 0.3607  data: 0.0612  max mem: 4959
# Test: Total time: 0:00:07 (0.3624 s / it)
# Averaged stats: model_time: 0.2557 (0.2578)  evaluator_time: 0.0093 (0.0119)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.228
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.578
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.170
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.440
# Epoch: [6]  [ 0/74]  eta: 0:02:50  lr: 0.000050  loss: 0.1430 (0.1430)  loss_classifier: 0.0437 (0.0437)  loss_box_reg: 0.0956 (0.0956)  loss_objectness: 0.0013 (0.0013)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 2.3085  data: 1.6183  max mem: 4959
# Epoch: [6]  [10/74]  eta: 0:00:51  lr: 0.000050  loss: 0.1360 (0.1472)  loss_classifier: 0.0348 (0.0385)  loss_box_reg: 0.0959 (0.1041)  loss_objectness: 0.0006 (0.0015)  loss_rpn_box_reg: 0.0027 (0.0031)  time: 0.7995  data: 0.1735  max mem: 4959
# Epoch: [6]  [20/74]  eta: 0:00:39  lr: 0.000050  loss: 0.1344 (0.1544)  loss_classifier: 0.0342 (0.0407)  loss_box_reg: 0.0959 (0.1072)  loss_objectness: 0.0010 (0.0027)  loss_rpn_box_reg: 0.0027 (0.0038)  time: 0.6506  data: 0.0309  max mem: 4959
# Epoch: [6]  [30/74]  eta: 0:00:30  lr: 0.000050  loss: 0.1405 (0.1552)  loss_classifier: 0.0344 (0.0414)  loss_box_reg: 0.0934 (0.1078)  loss_objectness: 0.0010 (0.0021)  loss_rpn_box_reg: 0.0032 (0.0038)  time: 0.6496  data: 0.0327  max mem: 4959
# Epoch: [6]  [40/74]  eta: 0:00:23  lr: 0.000050  loss: 0.1542 (0.1576)  loss_classifier: 0.0391 (0.0418)  loss_box_reg: 0.1110 (0.1099)  loss_objectness: 0.0009 (0.0022)  loss_rpn_box_reg: 0.0035 (0.0038)  time: 0.6477  data: 0.0325  max mem: 4959
# Epoch: [6]  [50/74]  eta: 0:00:16  lr: 0.000050  loss: 0.1460 (0.1534)  loss_classifier: 0.0389 (0.0406)  loss_box_reg: 0.1024 (0.1072)  loss_objectness: 0.0009 (0.0020)  loss_rpn_box_reg: 0.0032 (0.0036)  time: 0.6490  data: 0.0324  max mem: 4959
# Epoch: [6]  [60/74]  eta: 0:00:09  lr: 0.000050  loss: 0.1388 (0.1508)  loss_classifier: 0.0365 (0.0401)  loss_box_reg: 0.0966 (0.1053)  loss_objectness: 0.0005 (0.0018)  loss_rpn_box_reg: 0.0029 (0.0036)  time: 0.6481  data: 0.0323  max mem: 4959
# Epoch: [6]  [70/74]  eta: 0:00:02  lr: 0.000050  loss: 0.1388 (0.1528)  loss_classifier: 0.0365 (0.0407)  loss_box_reg: 0.0943 (0.1066)  loss_objectness: 0.0009 (0.0018)  loss_rpn_box_reg: 0.0031 (0.0037)  time: 0.6434  data: 0.0313  max mem: 4959
# Epoch: [6]  [73/74]  eta: 0:00:00  lr: 0.000050  loss: 0.1329 (0.1516)  loss_classifier: 0.0332 (0.0403)  loss_box_reg: 0.0938 (0.1058)  loss_objectness: 0.0009 (0.0019)  loss_rpn_box_reg: 0.0031 (0.0037)  time: 0.6188  data: 0.0303  max mem: 4959
# Epoch: [6] Total time: 0:00:49 (0.6640 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2829 (0.2829)  evaluator_time: 0.0064 (0.0064)  time: 0.9814  data: 0.6075  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2563 (0.2578)  evaluator_time: 0.0093 (0.0119)  time: 0.3566  data: 0.0567  max mem: 4959
# Test: Total time: 0:00:07 (0.3584 s / it)
# Averaged stats: model_time: 0.2563 (0.2578)  evaluator_time: 0.0093 (0.0119)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.228
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.581
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.112
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.079
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.328
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
# Epoch: [7]  [ 0/74]  eta: 0:02:14  lr: 0.000050  loss: 0.1335 (0.1335)  loss_classifier: 0.0395 (0.0395)  loss_box_reg: 0.0875 (0.0875)  loss_objectness: 0.0032 (0.0032)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 1.8184  data: 1.1139  max mem: 4959
# Epoch: [7]  [10/74]  eta: 0:00:49  lr: 0.000050  loss: 0.1503 (0.1651)  loss_classifier: 0.0395 (0.0416)  loss_box_reg: 0.1160 (0.1164)  loss_objectness: 0.0010 (0.0029)  loss_rpn_box_reg: 0.0036 (0.0042)  time: 0.7768  data: 0.1362  max mem: 4959
# Epoch: [7]  [20/74]  eta: 0:00:38  lr: 0.000050  loss: 0.1387 (0.1519)  loss_classifier: 0.0394 (0.0397)  loss_box_reg: 0.0956 (0.1061)  loss_objectness: 0.0010 (0.0026)  loss_rpn_box_reg: 0.0032 (0.0036)  time: 0.6608  data: 0.0354  max mem: 4959
# Epoch: [7]  [30/74]  eta: 0:00:30  lr: 0.000050  loss: 0.1340 (0.1487)  loss_classifier: 0.0358 (0.0398)  loss_box_reg: 0.0915 (0.1017)  loss_objectness: 0.0007 (0.0034)  loss_rpn_box_reg: 0.0027 (0.0038)  time: 0.6491  data: 0.0316  max mem: 4959
# Epoch: [7]  [40/74]  eta: 0:00:23  lr: 0.000050  loss: 0.1391 (0.1523)  loss_classifier: 0.0391 (0.0406)  loss_box_reg: 0.0981 (0.1051)  loss_objectness: 0.0005 (0.0028)  loss_rpn_box_reg: 0.0027 (0.0038)  time: 0.6536  data: 0.0316  max mem: 4959
# Epoch: [7]  [50/74]  eta: 0:00:16  lr: 0.000050  loss: 0.1293 (0.1475)  loss_classifier: 0.0391 (0.0398)  loss_box_reg: 0.0891 (0.1016)  loss_objectness: 0.0005 (0.0024)  loss_rpn_box_reg: 0.0026 (0.0037)  time: 0.6548  data: 0.0331  max mem: 4959
# Epoch: [7]  [60/74]  eta: 0:00:09  lr: 0.000050  loss: 0.1229 (0.1491)  loss_classifier: 0.0348 (0.0399)  loss_box_reg: 0.0851 (0.1032)  loss_objectness: 0.0003 (0.0023)  loss_rpn_box_reg: 0.0030 (0.0037)  time: 0.6491  data: 0.0337  max mem: 4959
# Epoch: [7]  [70/74]  eta: 0:00:02  lr: 0.000050  loss: 0.1801 (0.1528)  loss_classifier: 0.0430 (0.0403)  loss_box_reg: 0.1325 (0.1066)  loss_objectness: 0.0006 (0.0022)  loss_rpn_box_reg: 0.0037 (0.0037)  time: 0.6428  data: 0.0305  max mem: 4959
# Epoch: [7]  [73/74]  eta: 0:00:00  lr: 0.000050  loss: 0.1801 (0.1528)  loss_classifier: 0.0428 (0.0403)  loss_box_reg: 0.1307 (0.1065)  loss_objectness: 0.0006 (0.0022)  loss_rpn_box_reg: 0.0036 (0.0037)  time: 0.6191  data: 0.0293  max mem: 4959
# Epoch: [7] Total time: 0:00:48 (0.6619 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.2855 (0.2855)  evaluator_time: 0.0073 (0.0073)  time: 1.0083  data: 0.6504  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2574 (0.2587)  evaluator_time: 0.0094 (0.0127)  time: 0.3600  data: 0.0590  max mem: 4959
# Test: Total time: 0:00:07 (0.3618 s / it)
# Averaged stats: model_time: 0.2574 (0.2587)  evaluator_time: 0.0094 (0.0127)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.226
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.576
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.328
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
# Epoch: [8]  [ 0/74]  eta: 0:02:28  lr: 0.000050  loss: 0.1561 (0.1561)  loss_classifier: 0.0462 (0.0462)  loss_box_reg: 0.1062 (0.1062)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 2.0031  data: 1.3061  max mem: 4959
# Epoch: [8]  [10/74]  eta: 0:00:50  lr: 0.000050  loss: 0.1447 (0.1539)  loss_classifier: 0.0396 (0.0394)  loss_box_reg: 0.1062 (0.1101)  loss_objectness: 0.0006 (0.0011)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 0.7833  data: 0.1514  max mem: 4959
# Epoch: [8]  [20/74]  eta: 0:00:38  lr: 0.000050  loss: 0.1484 (0.1530)  loss_classifier: 0.0396 (0.0399)  loss_box_reg: 0.1018 (0.1079)  loss_objectness: 0.0004 (0.0014)  loss_rpn_box_reg: 0.0035 (0.0038)  time: 0.6551  data: 0.0347  max mem: 4959
# Epoch: [8]  [30/74]  eta: 0:00:30  lr: 0.000050  loss: 0.1485 (0.1482)  loss_classifier: 0.0374 (0.0392)  loss_box_reg: 0.1018 (0.1042)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0035 (0.0035)  time: 0.6494  data: 0.0334  max mem: 4959
# Epoch: [8]  [40/74]  eta: 0:00:23  lr: 0.000050  loss: 0.1417 (0.1472)  loss_classifier: 0.0355 (0.0393)  loss_box_reg: 0.1008 (0.1032)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0026 (0.0034)  time: 0.6512  data: 0.0335  max mem: 4960
# Epoch: [8]  [50/74]  eta: 0:00:16  lr: 0.000050  loss: 0.1417 (0.1484)  loss_classifier: 0.0362 (0.0390)  loss_box_reg: 0.1008 (0.1046)  loss_objectness: 0.0007 (0.0015)  loss_rpn_box_reg: 0.0029 (0.0034)  time: 0.6501  data: 0.0328  max mem: 4960
# Epoch: [8]  [60/74]  eta: 0:00:09  lr: 0.000050  loss: 0.1581 (0.1515)  loss_classifier: 0.0370 (0.0402)  loss_box_reg: 0.1107 (0.1061)  loss_objectness: 0.0006 (0.0016)  loss_rpn_box_reg: 0.0035 (0.0037)  time: 0.6483  data: 0.0326  max mem: 4960
# Epoch: [8]  [70/74]  eta: 0:00:02  lr: 0.000050  loss: 0.1697 (0.1543)  loss_classifier: 0.0473 (0.0409)  loss_box_reg: 0.1107 (0.1079)  loss_objectness: 0.0009 (0.0016)  loss_rpn_box_reg: 0.0038 (0.0039)  time: 0.6421  data: 0.0300  max mem: 4960
# Epoch: [8]  [73/74]  eta: 0:00:00  lr: 0.000050  loss: 0.1697 (0.1530)  loss_classifier: 0.0473 (0.0409)  loss_box_reg: 0.1107 (0.1068)  loss_objectness: 0.0006 (0.0015)  loss_rpn_box_reg: 0.0034 (0.0039)  time: 0.6165  data: 0.0288  max mem: 4960
# Epoch: [8] Total time: 0:00:48 (0.6614 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:18  model_time: 0.2737 (0.2737)  evaluator_time: 0.0058 (0.0058)  time: 0.9010  data: 0.5848  max mem: 4960
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2568 (0.2593)  evaluator_time: 0.0097 (0.0146)  time: 0.3620  data: 0.0577  max mem: 4960
# Test: Total time: 0:00:07 (0.3641 s / it)
# Averaged stats: model_time: 0.2568 (0.2593)  evaluator_time: 0.0097 (0.0146)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.582
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.079
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.354
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.440
# Epoch: [9]  [ 0/74]  eta: 0:02:35  lr: 0.000005  loss: 0.1300 (0.1300)  loss_classifier: 0.0354 (0.0354)  loss_box_reg: 0.0902 (0.0902)  loss_objectness: 0.0012 (0.0012)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 2.0988  data: 1.4618  max mem: 4960
# Epoch: [9]  [10/74]  eta: 0:00:50  lr: 0.000005  loss: 0.1621 (0.1669)  loss_classifier: 0.0483 (0.0462)  loss_box_reg: 0.1142 (0.1156)  loss_objectness: 0.0012 (0.0011)  loss_rpn_box_reg: 0.0033 (0.0040)  time: 0.7938  data: 0.1641  max mem: 4960
# Epoch: [9]  [20/74]  eta: 0:00:39  lr: 0.000005  loss: 0.1540 (0.1573)  loss_classifier: 0.0447 (0.0430)  loss_box_reg: 0.1038 (0.1096)  loss_objectness: 0.0009 (0.0010)  loss_rpn_box_reg: 0.0027 (0.0036)  time: 0.6564  data: 0.0331  max mem: 4960
# Epoch: [9]  [30/74]  eta: 0:00:30  lr: 0.000005  loss: 0.1348 (0.1468)  loss_classifier: 0.0349 (0.0400)  loss_box_reg: 0.0966 (0.1023)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0026 (0.0035)  time: 0.6466  data: 0.0319  max mem: 4960
# Epoch: [9]  [40/74]  eta: 0:00:23  lr: 0.000005  loss: 0.1506 (0.1575)  loss_classifier: 0.0354 (0.0425)  loss_box_reg: 0.1102 (0.1094)  loss_objectness: 0.0005 (0.0017)  loss_rpn_box_reg: 0.0028 (0.0039)  time: 0.6482  data: 0.0332  max mem: 4960
# Epoch: [9]  [50/74]  eta: 0:00:16  lr: 0.000005  loss: 0.1480 (0.1571)  loss_classifier: 0.0357 (0.0420)  loss_box_reg: 0.1102 (0.1099)  loss_objectness: 0.0006 (0.0015)  loss_rpn_box_reg: 0.0027 (0.0037)  time: 0.6498  data: 0.0336  max mem: 4960
# Epoch: [9]  [60/74]  eta: 0:00:09  lr: 0.000005  loss: 0.1311 (0.1507)  loss_classifier: 0.0334 (0.0408)  loss_box_reg: 0.0919 (0.1048)  loss_objectness: 0.0004 (0.0014)  loss_rpn_box_reg: 0.0025 (0.0036)  time: 0.6507  data: 0.0339  max mem: 4960
# Epoch: [9]  [70/74]  eta: 0:00:02  lr: 0.000005  loss: 0.1334 (0.1522)  loss_classifier: 0.0366 (0.0409)  loss_box_reg: 0.0945 (0.1063)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0026 (0.0037)  time: 0.6466  data: 0.0320  max mem: 4960
# Epoch: [9]  [73/74]  eta: 0:00:00  lr: 0.000005  loss: 0.1504 (0.1536)  loss_classifier: 0.0390 (0.0417)  loss_box_reg: 0.1031 (0.1069)  loss_objectness: 0.0005 (0.0013)  loss_rpn_box_reg: 0.0032 (0.0037)  time: 0.6212  data: 0.0303  max mem: 4960
# Epoch: [9] Total time: 0:00:49 (0.6634 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.2721 (0.2721)  evaluator_time: 0.0062 (0.0062)  time: 1.0123  data: 0.6680  max mem: 4960
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2565 (0.2571)  evaluator_time: 0.0094 (0.0121)  time: 0.3611  data: 0.0614  max mem: 4960
# Test: Total time: 0:00:07 (0.3629 s / it)
# Averaged stats: model_time: 0.2565 (0.2571)  evaluator_time: 0.0094 (0.0121)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.228
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.582
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.080
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.352
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
