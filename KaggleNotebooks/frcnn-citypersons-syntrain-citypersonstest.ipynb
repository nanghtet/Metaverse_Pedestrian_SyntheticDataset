# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Download TorchVision repo to use some files from
# references/detection
# !pip install pycocotools --quiet
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 531477, done.
# remote: Counting objects: 100% (45087/45087), done.
# remote: Compressing objects: 100% (2077/2077), done.
# remote: Total 531477 (delta 43042), reused 44919 (delta 42937), pack-reused 486390
# Receiving objects: 100% (531477/531477), 1.00 GiB | 33.00 MiB/s, done.
# Resolving deltas: 100% (496286/496286), done.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
from torch.utils.data import ConcatDataset

from torch.utils.data import Subset
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
# defining the files directory and testing directory
train_dir = '/kaggle/input/citypersons-testselection/NewTest'
test_dir = '/kaggle/input/citypersons-testselection/NewTest'

# %%
add_train_dir = '/kaggle/input/pedestriansyntheticdataset/train/train'

# %%
class ImagesDataset(torch.utils.data.Dataset):

    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
        
        # sorting the images for consistency
        # To get images, the extension of the filename is checked to be jpg
       # self.imgs = [image for image in sorted(os.listdir(files_dir))
                       # if image[-4:]=='.jpg']
        
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        
        
        
        # classes: 0 index is reserved for background
        self.classes = ['background','pedestrian']

    def __getitem__(self, idx):

        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # reading the images and converting them to correct size and color    
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        # diving by 255
        img_res /= 255.0
        
        # annotation file
        annot_filename = img_name[:-4] + '.xml'
        annot_file_path = os.path.join(self.files_dir, annot_filename)
        
        boxes = []
        labels = []
        tree = et.parse(annot_file_path)
        root = tree.getroot()
        
        # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        
        # box coordinates for xml files are extracted and corrected for image size given
        for member in root.findall('object'):
            label_text = member.find('name').text.lower()
            if label_text in ['ped', 'pedestrian']:
                labels.append(self.classes.index('pedestrian')) 
            
            # bounding box
            xmin = int(member.find('bndbox').find('xmin').text)
            xmax = int(member.find('bndbox').find('xmax').text)
            
            ymin = int(member.find('bndbox').find('ymin').text)
            ymax = int(member.find('bndbox').find('ymax').text)
            
            
            xmin_corr = (xmin/wt)*self.width
            xmax_corr = (xmax/wt)*self.width
            ymin_corr = (ymin/ht)*self.height
            ymax_corr = (ymax/ht)*self.height
            
            boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
        
        # convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        # getting the areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
        
        labels = torch.as_tensor(labels, dtype=torch.int64)


        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        # image_id
        image_id = idx
        target["image_id"] = image_id
        
  


        if self.transforms:
            
            sample = self.transforms(image = img_res,
                                     bboxes = target['boxes'],
                                     labels = labels)
            
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
            
            
            
        return img_res, target

    def __len__(self):
        return len(self.imgs)

# %%
def get_object_detection_model(num_classes):

    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 

    return model

# %%
# Send train=True fro training transforms and False for val/test transforms
def get_transform(train):
    
    if train:
        return A.Compose([
            A.HorizontalFlip(0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
            A.Rotate(limit=15, p=0.5),
            ToTensorV2(p=1.0)
        ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']))
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
# use our dataset and defined transformations
train_dataset = ImagesDataset(train_dir, 1920, 1080, transforms= get_transform(train=True))
add_train_dataset = ImagesDataset(add_train_dir, 1920, 1080, transforms= get_transform(train=True))
combined_dataset = ConcatDataset([train_dataset, add_train_dataset])

test_dataset = ImagesDataset(test_dir, 1920, 1080, transforms= get_transform(train=False))

# define training and validation data loaders
combined_data_loader_train = torch.utils.data.DataLoader(
    combined_dataset, batch_size=4, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    test_dataset, batch_size=4, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')


num_classes = 2

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:01<00:00, 145MB/s]

# %%
# training for 10 epochs
num_epochs = 10

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, combined_data_loader_train, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [ 0/92]  eta: 0:06:51  lr: 0.000060  loss: 1.0528 (1.0528)  loss_classifier: 0.8471 (0.8471)  loss_box_reg: 0.1834 (0.1834)  loss_objectness: 0.0164 (0.0164)  loss_rpn_box_reg: 0.0059 (0.0059)  time: 4.4718  data: 1.5026  max mem: 4799
# Epoch: [0]  [10/92]  eta: 0:01:21  lr: 0.000609  loss: 0.9405 (0.8553)  loss_classifier: 0.5596 (0.5238)  loss_box_reg: 0.2524 (0.2787)  loss_objectness: 0.0144 (0.0339)  loss_rpn_box_reg: 0.0090 (0.0189)  time: 0.9943  data: 0.1621  max mem: 4957
# Epoch: [0]  [20/92]  eta: 0:00:59  lr: 0.001158  loss: 0.6024 (0.7305)  loss_classifier: 0.2590 (0.3895)  loss_box_reg: 0.2397 (0.2680)  loss_objectness: 0.0144 (0.0435)  loss_rpn_box_reg: 0.0149 (0.0294)  time: 0.6457  data: 0.0298  max mem: 4957
# Epoch: [0]  [30/92]  eta: 0:00:47  lr: 0.001707  loss: 0.5093 (0.6766)  loss_classifier: 0.1953 (0.3261)  loss_box_reg: 0.2397 (0.2752)  loss_objectness: 0.0274 (0.0420)  loss_rpn_box_reg: 0.0169 (0.0332)  time: 0.6474  data: 0.0315  max mem: 4958
# Epoch: [0]  [40/92]  eta: 0:00:38  lr: 0.002255  loss: 0.4239 (0.6051)  loss_classifier: 0.1031 (0.2690)  loss_box_reg: 0.2374 (0.2702)  loss_objectness: 0.0260 (0.0366)  loss_rpn_box_reg: 0.0088 (0.0293)  time: 0.6505  data: 0.0322  max mem: 4958
# Epoch: [0]  [50/92]  eta: 0:00:30  lr: 0.002804  loss: 0.3241 (0.5684)  loss_classifier: 0.0793 (0.2358)  loss_box_reg: 0.2152 (0.2648)  loss_objectness: 0.0204 (0.0354)  loss_rpn_box_reg: 0.0109 (0.0324)  time: 0.6504  data: 0.0320  max mem: 4959
# Epoch: [0]  [60/92]  eta: 0:00:22  lr: 0.003353  loss: 0.3035 (0.5259)  loss_classifier: 0.0753 (0.2095)  loss_box_reg: 0.1858 (0.2531)  loss_objectness: 0.0191 (0.0325)  loss_rpn_box_reg: 0.0132 (0.0308)  time: 0.6498  data: 0.0310  max mem: 4959
# Epoch: [0]  [70/92]  eta: 0:00:15  lr: 0.003902  loss: 0.2509 (0.4974)  loss_classifier: 0.0672 (0.1923)  loss_box_reg: 0.1858 (0.2462)  loss_objectness: 0.0147 (0.0312)  loss_rpn_box_reg: 0.0074 (0.0278)  time: 0.6492  data: 0.0313  max mem: 4959
# Epoch: [0]  [80/92]  eta: 0:00:08  lr: 0.004451  loss: 0.3136 (0.4856)  loss_classifier: 0.0786 (0.1813)  loss_box_reg: 0.2138 (0.2463)  loss_objectness: 0.0130 (0.0295)  loss_rpn_box_reg: 0.0088 (0.0284)  time: 0.6507  data: 0.0332  max mem: 4959
# Epoch: [0]  [90/92]  eta: 0:00:01  lr: 0.005000  loss: 0.3146 (0.4730)  loss_classifier: 0.0856 (0.1716)  loss_box_reg: 0.1979 (0.2411)  loss_objectness: 0.0107 (0.0284)  loss_rpn_box_reg: 0.0122 (0.0319)  time: 0.6447  data: 0.0315  max mem: 4959
# Epoch: [0]  [91/92]  eta: 0:00:00  lr: 0.005000  loss: 0.3175 (0.4740)  loss_classifier: 0.0880 (0.1716)  loss_box_reg: 0.1983 (0.2419)  loss_objectness: 0.0107 (0.0283)  loss_rpn_box_reg: 0.0164 (0.0323)  time: 0.6440  data: 0.0313  max mem: 4959
# Epoch: [0] Total time: 0:01:03 (0.6895 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2759 (0.2759)  evaluator_time: 0.0820 (0.0820)  time: 0.9318  data: 0.5260  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2546 (0.2551)  evaluator_time: 0.0968 (0.1286)  time: 0.4658  data: 0.0539  max mem: 4959
# Test: Total time: 0:00:08 (0.4677 s / it)
# Averaged stats: model_time: 0.2546 (0.2551)  evaluator_time: 0.0968 (0.1286)
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.159
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.155
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.338
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.193
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.480
# Epoch: [1]  [ 0/92]  eta: 0:03:30  lr: 0.005000  loss: 0.2109 (0.2109)  loss_classifier: 0.0506 (0.0506)  loss_box_reg: 0.1538 (0.1538)  loss_objectness: 0.0024 (0.0024)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 2.2855  data: 1.6436  max mem: 4959
# Epoch: [1]  [10/92]  eta: 0:01:05  lr: 0.005000  loss: 0.2623 (0.3198)  loss_classifier: 0.0770 (0.0867)  loss_box_reg: 0.1538 (0.1804)  loss_objectness: 0.0137 (0.0166)  loss_rpn_box_reg: 0.0095 (0.0361)  time: 0.7964  data: 0.1766  max mem: 4959
# Epoch: [1]  [20/92]  eta: 0:00:52  lr: 0.005000  loss: 0.2656 (0.3407)  loss_classifier: 0.0833 (0.0919)  loss_box_reg: 0.1710 (0.1935)  loss_objectness: 0.0137 (0.0175)  loss_rpn_box_reg: 0.0089 (0.0378)  time: 0.6496  data: 0.0324  max mem: 4959
# Epoch: [1]  [30/92]  eta: 0:00:43  lr: 0.005000  loss: 0.2500 (0.3063)  loss_classifier: 0.0658 (0.0825)  loss_box_reg: 0.1561 (0.1801)  loss_objectness: 0.0063 (0.0141)  loss_rpn_box_reg: 0.0070 (0.0297)  time: 0.6465  data: 0.0328  max mem: 4959
# Epoch: [1]  [40/92]  eta: 0:00:35  lr: 0.005000  loss: 0.2398 (0.3022)  loss_classifier: 0.0646 (0.0821)  loss_box_reg: 0.1561 (0.1800)  loss_objectness: 0.0060 (0.0132)  loss_rpn_box_reg: 0.0081 (0.0269)  time: 0.6408  data: 0.0303  max mem: 4959
# Epoch: [1]  [50/92]  eta: 0:00:28  lr: 0.005000  loss: 0.2222 (0.2899)  loss_classifier: 0.0633 (0.0786)  loss_box_reg: 0.1496 (0.1772)  loss_objectness: 0.0048 (0.0117)  loss_rpn_box_reg: 0.0042 (0.0225)  time: 0.6442  data: 0.0323  max mem: 4959
# Epoch: [1]  [60/92]  eta: 0:00:21  lr: 0.005000  loss: 0.2151 (0.3046)  loss_classifier: 0.0633 (0.0823)  loss_box_reg: 0.1481 (0.1835)  loss_objectness: 0.0050 (0.0124)  loss_rpn_box_reg: 0.0042 (0.0264)  time: 0.6488  data: 0.0340  max mem: 4959
# Epoch: [1]  [70/92]  eta: 0:00:14  lr: 0.005000  loss: 0.3345 (0.3042)  loss_classifier: 0.0761 (0.0820)  loss_box_reg: 0.1688 (0.1822)  loss_objectness: 0.0093 (0.0120)  loss_rpn_box_reg: 0.0107 (0.0279)  time: 0.6482  data: 0.0335  max mem: 4959
# Epoch: [1]  [80/92]  eta: 0:00:08  lr: 0.005000  loss: 0.2516 (0.3017)  loss_classifier: 0.0674 (0.0812)  loss_box_reg: 0.1453 (0.1800)  loss_objectness: 0.0063 (0.0133)  loss_rpn_box_reg: 0.0129 (0.0271)  time: 0.6466  data: 0.0329  max mem: 4959
# Epoch: [1]  [90/92]  eta: 0:00:01  lr: 0.005000  loss: 0.2386 (0.2999)  loss_classifier: 0.0713 (0.0803)  loss_box_reg: 0.1755 (0.1810)  loss_objectness: 0.0051 (0.0125)  loss_rpn_box_reg: 0.0094 (0.0260)  time: 0.6406  data: 0.0300  max mem: 4959
# Epoch: [1]  [91/92]  eta: 0:00:00  lr: 0.005000  loss: 0.2386 (0.2989)  loss_classifier: 0.0713 (0.0801)  loss_box_reg: 0.1755 (0.1806)  loss_objectness: 0.0051 (0.0124)  loss_rpn_box_reg: 0.0086 (0.0258)  time: 0.6400  data: 0.0296  max mem: 4959
# Epoch: [1] Total time: 0:01:01 (0.6635 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:16  model_time: 0.2767 (0.2767)  evaluator_time: 0.0671 (0.0671)  time: 0.8655  data: 0.4797  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2561 (0.2543)  evaluator_time: 0.0552 (0.0835)  time: 0.4203  data: 0.0532  max mem: 4959
# Test: Total time: 0:00:08 (0.4222 s / it)
# Averaged stats: model_time: 0.2561 (0.2543)  evaluator_time: 0.0552 (0.0835)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.599
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.230
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.321
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.289
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.396
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.547
# Epoch: [2]  [ 0/92]  eta: 0:03:47  lr: 0.005000  loss: 0.1364 (0.1364)  loss_classifier: 0.0346 (0.0346)  loss_box_reg: 0.0918 (0.0918)  loss_objectness: 0.0023 (0.0023)  loss_rpn_box_reg: 0.0076 (0.0076)  time: 2.4740  data: 1.6977  max mem: 4959
# Epoch: [2]  [10/92]  eta: 0:01:08  lr: 0.005000  loss: 0.1836 (0.2823)  loss_classifier: 0.0490 (0.0824)  loss_box_reg: 0.1324 (0.1657)  loss_objectness: 0.0023 (0.0097)  loss_rpn_box_reg: 0.0070 (0.0244)  time: 0.8345  data: 0.1839  max mem: 4959
# Epoch: [2]  [20/92]  eta: 0:00:53  lr: 0.005000  loss: 0.2406 (0.2588)  loss_classifier: 0.0660 (0.0743)  loss_box_reg: 0.1295 (0.1552)  loss_objectness: 0.0026 (0.0078)  loss_rpn_box_reg: 0.0070 (0.0214)  time: 0.6597  data: 0.0324  max mem: 4959
# Epoch: [2]  [30/92]  eta: 0:00:44  lr: 0.005000  loss: 0.2480 (0.2775)  loss_classifier: 0.0660 (0.0776)  loss_box_reg: 0.1544 (0.1690)  loss_objectness: 0.0069 (0.0080)  loss_rpn_box_reg: 0.0091 (0.0228)  time: 0.6494  data: 0.0330  max mem: 4959
# Epoch: [2]  [40/92]  eta: 0:00:36  lr: 0.005000  loss: 0.2442 (0.2807)  loss_classifier: 0.0587 (0.0772)  loss_box_reg: 0.1690 (0.1717)  loss_objectness: 0.0070 (0.0085)  loss_rpn_box_reg: 0.0116 (0.0234)  time: 0.6495  data: 0.0335  max mem: 4959
# Epoch: [2]  [50/92]  eta: 0:00:28  lr: 0.005000  loss: 0.2117 (0.2777)  loss_classifier: 0.0569 (0.0774)  loss_box_reg: 0.1525 (0.1702)  loss_objectness: 0.0057 (0.0092)  loss_rpn_box_reg: 0.0058 (0.0211)  time: 0.6513  data: 0.0358  max mem: 4959
# Epoch: [2]  [60/92]  eta: 0:00:21  lr: 0.005000  loss: 0.2018 (0.2748)  loss_classifier: 0.0559 (0.0759)  loss_box_reg: 0.1274 (0.1676)  loss_objectness: 0.0027 (0.0087)  loss_rpn_box_reg: 0.0056 (0.0226)  time: 0.6471  data: 0.0343  max mem: 4959
# Epoch: [2]  [70/92]  eta: 0:00:14  lr: 0.005000  loss: 0.2151 (0.2729)  loss_classifier: 0.0546 (0.0741)  loss_box_reg: 0.1378 (0.1665)  loss_objectness: 0.0027 (0.0086)  loss_rpn_box_reg: 0.0091 (0.0237)  time: 0.6443  data: 0.0314  max mem: 4959
# Epoch: [2]  [80/92]  eta: 0:00:08  lr: 0.005000  loss: 0.2235 (0.2694)  loss_classifier: 0.0546 (0.0727)  loss_box_reg: 0.1378 (0.1652)  loss_objectness: 0.0064 (0.0084)  loss_rpn_box_reg: 0.0117 (0.0230)  time: 0.6460  data: 0.0310  max mem: 4959
# Epoch: [2]  [90/92]  eta: 0:00:01  lr: 0.005000  loss: 0.2371 (0.2696)  loss_classifier: 0.0574 (0.0730)  loss_box_reg: 0.1524 (0.1661)  loss_objectness: 0.0065 (0.0083)  loss_rpn_box_reg: 0.0117 (0.0223)  time: 0.6420  data: 0.0293  max mem: 4959
# Epoch: [2]  [91/92]  eta: 0:00:00  lr: 0.005000  loss: 0.2605 (0.2701)  loss_classifier: 0.0621 (0.0730)  loss_box_reg: 0.1533 (0.1664)  loss_objectness: 0.0083 (0.0084)  loss_rpn_box_reg: 0.0131 (0.0224)  time: 0.6409  data: 0.0293  max mem: 4959
# Epoch: [2] Total time: 0:01:01 (0.6697 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:18  model_time: 0.2712 (0.2712)  evaluator_time: 0.0595 (0.0595)  time: 0.9847  data: 0.5764  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2565 (0.2544)  evaluator_time: 0.0592 (0.0855)  time: 0.4287  data: 0.0571  max mem: 4959
# Test: Total time: 0:00:08 (0.4305 s / it)
# Averaged stats: model_time: 0.2565 (0.2544)  evaluator_time: 0.0592 (0.0855)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.622
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.236
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.323
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.397
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.431
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.564
# Epoch: [3]  [ 0/92]  eta: 0:03:00  lr: 0.000500  loss: 0.1608 (0.1608)  loss_classifier: 0.0425 (0.0425)  loss_box_reg: 0.1128 (0.1128)  loss_objectness: 0.0026 (0.0026)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 1.9601  data: 1.2781  max mem: 4959
# Epoch: [3]  [10/92]  eta: 0:01:03  lr: 0.000500  loss: 0.2607 (0.2706)  loss_classifier: 0.0752 (0.0694)  loss_box_reg: 0.1731 (0.1707)  loss_objectness: 0.0036 (0.0083)  loss_rpn_box_reg: 0.0062 (0.0222)  time: 0.7764  data: 0.1485  max mem: 4959
# Epoch: [3]  [20/92]  eta: 0:00:51  lr: 0.000500  loss: 0.2417 (0.2482)  loss_classifier: 0.0636 (0.0649)  loss_box_reg: 0.1580 (0.1589)  loss_objectness: 0.0033 (0.0063)  loss_rpn_box_reg: 0.0062 (0.0182)  time: 0.6531  data: 0.0343  max mem: 4959
# Epoch: [3]  [30/92]  eta: 0:00:43  lr: 0.000500  loss: 0.2199 (0.2416)  loss_classifier: 0.0584 (0.0643)  loss_box_reg: 0.1475 (0.1539)  loss_objectness: 0.0023 (0.0059)  loss_rpn_box_reg: 0.0071 (0.0176)  time: 0.6516  data: 0.0338  max mem: 4959
# Epoch: [3]  [40/92]  eta: 0:00:35  lr: 0.000500  loss: 0.2192 (0.2480)  loss_classifier: 0.0567 (0.0652)  loss_box_reg: 0.1452 (0.1584)  loss_objectness: 0.0037 (0.0066)  loss_rpn_box_reg: 0.0065 (0.0179)  time: 0.6568  data: 0.0348  max mem: 4959
# Epoch: [3]  [50/92]  eta: 0:00:28  lr: 0.000500  loss: 0.2633 (0.2617)  loss_classifier: 0.0639 (0.0687)  loss_box_reg: 0.1926 (0.1664)  loss_objectness: 0.0050 (0.0069)  loss_rpn_box_reg: 0.0093 (0.0197)  time: 0.6536  data: 0.0335  max mem: 4959
# Epoch: [3]  [60/92]  eta: 0:00:21  lr: 0.000500  loss: 0.2476 (0.2592)  loss_classifier: 0.0763 (0.0687)  loss_box_reg: 0.1436 (0.1638)  loss_objectness: 0.0055 (0.0070)  loss_rpn_box_reg: 0.0158 (0.0197)  time: 0.6468  data: 0.0322  max mem: 4959
# Epoch: [3]  [70/92]  eta: 0:00:14  lr: 0.000500  loss: 0.2306 (0.2615)  loss_classifier: 0.0639 (0.0695)  loss_box_reg: 0.1388 (0.1655)  loss_objectness: 0.0032 (0.0068)  loss_rpn_box_reg: 0.0112 (0.0198)  time: 0.6463  data: 0.0327  max mem: 4959
# Epoch: [3]  [80/92]  eta: 0:00:08  lr: 0.000500  loss: 0.1888 (0.2558)  loss_classifier: 0.0588 (0.0684)  loss_box_reg: 0.1378 (0.1628)  loss_objectness: 0.0026 (0.0065)  loss_rpn_box_reg: 0.0072 (0.0182)  time: 0.6495  data: 0.0332  max mem: 4959
# Epoch: [3]  [90/92]  eta: 0:00:01  lr: 0.000500  loss: 0.1828 (0.2548)  loss_classifier: 0.0511 (0.0678)  loss_box_reg: 0.1226 (0.1613)  loss_objectness: 0.0023 (0.0072)  loss_rpn_box_reg: 0.0049 (0.0185)  time: 0.6471  data: 0.0310  max mem: 4959
# Epoch: [3]  [91/92]  eta: 0:00:00  lr: 0.000500  loss: 0.1828 (0.2532)  loss_classifier: 0.0511 (0.0674)  loss_box_reg: 0.1203 (0.1604)  loss_objectness: 0.0023 (0.0071)  loss_rpn_box_reg: 0.0046 (0.0183)  time: 0.6462  data: 0.0305  max mem: 4959
# Epoch: [3] Total time: 0:01:01 (0.6651 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:16  model_time: 0.2902 (0.2902)  evaluator_time: 0.0612 (0.0612)  time: 0.8460  data: 0.4565  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2559 (0.2550)  evaluator_time: 0.0531 (0.0794)  time: 0.4145  data: 0.0515  max mem: 4959
# Test: Total time: 0:00:07 (0.4163 s / it)
# Averaged stats: model_time: 0.2559 (0.2550)  evaluator_time: 0.0531 (0.0794)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.634
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.265
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.335
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.063
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.409
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.264
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.555
# Epoch: [4]  [ 0/92]  eta: 0:03:18  lr: 0.000500  loss: 0.0582 (0.0582)  loss_classifier: 0.0184 (0.0184)  loss_box_reg: 0.0387 (0.0387)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0006)  time: 2.1546  data: 1.4531  max mem: 4959
# Epoch: [4]  [10/92]  eta: 0:01:04  lr: 0.000500  loss: 0.2282 (0.2680)  loss_classifier: 0.0750 (0.0737)  loss_box_reg: 0.1261 (0.1640)  loss_objectness: 0.0074 (0.0087)  loss_rpn_box_reg: 0.0213 (0.0216)  time: 0.7908  data: 0.1638  max mem: 4959
# Epoch: [4]  [20/92]  eta: 0:00:52  lr: 0.000500  loss: 0.2097 (0.2570)  loss_classifier: 0.0550 (0.0703)  loss_box_reg: 0.1261 (0.1588)  loss_objectness: 0.0063 (0.0072)  loss_rpn_box_reg: 0.0067 (0.0206)  time: 0.6514  data: 0.0330  max mem: 4959
# Epoch: [4]  [30/92]  eta: 0:00:43  lr: 0.000500  loss: 0.1824 (0.2453)  loss_classifier: 0.0519 (0.0661)  loss_box_reg: 0.1190 (0.1504)  loss_objectness: 0.0033 (0.0111)  loss_rpn_box_reg: 0.0051 (0.0177)  time: 0.6517  data: 0.0313  max mem: 4959
# Epoch: [4]  [40/92]  eta: 0:00:35  lr: 0.000500  loss: 0.2031 (0.2486)  loss_classifier: 0.0519 (0.0661)  loss_box_reg: 0.1267 (0.1529)  loss_objectness: 0.0029 (0.0095)  loss_rpn_box_reg: 0.0052 (0.0201)  time: 0.6510  data: 0.0322  max mem: 4959
# Epoch: [4]  [50/92]  eta: 0:00:28  lr: 0.000500  loss: 0.2069 (0.2473)  loss_classifier: 0.0492 (0.0650)  loss_box_reg: 0.1321 (0.1522)  loss_objectness: 0.0020 (0.0097)  loss_rpn_box_reg: 0.0053 (0.0203)  time: 0.6481  data: 0.0323  max mem: 4959
# Epoch: [4]  [60/92]  eta: 0:00:21  lr: 0.000500  loss: 0.2594 (0.2556)  loss_classifier: 0.0689 (0.0675)  loss_box_reg: 0.1864 (0.1591)  loss_objectness: 0.0026 (0.0098)  loss_rpn_box_reg: 0.0113 (0.0192)  time: 0.6492  data: 0.0318  max mem: 4959
# Epoch: [4]  [70/92]  eta: 0:00:14  lr: 0.000500  loss: 0.2726 (0.2522)  loss_classifier: 0.0716 (0.0669)  loss_box_reg: 0.1748 (0.1585)  loss_objectness: 0.0046 (0.0089)  loss_rpn_box_reg: 0.0063 (0.0179)  time: 0.6511  data: 0.0322  max mem: 4959
# Epoch: [4]  [80/92]  eta: 0:00:08  lr: 0.000500  loss: 0.1975 (0.2507)  loss_classifier: 0.0525 (0.0669)  loss_box_reg: 0.1449 (0.1582)  loss_objectness: 0.0028 (0.0083)  loss_rpn_box_reg: 0.0049 (0.0173)  time: 0.6529  data: 0.0341  max mem: 4959
# Epoch: [4]  [90/92]  eta: 0:00:01  lr: 0.000500  loss: 0.2173 (0.2497)  loss_classifier: 0.0634 (0.0670)  loss_box_reg: 0.1486 (0.1580)  loss_objectness: 0.0034 (0.0079)  loss_rpn_box_reg: 0.0098 (0.0167)  time: 0.6470  data: 0.0331  max mem: 4959
# Epoch: [4]  [91/92]  eta: 0:00:00  lr: 0.000500  loss: 0.2173 (0.2505)  loss_classifier: 0.0635 (0.0673)  loss_box_reg: 0.1486 (0.1585)  loss_objectness: 0.0034 (0.0079)  loss_rpn_box_reg: 0.0103 (0.0168)  time: 0.6469  data: 0.0330  max mem: 4959
# Epoch: [4] Total time: 0:01:01 (0.6668 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2658 (0.2658)  evaluator_time: 0.0465 (0.0465)  time: 0.9454  data: 0.5328  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2558 (0.2536)  evaluator_time: 0.0488 (0.0762)  time: 0.4157  data: 0.0541  max mem: 4959
# Test: Total time: 0:00:07 (0.4179 s / it)
# Averaged stats: model_time: 0.2558 (0.2536)  evaluator_time: 0.0488 (0.0762)
# Accumulating evaluation results...
# DONE (t=0.09s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.639
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.251
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.334
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.502
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.409
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.262
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.441
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554
# Epoch: [5]  [ 0/92]  eta: 0:03:14  lr: 0.000500  loss: 0.1541 (0.1541)  loss_classifier: 0.0399 (0.0399)  loss_box_reg: 0.1119 (0.1119)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0019 (0.0019)  time: 2.1167  data: 1.4469  max mem: 4959
# Epoch: [5]  [10/92]  eta: 0:01:04  lr: 0.000500  loss: 0.2561 (0.2793)  loss_classifier: 0.0755 (0.0757)  loss_box_reg: 0.1405 (0.1715)  loss_objectness: 0.0077 (0.0097)  loss_rpn_box_reg: 0.0150 (0.0224)  time: 0.7926  data: 0.1637  max mem: 4959
# Epoch: [5]  [20/92]  eta: 0:00:52  lr: 0.000500  loss: 0.2090 (0.2694)  loss_classifier: 0.0619 (0.0715)  loss_box_reg: 0.1326 (0.1656)  loss_objectness: 0.0053 (0.0084)  loss_rpn_box_reg: 0.0148 (0.0239)  time: 0.6587  data: 0.0351  max mem: 4959
# Epoch: [5]  [30/92]  eta: 0:00:43  lr: 0.000500  loss: 0.2193 (0.2576)  loss_classifier: 0.0611 (0.0694)  loss_box_reg: 0.1468 (0.1610)  loss_objectness: 0.0026 (0.0069)  loss_rpn_box_reg: 0.0063 (0.0203)  time: 0.6522  data: 0.0341  max mem: 4959
# Epoch: [5]  [40/92]  eta: 0:00:35  lr: 0.000500  loss: 0.2260 (0.2498)  loss_classifier: 0.0612 (0.0678)  loss_box_reg: 0.1475 (0.1578)  loss_objectness: 0.0024 (0.0062)  loss_rpn_box_reg: 0.0061 (0.0180)  time: 0.6463  data: 0.0329  max mem: 4959
# Epoch: [5]  [50/92]  eta: 0:00:28  lr: 0.000500  loss: 0.2134 (0.2422)  loss_classifier: 0.0522 (0.0650)  loss_box_reg: 0.1413 (0.1552)  loss_objectness: 0.0024 (0.0057)  loss_rpn_box_reg: 0.0040 (0.0164)  time: 0.6465  data: 0.0336  max mem: 4959
# Epoch: [5]  [60/92]  eta: 0:00:21  lr: 0.000500  loss: 0.2134 (0.2439)  loss_classifier: 0.0530 (0.0649)  loss_box_reg: 0.1536 (0.1566)  loss_objectness: 0.0027 (0.0055)  loss_rpn_box_reg: 0.0059 (0.0168)  time: 0.6495  data: 0.0347  max mem: 4959
# Epoch: [5]  [70/92]  eta: 0:00:14  lr: 0.000500  loss: 0.2218 (0.2462)  loss_classifier: 0.0595 (0.0655)  loss_box_reg: 0.1536 (0.1570)  loss_objectness: 0.0050 (0.0069)  loss_rpn_box_reg: 0.0094 (0.0168)  time: 0.6528  data: 0.0339  max mem: 4959
# Epoch: [5]  [80/92]  eta: 0:00:08  lr: 0.000500  loss: 0.2251 (0.2438)  loss_classifier: 0.0595 (0.0649)  loss_box_reg: 0.1405 (0.1555)  loss_objectness: 0.0044 (0.0067)  loss_rpn_box_reg: 0.0068 (0.0167)  time: 0.6508  data: 0.0322  max mem: 4959
# Epoch: [5]  [90/92]  eta: 0:00:01  lr: 0.000500  loss: 0.2188 (0.2437)  loss_classifier: 0.0494 (0.0650)  loss_box_reg: 0.1405 (0.1557)  loss_objectness: 0.0021 (0.0065)  loss_rpn_box_reg: 0.0054 (0.0164)  time: 0.6420  data: 0.0299  max mem: 4959
# Epoch: [5]  [91/92]  eta: 0:00:00  lr: 0.000500  loss: 0.2188 (0.2429)  loss_classifier: 0.0494 (0.0647)  loss_box_reg: 0.1405 (0.1554)  loss_objectness: 0.0021 (0.0065)  loss_rpn_box_reg: 0.0054 (0.0163)  time: 0.6420  data: 0.0301  max mem: 4959
# Epoch: [5] Total time: 0:01:01 (0.6662 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:16  model_time: 0.2736 (0.2736)  evaluator_time: 0.0920 (0.0920)  time: 0.8574  data: 0.4524  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2559 (0.2544)  evaluator_time: 0.0686 (0.0857)  time: 0.4182  data: 0.0500  max mem: 4959
# Test: Total time: 0:00:07 (0.4201 s / it)
# Averaged stats: model_time: 0.2559 (0.2544)  evaluator_time: 0.0686 (0.0857)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.260
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.104
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.339
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.499
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.264
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.445
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.556
# Epoch: [6]  [ 0/92]  eta: 0:03:25  lr: 0.000050  loss: 0.4242 (0.4242)  loss_classifier: 0.1181 (0.1181)  loss_box_reg: 0.2864 (0.2864)  loss_objectness: 0.0093 (0.0093)  loss_rpn_box_reg: 0.0104 (0.0104)  time: 2.2284  data: 1.4895  max mem: 4959
# Epoch: [6]  [10/92]  eta: 0:01:06  lr: 0.000050  loss: 0.1732 (0.2507)  loss_classifier: 0.0509 (0.0753)  loss_box_reg: 0.1226 (0.1570)  loss_objectness: 0.0029 (0.0047)  loss_rpn_box_reg: 0.0063 (0.0137)  time: 0.8066  data: 0.1669  max mem: 4959
# Epoch: [6]  [20/92]  eta: 0:00:53  lr: 0.000050  loss: 0.1732 (0.2435)  loss_classifier: 0.0479 (0.0673)  loss_box_reg: 0.1226 (0.1524)  loss_objectness: 0.0020 (0.0050)  loss_rpn_box_reg: 0.0047 (0.0187)  time: 0.6619  data: 0.0361  max mem: 4959
# Epoch: [6]  [30/92]  eta: 0:00:44  lr: 0.000050  loss: 0.2120 (0.2474)  loss_classifier: 0.0522 (0.0682)  loss_box_reg: 0.1424 (0.1544)  loss_objectness: 0.0026 (0.0054)  loss_rpn_box_reg: 0.0055 (0.0193)  time: 0.6573  data: 0.0355  max mem: 4959
# Epoch: [6]  [40/92]  eta: 0:00:36  lr: 0.000050  loss: 0.2155 (0.2353)  loss_classifier: 0.0576 (0.0645)  loss_box_reg: 0.1349 (0.1489)  loss_objectness: 0.0025 (0.0049)  loss_rpn_box_reg: 0.0071 (0.0169)  time: 0.6525  data: 0.0336  max mem: 4959
# Epoch: [6]  [50/92]  eta: 0:00:28  lr: 0.000050  loss: 0.1743 (0.2236)  loss_classifier: 0.0446 (0.0613)  loss_box_reg: 0.1190 (0.1419)  loss_objectness: 0.0012 (0.0047)  loss_rpn_box_reg: 0.0037 (0.0156)  time: 0.6513  data: 0.0335  max mem: 4959
# Epoch: [6]  [60/92]  eta: 0:00:21  lr: 0.000050  loss: 0.1663 (0.2245)  loss_classifier: 0.0391 (0.0616)  loss_box_reg: 0.1190 (0.1425)  loss_objectness: 0.0032 (0.0050)  loss_rpn_box_reg: 0.0043 (0.0154)  time: 0.6501  data: 0.0331  max mem: 4959
# Epoch: [6]  [70/92]  eta: 0:00:14  lr: 0.000050  loss: 0.2840 (0.2353)  loss_classifier: 0.0725 (0.0648)  loss_box_reg: 0.1752 (0.1481)  loss_objectness: 0.0051 (0.0053)  loss_rpn_box_reg: 0.0088 (0.0171)  time: 0.6486  data: 0.0333  max mem: 4959
# Epoch: [6]  [80/92]  eta: 0:00:08  lr: 0.000050  loss: 0.2385 (0.2332)  loss_classifier: 0.0611 (0.0637)  loss_box_reg: 0.1629 (0.1482)  loss_objectness: 0.0037 (0.0051)  loss_rpn_box_reg: 0.0083 (0.0162)  time: 0.6515  data: 0.0336  max mem: 4959
# Epoch: [6]  [90/92]  eta: 0:00:01  lr: 0.000050  loss: 0.2385 (0.2364)  loss_classifier: 0.0611 (0.0644)  loss_box_reg: 0.1629 (0.1511)  loss_objectness: 0.0037 (0.0051)  loss_rpn_box_reg: 0.0055 (0.0157)  time: 0.6446  data: 0.0312  max mem: 4959
# Epoch: [6]  [91/92]  eta: 0:00:00  lr: 0.000050  loss: 0.2266 (0.2348)  loss_classifier: 0.0582 (0.0640)  loss_box_reg: 0.1626 (0.1501)  loss_objectness: 0.0031 (0.0051)  loss_rpn_box_reg: 0.0054 (0.0155)  time: 0.6430  data: 0.0308  max mem: 4959
# Epoch: [6] Total time: 0:01:01 (0.6695 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2693 (0.2693)  evaluator_time: 0.0535 (0.0535)  time: 0.9382  data: 0.5289  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2557 (0.2534)  evaluator_time: 0.0535 (0.0837)  time: 0.4233  data: 0.0549  max mem: 4959
# Test: Total time: 0:00:08 (0.4252 s / it)
# Averaged stats: model_time: 0.2557 (0.2534)  evaluator_time: 0.0535 (0.0837)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.307
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.263
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.340
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.441
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
# Epoch: [7]  [ 0/92]  eta: 0:03:15  lr: 0.000050  loss: 0.4376 (0.4376)  loss_classifier: 0.1123 (0.1123)  loss_box_reg: 0.2844 (0.2844)  loss_objectness: 0.0093 (0.0093)  loss_rpn_box_reg: 0.0316 (0.0316)  time: 2.1269  data: 1.4368  max mem: 4959
# Epoch: [7]  [10/92]  eta: 0:01:04  lr: 0.000050  loss: 0.2293 (0.2544)  loss_classifier: 0.0637 (0.0697)  loss_box_reg: 0.1670 (0.1652)  loss_objectness: 0.0033 (0.0052)  loss_rpn_box_reg: 0.0084 (0.0144)  time: 0.7872  data: 0.1591  max mem: 4959
# Epoch: [7]  [20/92]  eta: 0:00:51  lr: 0.000050  loss: 0.1809 (0.2215)  loss_classifier: 0.0486 (0.0600)  loss_box_reg: 0.1212 (0.1425)  loss_objectness: 0.0031 (0.0064)  loss_rpn_box_reg: 0.0063 (0.0126)  time: 0.6498  data: 0.0319  max mem: 4959
# Epoch: [7]  [30/92]  eta: 0:00:43  lr: 0.000050  loss: 0.1691 (0.2277)  loss_classifier: 0.0433 (0.0619)  loss_box_reg: 0.1163 (0.1472)  loss_objectness: 0.0030 (0.0057)  loss_rpn_box_reg: 0.0033 (0.0130)  time: 0.6464  data: 0.0323  max mem: 4959
# Epoch: [7]  [40/92]  eta: 0:00:35  lr: 0.000050  loss: 0.2143 (0.2284)  loss_classifier: 0.0656 (0.0630)  loss_box_reg: 0.1385 (0.1472)  loss_objectness: 0.0040 (0.0057)  loss_rpn_box_reg: 0.0075 (0.0125)  time: 0.6509  data: 0.0330  max mem: 4959
# Epoch: [7]  [50/92]  eta: 0:00:28  lr: 0.000050  loss: 0.2011 (0.2357)  loss_classifier: 0.0582 (0.0651)  loss_box_reg: 0.1420 (0.1509)  loss_objectness: 0.0043 (0.0060)  loss_rpn_box_reg: 0.0081 (0.0137)  time: 0.6514  data: 0.0326  max mem: 4959
# Epoch: [7]  [60/92]  eta: 0:00:21  lr: 0.000050  loss: 0.2024 (0.2353)  loss_classifier: 0.0539 (0.0651)  loss_box_reg: 0.1438 (0.1507)  loss_objectness: 0.0015 (0.0056)  loss_rpn_box_reg: 0.0040 (0.0138)  time: 0.6478  data: 0.0321  max mem: 4959
# Epoch: [7]  [70/92]  eta: 0:00:14  lr: 0.000050  loss: 0.2066 (0.2385)  loss_classifier: 0.0569 (0.0654)  loss_box_reg: 0.1435 (0.1536)  loss_objectness: 0.0039 (0.0056)  loss_rpn_box_reg: 0.0076 (0.0139)  time: 0.6477  data: 0.0327  max mem: 4959
# Epoch: [7]  [80/92]  eta: 0:00:08  lr: 0.000050  loss: 0.2187 (0.2478)  loss_classifier: 0.0604 (0.0669)  loss_box_reg: 0.1544 (0.1584)  loss_objectness: 0.0049 (0.0058)  loss_rpn_box_reg: 0.0077 (0.0168)  time: 0.6486  data: 0.0328  max mem: 4959
# Epoch: [7]  [90/92]  eta: 0:00:01  lr: 0.000050  loss: 0.1728 (0.2383)  loss_classifier: 0.0476 (0.0643)  loss_box_reg: 0.1172 (0.1534)  loss_objectness: 0.0011 (0.0053)  loss_rpn_box_reg: 0.0046 (0.0154)  time: 0.6459  data: 0.0314  max mem: 4959
# Epoch: [7]  [91/92]  eta: 0:00:00  lr: 0.000050  loss: 0.1728 (0.2389)  loss_classifier: 0.0476 (0.0644)  loss_box_reg: 0.1172 (0.1535)  loss_objectness: 0.0011 (0.0053)  loss_rpn_box_reg: 0.0046 (0.0157)  time: 0.6449  data: 0.0308  max mem: 4959
# Epoch: [7] Total time: 0:01:01 (0.6648 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:19  model_time: 0.2706 (0.2706)  evaluator_time: 0.0498 (0.0498)  time: 1.0076  data: 0.6212  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2560 (0.2539)  evaluator_time: 0.0504 (0.0807)  time: 0.4270  data: 0.0605  max mem: 4959
# Test: Total time: 0:00:08 (0.4289 s / it)
# Averaged stats: model_time: 0.2560 (0.2539)  evaluator_time: 0.0504 (0.0807)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.310
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.639
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.262
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.502
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.310
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.443
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.555
# Epoch: [8]  [ 0/92]  eta: 0:03:01  lr: 0.000050  loss: 0.1131 (0.1131)  loss_classifier: 0.0341 (0.0341)  loss_box_reg: 0.0759 (0.0759)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0027 (0.0027)  time: 1.9724  data: 1.3312  max mem: 4959
# Epoch: [8]  [10/92]  eta: 0:01:03  lr: 0.000050  loss: 0.1626 (0.1911)  loss_classifier: 0.0480 (0.0543)  loss_box_reg: 0.1092 (0.1255)  loss_objectness: 0.0041 (0.0045)  loss_rpn_box_reg: 0.0038 (0.0068)  time: 0.7684  data: 0.1515  max mem: 4959
# Epoch: [8]  [20/92]  eta: 0:00:51  lr: 0.000050  loss: 0.1906 (0.2141)  loss_classifier: 0.0483 (0.0590)  loss_box_reg: 0.1230 (0.1380)  loss_objectness: 0.0041 (0.0047)  loss_rpn_box_reg: 0.0074 (0.0124)  time: 0.6493  data: 0.0334  max mem: 4959
# Epoch: [8]  [30/92]  eta: 0:00:43  lr: 0.000050  loss: 0.1906 (0.2245)  loss_classifier: 0.0483 (0.0608)  loss_box_reg: 0.1306 (0.1436)  loss_objectness: 0.0047 (0.0066)  loss_rpn_box_reg: 0.0085 (0.0135)  time: 0.6530  data: 0.0350  max mem: 4959
# Epoch: [8]  [40/92]  eta: 0:00:35  lr: 0.000050  loss: 0.1624 (0.2203)  loss_classifier: 0.0498 (0.0599)  loss_box_reg: 0.1170 (0.1409)  loss_objectness: 0.0027 (0.0059)  loss_rpn_box_reg: 0.0057 (0.0136)  time: 0.6542  data: 0.0355  max mem: 4959
# Epoch: [8]  [50/92]  eta: 0:00:28  lr: 0.000050  loss: 0.1624 (0.2322)  loss_classifier: 0.0499 (0.0634)  loss_box_reg: 0.1148 (0.1480)  loss_objectness: 0.0024 (0.0056)  loss_rpn_box_reg: 0.0037 (0.0152)  time: 0.6475  data: 0.0325  max mem: 4959
# Epoch: [8]  [60/92]  eta: 0:00:21  lr: 0.000050  loss: 0.1746 (0.2239)  loss_classifier: 0.0439 (0.0607)  loss_box_reg: 0.1230 (0.1438)  loss_objectness: 0.0028 (0.0053)  loss_rpn_box_reg: 0.0044 (0.0141)  time: 0.6413  data: 0.0305  max mem: 4959
# Epoch: [8]  [70/92]  eta: 0:00:14  lr: 0.000050  loss: 0.1960 (0.2336)  loss_classifier: 0.0503 (0.0619)  loss_box_reg: 0.1301 (0.1488)  loss_objectness: 0.0039 (0.0080)  loss_rpn_box_reg: 0.0053 (0.0149)  time: 0.6428  data: 0.0319  max mem: 4959
# Epoch: [8]  [80/92]  eta: 0:00:07  lr: 0.000050  loss: 0.2735 (0.2392)  loss_classifier: 0.0676 (0.0636)  loss_box_reg: 0.1690 (0.1530)  loss_objectness: 0.0065 (0.0078)  loss_rpn_box_reg: 0.0112 (0.0148)  time: 0.6497  data: 0.0340  max mem: 4959
# Epoch: [8]  [90/92]  eta: 0:00:01  lr: 0.000050  loss: 0.2330 (0.2398)  loss_classifier: 0.0676 (0.0641)  loss_box_reg: 0.1560 (0.1533)  loss_objectness: 0.0039 (0.0074)  loss_rpn_box_reg: 0.0059 (0.0149)  time: 0.6463  data: 0.0315  max mem: 4959
# Epoch: [8]  [91/92]  eta: 0:00:00  lr: 0.000050  loss: 0.2138 (0.2390)  loss_classifier: 0.0676 (0.0640)  loss_box_reg: 0.1464 (0.1528)  loss_objectness: 0.0039 (0.0074)  loss_rpn_box_reg: 0.0051 (0.0148)  time: 0.6447  data: 0.0310  max mem: 4959
# Epoch: [8] Total time: 0:01:00 (0.6622 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2625 (0.2625)  evaluator_time: 0.0528 (0.0528)  time: 0.9298  data: 0.5584  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2560 (0.2539)  evaluator_time: 0.0518 (0.0771)  time: 0.4165  data: 0.0562  max mem: 4959
# Test: Total time: 0:00:07 (0.4184 s / it)
# Averaged stats: model_time: 0.2560 (0.2539)  evaluator_time: 0.0518 (0.0771)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.310
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.264
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.104
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.343
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.411
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.270
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.557
# Epoch: [9]  [ 0/92]  eta: 0:03:15  lr: 0.000005  loss: 0.1877 (0.1877)  loss_classifier: 0.0557 (0.0557)  loss_box_reg: 0.1242 (0.1242)  loss_objectness: 0.0058 (0.0058)  loss_rpn_box_reg: 0.0019 (0.0019)  time: 2.1301  data: 1.4577  max mem: 4959
# Epoch: [9]  [10/92]  eta: 0:01:04  lr: 0.000005  loss: 0.1997 (0.2160)  loss_classifier: 0.0542 (0.0538)  loss_box_reg: 0.1447 (0.1477)  loss_objectness: 0.0023 (0.0051)  loss_rpn_box_reg: 0.0043 (0.0094)  time: 0.7889  data: 0.1623  max mem: 4959
# Epoch: [9]  [20/92]  eta: 0:00:51  lr: 0.000005  loss: 0.1721 (0.2035)  loss_classifier: 0.0473 (0.0522)  loss_box_reg: 0.1243 (0.1360)  loss_objectness: 0.0018 (0.0045)  loss_rpn_box_reg: 0.0043 (0.0109)  time: 0.6509  data: 0.0324  max mem: 4959
# Epoch: [9]  [30/92]  eta: 0:00:43  lr: 0.000005  loss: 0.2174 (0.2205)  loss_classifier: 0.0585 (0.0568)  loss_box_reg: 0.1487 (0.1441)  loss_objectness: 0.0034 (0.0055)  loss_rpn_box_reg: 0.0057 (0.0141)  time: 0.6488  data: 0.0320  max mem: 4959
# Epoch: [9]  [40/92]  eta: 0:00:35  lr: 0.000005  loss: 0.2233 (0.2297)  loss_classifier: 0.0641 (0.0610)  loss_box_reg: 0.1617 (0.1491)  loss_objectness: 0.0030 (0.0053)  loss_rpn_box_reg: 0.0057 (0.0143)  time: 0.6490  data: 0.0318  max mem: 4959
# Epoch: [9]  [50/92]  eta: 0:00:28  lr: 0.000005  loss: 0.1704 (0.2194)  loss_classifier: 0.0508 (0.0588)  loss_box_reg: 0.1099 (0.1431)  loss_objectness: 0.0015 (0.0047)  loss_rpn_box_reg: 0.0040 (0.0129)  time: 0.6495  data: 0.0326  max mem: 4959
# Epoch: [9]  [60/92]  eta: 0:00:21  lr: 0.000005  loss: 0.1789 (0.2229)  loss_classifier: 0.0505 (0.0593)  loss_box_reg: 0.1279 (0.1449)  loss_objectness: 0.0016 (0.0051)  loss_rpn_box_reg: 0.0050 (0.0135)  time: 0.6513  data: 0.0326  max mem: 4959
# Epoch: [9]  [70/92]  eta: 0:00:14  lr: 0.000005  loss: 0.2410 (0.2305)  loss_classifier: 0.0676 (0.0612)  loss_box_reg: 0.1665 (0.1498)  loss_objectness: 0.0044 (0.0052)  loss_rpn_box_reg: 0.0076 (0.0144)  time: 0.6497  data: 0.0311  max mem: 4959
# Epoch: [9]  [80/92]  eta: 0:00:08  lr: 0.000005  loss: 0.2524 (0.2352)  loss_classifier: 0.0742 (0.0630)  loss_box_reg: 0.1695 (0.1520)  loss_objectness: 0.0044 (0.0053)  loss_rpn_box_reg: 0.0068 (0.0149)  time: 0.6501  data: 0.0322  max mem: 4959
# Epoch: [9]  [90/92]  eta: 0:00:01  lr: 0.000005  loss: 0.2382 (0.2375)  loss_classifier: 0.0574 (0.0634)  loss_box_reg: 0.1510 (0.1529)  loss_objectness: 0.0041 (0.0053)  loss_rpn_box_reg: 0.0068 (0.0159)  time: 0.6432  data: 0.0308  max mem: 4959
# Epoch: [9]  [91/92]  eta: 0:00:00  lr: 0.000005  loss: 0.2382 (0.2360)  loss_classifier: 0.0574 (0.0630)  loss_box_reg: 0.1510 (0.1519)  loss_objectness: 0.0044 (0.0053)  loss_rpn_box_reg: 0.0068 (0.0157)  time: 0.6407  data: 0.0305  max mem: 4959
# Epoch: [9] Total time: 0:01:01 (0.6650 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:16  model_time: 0.2683 (0.2683)  evaluator_time: 0.0484 (0.0484)  time: 0.8703  data: 0.5142  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2553 (0.2534)  evaluator_time: 0.0484 (0.0766)  time: 0.4121  data: 0.0535  max mem: 4959
# Test: Total time: 0:00:07 (0.4138 s / it)
# Averaged stats: model_time: 0.2553 (0.2534)  evaluator_time: 0.0484 (0.0766)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.310
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.636
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.262
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.105
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.502
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.310
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.414
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.279
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.557
