# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Download TorchVision repo to use some files from
# references/detection
# !pip install pycocotools --quiet
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 531472, done.
# remote: Counting objects: 100% (45082/45082), done.
# remote: Compressing objects: 100% (2074/2074), done.
# remote: Total 531472 (delta 43039), reused 44915 (delta 42935), pack-reused 486390
# Receiving objects: 100% (531472/531472), 1.00 GiB | 43.70 MiB/s, done.
# Resolving deltas: 100% (496283/496283), done.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
# defining the files directory and testing directory
train_dir = '/kaggle/input/pedestriansyntheticdataset/train/train'
test_dir = '/kaggle/input/pedestriansyntheticdataset/test/test'

# %%
class ImagesDataset(torch.utils.data.Dataset):

    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
        
        # sorting the images for consistency
        # To get images, the extension of the filename is checked to be jpg
       # self.imgs = [image for image in sorted(os.listdir(files_dir))
                       # if image[-4:]=='.jpg']
        
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        
        
        
        # classes: 0 index is reserved for background
        self.classes = ['background','pedestrian']

    def __getitem__(self, idx):

        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # reading the images and converting them to correct size and color    
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        # diving by 255
        img_res /= 255.0
        
        # annotation file
        annot_filename = img_name[:-4] + '.xml'
        annot_file_path = os.path.join(self.files_dir, annot_filename)
        
        boxes = []
        labels = []
        tree = et.parse(annot_file_path)
        root = tree.getroot()
        
        # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        
        # box coordinates for xml files are extracted and corrected for image size given
        for member in root.findall('object'):
            label_text = member.find('name').text.lower()
            if label_text in ['ped', 'pedestrian']:
                labels.append(self.classes.index('pedestrian')) 
            
            # bounding box
            xmin = int(member.find('bndbox').find('xmin').text)
            xmax = int(member.find('bndbox').find('xmax').text)
            
            ymin = int(member.find('bndbox').find('ymin').text)
            ymax = int(member.find('bndbox').find('ymax').text)
            
            
            xmin_corr = (xmin/wt)*self.width
            xmax_corr = (xmax/wt)*self.width
            ymin_corr = (ymin/ht)*self.height
            ymax_corr = (ymax/ht)*self.height
            
            boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
        
        # convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        # getting the areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
        
        labels = torch.as_tensor(labels, dtype=torch.int64)


        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        # image_id
        image_id = idx
        target["image_id"] = image_id
        
  


        if self.transforms:
            
            sample = self.transforms(image = img_res,
                                     bboxes = target['boxes'],
                                     labels = labels)
            
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
            
            
            
        return img_res, target

    def __len__(self):
        return len(self.imgs)

# %%
def get_object_detection_model(num_classes):

    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 

    return model

# %%
# Send train=True fro training transforms and False for val/test transforms
def get_transform(train):
    
    if train:
        return A.Compose([
            A.HorizontalFlip(0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
            A.Rotate(limit=15, p=0.5),
            ToTensorV2(p=1.0)
        ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']))
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
# use our dataset and defined transformations
train_dataset = ImagesDataset(train_dir, 1920, 1080, transforms= get_transform(train=True))
test_dataset = ImagesDataset(test_dir, 1920, 1080, transforms= get_transform(train=False))

# define training and validation data loaders
data_loader_train= torch.utils.data.DataLoader(
    train_dataset, batch_size=4, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    test_dataset, batch_size=4, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')


num_classes = 2

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:01<00:00, 146MB/s]

# %%
# training for 10 epochs
num_epochs = 10

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, data_loader_train, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [ 0/74]  eta: 0:06:23  lr: 0.000073  loss: 0.8322 (0.8322)  loss_classifier: 0.5351 (0.5351)  loss_box_reg: 0.2319 (0.2319)  loss_objectness: 0.0427 (0.0427)  loss_rpn_box_reg: 0.0225 (0.0225)  time: 5.1793  data: 1.7646  max mem: 4799
# Epoch: [0]  [10/74]  eta: 0:01:07  lr: 0.000758  loss: 0.6673 (0.6409)  loss_classifier: 0.3871 (0.3630)  loss_box_reg: 0.2346 (0.2492)  loss_objectness: 0.0117 (0.0154)  loss_rpn_box_reg: 0.0130 (0.0133)  time: 1.0596  data: 0.1884  max mem: 4957
# Epoch: [0]  [20/74]  eta: 0:00:46  lr: 0.001442  loss: 0.5346 (0.5927)  loss_classifier: 0.2199 (0.2919)  loss_box_reg: 0.2795 (0.2775)  loss_objectness: 0.0086 (0.0116)  loss_rpn_box_reg: 0.0089 (0.0116)  time: 0.6469  data: 0.0309  max mem: 4957
# Epoch: [0]  [30/74]  eta: 0:00:34  lr: 0.002126  loss: 0.4578 (0.5331)  loss_classifier: 0.1411 (0.2283)  loss_box_reg: 0.2882 (0.2817)  loss_objectness: 0.0065 (0.0134)  loss_rpn_box_reg: 0.0074 (0.0098)  time: 0.6497  data: 0.0324  max mem: 4959
# Epoch: [0]  [40/74]  eta: 0:00:25  lr: 0.002810  loss: 0.3685 (0.4872)  loss_classifier: 0.0906 (0.1929)  loss_box_reg: 0.2694 (0.2731)  loss_objectness: 0.0080 (0.0123)  loss_rpn_box_reg: 0.0056 (0.0089)  time: 0.6594  data: 0.0339  max mem: 4959
# Epoch: [0]  [50/74]  eta: 0:00:17  lr: 0.003495  loss: 0.3160 (0.4489)  loss_classifier: 0.0775 (0.1687)  loss_box_reg: 0.2445 (0.2610)  loss_objectness: 0.0054 (0.0108)  loss_rpn_box_reg: 0.0054 (0.0084)  time: 0.6565  data: 0.0333  max mem: 4959
# Epoch: [0]  [60/74]  eta: 0:00:10  lr: 0.004179  loss: 0.2483 (0.4199)  loss_classifier: 0.0571 (0.1520)  loss_box_reg: 0.1757 (0.2499)  loss_objectness: 0.0045 (0.0099)  loss_rpn_box_reg: 0.0054 (0.0081)  time: 0.6493  data: 0.0321  max mem: 4959
# Epoch: [0]  [70/74]  eta: 0:00:02  lr: 0.004863  loss: 0.2454 (0.3962)  loss_classifier: 0.0569 (0.1389)  loss_box_reg: 0.1714 (0.2397)  loss_objectness: 0.0046 (0.0094)  loss_rpn_box_reg: 0.0072 (0.0083)  time: 0.6470  data: 0.0299  max mem: 4959
# Epoch: [0]  [73/74]  eta: 0:00:00  lr: 0.005000  loss: 0.2381 (0.3882)  loss_classifier: 0.0559 (0.1353)  loss_box_reg: 0.1689 (0.2357)  loss_objectness: 0.0036 (0.0091)  loss_rpn_box_reg: 0.0058 (0.0081)  time: 0.6273  data: 0.0289  max mem: 4959
# Epoch: [0] Total time: 0:00:52 (0.7070 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:23  model_time: 0.3607 (0.3607)  evaluator_time: 0.0174 (0.0174)  time: 1.2254  data: 0.7873  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2552 (0.2515)  evaluator_time: 0.0056 (0.0070)  time: 0.3604  data: 0.0724  max mem: 4959
# Test: Total time: 0:00:06 (0.3623 s / it)
# Averaged stats: model_time: 0.2552 (0.2515)  evaluator_time: 0.0056 (0.0070)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.938
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.314
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.545
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.612
# Epoch: [1]  [ 0/74]  eta: 0:02:16  lr: 0.005000  loss: 0.1235 (0.1235)  loss_classifier: 0.0290 (0.0290)  loss_box_reg: 0.0857 (0.0857)  loss_objectness: 0.0049 (0.0049)  loss_rpn_box_reg: 0.0039 (0.0039)  time: 1.8456  data: 1.1464  max mem: 4959
# Epoch: [1]  [10/74]  eta: 0:00:48  lr: 0.005000  loss: 0.1844 (0.1715)  loss_classifier: 0.0439 (0.0422)  loss_box_reg: 0.1297 (0.1230)  loss_objectness: 0.0011 (0.0020)  loss_rpn_box_reg: 0.0044 (0.0043)  time: 0.7637  data: 0.1350  max mem: 4959
# Epoch: [1]  [20/74]  eta: 0:00:38  lr: 0.005000  loss: 0.1844 (0.1915)  loss_classifier: 0.0432 (0.0463)  loss_box_reg: 0.1375 (0.1384)  loss_objectness: 0.0010 (0.0019)  loss_rpn_box_reg: 0.0036 (0.0048)  time: 0.6542  data: 0.0345  max mem: 4959
# Epoch: [1]  [30/74]  eta: 0:00:30  lr: 0.005000  loss: 0.2133 (0.2057)  loss_classifier: 0.0523 (0.0496)  loss_box_reg: 0.1610 (0.1493)  loss_objectness: 0.0010 (0.0020)  loss_rpn_box_reg: 0.0039 (0.0048)  time: 0.6533  data: 0.0349  max mem: 4959
# Epoch: [1]  [40/74]  eta: 0:00:23  lr: 0.005000  loss: 0.2565 (0.2106)  loss_classifier: 0.0606 (0.0511)  loss_box_reg: 0.1712 (0.1518)  loss_objectness: 0.0015 (0.0022)  loss_rpn_box_reg: 0.0044 (0.0055)  time: 0.6480  data: 0.0324  max mem: 4959
# Epoch: [1]  [50/74]  eta: 0:00:16  lr: 0.005000  loss: 0.2071 (0.2104)  loss_classifier: 0.0567 (0.0525)  loss_box_reg: 0.1509 (0.1485)  loss_objectness: 0.0029 (0.0036)  loss_rpn_box_reg: 0.0045 (0.0057)  time: 0.6449  data: 0.0311  max mem: 4959
# Epoch: [1]  [60/74]  eta: 0:00:09  lr: 0.005000  loss: 0.2188 (0.2123)  loss_classifier: 0.0577 (0.0535)  loss_box_reg: 0.1509 (0.1496)  loss_objectness: 0.0031 (0.0035)  loss_rpn_box_reg: 0.0047 (0.0057)  time: 0.6495  data: 0.0331  max mem: 4959
# Epoch: [1]  [70/74]  eta: 0:00:02  lr: 0.005000  loss: 0.2253 (0.2184)  loss_classifier: 0.0573 (0.0539)  loss_box_reg: 0.1529 (0.1496)  loss_objectness: 0.0027 (0.0088)  loss_rpn_box_reg: 0.0040 (0.0060)  time: 0.6471  data: 0.0320  max mem: 4959
# Epoch: [1]  [73/74]  eta: 0:00:00  lr: 0.005000  loss: 0.2271 (0.2179)  loss_classifier: 0.0562 (0.0538)  loss_box_reg: 0.1572 (0.1493)  loss_objectness: 0.0027 (0.0087)  loss_rpn_box_reg: 0.0040 (0.0061)  time: 0.6233  data: 0.0309  max mem: 4959
# Epoch: [1] Total time: 0:00:48 (0.6595 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:23  model_time: 0.2904 (0.2904)  evaluator_time: 0.0096 (0.0096)  time: 1.2164  data: 0.8746  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2559 (0.2489)  evaluator_time: 0.0054 (0.0055)  time: 0.3580  data: 0.0744  max mem: 4959
# Test: Total time: 0:00:06 (0.3605 s / it)
# Averaged stats: model_time: 0.2559 (0.2489)  evaluator_time: 0.0054 (0.0055)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.483
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.948
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.425
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.618
# Epoch: [2]  [ 0/74]  eta: 0:02:50  lr: 0.005000  loss: 0.1266 (0.1266)  loss_classifier: 0.0349 (0.0349)  loss_box_reg: 0.0881 (0.0881)  loss_objectness: 0.0019 (0.0019)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 2.3088  data: 1.6230  max mem: 4959
# Epoch: [2]  [10/74]  eta: 0:00:51  lr: 0.005000  loss: 0.1633 (0.1663)  loss_classifier: 0.0419 (0.0418)  loss_box_reg: 0.1113 (0.1163)  loss_objectness: 0.0024 (0.0045)  loss_rpn_box_reg: 0.0039 (0.0037)  time: 0.8094  data: 0.1798  max mem: 4959
# Epoch: [2]  [20/74]  eta: 0:00:39  lr: 0.005000  loss: 0.1630 (0.1696)  loss_classifier: 0.0419 (0.0434)  loss_box_reg: 0.1113 (0.1190)  loss_objectness: 0.0017 (0.0032)  loss_rpn_box_reg: 0.0040 (0.0040)  time: 0.6542  data: 0.0345  max mem: 4959
# Epoch: [2]  [30/74]  eta: 0:00:31  lr: 0.005000  loss: 0.1527 (0.1635)  loss_classifier: 0.0357 (0.0410)  loss_box_reg: 0.1096 (0.1150)  loss_objectness: 0.0012 (0.0035)  loss_rpn_box_reg: 0.0038 (0.0041)  time: 0.6471  data: 0.0324  max mem: 4959
# Epoch: [2]  [40/74]  eta: 0:00:23  lr: 0.005000  loss: 0.1577 (0.1794)  loss_classifier: 0.0473 (0.0455)  loss_box_reg: 0.1202 (0.1257)  loss_objectness: 0.0017 (0.0034)  loss_rpn_box_reg: 0.0050 (0.0048)  time: 0.6443  data: 0.0318  max mem: 4959
# Epoch: [2]  [50/74]  eta: 0:00:16  lr: 0.005000  loss: 0.2133 (0.1789)  loss_classifier: 0.0574 (0.0459)  loss_box_reg: 0.1383 (0.1252)  loss_objectness: 0.0009 (0.0029)  loss_rpn_box_reg: 0.0047 (0.0048)  time: 0.6462  data: 0.0333  max mem: 4959
# Epoch: [2]  [60/74]  eta: 0:00:09  lr: 0.005000  loss: 0.1443 (0.1762)  loss_classifier: 0.0377 (0.0450)  loss_box_reg: 0.1086 (0.1237)  loss_objectness: 0.0012 (0.0028)  loss_rpn_box_reg: 0.0036 (0.0047)  time: 0.6483  data: 0.0332  max mem: 4959
# Epoch: [2]  [70/74]  eta: 0:00:02  lr: 0.005000  loss: 0.1576 (0.1786)  loss_classifier: 0.0378 (0.0454)  loss_box_reg: 0.1142 (0.1254)  loss_objectness: 0.0012 (0.0030)  loss_rpn_box_reg: 0.0039 (0.0048)  time: 0.6449  data: 0.0313  max mem: 4959
# Epoch: [2]  [73/74]  eta: 0:00:00  lr: 0.005000  loss: 0.1636 (0.1775)  loss_classifier: 0.0411 (0.0450)  loss_box_reg: 0.1151 (0.1249)  loss_objectness: 0.0009 (0.0029)  loss_rpn_box_reg: 0.0042 (0.0047)  time: 0.6204  data: 0.0299  max mem: 4959
# Epoch: [2] Total time: 0:00:49 (0.6644 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:23  model_time: 0.2979 (0.2979)  evaluator_time: 0.0095 (0.0095)  time: 1.2504  data: 0.8809  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2561 (0.2492)  evaluator_time: 0.0043 (0.0050)  time: 0.3586  data: 0.0748  max mem: 4959
# Test: Total time: 0:00:06 (0.3605 s / it)
# Averaged stats: model_time: 0.2561 (0.2492)  evaluator_time: 0.0043 (0.0050)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.497
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.952
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.453
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.347
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.573
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.573
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.423
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.649
# Epoch: [3]  [ 0/74]  eta: 0:02:23  lr: 0.000500  loss: 0.1533 (0.1533)  loss_classifier: 0.0417 (0.0417)  loss_box_reg: 0.1067 (0.1067)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0046 (0.0046)  time: 1.9457  data: 1.2882  max mem: 4959
# Epoch: [3]  [10/74]  eta: 0:00:50  lr: 0.000500  loss: 0.1537 (0.1695)  loss_classifier: 0.0417 (0.0437)  loss_box_reg: 0.1067 (0.1197)  loss_objectness: 0.0014 (0.0015)  loss_rpn_box_reg: 0.0047 (0.0046)  time: 0.7904  data: 0.1550  max mem: 4959
# Epoch: [3]  [20/74]  eta: 0:00:39  lr: 0.000500  loss: 0.1959 (0.1847)  loss_classifier: 0.0477 (0.0500)  loss_box_reg: 0.1310 (0.1284)  loss_objectness: 0.0014 (0.0019)  loss_rpn_box_reg: 0.0043 (0.0045)  time: 0.6644  data: 0.0387  max mem: 4959
# Epoch: [3]  [30/74]  eta: 0:00:30  lr: 0.000500  loss: 0.1745 (0.1919)  loss_classifier: 0.0473 (0.0492)  loss_box_reg: 0.1247 (0.1278)  loss_objectness: 0.0008 (0.0101)  loss_rpn_box_reg: 0.0036 (0.0048)  time: 0.6515  data: 0.0342  max mem: 4959
# Epoch: [3]  [40/74]  eta: 0:00:23  lr: 0.000500  loss: 0.1531 (0.1822)  loss_classifier: 0.0408 (0.0468)  loss_box_reg: 0.1086 (0.1230)  loss_objectness: 0.0005 (0.0080)  loss_rpn_box_reg: 0.0032 (0.0045)  time: 0.6479  data: 0.0324  max mem: 4959
# Epoch: [3]  [50/74]  eta: 0:00:16  lr: 0.000500  loss: 0.1364 (0.1761)  loss_classifier: 0.0360 (0.0456)  loss_box_reg: 0.1003 (0.1192)  loss_objectness: 0.0007 (0.0070)  loss_rpn_box_reg: 0.0026 (0.0043)  time: 0.6472  data: 0.0318  max mem: 4959
# Epoch: [3]  [60/74]  eta: 0:00:09  lr: 0.000500  loss: 0.1596 (0.1750)  loss_classifier: 0.0437 (0.0451)  loss_box_reg: 0.1101 (0.1198)  loss_objectness: 0.0006 (0.0060)  loss_rpn_box_reg: 0.0026 (0.0042)  time: 0.6509  data: 0.0326  max mem: 4959
# Epoch: [3]  [70/74]  eta: 0:00:02  lr: 0.000500  loss: 0.1644 (0.1728)  loss_classifier: 0.0437 (0.0445)  loss_box_reg: 0.1060 (0.1187)  loss_objectness: 0.0005 (0.0054)  loss_rpn_box_reg: 0.0035 (0.0042)  time: 0.6489  data: 0.0329  max mem: 4959
# Epoch: [3]  [73/74]  eta: 0:00:00  lr: 0.000500  loss: 0.1410 (0.1703)  loss_classifier: 0.0352 (0.0441)  loss_box_reg: 0.1032 (0.1169)  loss_objectness: 0.0005 (0.0052)  loss_rpn_box_reg: 0.0028 (0.0041)  time: 0.6231  data: 0.0313  max mem: 4959
# Epoch: [3] Total time: 0:00:49 (0.6642 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:22  model_time: 0.2945 (0.2945)  evaluator_time: 0.0088 (0.0088)  time: 1.1702  data: 0.7971  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2567 (0.2494)  evaluator_time: 0.0043 (0.0048)  time: 0.3571  data: 0.0718  max mem: 4959
# Test: Total time: 0:00:06 (0.3589 s / it)
# Averaged stats: model_time: 0.2567 (0.2494)  evaluator_time: 0.0043 (0.0048)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.522
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.958
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.382
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.652
# Epoch: [4]  [ 0/74]  eta: 0:02:26  lr: 0.000500  loss: 0.1970 (0.1970)  loss_classifier: 0.0596 (0.0596)  loss_box_reg: 0.1337 (0.1337)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0035 (0.0035)  time: 1.9760  data: 1.2627  max mem: 4959
# Epoch: [4]  [10/74]  eta: 0:00:49  lr: 0.000500  loss: 0.1348 (0.1601)  loss_classifier: 0.0417 (0.0427)  loss_box_reg: 0.1006 (0.1124)  loss_objectness: 0.0005 (0.0012)  loss_rpn_box_reg: 0.0035 (0.0039)  time: 0.7758  data: 0.1450  max mem: 4959
# Epoch: [4]  [20/74]  eta: 0:00:38  lr: 0.000500  loss: 0.1478 (0.1609)  loss_classifier: 0.0391 (0.0429)  loss_box_reg: 0.1099 (0.1133)  loss_objectness: 0.0006 (0.0011)  loss_rpn_box_reg: 0.0035 (0.0036)  time: 0.6509  data: 0.0323  max mem: 4959
# Epoch: [4]  [30/74]  eta: 0:00:30  lr: 0.000500  loss: 0.1584 (0.1619)  loss_classifier: 0.0393 (0.0430)  loss_box_reg: 0.1165 (0.1142)  loss_objectness: 0.0008 (0.0011)  loss_rpn_box_reg: 0.0033 (0.0038)  time: 0.6491  data: 0.0327  max mem: 4959
# Epoch: [4]  [40/74]  eta: 0:00:23  lr: 0.000500  loss: 0.1436 (0.1568)  loss_classifier: 0.0393 (0.0421)  loss_box_reg: 0.1023 (0.1101)  loss_objectness: 0.0005 (0.0011)  loss_rpn_box_reg: 0.0030 (0.0035)  time: 0.6502  data: 0.0335  max mem: 4959
# Epoch: [4]  [50/74]  eta: 0:00:16  lr: 0.000500  loss: 0.1521 (0.1657)  loss_classifier: 0.0411 (0.0444)  loss_box_reg: 0.1032 (0.1163)  loss_objectness: 0.0009 (0.0012)  loss_rpn_box_reg: 0.0031 (0.0038)  time: 0.6479  data: 0.0323  max mem: 4959
# Epoch: [4]  [60/74]  eta: 0:00:09  lr: 0.000500  loss: 0.1425 (0.1611)  loss_classifier: 0.0360 (0.0430)  loss_box_reg: 0.1032 (0.1132)  loss_objectness: 0.0010 (0.0011)  loss_rpn_box_reg: 0.0035 (0.0037)  time: 0.6521  data: 0.0337  max mem: 4959
# Epoch: [4]  [70/74]  eta: 0:00:02  lr: 0.000500  loss: 0.1425 (0.1638)  loss_classifier: 0.0360 (0.0434)  loss_box_reg: 0.1046 (0.1154)  loss_objectness: 0.0010 (0.0013)  loss_rpn_box_reg: 0.0035 (0.0037)  time: 0.6508  data: 0.0330  max mem: 4959
# Epoch: [4]  [73/74]  eta: 0:00:00  lr: 0.000500  loss: 0.1484 (0.1627)  loss_classifier: 0.0360 (0.0432)  loss_box_reg: 0.1057 (0.1146)  loss_objectness: 0.0009 (0.0013)  loss_rpn_box_reg: 0.0029 (0.0036)  time: 0.6253  data: 0.0312  max mem: 4959
# Epoch: [4] Total time: 0:00:48 (0.6620 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:22  model_time: 0.2944 (0.2944)  evaluator_time: 0.0090 (0.0090)  time: 1.1635  data: 0.8017  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2575 (0.2507)  evaluator_time: 0.0044 (0.0051)  time: 0.3622  data: 0.0764  max mem: 4959
# Test: Total time: 0:00:06 (0.3641 s / it)
# Averaged stats: model_time: 0.2575 (0.2507)  evaluator_time: 0.0044 (0.0051)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.529
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.955
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.543
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.370
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.609
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.342
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.667
# Epoch: [5]  [ 0/74]  eta: 0:02:40  lr: 0.000500  loss: 0.2912 (0.2912)  loss_classifier: 0.0644 (0.0644)  loss_box_reg: 0.2109 (0.2109)  loss_objectness: 0.0070 (0.0070)  loss_rpn_box_reg: 0.0089 (0.0089)  time: 2.1628  data: 1.5210  max mem: 4959
# Epoch: [5]  [10/74]  eta: 0:00:50  lr: 0.000500  loss: 0.1908 (0.2036)  loss_classifier: 0.0547 (0.0519)  loss_box_reg: 0.1439 (0.1450)  loss_objectness: 0.0014 (0.0020)  loss_rpn_box_reg: 0.0043 (0.0047)  time: 0.7865  data: 0.1661  max mem: 4959
# Epoch: [5]  [20/74]  eta: 0:00:39  lr: 0.000500  loss: 0.1426 (0.1703)  loss_classifier: 0.0359 (0.0434)  loss_box_reg: 0.0990 (0.1214)  loss_objectness: 0.0007 (0.0017)  loss_rpn_box_reg: 0.0031 (0.0038)  time: 0.6536  data: 0.0330  max mem: 4959
# Epoch: [5]  [30/74]  eta: 0:00:30  lr: 0.000500  loss: 0.1426 (0.1711)  loss_classifier: 0.0381 (0.0435)  loss_box_reg: 0.0990 (0.1226)  loss_objectness: 0.0006 (0.0015)  loss_rpn_box_reg: 0.0030 (0.0037)  time: 0.6538  data: 0.0344  max mem: 4959
# Epoch: [5]  [40/74]  eta: 0:00:23  lr: 0.000500  loss: 0.1561 (0.1714)  loss_classifier: 0.0389 (0.0442)  loss_box_reg: 0.1125 (0.1218)  loss_objectness: 0.0008 (0.0015)  loss_rpn_box_reg: 0.0029 (0.0039)  time: 0.6526  data: 0.0336  max mem: 4959
# Epoch: [5]  [50/74]  eta: 0:00:16  lr: 0.000500  loss: 0.1542 (0.1663)  loss_classifier: 0.0410 (0.0434)  loss_box_reg: 0.1090 (0.1176)  loss_objectness: 0.0009 (0.0015)  loss_rpn_box_reg: 0.0029 (0.0038)  time: 0.6537  data: 0.0333  max mem: 4959
# Epoch: [5]  [60/74]  eta: 0:00:09  lr: 0.000500  loss: 0.1589 (0.1664)  loss_classifier: 0.0433 (0.0437)  loss_box_reg: 0.1130 (0.1173)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0032 (0.0039)  time: 0.6497  data: 0.0326  max mem: 4959
# Epoch: [5]  [70/74]  eta: 0:00:02  lr: 0.000500  loss: 0.1670 (0.1648)  loss_classifier: 0.0421 (0.0432)  loss_box_reg: 0.1134 (0.1163)  loss_objectness: 0.0008 (0.0015)  loss_rpn_box_reg: 0.0035 (0.0039)  time: 0.6477  data: 0.0327  max mem: 4959
# Epoch: [5]  [73/74]  eta: 0:00:00  lr: 0.000500  loss: 0.1676 (0.1652)  loss_classifier: 0.0443 (0.0438)  loss_box_reg: 0.1164 (0.1160)  loss_objectness: 0.0008 (0.0016)  loss_rpn_box_reg: 0.0036 (0.0039)  time: 0.6242  data: 0.0315  max mem: 4959
# Epoch: [5] Total time: 0:00:49 (0.6657 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:22  model_time: 0.2973 (0.2973)  evaluator_time: 0.0104 (0.0104)  time: 1.1944  data: 0.8558  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2573 (0.2495)  evaluator_time: 0.0038 (0.0046)  time: 0.3566  data: 0.0743  max mem: 4959
# Test: Total time: 0:00:06 (0.3585 s / it)
# Averaged stats: model_time: 0.2573 (0.2495)  evaluator_time: 0.0038 (0.0046)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.515
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.952
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.508
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.589
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.583
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.583
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.652
# Epoch: [6]  [ 0/74]  eta: 0:02:51  lr: 0.000050  loss: 0.0934 (0.0934)  loss_classifier: 0.0188 (0.0188)  loss_box_reg: 0.0706 (0.0706)  loss_objectness: 0.0015 (0.0015)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 2.3135  data: 1.6474  max mem: 4959
# Epoch: [6]  [10/74]  eta: 0:00:51  lr: 0.000050  loss: 0.1585 (0.1593)  loss_classifier: 0.0419 (0.0410)  loss_box_reg: 0.1128 (0.1117)  loss_objectness: 0.0015 (0.0023)  loss_rpn_box_reg: 0.0033 (0.0042)  time: 0.8036  data: 0.1781  max mem: 4959
# Epoch: [6]  [20/74]  eta: 0:00:39  lr: 0.000050  loss: 0.1585 (0.1587)  loss_classifier: 0.0419 (0.0409)  loss_box_reg: 0.1128 (0.1122)  loss_objectness: 0.0005 (0.0015)  loss_rpn_box_reg: 0.0033 (0.0041)  time: 0.6540  data: 0.0328  max mem: 4959
# Epoch: [6]  [30/74]  eta: 0:00:31  lr: 0.000050  loss: 0.1491 (0.1539)  loss_classifier: 0.0382 (0.0396)  loss_box_reg: 0.1068 (0.1091)  loss_objectness: 0.0003 (0.0014)  loss_rpn_box_reg: 0.0026 (0.0037)  time: 0.6542  data: 0.0339  max mem: 4959
# Epoch: [6]  [40/74]  eta: 0:00:23  lr: 0.000050  loss: 0.1437 (0.1535)  loss_classifier: 0.0372 (0.0398)  loss_box_reg: 0.1037 (0.1089)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0027 (0.0035)  time: 0.6534  data: 0.0337  max mem: 4959
# Epoch: [6]  [50/74]  eta: 0:00:16  lr: 0.000050  loss: 0.1303 (0.1564)  loss_classifier: 0.0363 (0.0419)  loss_box_reg: 0.0941 (0.1093)  loss_objectness: 0.0004 (0.0017)  loss_rpn_box_reg: 0.0029 (0.0036)  time: 0.6651  data: 0.0353  max mem: 4959
# Epoch: [6]  [60/74]  eta: 0:00:09  lr: 0.000050  loss: 0.1302 (0.1575)  loss_classifier: 0.0391 (0.0427)  loss_box_reg: 0.0884 (0.1097)  loss_objectness: 0.0007 (0.0016)  loss_rpn_box_reg: 0.0026 (0.0035)  time: 0.6634  data: 0.0353  max mem: 4959
# Epoch: [6]  [70/74]  eta: 0:00:02  lr: 0.000050  loss: 0.1337 (0.1571)  loss_classifier: 0.0427 (0.0430)  loss_box_reg: 0.0899 (0.1090)  loss_objectness: 0.0005 (0.0015)  loss_rpn_box_reg: 0.0028 (0.0035)  time: 0.6521  data: 0.0344  max mem: 4959
# Epoch: [6]  [73/74]  eta: 0:00:00  lr: 0.000050  loss: 0.1478 (0.1585)  loss_classifier: 0.0440 (0.0431)  loss_box_reg: 0.0986 (0.1103)  loss_objectness: 0.0004 (0.0015)  loss_rpn_box_reg: 0.0031 (0.0035)  time: 0.6276  data: 0.0335  max mem: 4959
# Epoch: [6] Total time: 0:00:49 (0.6728 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:23  model_time: 0.2899 (0.2899)  evaluator_time: 0.0076 (0.0076)  time: 1.2354  data: 0.8935  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2575 (0.2501)  evaluator_time: 0.0043 (0.0055)  time: 0.3704  data: 0.0825  max mem: 4959
# Test: Total time: 0:00:07 (0.3727 s / it)
# Averaged stats: model_time: 0.2575 (0.2501)  evaluator_time: 0.0043 (0.0055)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.524
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.953
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.534
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.364
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.603
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.587
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.587
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.659
# Epoch: [7]  [ 0/74]  eta: 0:02:30  lr: 0.000050  loss: 0.1185 (0.1185)  loss_classifier: 0.0348 (0.0348)  loss_box_reg: 0.0801 (0.0801)  loss_objectness: 0.0014 (0.0014)  loss_rpn_box_reg: 0.0022 (0.0022)  time: 2.0352  data: 1.3628  max mem: 4959
# Epoch: [7]  [10/74]  eta: 0:00:50  lr: 0.000050  loss: 0.1293 (0.1639)  loss_classifier: 0.0348 (0.0403)  loss_box_reg: 0.0929 (0.1058)  loss_objectness: 0.0004 (0.0123)  loss_rpn_box_reg: 0.0026 (0.0055)  time: 0.7961  data: 0.1642  max mem: 4959
# Epoch: [7]  [20/74]  eta: 0:00:39  lr: 0.000050  loss: 0.1442 (0.1611)  loss_classifier: 0.0387 (0.0411)  loss_box_reg: 0.1029 (0.1088)  loss_objectness: 0.0004 (0.0068)  loss_rpn_box_reg: 0.0027 (0.0044)  time: 0.6675  data: 0.0416  max mem: 4959
# Epoch: [7]  [30/74]  eta: 0:00:31  lr: 0.000050  loss: 0.1532 (0.1661)  loss_classifier: 0.0405 (0.0426)  loss_box_reg: 0.1083 (0.1144)  loss_objectness: 0.0005 (0.0050)  loss_rpn_box_reg: 0.0029 (0.0040)  time: 0.6587  data: 0.0373  max mem: 4959
# Epoch: [7]  [40/74]  eta: 0:00:23  lr: 0.000050  loss: 0.1588 (0.1664)  loss_classifier: 0.0397 (0.0433)  loss_box_reg: 0.1146 (0.1150)  loss_objectness: 0.0008 (0.0040)  loss_rpn_box_reg: 0.0031 (0.0040)  time: 0.6539  data: 0.0342  max mem: 4959
# Epoch: [7]  [50/74]  eta: 0:00:16  lr: 0.000050  loss: 0.1431 (0.1611)  loss_classifier: 0.0397 (0.0429)  loss_box_reg: 0.1006 (0.1111)  loss_objectness: 0.0005 (0.0034)  loss_rpn_box_reg: 0.0027 (0.0037)  time: 0.6573  data: 0.0342  max mem: 4959
# Epoch: [7]  [60/74]  eta: 0:00:09  lr: 0.000050  loss: 0.1295 (0.1580)  loss_classifier: 0.0338 (0.0422)  loss_box_reg: 0.0929 (0.1091)  loss_objectness: 0.0004 (0.0031)  loss_rpn_box_reg: 0.0024 (0.0036)  time: 0.6587  data: 0.0349  max mem: 4959
# Epoch: [7]  [70/74]  eta: 0:00:02  lr: 0.000050  loss: 0.1428 (0.1595)  loss_classifier: 0.0346 (0.0426)  loss_box_reg: 0.0984 (0.1103)  loss_objectness: 0.0005 (0.0029)  loss_rpn_box_reg: 0.0026 (0.0037)  time: 0.6517  data: 0.0339  max mem: 4959
# Epoch: [7]  [73/74]  eta: 0:00:00  lr: 0.000050  loss: 0.1347 (0.1567)  loss_classifier: 0.0338 (0.0419)  loss_box_reg: 0.0981 (0.1084)  loss_objectness: 0.0004 (0.0028)  loss_rpn_box_reg: 0.0023 (0.0036)  time: 0.6281  data: 0.0330  max mem: 4959
# Epoch: [7] Total time: 0:00:49 (0.6705 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:21  model_time: 0.2968 (0.2968)  evaluator_time: 0.0097 (0.0097)  time: 1.1573  data: 0.8024  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2574 (0.2511)  evaluator_time: 0.0041 (0.0052)  time: 0.3608  data: 0.0739  max mem: 4959
# Test: Total time: 0:00:06 (0.3626 s / it)
# Averaged stats: model_time: 0.2574 (0.2511)  evaluator_time: 0.0041 (0.0052)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.523
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.953
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.516
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.371
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.337
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.655
# Epoch: [8]  [ 0/74]  eta: 0:02:33  lr: 0.000050  loss: 0.1932 (0.1932)  loss_classifier: 0.0481 (0.0481)  loss_box_reg: 0.1395 (0.1395)  loss_objectness: 0.0011 (0.0011)  loss_rpn_box_reg: 0.0045 (0.0045)  time: 2.0732  data: 1.3791  max mem: 4959
# Epoch: [8]  [10/74]  eta: 0:00:50  lr: 0.000050  loss: 0.1932 (0.1718)  loss_classifier: 0.0479 (0.0449)  loss_box_reg: 0.1318 (0.1182)  loss_objectness: 0.0008 (0.0042)  loss_rpn_box_reg: 0.0037 (0.0046)  time: 0.7842  data: 0.1547  max mem: 4959
# Epoch: [8]  [20/74]  eta: 0:00:38  lr: 0.000050  loss: 0.1542 (0.1587)  loss_classifier: 0.0393 (0.0414)  loss_box_reg: 0.1039 (0.1109)  loss_objectness: 0.0007 (0.0026)  loss_rpn_box_reg: 0.0029 (0.0038)  time: 0.6500  data: 0.0323  max mem: 4959
# Epoch: [8]  [30/74]  eta: 0:00:30  lr: 0.000050  loss: 0.1588 (0.1682)  loss_classifier: 0.0389 (0.0436)  loss_box_reg: 0.1110 (0.1180)  loss_objectness: 0.0006 (0.0027)  loss_rpn_box_reg: 0.0029 (0.0038)  time: 0.6503  data: 0.0336  max mem: 4959
# Epoch: [8]  [40/74]  eta: 0:00:23  lr: 0.000050  loss: 0.1575 (0.1655)  loss_classifier: 0.0389 (0.0435)  loss_box_reg: 0.1117 (0.1158)  loss_objectness: 0.0008 (0.0025)  loss_rpn_box_reg: 0.0027 (0.0037)  time: 0.6517  data: 0.0344  max mem: 4959
# Epoch: [8]  [50/74]  eta: 0:00:16  lr: 0.000050  loss: 0.1341 (0.1613)  loss_classifier: 0.0389 (0.0429)  loss_box_reg: 0.0922 (0.1127)  loss_objectness: 0.0008 (0.0022)  loss_rpn_box_reg: 0.0023 (0.0036)  time: 0.6480  data: 0.0337  max mem: 4959
# Epoch: [8]  [60/74]  eta: 0:00:09  lr: 0.000050  loss: 0.1329 (0.1579)  loss_classifier: 0.0389 (0.0420)  loss_box_reg: 0.0915 (0.1105)  loss_objectness: 0.0004 (0.0020)  loss_rpn_box_reg: 0.0023 (0.0035)  time: 0.6477  data: 0.0323  max mem: 4959
# Epoch: [8]  [70/74]  eta: 0:00:02  lr: 0.000050  loss: 0.1572 (0.1606)  loss_classifier: 0.0405 (0.0430)  loss_box_reg: 0.1035 (0.1121)  loss_objectness: 0.0011 (0.0019)  loss_rpn_box_reg: 0.0032 (0.0036)  time: 0.6450  data: 0.0313  max mem: 4959
# Epoch: [8]  [73/74]  eta: 0:00:00  lr: 0.000050  loss: 0.1499 (0.1597)  loss_classifier: 0.0405 (0.0427)  loss_box_reg: 0.1023 (0.1116)  loss_objectness: 0.0011 (0.0019)  loss_rpn_box_reg: 0.0029 (0.0035)  time: 0.6219  data: 0.0308  max mem: 4959
# Epoch: [8] Total time: 0:00:49 (0.6624 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:22  model_time: 0.3466 (0.3466)  evaluator_time: 0.0091 (0.0091)  time: 1.1926  data: 0.7725  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2575 (0.2530)  evaluator_time: 0.0038 (0.0047)  time: 0.3599  data: 0.0719  max mem: 4959
# Test: Total time: 0:00:06 (0.3618 s / it)
# Averaged stats: model_time: 0.2575 (0.2530)  evaluator_time: 0.0038 (0.0047)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.527
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.953
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.536
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.370
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.605
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.339
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.592
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.592
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.662
# Epoch: [9]  [ 0/74]  eta: 0:02:25  lr: 0.000005  loss: 0.1698 (0.1698)  loss_classifier: 0.0407 (0.0407)  loss_box_reg: 0.1249 (0.1249)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 1.9707  data: 1.3387  max mem: 4959
# Epoch: [9]  [10/74]  eta: 0:00:49  lr: 0.000005  loss: 0.1744 (0.1779)  loss_classifier: 0.0407 (0.0448)  loss_box_reg: 0.1302 (0.1281)  loss_objectness: 0.0006 (0.0008)  loss_rpn_box_reg: 0.0037 (0.0042)  time: 0.7765  data: 0.1523  max mem: 4959
# Epoch: [9]  [20/74]  eta: 0:00:38  lr: 0.000005  loss: 0.1830 (0.1746)  loss_classifier: 0.0482 (0.0463)  loss_box_reg: 0.1302 (0.1239)  loss_objectness: 0.0004 (0.0007)  loss_rpn_box_reg: 0.0034 (0.0036)  time: 0.6523  data: 0.0323  max mem: 4959
# Epoch: [9]  [30/74]  eta: 0:00:30  lr: 0.000005  loss: 0.1870 (0.1792)  loss_classifier: 0.0495 (0.0482)  loss_box_reg: 0.1310 (0.1262)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0036 (0.0038)  time: 0.6486  data: 0.0316  max mem: 4959
# Epoch: [9]  [40/74]  eta: 0:00:23  lr: 0.000005  loss: 0.1537 (0.1677)  loss_classifier: 0.0397 (0.0447)  loss_box_reg: 0.1068 (0.1185)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0034 (0.0036)  time: 0.6498  data: 0.0337  max mem: 4959
# Epoch: [9]  [50/74]  eta: 0:00:16  lr: 0.000005  loss: 0.1244 (0.1608)  loss_classifier: 0.0333 (0.0431)  loss_box_reg: 0.0899 (0.1135)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0023 (0.0034)  time: 0.6537  data: 0.0354  max mem: 4959
# Epoch: [9]  [60/74]  eta: 0:00:09  lr: 0.000005  loss: 0.1347 (0.1628)  loss_classifier: 0.0397 (0.0434)  loss_box_reg: 0.0902 (0.1146)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0022 (0.0036)  time: 0.6513  data: 0.0332  max mem: 4959
# Epoch: [9]  [70/74]  eta: 0:00:02  lr: 0.000005  loss: 0.1355 (0.1621)  loss_classifier: 0.0404 (0.0436)  loss_box_reg: 0.0926 (0.1139)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0031 (0.0036)  time: 0.6430  data: 0.0301  max mem: 4959
# Epoch: [9]  [73/74]  eta: 0:00:00  lr: 0.000005  loss: 0.1355 (0.1599)  loss_classifier: 0.0397 (0.0430)  loss_box_reg: 0.0926 (0.1123)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0031 (0.0036)  time: 0.6194  data: 0.0290  max mem: 4959
# Epoch: [9] Total time: 0:00:48 (0.6616 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:24  model_time: 0.3299 (0.3299)  evaluator_time: 0.0190 (0.0190)  time: 1.2649  data: 0.8859  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2583 (0.2530)  evaluator_time: 0.0042 (0.0059)  time: 0.3672  data: 0.0788  max mem: 4959
# Test: Total time: 0:00:07 (0.3693 s / it)
# Averaged stats: model_time: 0.2583 (0.2530)  evaluator_time: 0.0042 (0.0059)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.527
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.953
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.536
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.370
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.338
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.591
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.591
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.661
