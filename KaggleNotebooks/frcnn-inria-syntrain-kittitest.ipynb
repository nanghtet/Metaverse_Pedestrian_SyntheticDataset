# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Download TorchVision repo to use some files from
# references/detection
# !pip install pycocotools --quiet
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# Out:
# fatal: destination path 'vision' already exists and is not an empty directory.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
from torch.utils.data import ConcatDataset

from torch.utils.data import Subset
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
mkdir -p /kaggle/working/train-inriaperson && cp -r /kaggle/input/inriaperson/Train/Annotations/* /kaggle/working/train-inriaperson

# %%
cp -r /kaggle/input/inriaperson/Train/JPEGImages/* /kaggle/working/train-inriaperson

# %%
# defining the files directory and testing directory
train_dir = '/kaggle/working/train-inriaperson'
test_dir = '//kaggle/input/kitti-train-test-selection/Train_Test_Selection/Test'

# %%
add_train_dir = '/kaggle/input/pedestriansyntheticdataset/train/train'

# %%
#for xml-annotatation dataset
class ImagesDataset(torch.utils.data.Dataset):

    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
            
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        
        
        # classes: 0 index is reserved for background
        self.classes = ['background','Pedestrian']

    def __getitem__(self, idx):

        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # reading the images and converting them to correct size and color    
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        # diving by 255
        img_res /= 255.0
        
        # annotation file
        annot_filename = img_name[:-4] + '.xml'
        annot_file_path = os.path.join(self.files_dir, annot_filename)
        
        boxes = []
        labels = []
        tree = et.parse(annot_file_path)
        root = tree.getroot()
        
        # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        
        # box coordinates for xml files are extracted and corrected for image size given
        for member in root.findall('object'):
            label_text = member.find('name').text.lower()
            if label_text in ['ped', 'pedestrian','person']:
                labels.append(self.classes.index('Pedestrian')) 
            
            # bounding box
            xmin = int(member.find('bndbox').find('xmin').text)
            xmax = int(member.find('bndbox').find('xmax').text)
            
            ymin = int(member.find('bndbox').find('ymin').text)
            ymax = int(member.find('bndbox').find('ymax').text)
            
            
            xmin_corr = (xmin/wt)*self.width
            xmax_corr = (xmax/wt)*self.width
            ymin_corr = (ymin/ht)*self.height
            ymax_corr = (ymax/ht)*self.height
            
            boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
          
        
        # convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        
        # getting the areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
        
        labels = torch.as_tensor(labels, dtype=torch.int64)


        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        # image_id
        image_id = idx
        target["image_id"] = image_id
        
  


        if self.transforms:
            
            sample = self.transforms(image = img_res,
                                     bboxes = target['boxes'],
                                     labels = labels)
            
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
            
            
            
        return img_res, target

    def __len__(self):
        return len(self.imgs)

# %%
#for txt-annotatation dataset
class KittiDataset(torch.utils.data.Dataset):
    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        self.classes = ['background', 'Pedestrian']

    def __getitem__(self, idx):
        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # Reading the images and converting them to correct size and color
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        img_res /= 255.0

        # Annotation file
        annot_filename = img_name[:-4] + '.txt'
        annot_file_path = os.path.join(self.files_dir, annot_filename)

        boxes = []
        labels = []

           # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        # Read annotation data from text file
        with open(annot_file_path, 'r') as file:
            for line in file:
                parts = line.strip().split(' ')
                label_text = parts[0].lower()

                if label_text in ['pedestrian', 'person']:
                    labels.append(self.classes.index('Pedestrian'))

                    # Bounding box coordinates
                    xmin = float(parts[4])
                    ymin = float(parts[5])
                    xmax = float(parts[6])
                    ymax = float(parts[7])

                    # Normalize coordinates
                    xmin_corr = (xmin/wt)*self.width
                    xmax_corr = (xmax/wt)*self.width
                    ymin_corr = (ymin/ht)*self.height
                    ymax_corr = (ymax/ht)*self.height

                    boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])

        # Convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        #print("boxes shape: ", boxes.size(), "at index",idx, img_name)
       
      
           

        # Calculate areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # Suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)

        labels = torch.as_tensor(labels, dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd

        # image_id
        #image_id = torch.tensor([idx])
        image_id = idx
        target["image_id"] = image_id

        if self.transforms:
            sample = self.transforms(image=img_res, bboxes=target['boxes'], labels=labels)
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
        return img_res, target
    
    

    def __len__(self):
        return len(self.imgs)

# %%
def get_object_detection_model(num_classes):

    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 

    return model

# %%
# Send train=True fro training transforms and False for val/test transforms
def get_transform(train):
    
    if train:
        return A.Compose([
            A.HorizontalFlip(0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
            A.Rotate(limit=15, p=0.5),
            ToTensorV2(p=1.0)
        ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']))
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
# check train dataset
train_dataset = ImagesDataset(train_dir, 1920, 1080)
print('length of dataset = ', len(train_dataset), '\n')

# getting the image and target for a test index.  Feel free to change the index.
img, target = train_dataset[7]
print(img.shape, '\n',target)
# Out:
# length of dataset =  614
#
# (1080, 1920, 3)
#  {'boxes': tensor([[ 570.8836,  441.2571,  713.6045,  637.2000],
#         [ 955.9608,  496.8000, 1120.2244,  683.4857]]), 'labels': tensor([1, 1]), 'area': tensor([27965.1406, 30665.6719]), 'iscrowd': tensor([0, 0]), 'image_id': 7}

# %%
# # check test dataset
test_dataset = KittiDataset(test_dir, 1920, 1080)
print('length of dataset = ', len(test_dataset), '\n')

# getting the image and target for a test index.  Feel free to change the index.
img, target = test_dataset[7]
print(img.shape, '\n',target)
# Out:
# length of dataset =  80
#
# (1080, 1920, 3)
#  {'boxes': tensor([[1128.2241,  475.8912, 1165.2483,  649.4400]]), 'labels': tensor([1]), 'area': tensor([6425.5000]), 'iscrowd': tensor([0]), 'image_id': 7}

# %%
#Adjust the length of test dataset to align with other test datasets
# Define the total number of samples in your dataset
total_samples = len(train_dataset)

# Define the percentage of the dataset you want to load
portion_to_load = 0.5  # Example: load 50% of the dataset

# Calculate the number of samples to load
num_samples_to_load = int(total_samples * portion_to_load)

# Generate random indices to select a random subset of the dataset

indices = random.sample(range(total_samples), num_samples_to_load)

# Create a Subset dataset containing only the selected indices
subset = Subset(train_dataset, indices)
len(subset)
# Out:
# 307

# %%
#Adjust the length of test dataset to align with other test datasets
# Define the total number of samples in your dataset
total_samples = len(train_dataset)

# Define the percentage of the dataset you want to load
portion_to_load = 0.5  # Example: load 50% of the dataset

# Calculate the number of samples to load
num_samples_to_load = int(total_samples * portion_to_load)

# Generate random indices to select a random subset of the dataset

indices = random.sample(range(total_samples), num_samples_to_load)

# Create a Subset dataset containing only the selected indices
subset = Subset(train_dataset, indices)
#len(subset)

# %%
# use our dataset and defined transformations
train_dataset = ImagesDataset(train_dir, 1920, 1080, transforms= get_transform(train=True))
subset = Subset(train_dataset, indices)
train_dataset = subset
add_train_dataset = ImagesDataset(add_train_dir, 1920, 1080, transforms= get_transform(train=True))
combined_dataset = ConcatDataset([train_dataset, add_train_dataset])
test_dataset = KittiDataset(test_dir, 1920, 1080, transforms= get_transform(train=False))

# define training and validation data loaders
data_loader_train = torch.utils.data.DataLoader(
    combined_dataset, batch_size=4, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    test_dataset, batch_size=4, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')


num_classes = 2

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %%
# training for 10 epochs
num_epochs = 10

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, data_loader_train, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [  0/112]  eta: 0:04:15  lr: 0.000050  loss: 0.9863 (0.9863)  loss_classifier: 0.7030 (0.7030)  loss_box_reg: 0.2480 (0.2480)  loss_objectness: 0.0284 (0.0284)  loss_rpn_box_reg: 0.0068 (0.0068)  time: 2.2818  data: 1.5658  max mem: 5941
# Epoch: [0]  [ 10/112]  eta: 0:01:22  lr: 0.000500  loss: 0.8642 (0.7884)  loss_classifier: 0.5501 (0.5141)  loss_box_reg: 0.2292 (0.2493)  loss_objectness: 0.0136 (0.0176)  loss_rpn_box_reg: 0.0065 (0.0074)  time: 0.8127  data: 0.1786  max mem: 6100
# Epoch: [0]  [ 20/112]  eta: 0:01:08  lr: 0.000950  loss: 0.5982 (0.6611)  loss_classifier: 0.2742 (0.3829)  loss_box_reg: 0.2292 (0.2542)  loss_objectness: 0.0101 (0.0154)  loss_rpn_box_reg: 0.0065 (0.0085)  time: 0.6668  data: 0.0395  max mem: 6100
# Epoch: [0]  [ 30/112]  eta: 0:00:58  lr: 0.001400  loss: 0.4632 (0.6041)  loss_classifier: 0.2049 (0.3236)  loss_box_reg: 0.2585 (0.2579)  loss_objectness: 0.0099 (0.0142)  loss_rpn_box_reg: 0.0076 (0.0083)  time: 0.6614  data: 0.0372  max mem: 6100
# Epoch: [0]  [ 40/112]  eta: 0:00:50  lr: 0.001850  loss: 0.3536 (0.5365)  loss_classifier: 0.1144 (0.2672)  loss_box_reg: 0.2347 (0.2484)  loss_objectness: 0.0099 (0.0136)  loss_rpn_box_reg: 0.0049 (0.0073)  time: 0.6551  data: 0.0357  max mem: 6100
# Epoch: [0]  [ 50/112]  eta: 0:00:42  lr: 0.002300  loss: 0.2890 (0.4987)  loss_classifier: 0.0863 (0.2333)  loss_box_reg: 0.2051 (0.2455)  loss_objectness: 0.0075 (0.0128)  loss_rpn_box_reg: 0.0032 (0.0070)  time: 0.6580  data: 0.0363  max mem: 6100
# Epoch: [0]  [ 60/112]  eta: 0:00:35  lr: 0.002750  loss: 0.2819 (0.4603)  loss_classifier: 0.0774 (0.2080)  loss_box_reg: 0.1742 (0.2336)  loss_objectness: 0.0071 (0.0117)  loss_rpn_box_reg: 0.0045 (0.0070)  time: 0.6653  data: 0.0376  max mem: 6100
# Epoch: [0]  [ 70/112]  eta: 0:00:28  lr: 0.003200  loss: 0.2498 (0.4331)  loss_classifier: 0.0705 (0.1897)  loss_box_reg: 0.1728 (0.2255)  loss_objectness: 0.0041 (0.0110)  loss_rpn_box_reg: 0.0067 (0.0069)  time: 0.6665  data: 0.0386  max mem: 6100
# Epoch: [0]  [ 80/112]  eta: 0:00:21  lr: 0.003650  loss: 0.2373 (0.4082)  loss_classifier: 0.0662 (0.1749)  loss_box_reg: 0.1617 (0.2163)  loss_objectness: 0.0031 (0.0103)  loss_rpn_box_reg: 0.0057 (0.0066)  time: 0.6596  data: 0.0378  max mem: 6100
# Epoch: [0]  [ 90/112]  eta: 0:00:14  lr: 0.004100  loss: 0.2101 (0.3879)  loss_classifier: 0.0672 (0.1635)  loss_box_reg: 0.1404 (0.2083)  loss_objectness: 0.0030 (0.0096)  loss_rpn_box_reg: 0.0043 (0.0064)  time: 0.6642  data: 0.0389  max mem: 6101
# Epoch: [0]  [100/112]  eta: 0:00:08  lr: 0.004550  loss: 0.2091 (0.3740)  loss_classifier: 0.0651 (0.1547)  loss_box_reg: 0.1355 (0.2040)  loss_objectness: 0.0025 (0.0090)  loss_rpn_box_reg: 0.0038 (0.0063)  time: 0.6650  data: 0.0398  max mem: 6101
# Epoch: [0]  [110/112]  eta: 0:00:01  lr: 0.005000  loss: 0.2091 (0.3597)  loss_classifier: 0.0651 (0.1470)  loss_box_reg: 0.1355 (0.1976)  loss_objectness: 0.0037 (0.0089)  loss_rpn_box_reg: 0.0051 (0.0062)  time: 0.6529  data: 0.0356  max mem: 6101
# Epoch: [0]  [111/112]  eta: 0:00:00  lr: 0.005000  loss: 0.2091 (0.3579)  loss_classifier: 0.0651 (0.1460)  loss_box_reg: 0.1355 (0.1969)  loss_objectness: 0.0020 (0.0088)  loss_rpn_box_reg: 0.0051 (0.0061)  time: 0.6380  data: 0.0351  max mem: 6101
# Epoch: [0] Total time: 0:01:15 (0.6735 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.2763 (0.2763)  evaluator_time: 0.0077 (0.0077)  time: 1.0082  data: 0.6837  max mem: 6101
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2580 (0.2593)  evaluator_time: 0.0077 (0.0091)  time: 0.3651  data: 0.0650  max mem: 6101
# Test: Total time: 0:00:07 (0.3677 s / it)
# Averaged stats: model_time: 0.2580 (0.2593)  evaluator_time: 0.0077 (0.0091)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.524
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.082
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.376
# Epoch: [1]  [  0/112]  eta: 0:04:29  lr: 0.005000  loss: 0.1147 (0.1147)  loss_classifier: 0.0312 (0.0312)  loss_box_reg: 0.0748 (0.0748)  loss_objectness: 0.0042 (0.0042)  loss_rpn_box_reg: 0.0046 (0.0046)  time: 2.4057  data: 1.7116  max mem: 6101
# Epoch: [1]  [ 10/112]  eta: 0:01:24  lr: 0.005000  loss: 0.1940 (0.2103)  loss_classifier: 0.0655 (0.0647)  loss_box_reg: 0.1270 (0.1371)  loss_objectness: 0.0030 (0.0033)  loss_rpn_box_reg: 0.0046 (0.0051)  time: 0.8268  data: 0.1898  max mem: 6101
# Epoch: [1]  [ 20/112]  eta: 0:01:08  lr: 0.005000  loss: 0.1902 (0.1916)  loss_classifier: 0.0537 (0.0570)  loss_box_reg: 0.1266 (0.1266)  loss_objectness: 0.0030 (0.0038)  loss_rpn_box_reg: 0.0032 (0.0042)  time: 0.6668  data: 0.0361  max mem: 6101
# Epoch: [1]  [ 30/112]  eta: 0:00:59  lr: 0.005000  loss: 0.1826 (0.1991)  loss_classifier: 0.0504 (0.0601)  loss_box_reg: 0.1247 (0.1304)  loss_objectness: 0.0018 (0.0038)  loss_rpn_box_reg: 0.0049 (0.0048)  time: 0.6644  data: 0.0358  max mem: 6101
# Epoch: [1]  [ 40/112]  eta: 0:00:50  lr: 0.005000  loss: 0.1678 (0.2056)  loss_classifier: 0.0508 (0.0629)  loss_box_reg: 0.1156 (0.1342)  loss_objectness: 0.0018 (0.0037)  loss_rpn_box_reg: 0.0053 (0.0048)  time: 0.6579  data: 0.0351  max mem: 6101
# Epoch: [1]  [ 50/112]  eta: 0:00:43  lr: 0.005000  loss: 0.1841 (0.2091)  loss_classifier: 0.0537 (0.0645)  loss_box_reg: 0.1151 (0.1349)  loss_objectness: 0.0020 (0.0050)  loss_rpn_box_reg: 0.0036 (0.0047)  time: 0.6566  data: 0.0350  max mem: 6101
# Epoch: [1]  [ 60/112]  eta: 0:00:35  lr: 0.005000  loss: 0.2120 (0.2100)  loss_classifier: 0.0618 (0.0652)  loss_box_reg: 0.1358 (0.1354)  loss_objectness: 0.0011 (0.0048)  loss_rpn_box_reg: 0.0043 (0.0047)  time: 0.6653  data: 0.0390  max mem: 6101
# Epoch: [1]  [ 70/112]  eta: 0:00:28  lr: 0.005000  loss: 0.2025 (0.2112)  loss_classifier: 0.0626 (0.0657)  loss_box_reg: 0.1358 (0.1359)  loss_objectness: 0.0020 (0.0048)  loss_rpn_box_reg: 0.0041 (0.0047)  time: 0.6656  data: 0.0385  max mem: 6101
# Epoch: [1]  [ 80/112]  eta: 0:00:21  lr: 0.005000  loss: 0.1636 (0.2054)  loss_classifier: 0.0563 (0.0642)  loss_box_reg: 0.1155 (0.1321)  loss_objectness: 0.0020 (0.0046)  loss_rpn_box_reg: 0.0032 (0.0045)  time: 0.6608  data: 0.0371  max mem: 6101
# Epoch: [1]  [ 90/112]  eta: 0:00:14  lr: 0.005000  loss: 0.1741 (0.2052)  loss_classifier: 0.0515 (0.0643)  loss_box_reg: 0.1216 (0.1322)  loss_objectness: 0.0011 (0.0042)  loss_rpn_box_reg: 0.0031 (0.0045)  time: 0.6605  data: 0.0379  max mem: 6101
# Epoch: [1]  [100/112]  eta: 0:00:08  lr: 0.005000  loss: 0.1689 (0.2002)  loss_classifier: 0.0497 (0.0627)  loss_box_reg: 0.1142 (0.1292)  loss_objectness: 0.0008 (0.0039)  loss_rpn_box_reg: 0.0030 (0.0043)  time: 0.6629  data: 0.0377  max mem: 6101
# Epoch: [1]  [110/112]  eta: 0:00:01  lr: 0.005000  loss: 0.1860 (0.2022)  loss_classifier: 0.0496 (0.0628)  loss_box_reg: 0.1226 (0.1306)  loss_objectness: 0.0013 (0.0041)  loss_rpn_box_reg: 0.0031 (0.0047)  time: 0.6623  data: 0.0377  max mem: 6101
# Epoch: [1]  [111/112]  eta: 0:00:00  lr: 0.005000  loss: 0.2029 (0.2034)  loss_classifier: 0.0508 (0.0631)  loss_box_reg: 0.1243 (0.1315)  loss_objectness: 0.0023 (0.0041)  loss_rpn_box_reg: 0.0032 (0.0047)  time: 0.6463  data: 0.0366  max mem: 6101
# Epoch: [1] Total time: 0:01:15 (0.6759 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2883 (0.2883)  evaluator_time: 0.0065 (0.0065)  time: 0.9815  data: 0.5883  max mem: 6101
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2592 (0.2608)  evaluator_time: 0.0087 (0.0103)  time: 0.3663  data: 0.0610  max mem: 6101
# Test: Total time: 0:00:07 (0.3691 s / it)
# Averaged stats: model_time: 0.2592 (0.2608)  evaluator_time: 0.0087 (0.0103)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.161
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.515
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.227
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.125
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.260
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.349
# Epoch: [2]  [  0/112]  eta: 0:04:14  lr: 0.005000  loss: 0.1592 (0.1592)  loss_classifier: 0.0400 (0.0400)  loss_box_reg: 0.1134 (0.1134)  loss_objectness: 0.0017 (0.0017)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 2.2738  data: 1.5835  max mem: 6101
# Epoch: [2]  [ 10/112]  eta: 0:01:24  lr: 0.005000  loss: 0.1579 (0.1605)  loss_classifier: 0.0458 (0.0460)  loss_box_reg: 0.1101 (0.1091)  loss_objectness: 0.0009 (0.0018)  loss_rpn_box_reg: 0.0026 (0.0036)  time: 0.8280  data: 0.1860  max mem: 6101
# Epoch: [2]  [ 20/112]  eta: 0:01:09  lr: 0.005000  loss: 0.1497 (0.1572)  loss_classifier: 0.0440 (0.0468)  loss_box_reg: 0.0987 (0.1035)  loss_objectness: 0.0014 (0.0035)  loss_rpn_box_reg: 0.0025 (0.0035)  time: 0.6784  data: 0.0431  max mem: 6101
# Epoch: [2]  [ 30/112]  eta: 0:00:59  lr: 0.005000  loss: 0.1454 (0.1720)  loss_classifier: 0.0514 (0.0568)  loss_box_reg: 0.0854 (0.1081)  loss_objectness: 0.0014 (0.0036)  loss_rpn_box_reg: 0.0031 (0.0036)  time: 0.6751  data: 0.0405  max mem: 6101
# Epoch: [2]  [ 40/112]  eta: 0:00:51  lr: 0.005000  loss: 0.2122 (0.1905)  loss_classifier: 0.0689 (0.0624)  loss_box_reg: 0.1235 (0.1197)  loss_objectness: 0.0027 (0.0042)  loss_rpn_box_reg: 0.0045 (0.0042)  time: 0.6731  data: 0.0394  max mem: 6101
# Epoch: [2]  [ 50/112]  eta: 0:00:43  lr: 0.005000  loss: 0.1745 (0.1818)  loss_classifier: 0.0556 (0.0592)  loss_box_reg: 0.1192 (0.1150)  loss_objectness: 0.0013 (0.0036)  loss_rpn_box_reg: 0.0042 (0.0040)  time: 0.6670  data: 0.0379  max mem: 6101
# Epoch: [2]  [ 60/112]  eta: 0:00:36  lr: 0.005000  loss: 0.1575 (0.1828)  loss_classifier: 0.0502 (0.0600)  loss_box_reg: 0.1013 (0.1150)  loss_objectness: 0.0011 (0.0038)  loss_rpn_box_reg: 0.0034 (0.0040)  time: 0.6643  data: 0.0369  max mem: 6101
# Epoch: [2]  [ 70/112]  eta: 0:00:29  lr: 0.005000  loss: 0.1667 (0.1854)  loss_classifier: 0.0600 (0.0601)  loss_box_reg: 0.1086 (0.1177)  loss_objectness: 0.0019 (0.0037)  loss_rpn_box_reg: 0.0034 (0.0039)  time: 0.6637  data: 0.0366  max mem: 6101
# Epoch: [2]  [ 80/112]  eta: 0:00:22  lr: 0.005000  loss: 0.1691 (0.1832)  loss_classifier: 0.0542 (0.0586)  loss_box_reg: 0.1105 (0.1170)  loss_objectness: 0.0013 (0.0037)  loss_rpn_box_reg: 0.0034 (0.0039)  time: 0.6675  data: 0.0378  max mem: 6101
# Epoch: [2]  [ 90/112]  eta: 0:00:15  lr: 0.005000  loss: 0.1453 (0.1827)  loss_classifier: 0.0433 (0.0578)  loss_box_reg: 0.1040 (0.1172)  loss_objectness: 0.0014 (0.0037)  loss_rpn_box_reg: 0.0034 (0.0040)  time: 0.6665  data: 0.0378  max mem: 6101
# Epoch: [2]  [100/112]  eta: 0:00:08  lr: 0.005000  loss: 0.1378 (0.1820)  loss_classifier: 0.0504 (0.0579)  loss_box_reg: 0.0801 (0.1166)  loss_objectness: 0.0019 (0.0035)  loss_rpn_box_reg: 0.0030 (0.0040)  time: 0.6646  data: 0.0389  max mem: 6101
# Epoch: [2]  [110/112]  eta: 0:00:01  lr: 0.005000  loss: 0.1648 (0.1827)  loss_classifier: 0.0554 (0.0577)  loss_box_reg: 0.1151 (0.1176)  loss_objectness: 0.0021 (0.0034)  loss_rpn_box_reg: 0.0026 (0.0039)  time: 0.6589  data: 0.0368  max mem: 6101
# Epoch: [2]  [111/112]  eta: 0:00:00  lr: 0.005000  loss: 0.1759 (0.1845)  loss_classifier: 0.0558 (0.0582)  loss_box_reg: 0.1214 (0.1189)  loss_objectness: 0.0023 (0.0034)  loss_rpn_box_reg: 0.0030 (0.0040)  time: 0.6432  data: 0.0361  max mem: 6101
# Epoch: [2] Total time: 0:01:16 (0.6800 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:22  model_time: 0.2969 (0.2969)  evaluator_time: 0.0081 (0.0081)  time: 1.1080  data: 0.7644  max mem: 6101
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2586 (0.2618)  evaluator_time: 0.0071 (0.0079)  time: 0.3709  data: 0.0692  max mem: 6101
# Test: Total time: 0:00:07 (0.3739 s / it)
# Averaged stats: model_time: 0.2586 (0.2618)  evaluator_time: 0.0071 (0.0079)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.473
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.145
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.284
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.158
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.376
# Epoch: [3]  [  0/112]  eta: 0:04:21  lr: 0.000500  loss: 0.1939 (0.1939)  loss_classifier: 0.0523 (0.0523)  loss_box_reg: 0.1348 (0.1348)  loss_objectness: 0.0017 (0.0017)  loss_rpn_box_reg: 0.0051 (0.0051)  time: 2.3372  data: 1.5911  max mem: 6101
# Epoch: [3]  [ 10/112]  eta: 0:01:24  lr: 0.000500  loss: 0.1899 (0.2129)  loss_classifier: 0.0500 (0.0591)  loss_box_reg: 0.1313 (0.1473)  loss_objectness: 0.0031 (0.0026)  loss_rpn_box_reg: 0.0039 (0.0039)  time: 0.8268  data: 0.1801  max mem: 6101
# Epoch: [3]  [ 20/112]  eta: 0:01:08  lr: 0.000500  loss: 0.1777 (0.1945)  loss_classifier: 0.0482 (0.0567)  loss_box_reg: 0.1154 (0.1314)  loss_objectness: 0.0014 (0.0021)  loss_rpn_box_reg: 0.0036 (0.0043)  time: 0.6678  data: 0.0370  max mem: 6101
# Epoch: [3]  [ 30/112]  eta: 0:00:59  lr: 0.000500  loss: 0.1324 (0.1809)  loss_classifier: 0.0502 (0.0543)  loss_box_reg: 0.0941 (0.1208)  loss_objectness: 0.0007 (0.0019)  loss_rpn_box_reg: 0.0023 (0.0040)  time: 0.6609  data: 0.0363  max mem: 6101
# Epoch: [3]  [ 40/112]  eta: 0:00:50  lr: 0.000500  loss: 0.1457 (0.1774)  loss_classifier: 0.0507 (0.0536)  loss_box_reg: 0.0974 (0.1180)  loss_objectness: 0.0010 (0.0017)  loss_rpn_box_reg: 0.0026 (0.0040)  time: 0.6643  data: 0.0374  max mem: 6101
# Epoch: [3]  [ 50/112]  eta: 0:00:43  lr: 0.000500  loss: 0.1378 (0.1693)  loss_classifier: 0.0439 (0.0515)  loss_box_reg: 0.0880 (0.1121)  loss_objectness: 0.0010 (0.0018)  loss_rpn_box_reg: 0.0029 (0.0038)  time: 0.6642  data: 0.0364  max mem: 6101
# Epoch: [3]  [ 60/112]  eta: 0:00:36  lr: 0.000500  loss: 0.1186 (0.1624)  loss_classifier: 0.0355 (0.0498)  loss_box_reg: 0.0732 (0.1070)  loss_objectness: 0.0007 (0.0018)  loss_rpn_box_reg: 0.0028 (0.0038)  time: 0.6631  data: 0.0370  max mem: 6101
# Epoch: [3]  [ 70/112]  eta: 0:00:28  lr: 0.000500  loss: 0.1116 (0.1575)  loss_classifier: 0.0391 (0.0486)  loss_box_reg: 0.0715 (0.1034)  loss_objectness: 0.0007 (0.0019)  loss_rpn_box_reg: 0.0024 (0.0036)  time: 0.6644  data: 0.0384  max mem: 6101
# Epoch: [3]  [ 80/112]  eta: 0:00:21  lr: 0.000500  loss: 0.1207 (0.1536)  loss_classifier: 0.0392 (0.0473)  loss_box_reg: 0.0761 (0.1011)  loss_objectness: 0.0010 (0.0018)  loss_rpn_box_reg: 0.0024 (0.0035)  time: 0.6651  data: 0.0390  max mem: 6101
# Epoch: [3]  [ 90/112]  eta: 0:00:15  lr: 0.000500  loss: 0.1405 (0.1551)  loss_classifier: 0.0443 (0.0473)  loss_box_reg: 0.0983 (0.1025)  loss_objectness: 0.0009 (0.0018)  loss_rpn_box_reg: 0.0030 (0.0035)  time: 0.6689  data: 0.0395  max mem: 6101
# Epoch: [3]  [100/112]  eta: 0:00:08  lr: 0.000500  loss: 0.1712 (0.1566)  loss_classifier: 0.0450 (0.0477)  loss_box_reg: 0.1035 (0.1036)  loss_objectness: 0.0012 (0.0019)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 0.6695  data: 0.0393  max mem: 6101
# Epoch: [3]  [110/112]  eta: 0:00:01  lr: 0.000500  loss: 0.1729 (0.1604)  loss_classifier: 0.0491 (0.0487)  loss_box_reg: 0.1102 (0.1062)  loss_objectness: 0.0011 (0.0019)  loss_rpn_box_reg: 0.0034 (0.0035)  time: 0.6589  data: 0.0356  max mem: 6101
# Epoch: [3]  [111/112]  eta: 0:00:00  lr: 0.000500  loss: 0.1729 (0.1603)  loss_classifier: 0.0491 (0.0487)  loss_box_reg: 0.1102 (0.1062)  loss_objectness: 0.0012 (0.0019)  loss_rpn_box_reg: 0.0034 (0.0035)  time: 0.6428  data: 0.0348  max mem: 6101
# Epoch: [3] Total time: 0:01:15 (0.6774 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:22  model_time: 0.2911 (0.2911)  evaluator_time: 0.0054 (0.0054)  time: 1.1059  data: 0.7696  max mem: 6101
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2590 (0.2606)  evaluator_time: 0.0067 (0.0081)  time: 0.3711  data: 0.0702  max mem: 6101
# Test: Total time: 0:00:07 (0.3737 s / it)
# Averaged stats: model_time: 0.2590 (0.2606)  evaluator_time: 0.0067 (0.0081)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.525
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.121
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.341
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.196
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
# Epoch: [4]  [  0/112]  eta: 0:03:43  lr: 0.000500  loss: 0.0813 (0.0813)  loss_classifier: 0.0215 (0.0215)  loss_box_reg: 0.0565 (0.0565)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 1.9998  data: 1.3151  max mem: 6101
# Epoch: [4]  [ 10/112]  eta: 0:01:22  lr: 0.000500  loss: 0.1474 (0.1721)  loss_classifier: 0.0493 (0.0568)  loss_box_reg: 0.0989 (0.1092)  loss_objectness: 0.0012 (0.0025)  loss_rpn_box_reg: 0.0027 (0.0036)  time: 0.8080  data: 0.1614  max mem: 6101
# Epoch: [4]  [ 20/112]  eta: 0:01:08  lr: 0.000500  loss: 0.1447 (0.1564)  loss_classifier: 0.0454 (0.0505)  loss_box_reg: 0.0981 (0.1005)  loss_objectness: 0.0011 (0.0018)  loss_rpn_box_reg: 0.0027 (0.0035)  time: 0.6799  data: 0.0420  max mem: 6101
# Epoch: [4]  [ 30/112]  eta: 0:00:58  lr: 0.000500  loss: 0.1214 (0.1473)  loss_classifier: 0.0360 (0.0479)  loss_box_reg: 0.0745 (0.0943)  loss_objectness: 0.0010 (0.0020)  loss_rpn_box_reg: 0.0027 (0.0032)  time: 0.6689  data: 0.0374  max mem: 6101
# Epoch: [4]  [ 40/112]  eta: 0:00:50  lr: 0.000500  loss: 0.1399 (0.1501)  loss_classifier: 0.0452 (0.0471)  loss_box_reg: 0.0949 (0.0979)  loss_objectness: 0.0009 (0.0020)  loss_rpn_box_reg: 0.0025 (0.0032)  time: 0.6667  data: 0.0375  max mem: 6101
# Epoch: [4]  [ 50/112]  eta: 0:00:43  lr: 0.000500  loss: 0.1528 (0.1504)  loss_classifier: 0.0470 (0.0476)  loss_box_reg: 0.1003 (0.0977)  loss_objectness: 0.0009 (0.0018)  loss_rpn_box_reg: 0.0029 (0.0032)  time: 0.6652  data: 0.0370  max mem: 6101
# Epoch: [4]  [ 60/112]  eta: 0:00:35  lr: 0.000500  loss: 0.1472 (0.1520)  loss_classifier: 0.0431 (0.0477)  loss_box_reg: 0.0909 (0.0990)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0032 (0.0034)  time: 0.6639  data: 0.0382  max mem: 6101
# Epoch: [4]  [ 70/112]  eta: 0:00:28  lr: 0.000500  loss: 0.1460 (0.1506)  loss_classifier: 0.0407 (0.0473)  loss_box_reg: 0.0964 (0.0981)  loss_objectness: 0.0007 (0.0018)  loss_rpn_box_reg: 0.0028 (0.0033)  time: 0.6607  data: 0.0382  max mem: 6101
# Epoch: [4]  [ 80/112]  eta: 0:00:21  lr: 0.000500  loss: 0.1409 (0.1523)  loss_classifier: 0.0433 (0.0473)  loss_box_reg: 0.0980 (0.0999)  loss_objectness: 0.0005 (0.0017)  loss_rpn_box_reg: 0.0025 (0.0034)  time: 0.6555  data: 0.0359  max mem: 6101
# Epoch: [4]  [ 90/112]  eta: 0:00:14  lr: 0.000500  loss: 0.1312 (0.1504)  loss_classifier: 0.0378 (0.0465)  loss_box_reg: 0.0891 (0.0989)  loss_objectness: 0.0005 (0.0017)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 0.6566  data: 0.0356  max mem: 6101
# Epoch: [4]  [100/112]  eta: 0:00:08  lr: 0.000500  loss: 0.1284 (0.1524)  loss_classifier: 0.0402 (0.0469)  loss_box_reg: 0.0891 (0.1002)  loss_objectness: 0.0013 (0.0018)  loss_rpn_box_reg: 0.0027 (0.0035)  time: 0.6619  data: 0.0375  max mem: 6101
# Epoch: [4]  [110/112]  eta: 0:00:01  lr: 0.000500  loss: 0.1412 (0.1517)  loss_classifier: 0.0414 (0.0466)  loss_box_reg: 0.0980 (0.0999)  loss_objectness: 0.0010 (0.0017)  loss_rpn_box_reg: 0.0033 (0.0035)  time: 0.6579  data: 0.0371  max mem: 6101
# Epoch: [4]  [111/112]  eta: 0:00:00  lr: 0.000500  loss: 0.1466 (0.1524)  loss_classifier: 0.0457 (0.0471)  loss_box_reg: 0.1000 (0.1001)  loss_objectness: 0.0010 (0.0017)  loss_rpn_box_reg: 0.0034 (0.0035)  time: 0.6424  data: 0.0367  max mem: 6101
# Epoch: [4] Total time: 0:01:15 (0.6741 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:22  model_time: 0.2889 (0.2889)  evaluator_time: 0.0048 (0.0048)  time: 1.1223  data: 0.7404  max mem: 6101
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2583 (0.2604)  evaluator_time: 0.0064 (0.0078)  time: 0.3679  data: 0.0661  max mem: 6101
# Test: Total time: 0:00:07 (0.3708 s / it)
# Averaged stats: model_time: 0.2583 (0.2604)  evaluator_time: 0.0064 (0.0078)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.533
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.166
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.339
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.191
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.440
# Epoch: [5]  [  0/112]  eta: 0:04:12  lr: 0.000500  loss: 0.1303 (0.1303)  loss_classifier: 0.0503 (0.0503)  loss_box_reg: 0.0756 (0.0756)  loss_objectness: 0.0015 (0.0015)  loss_rpn_box_reg: 0.0030 (0.0030)  time: 2.2580  data: 1.5591  max mem: 6101
# Epoch: [5]  [ 10/112]  eta: 0:01:24  lr: 0.000500  loss: 0.1658 (0.1679)  loss_classifier: 0.0488 (0.0503)  loss_box_reg: 0.1160 (0.1108)  loss_objectness: 0.0026 (0.0028)  loss_rpn_box_reg: 0.0035 (0.0041)  time: 0.8288  data: 0.1854  max mem: 6101
# Epoch: [5]  [ 20/112]  eta: 0:01:09  lr: 0.000500  loss: 0.1683 (0.1757)  loss_classifier: 0.0488 (0.0533)  loss_box_reg: 0.1160 (0.1154)  loss_objectness: 0.0026 (0.0030)  loss_rpn_box_reg: 0.0031 (0.0040)  time: 0.6761  data: 0.0435  max mem: 6101
# Epoch: [5]  [ 30/112]  eta: 0:00:59  lr: 0.000500  loss: 0.1587 (0.1660)  loss_classifier: 0.0459 (0.0507)  loss_box_reg: 0.1004 (0.1093)  loss_objectness: 0.0009 (0.0023)  loss_rpn_box_reg: 0.0030 (0.0038)  time: 0.6659  data: 0.0387  max mem: 6101
# Epoch: [5]  [ 40/112]  eta: 0:00:50  lr: 0.000500  loss: 0.1454 (0.1608)  loss_classifier: 0.0457 (0.0493)  loss_box_reg: 0.0955 (0.1056)  loss_objectness: 0.0006 (0.0022)  loss_rpn_box_reg: 0.0025 (0.0037)  time: 0.6595  data: 0.0360  max mem: 6101
# Epoch: [5]  [ 50/112]  eta: 0:00:43  lr: 0.000500  loss: 0.1336 (0.1539)  loss_classifier: 0.0421 (0.0466)  loss_box_reg: 0.0930 (0.1020)  loss_objectness: 0.0003 (0.0018)  loss_rpn_box_reg: 0.0025 (0.0035)  time: 0.6561  data: 0.0349  max mem: 6101
# Epoch: [5]  [ 60/112]  eta: 0:00:35  lr: 0.000500  loss: 0.1357 (0.1527)  loss_classifier: 0.0431 (0.0472)  loss_box_reg: 0.0949 (0.1004)  loss_objectness: 0.0003 (0.0017)  loss_rpn_box_reg: 0.0025 (0.0034)  time: 0.6592  data: 0.0359  max mem: 6101
# Epoch: [5]  [ 70/112]  eta: 0:00:28  lr: 0.000500  loss: 0.1429 (0.1508)  loss_classifier: 0.0474 (0.0464)  loss_box_reg: 0.0971 (0.0995)  loss_objectness: 0.0006 (0.0016)  loss_rpn_box_reg: 0.0026 (0.0033)  time: 0.6648  data: 0.0372  max mem: 6101
# Epoch: [5]  [ 80/112]  eta: 0:00:21  lr: 0.000500  loss: 0.1429 (0.1509)  loss_classifier: 0.0414 (0.0462)  loss_box_reg: 0.0983 (0.0994)  loss_objectness: 0.0006 (0.0020)  loss_rpn_box_reg: 0.0025 (0.0033)  time: 0.6650  data: 0.0374  max mem: 6101
# Epoch: [5]  [ 90/112]  eta: 0:00:15  lr: 0.000500  loss: 0.1438 (0.1527)  loss_classifier: 0.0421 (0.0473)  loss_box_reg: 0.0983 (0.1000)  loss_objectness: 0.0008 (0.0020)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 0.6628  data: 0.0369  max mem: 6101
# Epoch: [5]  [100/112]  eta: 0:00:08  lr: 0.000500  loss: 0.1259 (0.1506)  loss_classifier: 0.0400 (0.0465)  loss_box_reg: 0.0729 (0.0988)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0030 (0.0034)  time: 0.6640  data: 0.0380  max mem: 6101
# Epoch: [5]  [110/112]  eta: 0:00:01  lr: 0.000500  loss: 0.1200 (0.1503)  loss_classifier: 0.0372 (0.0462)  loss_box_reg: 0.0759 (0.0988)  loss_objectness: 0.0008 (0.0019)  loss_rpn_box_reg: 0.0030 (0.0034)  time: 0.6590  data: 0.0360  max mem: 6101
# Epoch: [5]  [111/112]  eta: 0:00:00  lr: 0.000500  loss: 0.1200 (0.1498)  loss_classifier: 0.0372 (0.0460)  loss_box_reg: 0.0759 (0.0984)  loss_objectness: 0.0008 (0.0019)  loss_rpn_box_reg: 0.0029 (0.0034)  time: 0.6440  data: 0.0354  max mem: 6101
# Epoch: [5] Total time: 0:01:15 (0.6761 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:22  model_time: 0.3129 (0.3129)  evaluator_time: 0.0050 (0.0050)  time: 1.1229  data: 0.7627  max mem: 6101
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2598 (0.2636)  evaluator_time: 0.0069 (0.0080)  time: 0.3733  data: 0.0699  max mem: 6101
# Test: Total time: 0:00:07 (0.3759 s / it)
# Averaged stats: model_time: 0.2598 (0.2636)  evaluator_time: 0.0069 (0.0080)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.235
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.537
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.442
# Epoch: [6]  [  0/112]  eta: 0:04:16  lr: 0.000050  loss: 0.1760 (0.1760)  loss_classifier: 0.0518 (0.0518)  loss_box_reg: 0.1206 (0.1206)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 2.2897  data: 1.5379  max mem: 6101
# Epoch: [6]  [ 10/112]  eta: 0:01:23  lr: 0.000050  loss: 0.1760 (0.1783)  loss_classifier: 0.0536 (0.0549)  loss_box_reg: 0.1109 (0.1140)  loss_objectness: 0.0014 (0.0051)  loss_rpn_box_reg: 0.0037 (0.0044)  time: 0.8172  data: 0.1719  max mem: 6101
# Epoch: [6]  [ 20/112]  eta: 0:01:08  lr: 0.000050  loss: 0.1487 (0.1551)  loss_classifier: 0.0450 (0.0476)  loss_box_reg: 0.0982 (0.1006)  loss_objectness: 0.0012 (0.0032)  loss_rpn_box_reg: 0.0033 (0.0038)  time: 0.6682  data: 0.0364  max mem: 6101
# Epoch: [6]  [ 30/112]  eta: 0:00:58  lr: 0.000050  loss: 0.1398 (0.1524)  loss_classifier: 0.0455 (0.0490)  loss_box_reg: 0.0925 (0.0976)  loss_objectness: 0.0007 (0.0025)  loss_rpn_box_reg: 0.0024 (0.0033)  time: 0.6654  data: 0.0355  max mem: 6101
# Epoch: [6]  [ 40/112]  eta: 0:00:51  lr: 0.000050  loss: 0.1410 (0.1567)  loss_classifier: 0.0511 (0.0502)  loss_box_reg: 0.0903 (0.1006)  loss_objectness: 0.0008 (0.0025)  loss_rpn_box_reg: 0.0025 (0.0035)  time: 0.6698  data: 0.0372  max mem: 6101
# Epoch: [6]  [ 50/112]  eta: 0:00:43  lr: 0.000050  loss: 0.1640 (0.1591)  loss_classifier: 0.0510 (0.0503)  loss_box_reg: 0.1035 (0.1028)  loss_objectness: 0.0008 (0.0023)  loss_rpn_box_reg: 0.0036 (0.0037)  time: 0.6696  data: 0.0381  max mem: 6101
# Epoch: [6]  [ 60/112]  eta: 0:00:36  lr: 0.000050  loss: 0.1399 (0.1541)  loss_classifier: 0.0387 (0.0484)  loss_box_reg: 0.1013 (0.1000)  loss_objectness: 0.0006 (0.0021)  loss_rpn_box_reg: 0.0029 (0.0036)  time: 0.6630  data: 0.0357  max mem: 6101
# Epoch: [6]  [ 70/112]  eta: 0:00:28  lr: 0.000050  loss: 0.1207 (0.1513)  loss_classifier: 0.0405 (0.0474)  loss_box_reg: 0.0841 (0.0985)  loss_objectness: 0.0006 (0.0020)  loss_rpn_box_reg: 0.0023 (0.0034)  time: 0.6648  data: 0.0372  max mem: 6101
# Epoch: [6]  [ 80/112]  eta: 0:00:21  lr: 0.000050  loss: 0.1207 (0.1478)  loss_classifier: 0.0377 (0.0463)  loss_box_reg: 0.0786 (0.0963)  loss_objectness: 0.0007 (0.0019)  loss_rpn_box_reg: 0.0019 (0.0033)  time: 0.6681  data: 0.0380  max mem: 6101
# Epoch: [6]  [ 90/112]  eta: 0:00:15  lr: 0.000050  loss: 0.1240 (0.1472)  loss_classifier: 0.0377 (0.0463)  loss_box_reg: 0.0808 (0.0957)  loss_objectness: 0.0010 (0.0020)  loss_rpn_box_reg: 0.0019 (0.0032)  time: 0.6699  data: 0.0384  max mem: 6101
# Epoch: [6]  [100/112]  eta: 0:00:08  lr: 0.000050  loss: 0.1260 (0.1469)  loss_classifier: 0.0396 (0.0461)  loss_box_reg: 0.0869 (0.0958)  loss_objectness: 0.0010 (0.0019)  loss_rpn_box_reg: 0.0022 (0.0033)  time: 0.6664  data: 0.0386  max mem: 6101
# Epoch: [6]  [110/112]  eta: 0:00:01  lr: 0.000050  loss: 0.1154 (0.1467)  loss_classifier: 0.0384 (0.0457)  loss_box_reg: 0.0808 (0.0960)  loss_objectness: 0.0007 (0.0018)  loss_rpn_box_reg: 0.0027 (0.0032)  time: 0.6587  data: 0.0366  max mem: 6101
# Epoch: [6]  [111/112]  eta: 0:00:00  lr: 0.000050  loss: 0.1154 (0.1465)  loss_classifier: 0.0353 (0.0456)  loss_box_reg: 0.0811 (0.0960)  loss_objectness: 0.0007 (0.0018)  loss_rpn_box_reg: 0.0022 (0.0032)  time: 0.6430  data: 0.0356  max mem: 6101
# Epoch: [6] Total time: 0:01:15 (0.6785 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:21  model_time: 0.2965 (0.2965)  evaluator_time: 0.0051 (0.0051)  time: 1.0611  data: 0.7281  max mem: 6101
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2589 (0.2611)  evaluator_time: 0.0064 (0.0081)  time: 0.3683  data: 0.0676  max mem: 6101
# Test: Total time: 0:00:07 (0.3710 s / it)
# Averaged stats: model_time: 0.2589 (0.2611)  evaluator_time: 0.0064 (0.0081)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.232
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.534
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.203
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
# Epoch: [7]  [  0/112]  eta: 0:05:12  lr: 0.000050  loss: 0.1948 (0.1948)  loss_classifier: 0.0523 (0.0523)  loss_box_reg: 0.1315 (0.1315)  loss_objectness: 0.0067 (0.0067)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 2.7930  data: 2.0343  max mem: 6101
# Epoch: [7]  [ 10/112]  eta: 0:01:27  lr: 0.000050  loss: 0.1625 (0.1676)  loss_classifier: 0.0523 (0.0514)  loss_box_reg: 0.1124 (0.1100)  loss_objectness: 0.0009 (0.0024)  loss_rpn_box_reg: 0.0032 (0.0038)  time: 0.8623  data: 0.2166  max mem: 6101
# Epoch: [7]  [ 20/112]  eta: 0:01:10  lr: 0.000050  loss: 0.1593 (0.1623)  loss_classifier: 0.0494 (0.0505)  loss_box_reg: 0.1066 (0.1056)  loss_objectness: 0.0008 (0.0020)  loss_rpn_box_reg: 0.0032 (0.0041)  time: 0.6659  data: 0.0367  max mem: 6101
# Epoch: [7]  [ 30/112]  eta: 0:01:00  lr: 0.000050  loss: 0.1458 (0.1551)  loss_classifier: 0.0441 (0.0485)  loss_box_reg: 0.0942 (0.1010)  loss_objectness: 0.0008 (0.0019)  loss_rpn_box_reg: 0.0025 (0.0037)  time: 0.6658  data: 0.0390  max mem: 6101
# Epoch: [7]  [ 40/112]  eta: 0:00:51  lr: 0.000050  loss: 0.1359 (0.1499)  loss_classifier: 0.0408 (0.0471)  loss_box_reg: 0.0929 (0.0976)  loss_objectness: 0.0008 (0.0017)  loss_rpn_box_reg: 0.0025 (0.0034)  time: 0.6630  data: 0.0375  max mem: 6101
# Epoch: [7]  [ 50/112]  eta: 0:00:43  lr: 0.000050  loss: 0.1156 (0.1487)  loss_classifier: 0.0341 (0.0463)  loss_box_reg: 0.0791 (0.0973)  loss_objectness: 0.0005 (0.0016)  loss_rpn_box_reg: 0.0025 (0.0034)  time: 0.6603  data: 0.0370  max mem: 6101
# Epoch: [7]  [ 60/112]  eta: 0:00:36  lr: 0.000050  loss: 0.1059 (0.1448)  loss_classifier: 0.0327 (0.0454)  loss_box_reg: 0.0715 (0.0947)  loss_objectness: 0.0004 (0.0015)  loss_rpn_box_reg: 0.0020 (0.0033)  time: 0.6646  data: 0.0395  max mem: 6101
# Epoch: [7]  [ 70/112]  eta: 0:00:29  lr: 0.000050  loss: 0.1247 (0.1429)  loss_classifier: 0.0381 (0.0445)  loss_box_reg: 0.0835 (0.0937)  loss_objectness: 0.0004 (0.0014)  loss_rpn_box_reg: 0.0032 (0.0033)  time: 0.6636  data: 0.0384  max mem: 6101
# Epoch: [7]  [ 80/112]  eta: 0:00:22  lr: 0.000050  loss: 0.1367 (0.1479)  loss_classifier: 0.0420 (0.0461)  loss_box_reg: 0.0879 (0.0969)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0035 (0.0034)  time: 0.6622  data: 0.0370  max mem: 6101
# Epoch: [7]  [ 90/112]  eta: 0:00:15  lr: 0.000050  loss: 0.1340 (0.1467)  loss_classifier: 0.0510 (0.0461)  loss_box_reg: 0.0823 (0.0959)  loss_objectness: 0.0007 (0.0014)  loss_rpn_box_reg: 0.0021 (0.0033)  time: 0.6608  data: 0.0370  max mem: 6101
# Epoch: [7]  [100/112]  eta: 0:00:08  lr: 0.000050  loss: 0.1180 (0.1449)  loss_classifier: 0.0376 (0.0452)  loss_box_reg: 0.0785 (0.0950)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0019 (0.0032)  time: 0.6643  data: 0.0373  max mem: 6101
# Epoch: [7]  [110/112]  eta: 0:00:01  lr: 0.000050  loss: 0.1402 (0.1465)  loss_classifier: 0.0384 (0.0453)  loss_box_reg: 0.0999 (0.0965)  loss_objectness: 0.0005 (0.0015)  loss_rpn_box_reg: 0.0024 (0.0033)  time: 0.6591  data: 0.0349  max mem: 6101
# Epoch: [7]  [111/112]  eta: 0:00:00  lr: 0.000050  loss: 0.1302 (0.1461)  loss_classifier: 0.0376 (0.0451)  loss_box_reg: 0.0895 (0.0963)  loss_objectness: 0.0005 (0.0015)  loss_rpn_box_reg: 0.0024 (0.0032)  time: 0.6442  data: 0.0346  max mem: 6101
# Epoch: [7] Total time: 0:01:16 (0.6796 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:22  model_time: 0.2888 (0.2888)  evaluator_time: 0.0061 (0.0061)  time: 1.1335  data: 0.7392  max mem: 6101
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2586 (0.2600)  evaluator_time: 0.0068 (0.0077)  time: 0.3710  data: 0.0682  max mem: 6101
# Test: Total time: 0:00:07 (0.3736 s / it)
# Averaged stats: model_time: 0.2586 (0.2600)  evaluator_time: 0.0068 (0.0077)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.532
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.328
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.203
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.438
# Epoch: [8]  [  0/112]  eta: 0:03:49  lr: 0.000050  loss: 0.1124 (0.1124)  loss_classifier: 0.0264 (0.0264)  loss_box_reg: 0.0828 (0.0828)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 2.0477  data: 1.2626  max mem: 6101
# Epoch: [8]  [ 10/112]  eta: 0:01:22  lr: 0.000050  loss: 0.1347 (0.1521)  loss_classifier: 0.0465 (0.0437)  loss_box_reg: 0.0973 (0.1029)  loss_objectness: 0.0003 (0.0019)  loss_rpn_box_reg: 0.0038 (0.0034)  time: 0.8062  data: 0.1550  max mem: 6101
# Epoch: [8]  [ 20/112]  eta: 0:01:07  lr: 0.000050  loss: 0.1355 (0.1498)  loss_classifier: 0.0423 (0.0437)  loss_box_reg: 0.0903 (0.1014)  loss_objectness: 0.0006 (0.0016)  loss_rpn_box_reg: 0.0023 (0.0030)  time: 0.6705  data: 0.0395  max mem: 6101
# Epoch: [8]  [ 30/112]  eta: 0:00:58  lr: 0.000050  loss: 0.1355 (0.1446)  loss_classifier: 0.0392 (0.0429)  loss_box_reg: 0.0865 (0.0970)  loss_objectness: 0.0007 (0.0018)  loss_rpn_box_reg: 0.0023 (0.0028)  time: 0.6605  data: 0.0352  max mem: 6101
# Epoch: [8]  [ 40/112]  eta: 0:00:50  lr: 0.000050  loss: 0.1197 (0.1480)  loss_classifier: 0.0387 (0.0452)  loss_box_reg: 0.0759 (0.0980)  loss_objectness: 0.0012 (0.0019)  loss_rpn_box_reg: 0.0023 (0.0030)  time: 0.6614  data: 0.0357  max mem: 6101
# Epoch: [8]  [ 50/112]  eta: 0:00:42  lr: 0.000050  loss: 0.1028 (0.1401)  loss_classifier: 0.0367 (0.0428)  loss_box_reg: 0.0663 (0.0927)  loss_objectness: 0.0006 (0.0017)  loss_rpn_box_reg: 0.0022 (0.0028)  time: 0.6646  data: 0.0367  max mem: 6101
# Epoch: [8]  [ 60/112]  eta: 0:00:35  lr: 0.000050  loss: 0.1162 (0.1417)  loss_classifier: 0.0368 (0.0441)  loss_box_reg: 0.0775 (0.0926)  loss_objectness: 0.0003 (0.0019)  loss_rpn_box_reg: 0.0022 (0.0030)  time: 0.6655  data: 0.0354  max mem: 6101
# Epoch: [8]  [ 70/112]  eta: 0:00:28  lr: 0.000050  loss: 0.1287 (0.1432)  loss_classifier: 0.0406 (0.0444)  loss_box_reg: 0.0872 (0.0939)  loss_objectness: 0.0006 (0.0018)  loss_rpn_box_reg: 0.0026 (0.0030)  time: 0.6645  data: 0.0349  max mem: 6101
# Epoch: [8]  [ 80/112]  eta: 0:00:21  lr: 0.000050  loss: 0.1400 (0.1444)  loss_classifier: 0.0479 (0.0448)  loss_box_reg: 0.0927 (0.0945)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0030 (0.0031)  time: 0.6640  data: 0.0355  max mem: 6101
# Epoch: [8]  [ 90/112]  eta: 0:00:14  lr: 0.000050  loss: 0.1400 (0.1452)  loss_classifier: 0.0433 (0.0454)  loss_box_reg: 0.0948 (0.0947)  loss_objectness: 0.0010 (0.0019)  loss_rpn_box_reg: 0.0030 (0.0031)  time: 0.6601  data: 0.0345  max mem: 6101
# Epoch: [8]  [100/112]  eta: 0:00:08  lr: 0.000050  loss: 0.1418 (0.1448)  loss_classifier: 0.0433 (0.0453)  loss_box_reg: 0.0948 (0.0946)  loss_objectness: 0.0006 (0.0018)  loss_rpn_box_reg: 0.0029 (0.0031)  time: 0.6615  data: 0.0346  max mem: 6101
# Epoch: [8]  [110/112]  eta: 0:00:01  lr: 0.000050  loss: 0.1425 (0.1461)  loss_classifier: 0.0482 (0.0457)  loss_box_reg: 0.0952 (0.0954)  loss_objectness: 0.0009 (0.0018)  loss_rpn_box_reg: 0.0025 (0.0032)  time: 0.6579  data: 0.0339  max mem: 6101
# Epoch: [8]  [111/112]  eta: 0:00:00  lr: 0.000050  loss: 0.1425 (0.1468)  loss_classifier: 0.0482 (0.0459)  loss_box_reg: 0.0952 (0.0959)  loss_objectness: 0.0009 (0.0018)  loss_rpn_box_reg: 0.0025 (0.0032)  time: 0.6423  data: 0.0334  max mem: 6101
# Epoch: [8] Total time: 0:01:15 (0.6737 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:21  model_time: 0.2981 (0.2981)  evaluator_time: 0.0050 (0.0050)  time: 1.0982  data: 0.7629  max mem: 6101
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2597 (0.2619)  evaluator_time: 0.0063 (0.0074)  time: 0.3711  data: 0.0707  max mem: 6101
# Test: Total time: 0:00:07 (0.3739 s / it)
# Averaged stats: model_time: 0.2597 (0.2619)  evaluator_time: 0.0063 (0.0074)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.232
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.534
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.117
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.344
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.204
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
# Epoch: [9]  [  0/112]  eta: 0:04:21  lr: 0.000005  loss: 0.1251 (0.1251)  loss_classifier: 0.0335 (0.0335)  loss_box_reg: 0.0894 (0.0894)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 2.3370  data: 1.6367  max mem: 6101
# Epoch: [9]  [ 10/112]  eta: 0:01:23  lr: 0.000005  loss: 0.1514 (0.1568)  loss_classifier: 0.0474 (0.0463)  loss_box_reg: 0.1008 (0.1043)  loss_objectness: 0.0015 (0.0022)  loss_rpn_box_reg: 0.0037 (0.0040)  time: 0.8234  data: 0.1850  max mem: 6101
# Epoch: [9]  [ 20/112]  eta: 0:01:08  lr: 0.000005  loss: 0.1554 (0.1595)  loss_classifier: 0.0474 (0.0481)  loss_box_reg: 0.1008 (0.1063)  loss_objectness: 0.0007 (0.0015)  loss_rpn_box_reg: 0.0033 (0.0036)  time: 0.6655  data: 0.0379  max mem: 6101
# Epoch: [9]  [ 30/112]  eta: 0:00:59  lr: 0.000005  loss: 0.1676 (0.1591)  loss_classifier: 0.0462 (0.0483)  loss_box_reg: 0.1117 (0.1057)  loss_objectness: 0.0007 (0.0015)  loss_rpn_box_reg: 0.0030 (0.0035)  time: 0.6639  data: 0.0368  max mem: 6101
# Epoch: [9]  [ 40/112]  eta: 0:00:50  lr: 0.000005  loss: 0.1369 (0.1501)  loss_classifier: 0.0410 (0.0458)  loss_box_reg: 0.0918 (0.0997)  loss_objectness: 0.0008 (0.0014)  loss_rpn_box_reg: 0.0028 (0.0032)  time: 0.6649  data: 0.0368  max mem: 6101
# Epoch: [9]  [ 50/112]  eta: 0:00:43  lr: 0.000005  loss: 0.1154 (0.1558)  loss_classifier: 0.0387 (0.0471)  loss_box_reg: 0.0752 (0.1040)  loss_objectness: 0.0007 (0.0014)  loss_rpn_box_reg: 0.0024 (0.0033)  time: 0.6655  data: 0.0379  max mem: 6101
# Epoch: [9]  [ 60/112]  eta: 0:00:36  lr: 0.000005  loss: 0.1062 (0.1461)  loss_classifier: 0.0348 (0.0443)  loss_box_reg: 0.0718 (0.0973)  loss_objectness: 0.0006 (0.0014)  loss_rpn_box_reg: 0.0021 (0.0031)  time: 0.6657  data: 0.0375  max mem: 6101
# Epoch: [9]  [ 70/112]  eta: 0:00:28  lr: 0.000005  loss: 0.1212 (0.1461)  loss_classifier: 0.0348 (0.0439)  loss_box_reg: 0.0704 (0.0976)  loss_objectness: 0.0009 (0.0014)  loss_rpn_box_reg: 0.0022 (0.0033)  time: 0.6625  data: 0.0358  max mem: 6101
# Epoch: [9]  [ 80/112]  eta: 0:00:21  lr: 0.000005  loss: 0.1365 (0.1457)  loss_classifier: 0.0393 (0.0440)  loss_box_reg: 0.0934 (0.0969)  loss_objectness: 0.0007 (0.0014)  loss_rpn_box_reg: 0.0032 (0.0033)  time: 0.6670  data: 0.0371  max mem: 6101
# Epoch: [9]  [ 90/112]  eta: 0:00:15  lr: 0.000005  loss: 0.1263 (0.1452)  loss_classifier: 0.0393 (0.0440)  loss_box_reg: 0.0818 (0.0964)  loss_objectness: 0.0007 (0.0015)  loss_rpn_box_reg: 0.0023 (0.0033)  time: 0.6652  data: 0.0368  max mem: 6101
# Epoch: [9]  [100/112]  eta: 0:00:08  lr: 0.000005  loss: 0.1236 (0.1452)  loss_classifier: 0.0418 (0.0440)  loss_box_reg: 0.0785 (0.0965)  loss_objectness: 0.0007 (0.0015)  loss_rpn_box_reg: 0.0025 (0.0032)  time: 0.6593  data: 0.0358  max mem: 6101
# Epoch: [9]  [110/112]  eta: 0:00:01  lr: 0.000005  loss: 0.1198 (0.1450)  loss_classifier: 0.0380 (0.0442)  loss_box_reg: 0.0780 (0.0959)  loss_objectness: 0.0008 (0.0015)  loss_rpn_box_reg: 0.0027 (0.0033)  time: 0.6584  data: 0.0350  max mem: 6101
# Epoch: [9]  [111/112]  eta: 0:00:00  lr: 0.000005  loss: 0.1198 (0.1445)  loss_classifier: 0.0352 (0.0441)  loss_box_reg: 0.0780 (0.0957)  loss_objectness: 0.0008 (0.0015)  loss_rpn_box_reg: 0.0027 (0.0033)  time: 0.6428  data: 0.0341  max mem: 6101
# Epoch: [9] Total time: 0:01:15 (0.6768 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:22  model_time: 0.2900 (0.2900)  evaluator_time: 0.0052 (0.0052)  time: 1.1306  data: 0.7987  max mem: 6101
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2610 (0.2640)  evaluator_time: 0.0067 (0.0084)  time: 0.3788  data: 0.0734  max mem: 6101
# Test: Total time: 0:00:07 (0.3815 s / it)
# Averaged stats: model_time: 0.2610 (0.2640)  evaluator_time: 0.0067 (0.0084)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.233
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.534
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.122
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.440
