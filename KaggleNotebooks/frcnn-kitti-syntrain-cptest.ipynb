# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Download TorchVision repo to use some files from
# references/detection
# !pip install pycocotools --quiet
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 531477, done.
# remote: Counting objects: 100% (45087/45087), done.
# remote: Compressing objects: 100% (2079/2079), done.
# remote: Total 531477 (delta 43041), reused 44913 (delta 42935), pack-reused 486390
# Receiving objects: 100% (531477/531477), 1023.04 MiB | 42.16 MiB/s, done.
# Resolving deltas: 100% (496288/496288), done.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
from torch.utils.data import ConcatDataset

from torch.utils.data import Subset
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
from torch.utils.data import ConcatDataset

from torch.utils.data import Subset
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
# defining the files directory and testing directory
train_dir = '/kaggle/input/kitti-train-test-selection/Train_Test_Selection/Train'
test_dir = '/kaggle/input/citypersons-testselection/NewTest'

# %%
add_train_dir = '/kaggle/input/pedestriansyntheticdataset/train/train'

# %%
#for xml-annotatation dataset
class ImagesDataset(torch.utils.data.Dataset):

    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
            
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        
        
        # classes: 0 index is reserved for background
        self.classes = ['background','Pedestrian']

    def __getitem__(self, idx):

        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # reading the images and converting them to correct size and color    
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        # diving by 255
        img_res /= 255.0
        
        # annotation file
        annot_filename = img_name[:-4] + '.xml'
        annot_file_path = os.path.join(self.files_dir, annot_filename)
        
        boxes = []
        labels = []
        tree = et.parse(annot_file_path)
        root = tree.getroot()
        
        # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        
        # box coordinates for xml files are extracted and corrected for image size given
        for member in root.findall('object'):
            label_text = member.find('name').text.lower()
            if label_text in ['ped', 'pedestrian','person']:
                labels.append(self.classes.index('Pedestrian')) 
            
            # bounding box
                xmin = int(member.find('bndbox').find('xmin').text)
                xmax = int(member.find('bndbox').find('xmax').text)
            
                ymin = int(member.find('bndbox').find('ymin').text)
                ymax = int(member.find('bndbox').find('ymax').text)
            
            
                xmin_corr = (xmin/wt)*self.width
                xmax_corr = (xmax/wt)*self.width
                ymin_corr = (ymin/ht)*self.height
                ymax_corr = (ymax/ht)*self.height
            
                boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
          
        
        # convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        
        # getting the areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
        
        labels = torch.as_tensor(labels, dtype=torch.int64)


        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        # image_id
        image_id = idx
        target["image_id"] = image_id
        
  


        if self.transforms:
            
            sample = self.transforms(image = img_res,
                                     bboxes = target['boxes'],
                                     labels = labels)
            
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
            
            
            
        return img_res, target

    def __len__(self):
        return len(self.imgs)

# %%
#for txt-annotatation dataset
class KittiDataset(torch.utils.data.Dataset):
    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        self.classes = ['background', 'Pedestrian']

    def __getitem__(self, idx):
        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # Reading the images and converting them to correct size and color
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        img_res /= 255.0

        # Annotation file
        annot_filename = img_name[:-4] + '.txt'
        annot_file_path = os.path.join(self.files_dir, annot_filename)

        boxes = []
        labels = []

           # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        # Read annotation data from text file
        with open(annot_file_path, 'r') as file:
            for line in file:
                parts = line.strip().split(' ')
                label_text = parts[0].lower()

                if label_text in ['ped', 'pedestrian','person']:
                    labels.append(self.classes.index('Pedestrian'))

                    # Bounding box coordinates
                    xmin = float(parts[4])
                    ymin = float(parts[5])
                    xmax = float(parts[6])
                    ymax = float(parts[7])

                    # Normalize coordinates
                    xmin_corr = (xmin/wt)*self.width
                    xmax_corr = (xmax/wt)*self.width
                    ymin_corr = (ymin/ht)*self.height
                    ymax_corr = (ymax/ht)*self.height
    
                    boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])

        # Convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        #print("boxes shape: ", boxes.size(), "at index",idx, img_name)
       
      
           

        # Calculate areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # Suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)

        labels = torch.as_tensor(labels, dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd

        # image_id
        image_id = torch.tensor([idx])
        target["image_id"] = image_id

        if self.transforms:
            sample = self.transforms(image=img_res, bboxes=target['boxes'], labels=labels)
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
        return img_res, target
    
    

    def __len__(self):
        return len(self.imgs)

# %%
def get_object_detection_model(num_classes):

    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 

    return model

# %%
# Send train=True fro training transforms and False for val/test transforms
def get_transform(train):
    
    if train:
        return A.Compose([
            A.HorizontalFlip(0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
            A.Rotate(limit=15, p=0.5),
            ToTensorV2(p=1.0)
        ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']))
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
# use our dataset and defined transformations
train_dataset = KittiDataset(train_dir, 1920, 1080, transforms= get_transform(train=True))
add_train_dataset = ImagesDataset(add_train_dir, 1920, 1080, transforms= get_transform(train=True))
combined_dataset = ConcatDataset([train_dataset, add_train_dataset])
test_dataset = ImagesDataset(test_dir, 1920, 1080, transforms= get_transform(train=False))

# define training and validation data loaders
combined_data_loader_train = torch.utils.data.DataLoader(
    combined_dataset, batch_size=4, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    test_dataset, batch_size=4, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')


num_classes = 2

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:01<00:00, 159MB/s]

# %%
# training for 10 epochs
num_epochs = 10

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, combined_data_loader_train, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [  0/149]  eta: 0:11:30  lr: 0.000039  loss: 1.1507 (1.1507)  loss_classifier: 0.9322 (0.9322)  loss_box_reg: 0.1545 (0.1545)  loss_objectness: 0.0536 (0.0536)  loss_rpn_box_reg: 0.0103 (0.0103)  time: 4.6320  data: 2.0085  max mem: 4799
# Epoch: [0]  [ 10/149]  eta: 0:02:22  lr: 0.000376  loss: 1.0519 (0.9264)  loss_classifier: 0.7248 (0.6624)  loss_box_reg: 0.2031 (0.1935)  loss_objectness: 0.0521 (0.0466)  loss_rpn_box_reg: 0.0171 (0.0240)  time: 1.0217  data: 0.2127  max mem: 4957
# Epoch: [0]  [ 20/149]  eta: 0:01:49  lr: 0.000714  loss: 0.6247 (0.7348)  loss_classifier: 0.2893 (0.4565)  loss_box_reg: 0.2072 (0.2152)  loss_objectness: 0.0430 (0.0417)  loss_rpn_box_reg: 0.0167 (0.0214)  time: 0.6557  data: 0.0325  max mem: 4957
# Epoch: [0]  [ 30/149]  eta: 0:01:32  lr: 0.001051  loss: 0.4893 (0.6657)  loss_classifier: 0.2196 (0.3796)  loss_box_reg: 0.2210 (0.2185)  loss_objectness: 0.0213 (0.0437)  loss_rpn_box_reg: 0.0157 (0.0240)  time: 0.6486  data: 0.0323  max mem: 4958
# Epoch: [0]  [ 40/149]  eta: 0:01:21  lr: 0.001389  loss: 0.4688 (0.6081)  loss_classifier: 0.1498 (0.3201)  loss_box_reg: 0.1856 (0.2200)  loss_objectness: 0.0310 (0.0432)  loss_rpn_box_reg: 0.0157 (0.0248)  time: 0.6480  data: 0.0324  max mem: 4958
# Epoch: [0]  [ 50/149]  eta: 0:01:12  lr: 0.001726  loss: 0.3493 (0.5532)  loss_classifier: 0.0968 (0.2745)  loss_box_reg: 0.1809 (0.2133)  loss_objectness: 0.0306 (0.0398)  loss_rpn_box_reg: 0.0126 (0.0256)  time: 0.6524  data: 0.0334  max mem: 4958
# Epoch: [0]  [ 60/149]  eta: 0:01:03  lr: 0.002064  loss: 0.3255 (0.5235)  loss_classifier: 0.0887 (0.2457)  loss_box_reg: 0.1988 (0.2191)  loss_objectness: 0.0174 (0.0355)  loss_rpn_box_reg: 0.0114 (0.0232)  time: 0.6575  data: 0.0339  max mem: 4958
# Epoch: [0]  [ 70/149]  eta: 0:00:56  lr: 0.002401  loss: 0.2942 (0.4887)  loss_classifier: 0.0775 (0.2221)  loss_box_reg: 0.1896 (0.2128)  loss_objectness: 0.0134 (0.0325)  loss_rpn_box_reg: 0.0095 (0.0213)  time: 0.6548  data: 0.0327  max mem: 4958
# Epoch: [0]  [ 80/149]  eta: 0:00:48  lr: 0.002739  loss: 0.2262 (0.4664)  loss_classifier: 0.0642 (0.2048)  loss_box_reg: 0.1416 (0.2088)  loss_objectness: 0.0134 (0.0320)  loss_rpn_box_reg: 0.0091 (0.0208)  time: 0.6479  data: 0.0324  max mem: 4958
# Epoch: [0]  [ 90/149]  eta: 0:00:41  lr: 0.003076  loss: 0.2170 (0.4487)  loss_classifier: 0.0687 (0.1909)  loss_box_reg: 0.1217 (0.2039)  loss_objectness: 0.0142 (0.0336)  loss_rpn_box_reg: 0.0090 (0.0203)  time: 0.6502  data: 0.0320  max mem: 4958
# Epoch: [0]  [100/149]  eta: 0:00:33  lr: 0.003414  loss: 0.1923 (0.4246)  loss_classifier: 0.0596 (0.1777)  loss_box_reg: 0.1182 (0.1947)  loss_objectness: 0.0150 (0.0323)  loss_rpn_box_reg: 0.0090 (0.0200)  time: 0.6557  data: 0.0330  max mem: 4958
# Epoch: [0]  [110/149]  eta: 0:00:26  lr: 0.003751  loss: 0.2242 (0.4141)  loss_classifier: 0.0633 (0.1683)  loss_box_reg: 0.1166 (0.1902)  loss_objectness: 0.0208 (0.0346)  loss_rpn_box_reg: 0.0156 (0.0210)  time: 0.6571  data: 0.0350  max mem: 4958
# Epoch: [0]  [120/149]  eta: 0:00:19  lr: 0.004089  loss: 0.2434 (0.3983)  loss_classifier: 0.0666 (0.1595)  loss_box_reg: 0.1126 (0.1842)  loss_objectness: 0.0299 (0.0338)  loss_rpn_box_reg: 0.0108 (0.0209)  time: 0.6544  data: 0.0346  max mem: 4958
# Epoch: [0]  [130/149]  eta: 0:00:12  lr: 0.004426  loss: 0.1987 (0.3863)  loss_classifier: 0.0589 (0.1525)  loss_box_reg: 0.1067 (0.1808)  loss_objectness: 0.0168 (0.0325)  loss_rpn_box_reg: 0.0089 (0.0205)  time: 0.6537  data: 0.0344  max mem: 4958
# Epoch: [0]  [140/149]  eta: 0:00:06  lr: 0.004764  loss: 0.2468 (0.3780)  loss_classifier: 0.0653 (0.1471)  loss_box_reg: 0.1278 (0.1789)  loss_objectness: 0.0083 (0.0314)  loss_rpn_box_reg: 0.0124 (0.0206)  time: 0.6543  data: 0.0344  max mem: 4958
# Epoch: [0]  [148/149]  eta: 0:00:00  lr: 0.005000  loss: 0.2136 (0.3727)  loss_classifier: 0.0647 (0.1433)  loss_box_reg: 0.1243 (0.1772)  loss_objectness: 0.0096 (0.0316)  loss_rpn_box_reg: 0.0124 (0.0205)  time: 0.6259  data: 0.0306  max mem: 4958
# Epoch: [0] Total time: 0:01:40 (0.6768 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2914 (0.2914)  evaluator_time: 0.0231 (0.0231)  time: 0.9262  data: 0.5413  max mem: 4958
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2545 (0.2542)  evaluator_time: 0.0259 (0.0404)  time: 0.3786  data: 0.0546  max mem: 4958
# Test: Total time: 0:00:07 (0.3803 s / it)
# Averaged stats: model_time: 0.2545 (0.2542)  evaluator_time: 0.0259 (0.0404)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.142
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.375
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.140
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.347
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.227
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.428
# Epoch: [1]  [  0/149]  eta: 0:05:42  lr: 0.005000  loss: 0.1942 (0.1942)  loss_classifier: 0.0688 (0.0688)  loss_box_reg: 0.1128 (0.1128)  loss_objectness: 0.0071 (0.0071)  loss_rpn_box_reg: 0.0054 (0.0054)  time: 2.2960  data: 1.6285  max mem: 4958
# Epoch: [1]  [ 10/149]  eta: 0:01:51  lr: 0.005000  loss: 0.2028 (0.2353)  loss_classifier: 0.0566 (0.0620)  loss_box_reg: 0.1221 (0.1374)  loss_objectness: 0.0138 (0.0207)  loss_rpn_box_reg: 0.0074 (0.0152)  time: 0.8048  data: 0.1759  max mem: 4958
# Epoch: [1]  [ 20/149]  eta: 0:01:33  lr: 0.005000  loss: 0.1881 (0.2094)  loss_classifier: 0.0497 (0.0554)  loss_box_reg: 0.1232 (0.1288)  loss_objectness: 0.0090 (0.0134)  loss_rpn_box_reg: 0.0063 (0.0118)  time: 0.6499  data: 0.0303  max mem: 4958
# Epoch: [1]  [ 30/149]  eta: 0:01:23  lr: 0.005000  loss: 0.1755 (0.2179)  loss_classifier: 0.0482 (0.0567)  loss_box_reg: 0.1238 (0.1340)  loss_objectness: 0.0035 (0.0136)  loss_rpn_box_reg: 0.0065 (0.0137)  time: 0.6488  data: 0.0322  max mem: 4958
# Epoch: [1]  [ 40/149]  eta: 0:01:15  lr: 0.005000  loss: 0.1594 (0.2047)  loss_classifier: 0.0441 (0.0548)  loss_box_reg: 0.0885 (0.1246)  loss_objectness: 0.0057 (0.0127)  loss_rpn_box_reg: 0.0084 (0.0127)  time: 0.6520  data: 0.0336  max mem: 4958
# Epoch: [1]  [ 50/149]  eta: 0:01:07  lr: 0.005000  loss: 0.1742 (0.2118)  loss_classifier: 0.0459 (0.0580)  loss_box_reg: 0.0940 (0.1252)  loss_objectness: 0.0088 (0.0143)  loss_rpn_box_reg: 0.0124 (0.0142)  time: 0.6477  data: 0.0318  max mem: 4958
# Epoch: [1]  [ 60/149]  eta: 0:01:00  lr: 0.005000  loss: 0.2033 (0.2113)  loss_classifier: 0.0551 (0.0584)  loss_box_reg: 0.1034 (0.1241)  loss_objectness: 0.0115 (0.0144)  loss_rpn_box_reg: 0.0149 (0.0144)  time: 0.6452  data: 0.0313  max mem: 4958
# Epoch: [1]  [ 70/149]  eta: 0:00:53  lr: 0.005000  loss: 0.1712 (0.2116)  loss_classifier: 0.0592 (0.0595)  loss_box_reg: 0.0918 (0.1218)  loss_objectness: 0.0098 (0.0148)  loss_rpn_box_reg: 0.0100 (0.0155)  time: 0.6472  data: 0.0333  max mem: 4958
# Epoch: [1]  [ 80/149]  eta: 0:00:46  lr: 0.005000  loss: 0.2450 (0.2272)  loss_classifier: 0.0617 (0.0610)  loss_box_reg: 0.1335 (0.1249)  loss_objectness: 0.0098 (0.0231)  loss_rpn_box_reg: 0.0125 (0.0182)  time: 0.6483  data: 0.0341  max mem: 4958
# Epoch: [1]  [ 90/149]  eta: 0:00:39  lr: 0.005000  loss: 0.2657 (0.2270)  loss_classifier: 0.0632 (0.0601)  loss_box_reg: 0.1302 (0.1236)  loss_objectness: 0.0309 (0.0248)  loss_rpn_box_reg: 0.0150 (0.0185)  time: 0.6493  data: 0.0338  max mem: 4958
# Epoch: [1]  [100/149]  eta: 0:00:32  lr: 0.005000  loss: 0.2139 (0.2276)  loss_classifier: 0.0632 (0.0613)  loss_box_reg: 0.1061 (0.1232)  loss_objectness: 0.0227 (0.0243)  loss_rpn_box_reg: 0.0150 (0.0188)  time: 0.6487  data: 0.0334  max mem: 4958
# Epoch: [1]  [110/149]  eta: 0:00:25  lr: 0.005000  loss: 0.2243 (0.2331)  loss_classifier: 0.0724 (0.0637)  loss_box_reg: 0.1300 (0.1271)  loss_objectness: 0.0104 (0.0234)  loss_rpn_box_reg: 0.0079 (0.0189)  time: 0.6448  data: 0.0318  max mem: 4958
# Epoch: [1]  [120/149]  eta: 0:00:19  lr: 0.005000  loss: 0.2417 (0.2345)  loss_classifier: 0.0732 (0.0647)  loss_box_reg: 0.1512 (0.1293)  loss_objectness: 0.0073 (0.0222)  loss_rpn_box_reg: 0.0100 (0.0183)  time: 0.6457  data: 0.0323  max mem: 4958
# Epoch: [1]  [130/149]  eta: 0:00:12  lr: 0.005000  loss: 0.2377 (0.2330)  loss_classifier: 0.0691 (0.0645)  loss_box_reg: 0.1472 (0.1293)  loss_objectness: 0.0068 (0.0211)  loss_rpn_box_reg: 0.0100 (0.0181)  time: 0.6522  data: 0.0350  max mem: 4958
# Epoch: [1]  [140/149]  eta: 0:00:05  lr: 0.005000  loss: 0.2139 (0.2329)  loss_classifier: 0.0545 (0.0641)  loss_box_reg: 0.1093 (0.1274)  loss_objectness: 0.0097 (0.0230)  loss_rpn_box_reg: 0.0086 (0.0185)  time: 0.6513  data: 0.0353  max mem: 4958
# Epoch: [1]  [148/149]  eta: 0:00:00  lr: 0.005000  loss: 0.1789 (0.2330)  loss_classifier: 0.0450 (0.0633)  loss_box_reg: 0.0891 (0.1260)  loss_objectness: 0.0155 (0.0232)  loss_rpn_box_reg: 0.0075 (0.0205)  time: 0.6209  data: 0.0319  max mem: 4958
# Epoch: [1] Total time: 0:01:37 (0.6563 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:15  model_time: 0.2665 (0.2665)  evaluator_time: 0.0160 (0.0160)  time: 0.8402  data: 0.4924  max mem: 4958
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2540 (0.2515)  evaluator_time: 0.0197 (0.0305)  time: 0.3641  data: 0.0523  max mem: 4958
# Test: Total time: 0:00:06 (0.3659 s / it)
# Averaged stats: model_time: 0.2540 (0.2515)  evaluator_time: 0.0197 (0.0305)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.395
# Epoch: [2]  [  0/149]  eta: 0:04:47  lr: 0.005000  loss: 0.2774 (0.2774)  loss_classifier: 0.0635 (0.0635)  loss_box_reg: 0.1594 (0.1594)  loss_objectness: 0.0154 (0.0154)  loss_rpn_box_reg: 0.0391 (0.0391)  time: 1.9282  data: 1.2514  max mem: 4958
# Epoch: [2]  [ 10/149]  eta: 0:01:46  lr: 0.005000  loss: 0.1966 (0.1949)  loss_classifier: 0.0500 (0.0508)  loss_box_reg: 0.1102 (0.1136)  loss_objectness: 0.0097 (0.0125)  loss_rpn_box_reg: 0.0100 (0.0180)  time: 0.7635  data: 0.1430  max mem: 4959
# Epoch: [2]  [ 20/149]  eta: 0:01:31  lr: 0.005000  loss: 0.1765 (0.1984)  loss_classifier: 0.0500 (0.0532)  loss_box_reg: 0.1007 (0.1118)  loss_objectness: 0.0097 (0.0147)  loss_rpn_box_reg: 0.0100 (0.0187)  time: 0.6514  data: 0.0342  max mem: 4959
# Epoch: [2]  [ 30/149]  eta: 0:01:22  lr: 0.005000  loss: 0.1806 (0.2098)  loss_classifier: 0.0542 (0.0570)  loss_box_reg: 0.1007 (0.1226)  loss_objectness: 0.0101 (0.0127)  loss_rpn_box_reg: 0.0084 (0.0176)  time: 0.6537  data: 0.0350  max mem: 4959
# Epoch: [2]  [ 40/149]  eta: 0:01:14  lr: 0.005000  loss: 0.2129 (0.2107)  loss_classifier: 0.0579 (0.0572)  loss_box_reg: 0.1344 (0.1265)  loss_objectness: 0.0047 (0.0109)  loss_rpn_box_reg: 0.0075 (0.0162)  time: 0.6463  data: 0.0323  max mem: 4959
# Epoch: [2]  [ 50/149]  eta: 0:01:06  lr: 0.005000  loss: 0.1935 (0.2066)  loss_classifier: 0.0526 (0.0565)  loss_box_reg: 0.1295 (0.1237)  loss_objectness: 0.0043 (0.0101)  loss_rpn_box_reg: 0.0093 (0.0163)  time: 0.6401  data: 0.0303  max mem: 4959
# Epoch: [2]  [ 60/149]  eta: 0:00:59  lr: 0.005000  loss: 0.1739 (0.2072)  loss_classifier: 0.0518 (0.0568)  loss_box_reg: 0.1133 (0.1254)  loss_objectness: 0.0045 (0.0092)  loss_rpn_box_reg: 0.0100 (0.0158)  time: 0.6440  data: 0.0317  max mem: 4959
# Epoch: [2]  [ 70/149]  eta: 0:00:52  lr: 0.005000  loss: 0.1860 (0.2065)  loss_classifier: 0.0553 (0.0566)  loss_box_reg: 0.1183 (0.1250)  loss_objectness: 0.0061 (0.0090)  loss_rpn_box_reg: 0.0106 (0.0159)  time: 0.6506  data: 0.0345  max mem: 4959
# Epoch: [2]  [ 80/149]  eta: 0:00:45  lr: 0.005000  loss: 0.1942 (0.2067)  loss_classifier: 0.0559 (0.0571)  loss_box_reg: 0.1210 (0.1252)  loss_objectness: 0.0061 (0.0092)  loss_rpn_box_reg: 0.0094 (0.0153)  time: 0.6541  data: 0.0357  max mem: 4959
# Epoch: [2]  [ 90/149]  eta: 0:00:39  lr: 0.005000  loss: 0.1760 (0.2022)  loss_classifier: 0.0510 (0.0560)  loss_box_reg: 0.1096 (0.1226)  loss_objectness: 0.0052 (0.0090)  loss_rpn_box_reg: 0.0083 (0.0145)  time: 0.6526  data: 0.0350  max mem: 4959
# Epoch: [2]  [100/149]  eta: 0:00:32  lr: 0.005000  loss: 0.1814 (0.2082)  loss_classifier: 0.0515 (0.0579)  loss_box_reg: 0.1125 (0.1267)  loss_objectness: 0.0058 (0.0092)  loss_rpn_box_reg: 0.0069 (0.0144)  time: 0.6475  data: 0.0332  max mem: 4959
# Epoch: [2]  [110/149]  eta: 0:00:25  lr: 0.005000  loss: 0.1814 (0.2062)  loss_classifier: 0.0497 (0.0573)  loss_box_reg: 0.1239 (0.1259)  loss_objectness: 0.0060 (0.0089)  loss_rpn_box_reg: 0.0070 (0.0141)  time: 0.6491  data: 0.0331  max mem: 4959
# Epoch: [2]  [120/149]  eta: 0:00:19  lr: 0.005000  loss: 0.1777 (0.2084)  loss_classifier: 0.0480 (0.0577)  loss_box_reg: 0.1239 (0.1280)  loss_objectness: 0.0038 (0.0086)  loss_rpn_box_reg: 0.0095 (0.0140)  time: 0.6543  data: 0.0339  max mem: 4959
# Epoch: [2]  [130/149]  eta: 0:00:12  lr: 0.005000  loss: 0.2029 (0.2092)  loss_classifier: 0.0586 (0.0580)  loss_box_reg: 0.1348 (0.1283)  loss_objectness: 0.0047 (0.0085)  loss_rpn_box_reg: 0.0102 (0.0144)  time: 0.6490  data: 0.0327  max mem: 4959
# Epoch: [2]  [140/149]  eta: 0:00:05  lr: 0.005000  loss: 0.2029 (0.2108)  loss_classifier: 0.0558 (0.0581)  loss_box_reg: 0.1309 (0.1288)  loss_objectness: 0.0054 (0.0087)  loss_rpn_box_reg: 0.0122 (0.0151)  time: 0.6434  data: 0.0322  max mem: 4959
# Epoch: [2]  [148/149]  eta: 0:00:00  lr: 0.005000  loss: 0.2076 (0.2090)  loss_classifier: 0.0558 (0.0576)  loss_box_reg: 0.1309 (0.1278)  loss_objectness: 0.0062 (0.0086)  loss_rpn_box_reg: 0.0124 (0.0150)  time: 0.6169  data: 0.0297  max mem: 4959
# Epoch: [2] Total time: 0:01:37 (0.6539 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:16  model_time: 0.2676 (0.2676)  evaluator_time: 0.0181 (0.0181)  time: 0.8472  data: 0.5272  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2551 (0.2527)  evaluator_time: 0.0204 (0.0320)  time: 0.3679  data: 0.0550  max mem: 4959
# Test: Total time: 0:00:07 (0.3703 s / it)
# Averaged stats: model_time: 0.2551 (0.2527)  evaluator_time: 0.0204 (0.0320)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.124
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.386
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.146
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.174
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.185
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.397
# Epoch: [3]  [  0/149]  eta: 0:05:27  lr: 0.000500  loss: 0.3533 (0.3533)  loss_classifier: 0.0822 (0.0822)  loss_box_reg: 0.2062 (0.2062)  loss_objectness: 0.0073 (0.0073)  loss_rpn_box_reg: 0.0576 (0.0576)  time: 2.1993  data: 1.5666  max mem: 4959
# Epoch: [3]  [ 10/149]  eta: 0:01:49  lr: 0.000500  loss: 0.1774 (0.1829)  loss_classifier: 0.0493 (0.0494)  loss_box_reg: 0.0970 (0.1081)  loss_objectness: 0.0036 (0.0062)  loss_rpn_box_reg: 0.0169 (0.0192)  time: 0.7901  data: 0.1718  max mem: 4959
# Epoch: [3]  [ 20/149]  eta: 0:01:33  lr: 0.000500  loss: 0.1307 (0.1664)  loss_classifier: 0.0384 (0.0476)  loss_box_reg: 0.0746 (0.0983)  loss_objectness: 0.0047 (0.0065)  loss_rpn_box_reg: 0.0066 (0.0140)  time: 0.6484  data: 0.0325  max mem: 4959
# Epoch: [3]  [ 30/149]  eta: 0:01:22  lr: 0.000500  loss: 0.1336 (0.1755)  loss_classifier: 0.0398 (0.0496)  loss_box_reg: 0.0858 (0.1073)  loss_objectness: 0.0047 (0.0062)  loss_rpn_box_reg: 0.0055 (0.0124)  time: 0.6452  data: 0.0318  max mem: 4959
# Epoch: [3]  [ 40/149]  eta: 0:01:14  lr: 0.000500  loss: 0.1721 (0.1839)  loss_classifier: 0.0507 (0.0520)  loss_box_reg: 0.1123 (0.1095)  loss_objectness: 0.0047 (0.0095)  loss_rpn_box_reg: 0.0069 (0.0128)  time: 0.6429  data: 0.0315  max mem: 4959
# Epoch: [3]  [ 50/149]  eta: 0:01:07  lr: 0.000500  loss: 0.1660 (0.1779)  loss_classifier: 0.0478 (0.0508)  loss_box_reg: 0.1107 (0.1072)  loss_objectness: 0.0053 (0.0087)  loss_rpn_box_reg: 0.0056 (0.0113)  time: 0.6491  data: 0.0336  max mem: 4959
# Epoch: [3]  [ 60/149]  eta: 0:00:59  lr: 0.000500  loss: 0.1301 (0.1760)  loss_classifier: 0.0378 (0.0499)  loss_box_reg: 0.0878 (0.1074)  loss_objectness: 0.0033 (0.0078)  loss_rpn_box_reg: 0.0041 (0.0109)  time: 0.6497  data: 0.0339  max mem: 4959
# Epoch: [3]  [ 70/149]  eta: 0:00:52  lr: 0.000500  loss: 0.1633 (0.1795)  loss_classifier: 0.0413 (0.0512)  loss_box_reg: 0.1142 (0.1097)  loss_objectness: 0.0030 (0.0075)  loss_rpn_box_reg: 0.0060 (0.0111)  time: 0.6447  data: 0.0327  max mem: 4959
# Epoch: [3]  [ 80/149]  eta: 0:00:45  lr: 0.000500  loss: 0.1850 (0.1809)  loss_classifier: 0.0492 (0.0515)  loss_box_reg: 0.1175 (0.1110)  loss_objectness: 0.0035 (0.0073)  loss_rpn_box_reg: 0.0073 (0.0112)  time: 0.6438  data: 0.0323  max mem: 4959
# Epoch: [3]  [ 90/149]  eta: 0:00:39  lr: 0.000500  loss: 0.1870 (0.1828)  loss_classifier: 0.0486 (0.0520)  loss_box_reg: 0.1221 (0.1123)  loss_objectness: 0.0041 (0.0071)  loss_rpn_box_reg: 0.0069 (0.0113)  time: 0.6454  data: 0.0326  max mem: 4959
# Epoch: [3]  [100/149]  eta: 0:00:32  lr: 0.000500  loss: 0.1587 (0.1848)  loss_classifier: 0.0529 (0.0530)  loss_box_reg: 0.0883 (0.1130)  loss_objectness: 0.0060 (0.0075)  loss_rpn_box_reg: 0.0073 (0.0113)  time: 0.6505  data: 0.0346  max mem: 4959
# Epoch: [3]  [110/149]  eta: 0:00:25  lr: 0.000500  loss: 0.1587 (0.1827)  loss_classifier: 0.0529 (0.0527)  loss_box_reg: 0.0873 (0.1117)  loss_objectness: 0.0044 (0.0072)  loss_rpn_box_reg: 0.0059 (0.0110)  time: 0.6519  data: 0.0346  max mem: 4959
# Epoch: [3]  [120/149]  eta: 0:00:19  lr: 0.000500  loss: 0.1769 (0.1850)  loss_classifier: 0.0538 (0.0532)  loss_box_reg: 0.1000 (0.1133)  loss_objectness: 0.0032 (0.0070)  loss_rpn_box_reg: 0.0059 (0.0115)  time: 0.6498  data: 0.0338  max mem: 4959
# Epoch: [3]  [130/149]  eta: 0:00:12  lr: 0.000500  loss: 0.1805 (0.1849)  loss_classifier: 0.0505 (0.0531)  loss_box_reg: 0.1088 (0.1137)  loss_objectness: 0.0024 (0.0067)  loss_rpn_box_reg: 0.0054 (0.0115)  time: 0.6453  data: 0.0324  max mem: 4959
# Epoch: [3]  [140/149]  eta: 0:00:05  lr: 0.000500  loss: 0.1640 (0.1863)  loss_classifier: 0.0545 (0.0536)  loss_box_reg: 0.1083 (0.1148)  loss_objectness: 0.0024 (0.0066)  loss_rpn_box_reg: 0.0058 (0.0113)  time: 0.6444  data: 0.0321  max mem: 4959
# Epoch: [3]  [148/149]  eta: 0:00:00  lr: 0.000500  loss: 0.1753 (0.1893)  loss_classifier: 0.0514 (0.0539)  loss_box_reg: 0.1238 (0.1176)  loss_objectness: 0.0029 (0.0065)  loss_rpn_box_reg: 0.0065 (0.0113)  time: 0.6189  data: 0.0311  max mem: 4959
# Epoch: [3] Total time: 0:01:37 (0.6542 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:18  model_time: 0.2732 (0.2732)  evaluator_time: 0.0163 (0.0163)  time: 0.9584  data: 0.5992  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2541 (0.2523)  evaluator_time: 0.0168 (0.0271)  time: 0.3685  data: 0.0587  max mem: 4959
# Test: Total time: 0:00:07 (0.3704 s / it)
# Averaged stats: model_time: 0.2541 (0.2523)  evaluator_time: 0.0168 (0.0271)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.148
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.405
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.364
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.444
# Epoch: [4]  [  0/149]  eta: 0:04:36  lr: 0.000500  loss: 0.1420 (0.1420)  loss_classifier: 0.0373 (0.0373)  loss_box_reg: 0.0778 (0.0778)  loss_objectness: 0.0106 (0.0106)  loss_rpn_box_reg: 0.0162 (0.0162)  time: 1.8547  data: 1.2068  max mem: 4959
# Epoch: [4]  [ 10/149]  eta: 0:01:46  lr: 0.000500  loss: 0.1848 (0.1892)  loss_classifier: 0.0604 (0.0546)  loss_box_reg: 0.1035 (0.1195)  loss_objectness: 0.0059 (0.0052)  loss_rpn_box_reg: 0.0092 (0.0099)  time: 0.7629  data: 0.1386  max mem: 4959
# Epoch: [4]  [ 20/149]  eta: 0:01:31  lr: 0.000500  loss: 0.1714 (0.1768)  loss_classifier: 0.0430 (0.0506)  loss_box_reg: 0.1020 (0.1143)  loss_objectness: 0.0022 (0.0044)  loss_rpn_box_reg: 0.0062 (0.0076)  time: 0.6505  data: 0.0323  max mem: 4959
# Epoch: [4]  [ 30/149]  eta: 0:01:21  lr: 0.000500  loss: 0.1353 (0.1794)  loss_classifier: 0.0419 (0.0513)  loss_box_reg: 0.0895 (0.1152)  loss_objectness: 0.0022 (0.0045)  loss_rpn_box_reg: 0.0048 (0.0084)  time: 0.6462  data: 0.0323  max mem: 4959
# Epoch: [4]  [ 40/149]  eta: 0:01:13  lr: 0.000500  loss: 0.1751 (0.1879)  loss_classifier: 0.0463 (0.0536)  loss_box_reg: 0.1147 (0.1214)  loss_objectness: 0.0039 (0.0044)  loss_rpn_box_reg: 0.0054 (0.0086)  time: 0.6454  data: 0.0324  max mem: 4959
# Epoch: [4]  [ 50/149]  eta: 0:01:06  lr: 0.000500  loss: 0.1630 (0.1829)  loss_classifier: 0.0463 (0.0524)  loss_box_reg: 0.1058 (0.1180)  loss_objectness: 0.0029 (0.0041)  loss_rpn_box_reg: 0.0076 (0.0084)  time: 0.6445  data: 0.0322  max mem: 4959
# Epoch: [4]  [ 60/149]  eta: 0:00:59  lr: 0.000500  loss: 0.1325 (0.1813)  loss_classifier: 0.0381 (0.0514)  loss_box_reg: 0.0922 (0.1147)  loss_objectness: 0.0025 (0.0053)  loss_rpn_box_reg: 0.0069 (0.0099)  time: 0.6447  data: 0.0313  max mem: 4959
# Epoch: [4]  [ 70/149]  eta: 0:00:52  lr: 0.000500  loss: 0.1499 (0.1841)  loss_classifier: 0.0399 (0.0521)  loss_box_reg: 0.0947 (0.1162)  loss_objectness: 0.0047 (0.0056)  loss_rpn_box_reg: 0.0062 (0.0102)  time: 0.6482  data: 0.0325  max mem: 4959
# Epoch: [4]  [ 80/149]  eta: 0:00:45  lr: 0.000500  loss: 0.1612 (0.1793)  loss_classifier: 0.0484 (0.0509)  loss_box_reg: 0.0996 (0.1129)  loss_objectness: 0.0060 (0.0057)  loss_rpn_box_reg: 0.0062 (0.0098)  time: 0.6479  data: 0.0326  max mem: 4959
# Epoch: [4]  [ 90/149]  eta: 0:00:38  lr: 0.000500  loss: 0.1401 (0.1780)  loss_classifier: 0.0443 (0.0508)  loss_box_reg: 0.0909 (0.1118)  loss_objectness: 0.0025 (0.0057)  loss_rpn_box_reg: 0.0051 (0.0097)  time: 0.6444  data: 0.0310  max mem: 4959
# Epoch: [4]  [100/149]  eta: 0:00:32  lr: 0.000500  loss: 0.1556 (0.1793)  loss_classifier: 0.0443 (0.0511)  loss_box_reg: 0.1002 (0.1122)  loss_objectness: 0.0018 (0.0057)  loss_rpn_box_reg: 0.0038 (0.0103)  time: 0.6455  data: 0.0325  max mem: 4959
# Epoch: [4]  [110/149]  eta: 0:00:25  lr: 0.000500  loss: 0.1584 (0.1806)  loss_classifier: 0.0487 (0.0518)  loss_box_reg: 0.1010 (0.1127)  loss_objectness: 0.0031 (0.0057)  loss_rpn_box_reg: 0.0087 (0.0104)  time: 0.6436  data: 0.0324  max mem: 4959
# Epoch: [4]  [120/149]  eta: 0:00:19  lr: 0.000500  loss: 0.1501 (0.1796)  loss_classifier: 0.0422 (0.0514)  loss_box_reg: 0.1010 (0.1122)  loss_objectness: 0.0028 (0.0055)  loss_rpn_box_reg: 0.0087 (0.0105)  time: 0.6429  data: 0.0320  max mem: 4959
# Epoch: [4]  [130/149]  eta: 0:00:12  lr: 0.000500  loss: 0.1957 (0.1804)  loss_classifier: 0.0542 (0.0517)  loss_box_reg: 0.1132 (0.1129)  loss_objectness: 0.0031 (0.0055)  loss_rpn_box_reg: 0.0061 (0.0102)  time: 0.6473  data: 0.0333  max mem: 4959
# Epoch: [4]  [140/149]  eta: 0:00:05  lr: 0.000500  loss: 0.1832 (0.1806)  loss_classifier: 0.0540 (0.0515)  loss_box_reg: 0.1132 (0.1133)  loss_objectness: 0.0037 (0.0054)  loss_rpn_box_reg: 0.0061 (0.0104)  time: 0.6486  data: 0.0332  max mem: 4959
# Epoch: [4]  [148/149]  eta: 0:00:00  lr: 0.000500  loss: 0.1618 (0.1876)  loss_classifier: 0.0540 (0.0550)  loss_box_reg: 0.1120 (0.1167)  loss_objectness: 0.0032 (0.0054)  loss_rpn_box_reg: 0.0068 (0.0106)  time: 0.6193  data: 0.0304  max mem: 4959
# Epoch: [4] Total time: 0:01:37 (0.6512 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:15  model_time: 0.2835 (0.2835)  evaluator_time: 0.0143 (0.0143)  time: 0.8055  data: 0.4618  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2549 (0.2533)  evaluator_time: 0.0144 (0.0240)  time: 0.3573  data: 0.0512  max mem: 4959
# Test: Total time: 0:00:06 (0.3592 s / it)
# Averaged stats: model_time: 0.2549 (0.2533)  evaluator_time: 0.0144 (0.0240)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.143
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.359
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.166
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.440
# Epoch: [5]  [  0/149]  eta: 0:04:08  lr: 0.000500  loss: 0.2777 (0.2777)  loss_classifier: 0.0788 (0.0788)  loss_box_reg: 0.1831 (0.1831)  loss_objectness: 0.0054 (0.0054)  loss_rpn_box_reg: 0.0103 (0.0103)  time: 1.6708  data: 0.9009  max mem: 4959
# Epoch: [5]  [ 10/149]  eta: 0:01:44  lr: 0.000500  loss: 0.2222 (0.2024)  loss_classifier: 0.0618 (0.0569)  loss_box_reg: 0.1286 (0.1263)  loss_objectness: 0.0051 (0.0054)  loss_rpn_box_reg: 0.0103 (0.0138)  time: 0.7532  data: 0.1175  max mem: 4959
# Epoch: [5]  [ 20/149]  eta: 0:01:30  lr: 0.000500  loss: 0.1488 (0.1726)  loss_classifier: 0.0395 (0.0495)  loss_box_reg: 0.0848 (0.1081)  loss_objectness: 0.0030 (0.0042)  loss_rpn_box_reg: 0.0056 (0.0108)  time: 0.6534  data: 0.0355  max mem: 4959
# Epoch: [5]  [ 30/149]  eta: 0:01:21  lr: 0.000500  loss: 0.1394 (0.1677)  loss_classifier: 0.0395 (0.0477)  loss_box_reg: 0.0777 (0.1038)  loss_objectness: 0.0025 (0.0043)  loss_rpn_box_reg: 0.0056 (0.0119)  time: 0.6450  data: 0.0317  max mem: 4959
# Epoch: [5]  [ 40/149]  eta: 0:01:13  lr: 0.000500  loss: 0.1747 (0.1767)  loss_classifier: 0.0476 (0.0511)  loss_box_reg: 0.0961 (0.1106)  loss_objectness: 0.0043 (0.0044)  loss_rpn_box_reg: 0.0058 (0.0107)  time: 0.6456  data: 0.0322  max mem: 4959
# Epoch: [5]  [ 50/149]  eta: 0:01:06  lr: 0.000500  loss: 0.1847 (0.1794)  loss_classifier: 0.0514 (0.0515)  loss_box_reg: 0.1240 (0.1118)  loss_objectness: 0.0047 (0.0046)  loss_rpn_box_reg: 0.0056 (0.0115)  time: 0.6490  data: 0.0344  max mem: 4959
# Epoch: [5]  [ 60/149]  eta: 0:00:59  lr: 0.000500  loss: 0.1611 (0.1823)  loss_classifier: 0.0460 (0.0526)  loss_box_reg: 0.0972 (0.1127)  loss_objectness: 0.0050 (0.0056)  loss_rpn_box_reg: 0.0072 (0.0115)  time: 0.6503  data: 0.0347  max mem: 4959
# Epoch: [5]  [ 70/149]  eta: 0:00:52  lr: 0.000500  loss: 0.1611 (0.1822)  loss_classifier: 0.0454 (0.0525)  loss_box_reg: 0.0972 (0.1122)  loss_objectness: 0.0043 (0.0056)  loss_rpn_box_reg: 0.0082 (0.0119)  time: 0.6525  data: 0.0347  max mem: 4959
# Epoch: [5]  [ 80/149]  eta: 0:00:45  lr: 0.000500  loss: 0.1626 (0.1855)  loss_classifier: 0.0561 (0.0537)  loss_box_reg: 0.1025 (0.1146)  loss_objectness: 0.0043 (0.0056)  loss_rpn_box_reg: 0.0105 (0.0115)  time: 0.6500  data: 0.0343  max mem: 4959
# Epoch: [5]  [ 90/149]  eta: 0:00:38  lr: 0.000500  loss: 0.1729 (0.1878)  loss_classifier: 0.0552 (0.0546)  loss_box_reg: 0.1025 (0.1151)  loss_objectness: 0.0050 (0.0063)  loss_rpn_box_reg: 0.0106 (0.0117)  time: 0.6458  data: 0.0332  max mem: 4959
# Epoch: [5]  [100/149]  eta: 0:00:32  lr: 0.000500  loss: 0.1877 (0.1915)  loss_classifier: 0.0549 (0.0548)  loss_box_reg: 0.0966 (0.1160)  loss_objectness: 0.0073 (0.0089)  loss_rpn_box_reg: 0.0096 (0.0117)  time: 0.6506  data: 0.0345  max mem: 4959
# Epoch: [5]  [110/149]  eta: 0:00:25  lr: 0.000500  loss: 0.1850 (0.1932)  loss_classifier: 0.0541 (0.0554)  loss_box_reg: 0.1145 (0.1179)  loss_objectness: 0.0039 (0.0085)  loss_rpn_box_reg: 0.0075 (0.0115)  time: 0.6519  data: 0.0346  max mem: 4959
# Epoch: [5]  [120/149]  eta: 0:00:19  lr: 0.000500  loss: 0.1686 (0.1900)  loss_classifier: 0.0447 (0.0546)  loss_box_reg: 0.1045 (0.1155)  loss_objectness: 0.0036 (0.0085)  loss_rpn_box_reg: 0.0042 (0.0114)  time: 0.6481  data: 0.0332  max mem: 4959
# Epoch: [5]  [130/149]  eta: 0:00:12  lr: 0.000500  loss: 0.1213 (0.1911)  loss_classifier: 0.0419 (0.0541)  loss_box_reg: 0.0833 (0.1150)  loss_objectness: 0.0030 (0.0086)  loss_rpn_box_reg: 0.0042 (0.0134)  time: 0.6434  data: 0.0316  max mem: 4959
# Epoch: [5]  [140/149]  eta: 0:00:05  lr: 0.000500  loss: 0.1671 (0.1893)  loss_classifier: 0.0456 (0.0533)  loss_box_reg: 0.0956 (0.1142)  loss_objectness: 0.0028 (0.0083)  loss_rpn_box_reg: 0.0057 (0.0134)  time: 0.6401  data: 0.0302  max mem: 4959
# Epoch: [5]  [148/149]  eta: 0:00:00  lr: 0.000500  loss: 0.1362 (0.1855)  loss_classifier: 0.0401 (0.0524)  loss_box_reg: 0.0947 (0.1122)  loss_objectness: 0.0027 (0.0080)  loss_rpn_box_reg: 0.0050 (0.0129)  time: 0.6141  data: 0.0285  max mem: 4959
# Epoch: [5] Total time: 0:01:37 (0.6517 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:16  model_time: 0.2595 (0.2595)  evaluator_time: 0.0141 (0.0141)  time: 0.8882  data: 0.5360  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2550 (0.2523)  evaluator_time: 0.0144 (0.0242)  time: 0.3636  data: 0.0551  max mem: 4959
# Test: Total time: 0:00:06 (0.3654 s / it)
# Averaged stats: model_time: 0.2550 (0.2523)  evaluator_time: 0.0144 (0.0242)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.138
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.133
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.158
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.180
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.422
# Epoch: [6]  [  0/149]  eta: 0:05:35  lr: 0.000050  loss: 0.1169 (0.1169)  loss_classifier: 0.0361 (0.0361)  loss_box_reg: 0.0572 (0.0572)  loss_objectness: 0.0092 (0.0092)  loss_rpn_box_reg: 0.0145 (0.0145)  time: 2.2499  data: 1.5469  max mem: 4959
# Epoch: [6]  [ 10/149]  eta: 0:01:51  lr: 0.000050  loss: 0.1772 (0.1809)  loss_classifier: 0.0494 (0.0496)  loss_box_reg: 0.1197 (0.1114)  loss_objectness: 0.0033 (0.0061)  loss_rpn_box_reg: 0.0114 (0.0138)  time: 0.8008  data: 0.1730  max mem: 4959
# Epoch: [6]  [ 20/149]  eta: 0:01:33  lr: 0.000050  loss: 0.1836 (0.1775)  loss_classifier: 0.0495 (0.0506)  loss_box_reg: 0.1185 (0.1081)  loss_objectness: 0.0035 (0.0054)  loss_rpn_box_reg: 0.0111 (0.0134)  time: 0.6498  data: 0.0339  max mem: 4959
# Epoch: [6]  [ 30/149]  eta: 0:01:23  lr: 0.000050  loss: 0.1827 (0.1800)  loss_classifier: 0.0468 (0.0502)  loss_box_reg: 0.1068 (0.1068)  loss_objectness: 0.0053 (0.0069)  loss_rpn_box_reg: 0.0111 (0.0159)  time: 0.6441  data: 0.0324  max mem: 4959
# Epoch: [6]  [ 40/149]  eta: 0:01:14  lr: 0.000050  loss: 0.1827 (0.1850)  loss_classifier: 0.0467 (0.0530)  loss_box_reg: 0.1068 (0.1118)  loss_objectness: 0.0038 (0.0060)  loss_rpn_box_reg: 0.0093 (0.0141)  time: 0.6460  data: 0.0328  max mem: 4959
# Epoch: [6]  [ 50/149]  eta: 0:01:07  lr: 0.000050  loss: 0.1466 (0.1792)  loss_classifier: 0.0440 (0.0518)  loss_box_reg: 0.0827 (0.1084)  loss_objectness: 0.0033 (0.0059)  loss_rpn_box_reg: 0.0077 (0.0132)  time: 0.6505  data: 0.0340  max mem: 4959
# Epoch: [6]  [ 60/149]  eta: 0:01:00  lr: 0.000050  loss: 0.1466 (0.1811)  loss_classifier: 0.0423 (0.0523)  loss_box_reg: 0.0827 (0.1101)  loss_objectness: 0.0032 (0.0059)  loss_rpn_box_reg: 0.0079 (0.0128)  time: 0.6493  data: 0.0334  max mem: 4959
# Epoch: [6]  [ 70/149]  eta: 0:00:52  lr: 0.000050  loss: 0.1389 (0.1793)  loss_classifier: 0.0406 (0.0519)  loss_box_reg: 0.0861 (0.1088)  loss_objectness: 0.0053 (0.0060)  loss_rpn_box_reg: 0.0058 (0.0125)  time: 0.6451  data: 0.0328  max mem: 4959
# Epoch: [6]  [ 80/149]  eta: 0:00:46  lr: 0.000050  loss: 0.1389 (0.1792)  loss_classifier: 0.0413 (0.0518)  loss_box_reg: 0.0861 (0.1094)  loss_objectness: 0.0022 (0.0056)  loss_rpn_box_reg: 0.0058 (0.0124)  time: 0.6452  data: 0.0325  max mem: 4959
# Epoch: [6]  [ 90/149]  eta: 0:00:39  lr: 0.000050  loss: 0.1759 (0.1794)  loss_classifier: 0.0454 (0.0515)  loss_box_reg: 0.1084 (0.1106)  loss_objectness: 0.0023 (0.0054)  loss_rpn_box_reg: 0.0056 (0.0119)  time: 0.6425  data: 0.0306  max mem: 4959
# Epoch: [6]  [100/149]  eta: 0:00:32  lr: 0.000050  loss: 0.1621 (0.1795)  loss_classifier: 0.0418 (0.0513)  loss_box_reg: 0.1084 (0.1106)  loss_objectness: 0.0028 (0.0055)  loss_rpn_box_reg: 0.0055 (0.0121)  time: 0.6440  data: 0.0316  max mem: 4959
# Epoch: [6]  [110/149]  eta: 0:00:25  lr: 0.000050  loss: 0.1772 (0.1824)  loss_classifier: 0.0492 (0.0521)  loss_box_reg: 0.1169 (0.1132)  loss_objectness: 0.0035 (0.0053)  loss_rpn_box_reg: 0.0065 (0.0117)  time: 0.6464  data: 0.0327  max mem: 4959
# Epoch: [6]  [120/149]  eta: 0:00:19  lr: 0.000050  loss: 0.2006 (0.1859)  loss_classifier: 0.0492 (0.0528)  loss_box_reg: 0.1338 (0.1156)  loss_objectness: 0.0028 (0.0054)  loss_rpn_box_reg: 0.0058 (0.0121)  time: 0.6459  data: 0.0326  max mem: 4959
# Epoch: [6]  [130/149]  eta: 0:00:12  lr: 0.000050  loss: 0.1768 (0.1842)  loss_classifier: 0.0441 (0.0523)  loss_box_reg: 0.1207 (0.1149)  loss_objectness: 0.0026 (0.0052)  loss_rpn_box_reg: 0.0050 (0.0119)  time: 0.6474  data: 0.0332  max mem: 4959
# Epoch: [6]  [140/149]  eta: 0:00:05  lr: 0.000050  loss: 0.1257 (0.1803)  loss_classifier: 0.0359 (0.0514)  loss_box_reg: 0.0787 (0.1124)  loss_objectness: 0.0023 (0.0050)  loss_rpn_box_reg: 0.0035 (0.0114)  time: 0.6472  data: 0.0335  max mem: 4959
# Epoch: [6]  [148/149]  eta: 0:00:00  lr: 0.000050  loss: 0.1260 (0.1802)  loss_classifier: 0.0382 (0.0513)  loss_box_reg: 0.0787 (0.1122)  loss_objectness: 0.0024 (0.0051)  loss_rpn_box_reg: 0.0033 (0.0115)  time: 0.6200  data: 0.0309  max mem: 4959
# Epoch: [6] Total time: 0:01:37 (0.6542 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2765 (0.2765)  evaluator_time: 0.0161 (0.0161)  time: 0.9096  data: 0.5358  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2545 (0.2534)  evaluator_time: 0.0160 (0.0244)  time: 0.3625  data: 0.0537  max mem: 4959
# Test: Total time: 0:00:06 (0.3643 s / it)
# Averaged stats: model_time: 0.2545 (0.2534)  evaluator_time: 0.0160 (0.0244)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.408
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.143
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.434
# Epoch: [7]  [  0/149]  eta: 0:05:10  lr: 0.000050  loss: 0.1357 (0.1357)  loss_classifier: 0.0437 (0.0437)  loss_box_reg: 0.0898 (0.0898)  loss_objectness: 0.0012 (0.0012)  loss_rpn_box_reg: 0.0010 (0.0010)  time: 2.0863  data: 1.3835  max mem: 4959
# Epoch: [7]  [ 10/149]  eta: 0:01:48  lr: 0.000050  loss: 0.1618 (0.1684)  loss_classifier: 0.0446 (0.0492)  loss_box_reg: 0.0976 (0.1092)  loss_objectness: 0.0023 (0.0036)  loss_rpn_box_reg: 0.0035 (0.0064)  time: 0.7810  data: 0.1532  max mem: 4959
# Epoch: [7]  [ 20/149]  eta: 0:01:32  lr: 0.000050  loss: 0.1488 (0.1552)  loss_classifier: 0.0403 (0.0446)  loss_box_reg: 0.0976 (0.1011)  loss_objectness: 0.0044 (0.0041)  loss_rpn_box_reg: 0.0035 (0.0053)  time: 0.6487  data: 0.0307  max mem: 4959
# Epoch: [7]  [ 30/149]  eta: 0:01:22  lr: 0.000050  loss: 0.1343 (0.1546)  loss_classifier: 0.0420 (0.0461)  loss_box_reg: 0.0818 (0.0962)  loss_objectness: 0.0044 (0.0047)  loss_rpn_box_reg: 0.0037 (0.0077)  time: 0.6502  data: 0.0328  max mem: 4959
# Epoch: [7]  [ 40/149]  eta: 0:01:14  lr: 0.000050  loss: 0.1218 (0.1633)  loss_classifier: 0.0420 (0.0482)  loss_box_reg: 0.0767 (0.1013)  loss_objectness: 0.0035 (0.0046)  loss_rpn_box_reg: 0.0059 (0.0091)  time: 0.6494  data: 0.0333  max mem: 4959
# Epoch: [7]  [ 50/149]  eta: 0:01:06  lr: 0.000050  loss: 0.1236 (0.1603)  loss_classifier: 0.0395 (0.0467)  loss_box_reg: 0.0849 (0.1003)  loss_objectness: 0.0035 (0.0044)  loss_rpn_box_reg: 0.0059 (0.0088)  time: 0.6453  data: 0.0323  max mem: 4959
# Epoch: [7]  [ 60/149]  eta: 0:00:59  lr: 0.000050  loss: 0.1507 (0.1662)  loss_classifier: 0.0423 (0.0468)  loss_box_reg: 0.0900 (0.1009)  loss_objectness: 0.0022 (0.0050)  loss_rpn_box_reg: 0.0050 (0.0136)  time: 0.6451  data: 0.0325  max mem: 4959
# Epoch: [7]  [ 70/149]  eta: 0:00:52  lr: 0.000050  loss: 0.1593 (0.1720)  loss_classifier: 0.0492 (0.0487)  loss_box_reg: 0.1067 (0.1044)  loss_objectness: 0.0030 (0.0051)  loss_rpn_box_reg: 0.0067 (0.0138)  time: 0.6438  data: 0.0321  max mem: 4959
# Epoch: [7]  [ 80/149]  eta: 0:00:45  lr: 0.000050  loss: 0.1397 (0.1727)  loss_classifier: 0.0445 (0.0493)  loss_box_reg: 0.0920 (0.1053)  loss_objectness: 0.0046 (0.0052)  loss_rpn_box_reg: 0.0071 (0.0129)  time: 0.6484  data: 0.0337  max mem: 4959
# Epoch: [7]  [ 90/149]  eta: 0:00:39  lr: 0.000050  loss: 0.1532 (0.1759)  loss_classifier: 0.0556 (0.0502)  loss_box_reg: 0.0826 (0.1076)  loss_objectness: 0.0046 (0.0051)  loss_rpn_box_reg: 0.0072 (0.0130)  time: 0.6528  data: 0.0346  max mem: 4959
# Epoch: [7]  [100/149]  eta: 0:00:32  lr: 0.000050  loss: 0.1716 (0.1745)  loss_classifier: 0.0424 (0.0496)  loss_box_reg: 0.1021 (0.1075)  loss_objectness: 0.0039 (0.0049)  loss_rpn_box_reg: 0.0072 (0.0126)  time: 0.6466  data: 0.0323  max mem: 4959
# Epoch: [7]  [110/149]  eta: 0:00:25  lr: 0.000050  loss: 0.1871 (0.1777)  loss_classifier: 0.0521 (0.0507)  loss_box_reg: 0.1129 (0.1094)  loss_objectness: 0.0024 (0.0048)  loss_rpn_box_reg: 0.0072 (0.0128)  time: 0.6421  data: 0.0316  max mem: 4959
# Epoch: [7]  [120/149]  eta: 0:00:19  lr: 0.000050  loss: 0.1871 (0.1766)  loss_classifier: 0.0529 (0.0503)  loss_box_reg: 0.1129 (0.1093)  loss_objectness: 0.0031 (0.0047)  loss_rpn_box_reg: 0.0086 (0.0123)  time: 0.6415  data: 0.0318  max mem: 4959
# Epoch: [7]  [130/149]  eta: 0:00:12  lr: 0.000050  loss: 0.1525 (0.1784)  loss_classifier: 0.0414 (0.0507)  loss_box_reg: 0.0993 (0.1101)  loss_objectness: 0.0044 (0.0049)  loss_rpn_box_reg: 0.0086 (0.0127)  time: 0.6478  data: 0.0338  max mem: 4959
# Epoch: [7]  [140/149]  eta: 0:00:05  lr: 0.000050  loss: 0.1625 (0.1783)  loss_classifier: 0.0457 (0.0504)  loss_box_reg: 0.0992 (0.1103)  loss_objectness: 0.0036 (0.0049)  loss_rpn_box_reg: 0.0166 (0.0127)  time: 0.6523  data: 0.0345  max mem: 4959
# Epoch: [7]  [148/149]  eta: 0:00:00  lr: 0.000050  loss: 0.1761 (0.1786)  loss_classifier: 0.0462 (0.0504)  loss_box_reg: 0.1144 (0.1108)  loss_objectness: 0.0036 (0.0049)  loss_rpn_box_reg: 0.0053 (0.0125)  time: 0.6219  data: 0.0308  max mem: 4959
# Epoch: [7] Total time: 0:01:37 (0.6536 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:18  model_time: 0.2772 (0.2772)  evaluator_time: 0.0135 (0.0135)  time: 0.9851  data: 0.6092  max mem: 4959
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2543 (0.2529)  evaluator_time: 0.0152 (0.0243)  time: 0.3653  data: 0.0576  max mem: 4959
# Test: Total time: 0:00:06 (0.3673 s / it)
# Averaged stats: model_time: 0.2543 (0.2529)  evaluator_time: 0.0152 (0.0243)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.415
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.143
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.359
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.428
# Epoch: [8]  [  0/149]  eta: 0:05:14  lr: 0.000050  loss: 0.1312 (0.1312)  loss_classifier: 0.0544 (0.0544)  loss_box_reg: 0.0595 (0.0595)  loss_objectness: 0.0070 (0.0070)  loss_rpn_box_reg: 0.0103 (0.0103)  time: 2.1077  data: 1.4392  max mem: 4959
# Epoch: [8]  [ 10/149]  eta: 0:01:51  lr: 0.000050  loss: 0.1950 (0.2031)  loss_classifier: 0.0578 (0.0572)  loss_box_reg: 0.1288 (0.1203)  loss_objectness: 0.0037 (0.0065)  loss_rpn_box_reg: 0.0072 (0.0192)  time: 0.8013  data: 0.1679  max mem: 4959
# Epoch: [8]  [ 20/149]  eta: 0:01:33  lr: 0.000050  loss: 0.1950 (0.2020)  loss_classifier: 0.0578 (0.0572)  loss_box_reg: 0.1288 (0.1254)  loss_objectness: 0.0021 (0.0047)  loss_rpn_box_reg: 0.0072 (0.0146)  time: 0.6592  data: 0.0374  max mem: 4959
# Epoch: [8]  [ 30/149]  eta: 0:01:23  lr: 0.000050  loss: 0.1550 (0.1955)  loss_classifier: 0.0421 (0.0560)  loss_box_reg: 0.1130 (0.1222)  loss_objectness: 0.0021 (0.0050)  loss_rpn_box_reg: 0.0058 (0.0123)  time: 0.6472  data: 0.0333  max mem: 4960
# Epoch: [8]  [ 40/149]  eta: 0:01:14  lr: 0.000050  loss: 0.1541 (0.2029)  loss_classifier: 0.0390 (0.0582)  loss_box_reg: 0.1041 (0.1267)  loss_objectness: 0.0036 (0.0050)  loss_rpn_box_reg: 0.0047 (0.0129)  time: 0.6445  data: 0.0321  max mem: 4960
# Epoch: [8]  [ 50/149]  eta: 0:01:07  lr: 0.000050  loss: 0.1705 (0.2017)  loss_classifier: 0.0461 (0.0575)  loss_box_reg: 0.1050 (0.1258)  loss_objectness: 0.0039 (0.0056)  loss_rpn_box_reg: 0.0048 (0.0128)  time: 0.6415  data: 0.0313  max mem: 4960
# Epoch: [8]  [ 60/149]  eta: 0:00:59  lr: 0.000050  loss: 0.1985 (0.2016)  loss_classifier: 0.0518 (0.0577)  loss_box_reg: 0.1262 (0.1257)  loss_objectness: 0.0046 (0.0057)  loss_rpn_box_reg: 0.0059 (0.0124)  time: 0.6424  data: 0.0315  max mem: 4960
# Epoch: [8]  [ 70/149]  eta: 0:00:52  lr: 0.000050  loss: 0.1410 (0.1918)  loss_classifier: 0.0399 (0.0548)  loss_box_reg: 0.0870 (0.1199)  loss_objectness: 0.0019 (0.0055)  loss_rpn_box_reg: 0.0049 (0.0116)  time: 0.6474  data: 0.0324  max mem: 4960
# Epoch: [8]  [ 80/149]  eta: 0:00:45  lr: 0.000050  loss: 0.1295 (0.1887)  loss_classifier: 0.0389 (0.0543)  loss_box_reg: 0.0832 (0.1182)  loss_objectness: 0.0012 (0.0053)  loss_rpn_box_reg: 0.0047 (0.0110)  time: 0.6465  data: 0.0323  max mem: 4960
# Epoch: [8]  [ 90/149]  eta: 0:00:39  lr: 0.000050  loss: 0.1351 (0.1822)  loss_classifier: 0.0389 (0.0524)  loss_box_reg: 0.0782 (0.1141)  loss_objectness: 0.0017 (0.0051)  loss_rpn_box_reg: 0.0047 (0.0106)  time: 0.6441  data: 0.0326  max mem: 4960
# Epoch: [8]  [100/149]  eta: 0:00:32  lr: 0.000050  loss: 0.1506 (0.1824)  loss_classifier: 0.0395 (0.0522)  loss_box_reg: 0.0914 (0.1145)  loss_objectness: 0.0027 (0.0050)  loss_rpn_box_reg: 0.0063 (0.0107)  time: 0.6455  data: 0.0334  max mem: 4960
# Epoch: [8]  [110/149]  eta: 0:00:25  lr: 0.000050  loss: 0.1719 (0.1810)  loss_classifier: 0.0477 (0.0516)  loss_box_reg: 0.1102 (0.1137)  loss_objectness: 0.0027 (0.0049)  loss_rpn_box_reg: 0.0073 (0.0107)  time: 0.6489  data: 0.0348  max mem: 4960
# Epoch: [8]  [120/149]  eta: 0:00:19  lr: 0.000050  loss: 0.1688 (0.1815)  loss_classifier: 0.0424 (0.0514)  loss_box_reg: 0.0735 (0.1120)  loss_objectness: 0.0027 (0.0052)  loss_rpn_box_reg: 0.0038 (0.0130)  time: 0.6498  data: 0.0343  max mem: 4960
# Epoch: [8]  [130/149]  eta: 0:00:12  lr: 0.000050  loss: 0.1710 (0.1821)  loss_classifier: 0.0464 (0.0515)  loss_box_reg: 0.1006 (0.1126)  loss_objectness: 0.0031 (0.0051)  loss_rpn_box_reg: 0.0078 (0.0130)  time: 0.6467  data: 0.0323  max mem: 4960
# Epoch: [8]  [140/149]  eta: 0:00:05  lr: 0.000050  loss: 0.1878 (0.1833)  loss_classifier: 0.0501 (0.0520)  loss_box_reg: 0.1030 (0.1134)  loss_objectness: 0.0032 (0.0050)  loss_rpn_box_reg: 0.0078 (0.0129)  time: 0.6470  data: 0.0321  max mem: 4960
# Epoch: [8]  [148/149]  eta: 0:00:00  lr: 0.000050  loss: 0.1406 (0.1802)  loss_classifier: 0.0399 (0.0511)  loss_box_reg: 0.0826 (0.1117)  loss_objectness: 0.0025 (0.0049)  loss_rpn_box_reg: 0.0064 (0.0126)  time: 0.6191  data: 0.0303  max mem: 4960
# Epoch: [8] Total time: 0:01:37 (0.6543 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2648 (0.2648)  evaluator_time: 0.0146 (0.0146)  time: 0.9186  data: 0.5533  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2559 (0.2534)  evaluator_time: 0.0152 (0.0264)  time: 0.3672  data: 0.0559  max mem: 4960
# Test: Total time: 0:00:07 (0.3690 s / it)
# Averaged stats: model_time: 0.2559 (0.2534)  evaluator_time: 0.0152 (0.0264)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.413
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.145
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.433
# Epoch: [9]  [  0/149]  eta: 0:05:27  lr: 0.000005  loss: 0.2011 (0.2011)  loss_classifier: 0.0526 (0.0526)  loss_box_reg: 0.1389 (0.1389)  loss_objectness: 0.0025 (0.0025)  loss_rpn_box_reg: 0.0071 (0.0071)  time: 2.1997  data: 1.5641  max mem: 4960
# Epoch: [9]  [ 10/149]  eta: 0:01:49  lr: 0.000005  loss: 0.1453 (0.1606)  loss_classifier: 0.0464 (0.0507)  loss_box_reg: 0.0929 (0.0974)  loss_objectness: 0.0039 (0.0040)  loss_rpn_box_reg: 0.0072 (0.0084)  time: 0.7843  data: 0.1679  max mem: 4960
# Epoch: [9]  [ 20/149]  eta: 0:01:32  lr: 0.000005  loss: 0.1686 (0.1833)  loss_classifier: 0.0529 (0.0542)  loss_box_reg: 0.1018 (0.1155)  loss_objectness: 0.0033 (0.0039)  loss_rpn_box_reg: 0.0070 (0.0097)  time: 0.6449  data: 0.0310  max mem: 4960
# Epoch: [9]  [ 30/149]  eta: 0:01:22  lr: 0.000005  loss: 0.1771 (0.1723)  loss_classifier: 0.0535 (0.0500)  loss_box_reg: 0.1204 (0.1110)  loss_objectness: 0.0022 (0.0035)  loss_rpn_box_reg: 0.0041 (0.0079)  time: 0.6477  data: 0.0336  max mem: 4960
# Epoch: [9]  [ 40/149]  eta: 0:01:14  lr: 0.000005  loss: 0.1909 (0.1831)  loss_classifier: 0.0492 (0.0537)  loss_box_reg: 0.1147 (0.1156)  loss_objectness: 0.0034 (0.0041)  loss_rpn_box_reg: 0.0041 (0.0097)  time: 0.6518  data: 0.0345  max mem: 4960
# Epoch: [9]  [ 50/149]  eta: 0:01:07  lr: 0.000005  loss: 0.1909 (0.1821)  loss_classifier: 0.0550 (0.0524)  loss_box_reg: 0.1147 (0.1143)  loss_objectness: 0.0041 (0.0045)  loss_rpn_box_reg: 0.0087 (0.0109)  time: 0.6498  data: 0.0332  max mem: 4960
# Epoch: [9]  [ 60/149]  eta: 0:00:59  lr: 0.000005  loss: 0.1733 (0.1844)  loss_classifier: 0.0477 (0.0540)  loss_box_reg: 0.1125 (0.1146)  loss_objectness: 0.0019 (0.0046)  loss_rpn_box_reg: 0.0059 (0.0112)  time: 0.6480  data: 0.0326  max mem: 4960
# Epoch: [9]  [ 70/149]  eta: 0:00:52  lr: 0.000005  loss: 0.1541 (0.1833)  loss_classifier: 0.0532 (0.0536)  loss_box_reg: 0.1088 (0.1143)  loss_objectness: 0.0034 (0.0045)  loss_rpn_box_reg: 0.0071 (0.0108)  time: 0.6499  data: 0.0338  max mem: 4960
# Epoch: [9]  [ 80/149]  eta: 0:00:45  lr: 0.000005  loss: 0.1541 (0.1800)  loss_classifier: 0.0472 (0.0528)  loss_box_reg: 0.1061 (0.1117)  loss_objectness: 0.0040 (0.0049)  loss_rpn_box_reg: 0.0081 (0.0105)  time: 0.6444  data: 0.0319  max mem: 4960
# Epoch: [9]  [ 90/149]  eta: 0:00:39  lr: 0.000005  loss: 0.1506 (0.1802)  loss_classifier: 0.0435 (0.0525)  loss_box_reg: 0.0949 (0.1121)  loss_objectness: 0.0061 (0.0051)  loss_rpn_box_reg: 0.0081 (0.0106)  time: 0.6459  data: 0.0330  max mem: 4960
# Epoch: [9]  [100/149]  eta: 0:00:32  lr: 0.000005  loss: 0.1334 (0.1761)  loss_classifier: 0.0382 (0.0512)  loss_box_reg: 0.0853 (0.1094)  loss_objectness: 0.0048 (0.0050)  loss_rpn_box_reg: 0.0042 (0.0105)  time: 0.6488  data: 0.0343  max mem: 4960
# Epoch: [9]  [110/149]  eta: 0:00:25  lr: 0.000005  loss: 0.1401 (0.1767)  loss_classifier: 0.0382 (0.0510)  loss_box_reg: 0.0871 (0.1106)  loss_objectness: 0.0026 (0.0049)  loss_rpn_box_reg: 0.0032 (0.0101)  time: 0.6477  data: 0.0331  max mem: 4960
# Epoch: [9]  [120/149]  eta: 0:00:19  lr: 0.000005  loss: 0.1732 (0.1785)  loss_classifier: 0.0468 (0.0512)  loss_box_reg: 0.1256 (0.1121)  loss_objectness: 0.0030 (0.0049)  loss_rpn_box_reg: 0.0050 (0.0103)  time: 0.6475  data: 0.0328  max mem: 4960
# Epoch: [9]  [130/149]  eta: 0:00:12  lr: 0.000005  loss: 0.1732 (0.1796)  loss_classifier: 0.0506 (0.0514)  loss_box_reg: 0.1100 (0.1127)  loss_objectness: 0.0042 (0.0049)  loss_rpn_box_reg: 0.0108 (0.0106)  time: 0.6449  data: 0.0323  max mem: 4960
# Epoch: [9]  [140/149]  eta: 0:00:05  lr: 0.000005  loss: 0.2140 (0.1842)  loss_classifier: 0.0556 (0.0529)  loss_box_reg: 0.1447 (0.1156)  loss_objectness: 0.0049 (0.0050)  loss_rpn_box_reg: 0.0083 (0.0108)  time: 0.6447  data: 0.0318  max mem: 4960
# Epoch: [9]  [148/149]  eta: 0:00:00  lr: 0.000005  loss: 0.2088 (0.1820)  loss_classifier: 0.0614 (0.0524)  loss_box_reg: 0.1100 (0.1139)  loss_objectness: 0.0043 (0.0050)  loss_rpn_box_reg: 0.0068 (0.0106)  time: 0.6187  data: 0.0301  max mem: 4960
# Epoch: [9] Total time: 0:01:37 (0.6543 s / it)
# creating index...
# index created!
# Test:  [ 0/19]  eta: 0:00:17  model_time: 0.2612 (0.2612)  evaluator_time: 0.0130 (0.0130)  time: 0.9245  data: 0.5839  max mem: 4960
# Test:  [18/19]  eta: 0:00:00  model_time: 0.2549 (0.2523)  evaluator_time: 0.0147 (0.0238)  time: 0.3619  data: 0.0566  max mem: 4960
# Test: Total time: 0:00:06 (0.3637 s / it)
# Averaged stats: model_time: 0.2549 (0.2523)  evaluator_time: 0.0147 (0.0238)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.415
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.433
