# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Download TorchVision repo to use some files from
# references/detection
# !pip install pycocotools --quiet
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 531477, done.
# remote: Counting objects: 100% (45087/45087), done.
# remote: Compressing objects: 100% (2079/2079), done.
# remote: Total 531477 (delta 43041), reused 44913 (delta 42935), pack-reused 486390
# Receiving objects: 100% (531477/531477), 1023.04 MiB | 15.61 MiB/s, done.
# Resolving deltas: 100% (496288/496288), done.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
from torch.utils.data import ConcatDataset

from torch.utils.data import Subset
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
# defining the files directory and testing directory
train_dir = '/kaggle/input/citypersons-testselection/NewTest'
test_dir = '//kaggle/input/kitti-train-test-selection/Train_Test_Selection/Test'

# %%
add_train_dir = '/kaggle/input/pedestriansyntheticdataset/train/train'

# %%
#for xml-annotatation dataset
class ImagesDataset(torch.utils.data.Dataset):

    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
            
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        
        
        # classes: 0 index is reserved for background
        self.classes = ['background','Pedestrian']

    def __getitem__(self, idx):

        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # reading the images and converting them to correct size and color    
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        # diving by 255
        img_res /= 255.0
        
        # annotation file
        annot_filename = img_name[:-4] + '.xml'
        annot_file_path = os.path.join(self.files_dir, annot_filename)
        
        boxes = []
        labels = []
        tree = et.parse(annot_file_path)
        root = tree.getroot()
        
        # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        
        # box coordinates for xml files are extracted and corrected for image size given
        for member in root.findall('object'):
            label_text = member.find('name').text.lower()
            if label_text in ['ped', 'pedestrian','person']:
                labels.append(self.classes.index('Pedestrian')) 
            
            # bounding box
            xmin = int(member.find('bndbox').find('xmin').text)
            xmax = int(member.find('bndbox').find('xmax').text)
            
            ymin = int(member.find('bndbox').find('ymin').text)
            ymax = int(member.find('bndbox').find('ymax').text)
            
            
            xmin_corr = (xmin/wt)*self.width
            xmax_corr = (xmax/wt)*self.width
            ymin_corr = (ymin/ht)*self.height
            ymax_corr = (ymax/ht)*self.height
            
            boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
          
        
        # convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        
        # getting the areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
        
        labels = torch.as_tensor(labels, dtype=torch.int64)


        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        # image_id
        image_id = idx
        target["image_id"] = image_id
        
  


        if self.transforms:
            
            sample = self.transforms(image = img_res,
                                     bboxes = target['boxes'],
                                     labels = labels)
            
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
            
            
            
        return img_res, target

    def __len__(self):
        return len(self.imgs)

# %%
#for txt-annotatation dataset
class KittiDataset(torch.utils.data.Dataset):
    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        self.classes = ['background', 'Pedestrian']

    def __getitem__(self, idx):
        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # Reading the images and converting them to correct size and color
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        img_res /= 255.0

        # Annotation file
        annot_filename = img_name[:-4] + '.txt'
        annot_file_path = os.path.join(self.files_dir, annot_filename)

        boxes = []
        labels = []

           # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        # Read annotation data from text file
        with open(annot_file_path, 'r') as file:
            for line in file:
                parts = line.strip().split(' ')
                label_text = parts[0].lower()

                if label_text in ['pedestrian', 'person']:
                    labels.append(self.classes.index('Pedestrian'))

                    # Bounding box coordinates
                    xmin = float(parts[4])
                    ymin = float(parts[5])
                    xmax = float(parts[6])
                    ymax = float(parts[7])

                    # Normalize coordinates
                    xmin_corr = (xmin/wt)*self.width
                    xmax_corr = (xmax/wt)*self.width
                    ymin_corr = (ymin/ht)*self.height
                    ymax_corr = (ymax/ht)*self.height

                    boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])

        # Convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        #print("boxes shape: ", boxes.size(), "at index",idx, img_name)
       
      
           

        # Calculate areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # Suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)

        labels = torch.as_tensor(labels, dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd

        # image_id
        #image_id = torch.tensor([idx])
        image_id = idx
        target["image_id"] = image_id

        if self.transforms:
            sample = self.transforms(image=img_res, bboxes=target['boxes'], labels=labels)
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
        return img_res, target
    
    

    def __len__(self):
        return len(self.imgs)

# %%
def get_object_detection_model(num_classes):

    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 

    return model

# %%
# Send train=True fro training transforms and False for val/test transforms
def get_transform(train):
    
    if train:
        return A.Compose([
            A.HorizontalFlip(0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
            A.Rotate(limit=15, p=0.5),
            ToTensorV2(p=1.0)
        ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']))
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
# use our dataset and defined transformations
train_dataset = ImagesDataset(train_dir, 1920, 1080, transforms= get_transform(train=True))
add_train_dataset = ImagesDataset(add_train_dir, 1920, 1080, transforms= get_transform(train=True))
combined_dataset = ConcatDataset([train_dataset, add_train_dataset])

test_dataset = KittiDataset(test_dir, 1920, 1080, transforms= get_transform(train=False))

# define training and validation data loaders
combined_data_loader_train = torch.utils.data.DataLoader(
    combined_dataset, batch_size=4, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    test_dataset, batch_size=4, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')


num_classes = 2

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:03<00:00, 52.6MB/s]

# %%
# training for 10 epochs
num_epochs = 10

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, combined_data_loader_train, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [ 0/92]  eta: 0:07:09  lr: 0.000060  loss: 1.0828 (1.0828)  loss_classifier: 0.6908 (0.6908)  loss_box_reg: 0.2716 (0.2716)  loss_objectness: 0.0816 (0.0816)  loss_rpn_box_reg: 0.0388 (0.0388)  time: 4.6689  data: 1.4081  max mem: 4799
# Epoch: [0]  [10/92]  eta: 0:01:22  lr: 0.000609  loss: 0.7857 (0.7997)  loss_classifier: 0.4704 (0.4633)  loss_box_reg: 0.2607 (0.2553)  loss_objectness: 0.0318 (0.0491)  loss_rpn_box_reg: 0.0156 (0.0320)  time: 1.0107  data: 0.1576  max mem: 4957
# Epoch: [0]  [20/92]  eta: 0:01:00  lr: 0.001158  loss: 0.6623 (0.7168)  loss_classifier: 0.2603 (0.3648)  loss_box_reg: 0.2486 (0.2679)  loss_objectness: 0.0280 (0.0513)  loss_rpn_box_reg: 0.0156 (0.0328)  time: 0.6450  data: 0.0327  max mem: 4957
# Epoch: [0]  [30/92]  eta: 0:00:48  lr: 0.001707  loss: 0.5202 (0.6863)  loss_classifier: 0.1958 (0.3100)  loss_box_reg: 0.2848 (0.2786)  loss_objectness: 0.0375 (0.0509)  loss_rpn_box_reg: 0.0171 (0.0468)  time: 0.6518  data: 0.0351  max mem: 4957
# Epoch: [0]  [40/92]  eta: 0:00:38  lr: 0.002255  loss: 0.5202 (0.6427)  loss_classifier: 0.1352 (0.2657)  loss_box_reg: 0.2993 (0.2910)  loss_objectness: 0.0306 (0.0447)  loss_rpn_box_reg: 0.0127 (0.0414)  time: 0.6551  data: 0.0351  max mem: 4957
# Epoch: [0]  [50/92]  eta: 0:00:30  lr: 0.002804  loss: 0.3699 (0.5763)  loss_classifier: 0.0940 (0.2291)  loss_box_reg: 0.2272 (0.2743)  loss_objectness: 0.0097 (0.0377)  loss_rpn_box_reg: 0.0074 (0.0353)  time: 0.6548  data: 0.0334  max mem: 4958
# Epoch: [0]  [60/92]  eta: 0:00:22  lr: 0.003353  loss: 0.3397 (0.5455)  loss_classifier: 0.0817 (0.2068)  loss_box_reg: 0.2090 (0.2672)  loss_objectness: 0.0087 (0.0350)  loss_rpn_box_reg: 0.0085 (0.0365)  time: 0.6532  data: 0.0344  max mem: 4958
# Epoch: [0]  [70/92]  eta: 0:00:15  lr: 0.003902  loss: 0.3397 (0.5159)  loss_classifier: 0.0817 (0.1889)  loss_box_reg: 0.1953 (0.2563)  loss_objectness: 0.0113 (0.0342)  loss_rpn_box_reg: 0.0102 (0.0364)  time: 0.6520  data: 0.0343  max mem: 4958
# Epoch: [0]  [80/92]  eta: 0:00:08  lr: 0.004451  loss: 0.2723 (0.4869)  loss_classifier: 0.0639 (0.1738)  loss_box_reg: 0.1864 (0.2461)  loss_objectness: 0.0127 (0.0337)  loss_rpn_box_reg: 0.0090 (0.0333)  time: 0.6564  data: 0.0344  max mem: 4959
# Epoch: [0]  [90/92]  eta: 0:00:01  lr: 0.005000  loss: 0.2974 (0.4710)  loss_classifier: 0.0684 (0.1654)  loss_box_reg: 0.1936 (0.2406)  loss_objectness: 0.0133 (0.0320)  loss_rpn_box_reg: 0.0091 (0.0330)  time: 0.6458  data: 0.0318  max mem: 4959
# Epoch: [0]  [91/92]  eta: 0:00:00  lr: 0.005000  loss: 0.2974 (0.4678)  loss_classifier: 0.0684 (0.1642)  loss_box_reg: 0.1936 (0.2392)  loss_objectness: 0.0133 (0.0318)  loss_rpn_box_reg: 0.0091 (0.0326)  time: 0.6450  data: 0.0317  max mem: 4959
# Epoch: [0] Total time: 0:01:03 (0.6943 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:18  model_time: 0.3226 (0.3226)  evaluator_time: 0.0293 (0.0293)  time: 0.9279  data: 0.4981  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2533 (0.2569)  evaluator_time: 0.0373 (0.0413)  time: 0.3793  data: 0.0512  max mem: 4959
# Test: Total time: 0:00:07 (0.3809 s / it)
# Averaged stats: model_time: 0.2533 (0.2569)  evaluator_time: 0.0373 (0.0413)
# Accumulating evaluation results...
# DONE (t=0.09s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.566
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.054
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.271
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.310
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.406
# Epoch: [1]  [ 0/92]  eta: 0:02:54  lr: 0.005000  loss: 0.2177 (0.2177)  loss_classifier: 0.0464 (0.0464)  loss_box_reg: 0.1646 (0.1646)  loss_objectness: 0.0026 (0.0026)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 1.9021  data: 1.1710  max mem: 4959
# Epoch: [1]  [10/92]  eta: 0:01:02  lr: 0.005000  loss: 0.3086 (0.3324)  loss_classifier: 0.0778 (0.0855)  loss_box_reg: 0.1778 (0.2000)  loss_objectness: 0.0157 (0.0177)  loss_rpn_box_reg: 0.0273 (0.0291)  time: 0.7570  data: 0.1324  max mem: 4959
# Epoch: [1]  [20/92]  eta: 0:00:50  lr: 0.005000  loss: 0.3555 (0.3325)  loss_classifier: 0.0787 (0.0875)  loss_box_reg: 0.1778 (0.2004)  loss_objectness: 0.0094 (0.0136)  loss_rpn_box_reg: 0.0254 (0.0311)  time: 0.6463  data: 0.0328  max mem: 4960
# Epoch: [1]  [30/92]  eta: 0:00:42  lr: 0.005000  loss: 0.3426 (0.3334)  loss_classifier: 0.0787 (0.0873)  loss_box_reg: 0.1698 (0.1998)  loss_objectness: 0.0086 (0.0158)  loss_rpn_box_reg: 0.0186 (0.0304)  time: 0.6493  data: 0.0351  max mem: 4960
# Epoch: [1]  [40/92]  eta: 0:00:35  lr: 0.005000  loss: 0.2703 (0.3213)  loss_classifier: 0.0628 (0.0834)  loss_box_reg: 0.1648 (0.1925)  loss_objectness: 0.0091 (0.0144)  loss_rpn_box_reg: 0.0088 (0.0310)  time: 0.6474  data: 0.0330  max mem: 4960
# Epoch: [1]  [50/92]  eta: 0:00:28  lr: 0.005000  loss: 0.2522 (0.3073)  loss_classifier: 0.0624 (0.0798)  loss_box_reg: 0.1638 (0.1855)  loss_objectness: 0.0063 (0.0132)  loss_rpn_box_reg: 0.0088 (0.0288)  time: 0.6454  data: 0.0332  max mem: 4960
# Epoch: [1]  [60/92]  eta: 0:00:21  lr: 0.005000  loss: 0.2034 (0.2940)  loss_classifier: 0.0515 (0.0764)  loss_box_reg: 0.1343 (0.1794)  loss_objectness: 0.0063 (0.0123)  loss_rpn_box_reg: 0.0059 (0.0259)  time: 0.6430  data: 0.0325  max mem: 4960
# Epoch: [1]  [70/92]  eta: 0:00:14  lr: 0.005000  loss: 0.2122 (0.2928)  loss_classifier: 0.0617 (0.0757)  loss_box_reg: 0.1478 (0.1807)  loss_objectness: 0.0064 (0.0117)  loss_rpn_box_reg: 0.0059 (0.0246)  time: 0.6482  data: 0.0342  max mem: 4960
# Epoch: [1]  [80/92]  eta: 0:00:07  lr: 0.005000  loss: 0.2734 (0.2965)  loss_classifier: 0.0662 (0.0759)  loss_box_reg: 0.1928 (0.1842)  loss_objectness: 0.0025 (0.0112)  loss_rpn_box_reg: 0.0067 (0.0252)  time: 0.6521  data: 0.0353  max mem: 4960
# Epoch: [1]  [90/92]  eta: 0:00:01  lr: 0.005000  loss: 0.2599 (0.2932)  loss_classifier: 0.0662 (0.0750)  loss_box_reg: 0.1786 (0.1827)  loss_objectness: 0.0039 (0.0109)  loss_rpn_box_reg: 0.0067 (0.0247)  time: 0.6421  data: 0.0313  max mem: 4960
# Epoch: [1]  [91/92]  eta: 0:00:00  lr: 0.005000  loss: 0.2599 (0.2913)  loss_classifier: 0.0662 (0.0746)  loss_box_reg: 0.1745 (0.1815)  loss_objectness: 0.0039 (0.0108)  loss_rpn_box_reg: 0.0067 (0.0244)  time: 0.6420  data: 0.0313  max mem: 4960
# Epoch: [1] Total time: 0:01:00 (0.6599 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:18  model_time: 0.2691 (0.2691)  evaluator_time: 0.0314 (0.0314)  time: 0.9156  data: 0.5692  max mem: 4960
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2542 (0.2559)  evaluator_time: 0.0414 (0.0537)  time: 0.3945  data: 0.0557  max mem: 4960
# Test: Total time: 0:00:07 (0.3964 s / it)
# Averaged stats: model_time: 0.2542 (0.2559)  evaluator_time: 0.0414 (0.0537)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.535
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.280
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.280
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.127
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.382
# Epoch: [2]  [ 0/92]  eta: 0:03:03  lr: 0.005000  loss: 0.1786 (0.1786)  loss_classifier: 0.0422 (0.0422)  loss_box_reg: 0.1142 (0.1142)  loss_objectness: 0.0152 (0.0152)  loss_rpn_box_reg: 0.0070 (0.0070)  time: 1.9898  data: 1.2628  max mem: 4960
# Epoch: [2]  [10/92]  eta: 0:01:04  lr: 0.005000  loss: 0.3030 (0.3558)  loss_classifier: 0.0867 (0.0884)  loss_box_reg: 0.2034 (0.2158)  loss_objectness: 0.0061 (0.0094)  loss_rpn_box_reg: 0.0186 (0.0421)  time: 0.7819  data: 0.1482  max mem: 4960
# Epoch: [2]  [20/92]  eta: 0:00:51  lr: 0.005000  loss: 0.2697 (0.3148)  loss_classifier: 0.0691 (0.0810)  loss_box_reg: 0.1782 (0.1914)  loss_objectness: 0.0047 (0.0086)  loss_rpn_box_reg: 0.0186 (0.0338)  time: 0.6562  data: 0.0361  max mem: 4960
# Epoch: [2]  [30/92]  eta: 0:00:43  lr: 0.005000  loss: 0.2221 (0.2960)  loss_classifier: 0.0657 (0.0803)  loss_box_reg: 0.1510 (0.1774)  loss_objectness: 0.0085 (0.0093)  loss_rpn_box_reg: 0.0105 (0.0289)  time: 0.6493  data: 0.0346  max mem: 4960
# Epoch: [2]  [40/92]  eta: 0:00:35  lr: 0.005000  loss: 0.1892 (0.3002)  loss_classifier: 0.0657 (0.0806)  loss_box_reg: 0.1078 (0.1738)  loss_objectness: 0.0093 (0.0109)  loss_rpn_box_reg: 0.0105 (0.0349)  time: 0.6471  data: 0.0333  max mem: 4960
# Epoch: [2]  [50/92]  eta: 0:00:28  lr: 0.005000  loss: 0.2009 (0.2872)  loss_classifier: 0.0608 (0.0776)  loss_box_reg: 0.1292 (0.1680)  loss_objectness: 0.0068 (0.0107)  loss_rpn_box_reg: 0.0052 (0.0309)  time: 0.6482  data: 0.0334  max mem: 4960
# Epoch: [2]  [60/92]  eta: 0:00:21  lr: 0.005000  loss: 0.1975 (0.2758)  loss_classifier: 0.0572 (0.0753)  loss_box_reg: 0.1324 (0.1635)  loss_objectness: 0.0042 (0.0099)  loss_rpn_box_reg: 0.0052 (0.0271)  time: 0.6501  data: 0.0344  max mem: 4960
# Epoch: [2]  [70/92]  eta: 0:00:14  lr: 0.005000  loss: 0.1922 (0.2733)  loss_classifier: 0.0572 (0.0746)  loss_box_reg: 0.1253 (0.1640)  loss_objectness: 0.0019 (0.0092)  loss_rpn_box_reg: 0.0067 (0.0255)  time: 0.6458  data: 0.0334  max mem: 4960
# Epoch: [2]  [80/92]  eta: 0:00:07  lr: 0.005000  loss: 0.1963 (0.2752)  loss_classifier: 0.0581 (0.0754)  loss_box_reg: 0.1337 (0.1651)  loss_objectness: 0.0036 (0.0093)  loss_rpn_box_reg: 0.0072 (0.0254)  time: 0.6418  data: 0.0325  max mem: 4960
# Epoch: [2]  [90/92]  eta: 0:00:01  lr: 0.005000  loss: 0.2335 (0.2758)  loss_classifier: 0.0587 (0.0751)  loss_box_reg: 0.1482 (0.1671)  loss_objectness: 0.0029 (0.0088)  loss_rpn_box_reg: 0.0088 (0.0247)  time: 0.6389  data: 0.0314  max mem: 4960
# Epoch: [2]  [91/92]  eta: 0:00:00  lr: 0.005000  loss: 0.2549 (0.2758)  loss_classifier: 0.0601 (0.0751)  loss_box_reg: 0.1703 (0.1675)  loss_objectness: 0.0029 (0.0087)  loss_rpn_box_reg: 0.0088 (0.0245)  time: 0.6379  data: 0.0310  max mem: 4960
# Epoch: [2] Total time: 0:01:00 (0.6623 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2811 (0.2811)  evaluator_time: 0.0271 (0.0271)  time: 0.9889  data: 0.6122  max mem: 4960
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2546 (0.2563)  evaluator_time: 0.0387 (0.0411)  time: 0.3847  data: 0.0572  max mem: 4960
# Test: Total time: 0:00:07 (0.3863 s / it)
# Averaged stats: model_time: 0.2546 (0.2563)  evaluator_time: 0.0387 (0.0411)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.526
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.288
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.389
# Epoch: [3]  [ 0/92]  eta: 0:02:50  lr: 0.000500  loss: 0.1709 (0.1709)  loss_classifier: 0.0445 (0.0445)  loss_box_reg: 0.1194 (0.1194)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0061 (0.0061)  time: 1.8582  data: 1.1834  max mem: 4960
# Epoch: [3]  [10/92]  eta: 0:01:02  lr: 0.000500  loss: 0.2384 (0.2493)  loss_classifier: 0.0608 (0.0647)  loss_box_reg: 0.1497 (0.1624)  loss_objectness: 0.0021 (0.0054)  loss_rpn_box_reg: 0.0056 (0.0168)  time: 0.7676  data: 0.1408  max mem: 4960
# Epoch: [3]  [20/92]  eta: 0:00:51  lr: 0.000500  loss: 0.2384 (0.2715)  loss_classifier: 0.0608 (0.0683)  loss_box_reg: 0.1545 (0.1697)  loss_objectness: 0.0038 (0.0073)  loss_rpn_box_reg: 0.0077 (0.0262)  time: 0.6559  data: 0.0367  max mem: 4960
# Epoch: [3]  [30/92]  eta: 0:00:42  lr: 0.000500  loss: 0.2544 (0.2902)  loss_classifier: 0.0668 (0.0739)  loss_box_reg: 0.1714 (0.1795)  loss_objectness: 0.0088 (0.0103)  loss_rpn_box_reg: 0.0167 (0.0264)  time: 0.6524  data: 0.0354  max mem: 4960
# Epoch: [3]  [40/92]  eta: 0:00:35  lr: 0.000500  loss: 0.2559 (0.2848)  loss_classifier: 0.0699 (0.0731)  loss_box_reg: 0.1614 (0.1755)  loss_objectness: 0.0083 (0.0099)  loss_rpn_box_reg: 0.0176 (0.0263)  time: 0.6487  data: 0.0335  max mem: 4960
# Epoch: [3]  [50/92]  eta: 0:00:28  lr: 0.000500  loss: 0.2502 (0.2784)  loss_classifier: 0.0633 (0.0721)  loss_box_reg: 0.1560 (0.1724)  loss_objectness: 0.0058 (0.0093)  loss_rpn_box_reg: 0.0080 (0.0247)  time: 0.6452  data: 0.0320  max mem: 4960
# Epoch: [3]  [60/92]  eta: 0:00:21  lr: 0.000500  loss: 0.2201 (0.2807)  loss_classifier: 0.0635 (0.0740)  loss_box_reg: 0.1560 (0.1733)  loss_objectness: 0.0031 (0.0088)  loss_rpn_box_reg: 0.0080 (0.0246)  time: 0.6472  data: 0.0322  max mem: 4960
# Epoch: [3]  [70/92]  eta: 0:00:14  lr: 0.000500  loss: 0.2005 (0.2658)  loss_classifier: 0.0607 (0.0702)  loss_box_reg: 0.1268 (0.1656)  loss_objectness: 0.0026 (0.0082)  loss_rpn_box_reg: 0.0056 (0.0219)  time: 0.6471  data: 0.0336  max mem: 4960
# Epoch: [3]  [80/92]  eta: 0:00:07  lr: 0.000500  loss: 0.1591 (0.2577)  loss_classifier: 0.0452 (0.0683)  loss_box_reg: 0.1107 (0.1616)  loss_objectness: 0.0017 (0.0075)  loss_rpn_box_reg: 0.0041 (0.0205)  time: 0.6426  data: 0.0319  max mem: 4960
# Epoch: [3]  [90/92]  eta: 0:00:01  lr: 0.000500  loss: 0.1591 (0.2492)  loss_classifier: 0.0444 (0.0661)  loss_box_reg: 0.1115 (0.1570)  loss_objectness: 0.0010 (0.0070)  loss_rpn_box_reg: 0.0037 (0.0191)  time: 0.6392  data: 0.0299  max mem: 4960
# Epoch: [3]  [91/92]  eta: 0:00:00  lr: 0.000500  loss: 0.1591 (0.2503)  loss_classifier: 0.0444 (0.0665)  loss_box_reg: 0.1115 (0.1573)  loss_objectness: 0.0020 (0.0071)  loss_rpn_box_reg: 0.0037 (0.0194)  time: 0.6374  data: 0.0295  max mem: 4960
# Epoch: [3] Total time: 0:01:00 (0.6609 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.2767 (0.2767)  evaluator_time: 0.0204 (0.0204)  time: 1.0082  data: 0.6337  max mem: 4960
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2542 (0.2560)  evaluator_time: 0.0298 (0.0342)  time: 0.3783  data: 0.0575  max mem: 4960
# Test: Total time: 0:00:07 (0.3801 s / it)
# Averaged stats: model_time: 0.2542 (0.2560)  evaluator_time: 0.0298 (0.0342)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.244
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.605
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.155
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.181
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.191
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.457
# Epoch: [4]  [ 0/92]  eta: 0:03:11  lr: 0.000500  loss: 0.1409 (0.1409)  loss_classifier: 0.0405 (0.0405)  loss_box_reg: 0.0971 (0.0971)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 2.0804  data: 1.4373  max mem: 4960
# Epoch: [4]  [10/92]  eta: 0:01:04  lr: 0.000500  loss: 0.1779 (0.2044)  loss_classifier: 0.0418 (0.0538)  loss_box_reg: 0.1315 (0.1395)  loss_objectness: 0.0009 (0.0022)  loss_rpn_box_reg: 0.0040 (0.0090)  time: 0.7822  data: 0.1603  max mem: 4960
# Epoch: [4]  [20/92]  eta: 0:00:51  lr: 0.000500  loss: 0.2052 (0.2262)  loss_classifier: 0.0479 (0.0607)  loss_box_reg: 0.1437 (0.1485)  loss_objectness: 0.0015 (0.0034)  loss_rpn_box_reg: 0.0051 (0.0136)  time: 0.6495  data: 0.0326  max mem: 4960
# Epoch: [4]  [30/92]  eta: 0:00:43  lr: 0.000500  loss: 0.2102 (0.2259)  loss_classifier: 0.0621 (0.0616)  loss_box_reg: 0.1408 (0.1438)  loss_objectness: 0.0043 (0.0046)  loss_rpn_box_reg: 0.0066 (0.0159)  time: 0.6459  data: 0.0327  max mem: 4960
# Epoch: [4]  [40/92]  eta: 0:00:35  lr: 0.000500  loss: 0.2238 (0.2331)  loss_classifier: 0.0596 (0.0639)  loss_box_reg: 0.1424 (0.1480)  loss_objectness: 0.0043 (0.0047)  loss_rpn_box_reg: 0.0066 (0.0166)  time: 0.6485  data: 0.0329  max mem: 4960
# Epoch: [4]  [50/92]  eta: 0:00:28  lr: 0.000500  loss: 0.2406 (0.2415)  loss_classifier: 0.0637 (0.0662)  loss_box_reg: 0.1476 (0.1498)  loss_objectness: 0.0064 (0.0086)  loss_rpn_box_reg: 0.0078 (0.0169)  time: 0.6509  data: 0.0339  max mem: 4960
# Epoch: [4]  [60/92]  eta: 0:00:21  lr: 0.000500  loss: 0.2380 (0.2516)  loss_classifier: 0.0645 (0.0689)  loss_box_reg: 0.1431 (0.1548)  loss_objectness: 0.0066 (0.0087)  loss_rpn_box_reg: 0.0118 (0.0192)  time: 0.6478  data: 0.0339  max mem: 4960
# Epoch: [4]  [70/92]  eta: 0:00:14  lr: 0.000500  loss: 0.2311 (0.2480)  loss_classifier: 0.0638 (0.0677)  loss_box_reg: 0.1430 (0.1532)  loss_objectness: 0.0041 (0.0081)  loss_rpn_box_reg: 0.0072 (0.0190)  time: 0.6493  data: 0.0336  max mem: 4960
# Epoch: [4]  [80/92]  eta: 0:00:07  lr: 0.000500  loss: 0.2349 (0.2517)  loss_classifier: 0.0638 (0.0689)  loss_box_reg: 0.1430 (0.1565)  loss_objectness: 0.0038 (0.0080)  loss_rpn_box_reg: 0.0072 (0.0184)  time: 0.6484  data: 0.0335  max mem: 4960
# Epoch: [4]  [90/92]  eta: 0:00:01  lr: 0.000500  loss: 0.2280 (0.2495)  loss_classifier: 0.0615 (0.0684)  loss_box_reg: 0.1480 (0.1554)  loss_objectness: 0.0039 (0.0078)  loss_rpn_box_reg: 0.0092 (0.0179)  time: 0.6439  data: 0.0315  max mem: 4960
# Epoch: [4]  [91/92]  eta: 0:00:00  lr: 0.000500  loss: 0.2412 (0.2498)  loss_classifier: 0.0615 (0.0684)  loss_box_reg: 0.1493 (0.1560)  loss_objectness: 0.0039 (0.0077)  loss_rpn_box_reg: 0.0092 (0.0177)  time: 0.6427  data: 0.0310  max mem: 4960
# Epoch: [4] Total time: 0:01:01 (0.6639 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:18  model_time: 0.2755 (0.2755)  evaluator_time: 0.0215 (0.0215)  time: 0.9098  data: 0.5751  max mem: 4960
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2548 (0.2564)  evaluator_time: 0.0326 (0.0351)  time: 0.3785  data: 0.0579  max mem: 4960
# Test: Total time: 0:00:07 (0.3805 s / it)
# Averaged stats: model_time: 0.2548 (0.2564)  evaluator_time: 0.0326 (0.0351)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.577
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.166
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.328
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.432
# Epoch: [5]  [ 0/92]  eta: 0:02:47  lr: 0.000500  loss: 0.1529 (0.1529)  loss_classifier: 0.0388 (0.0388)  loss_box_reg: 0.0987 (0.0987)  loss_objectness: 0.0102 (0.0102)  loss_rpn_box_reg: 0.0051 (0.0051)  time: 1.8175  data: 1.1269  max mem: 4960
# Epoch: [5]  [10/92]  eta: 0:01:03  lr: 0.000500  loss: 0.1893 (0.1981)  loss_classifier: 0.0424 (0.0523)  loss_box_reg: 0.1005 (0.1226)  loss_objectness: 0.0046 (0.0048)  loss_rpn_box_reg: 0.0059 (0.0184)  time: 0.7715  data: 0.1386  max mem: 4960
# Epoch: [5]  [20/92]  eta: 0:00:51  lr: 0.000500  loss: 0.1910 (0.2268)  loss_classifier: 0.0556 (0.0598)  loss_box_reg: 0.1406 (0.1365)  loss_objectness: 0.0030 (0.0055)  loss_rpn_box_reg: 0.0059 (0.0250)  time: 0.6571  data: 0.0359  max mem: 4960
# Epoch: [5]  [30/92]  eta: 0:00:42  lr: 0.000500  loss: 0.2245 (0.2217)  loss_classifier: 0.0587 (0.0585)  loss_box_reg: 0.1497 (0.1351)  loss_objectness: 0.0031 (0.0072)  loss_rpn_box_reg: 0.0050 (0.0209)  time: 0.6477  data: 0.0326  max mem: 4960
# Epoch: [5]  [40/92]  eta: 0:00:35  lr: 0.000500  loss: 0.2627 (0.2330)  loss_classifier: 0.0681 (0.0628)  loss_box_reg: 0.1559 (0.1423)  loss_objectness: 0.0031 (0.0069)  loss_rpn_box_reg: 0.0080 (0.0211)  time: 0.6483  data: 0.0337  max mem: 4960
# Epoch: [5]  [50/92]  eta: 0:00:28  lr: 0.000500  loss: 0.2307 (0.2325)  loss_classifier: 0.0681 (0.0636)  loss_box_reg: 0.1325 (0.1429)  loss_objectness: 0.0035 (0.0069)  loss_rpn_box_reg: 0.0103 (0.0191)  time: 0.6473  data: 0.0327  max mem: 4960
# Epoch: [5]  [60/92]  eta: 0:00:21  lr: 0.000500  loss: 0.1969 (0.2287)  loss_classifier: 0.0563 (0.0627)  loss_box_reg: 0.1284 (0.1407)  loss_objectness: 0.0047 (0.0068)  loss_rpn_box_reg: 0.0056 (0.0184)  time: 0.6476  data: 0.0327  max mem: 4960
# Epoch: [5]  [70/92]  eta: 0:00:14  lr: 0.000500  loss: 0.2015 (0.2255)  loss_classifier: 0.0629 (0.0615)  loss_box_reg: 0.1284 (0.1411)  loss_objectness: 0.0047 (0.0063)  loss_rpn_box_reg: 0.0043 (0.0166)  time: 0.6504  data: 0.0336  max mem: 4960
# Epoch: [5]  [80/92]  eta: 0:00:07  lr: 0.000500  loss: 0.2546 (0.2384)  loss_classifier: 0.0702 (0.0648)  loss_box_reg: 0.1823 (0.1494)  loss_objectness: 0.0036 (0.0066)  loss_rpn_box_reg: 0.0048 (0.0176)  time: 0.6509  data: 0.0341  max mem: 4960
# Epoch: [5]  [90/92]  eta: 0:00:01  lr: 0.000500  loss: 0.2542 (0.2403)  loss_classifier: 0.0706 (0.0649)  loss_box_reg: 0.1737 (0.1514)  loss_objectness: 0.0044 (0.0065)  loss_rpn_box_reg: 0.0124 (0.0175)  time: 0.6443  data: 0.0324  max mem: 4960
# Epoch: [5]  [91/92]  eta: 0:00:00  lr: 0.000500  loss: 0.2542 (0.2406)  loss_classifier: 0.0699 (0.0650)  loss_box_reg: 0.1737 (0.1518)  loss_objectness: 0.0036 (0.0064)  loss_rpn_box_reg: 0.0124 (0.0174)  time: 0.6428  data: 0.0317  max mem: 4960
# Epoch: [5] Total time: 0:01:00 (0.6627 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.2758 (0.2758)  evaluator_time: 0.0246 (0.0246)  time: 1.0153  data: 0.6501  max mem: 4960
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2547 (0.2561)  evaluator_time: 0.0286 (0.0354)  time: 0.3824  data: 0.0609  max mem: 4960
# Test: Total time: 0:00:07 (0.3840 s / it)
# Averaged stats: model_time: 0.2547 (0.2561)  evaluator_time: 0.0286 (0.0354)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.219
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.583
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.131
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.162
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.294
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.160
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.429
# Epoch: [6]  [ 0/92]  eta: 0:02:33  lr: 0.000050  loss: 0.1093 (0.1093)  loss_classifier: 0.0337 (0.0337)  loss_box_reg: 0.0691 (0.0691)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0064 (0.0064)  time: 1.6640  data: 0.9995  max mem: 4960
# Epoch: [6]  [10/92]  eta: 0:01:01  lr: 0.000050  loss: 0.2060 (0.2519)  loss_classifier: 0.0550 (0.0676)  loss_box_reg: 0.1376 (0.1621)  loss_objectness: 0.0037 (0.0053)  loss_rpn_box_reg: 0.0084 (0.0169)  time: 0.7558  data: 0.1246  max mem: 4960
# Epoch: [6]  [20/92]  eta: 0:00:50  lr: 0.000050  loss: 0.2149 (0.2580)  loss_classifier: 0.0633 (0.0695)  loss_box_reg: 0.1458 (0.1655)  loss_objectness: 0.0043 (0.0059)  loss_rpn_box_reg: 0.0084 (0.0170)  time: 0.6549  data: 0.0345  max mem: 4960
# Epoch: [6]  [30/92]  eta: 0:00:42  lr: 0.000050  loss: 0.2290 (0.2449)  loss_classifier: 0.0611 (0.0666)  loss_box_reg: 0.1433 (0.1558)  loss_objectness: 0.0043 (0.0054)  loss_rpn_box_reg: 0.0073 (0.0171)  time: 0.6431  data: 0.0317  max mem: 4960
# Epoch: [6]  [40/92]  eta: 0:00:35  lr: 0.000050  loss: 0.1600 (0.2307)  loss_classifier: 0.0469 (0.0621)  loss_box_reg: 0.1064 (0.1463)  loss_objectness: 0.0019 (0.0051)  loss_rpn_box_reg: 0.0052 (0.0173)  time: 0.6442  data: 0.0323  max mem: 4960
# Epoch: [6]  [50/92]  eta: 0:00:28  lr: 0.000050  loss: 0.1922 (0.2376)  loss_classifier: 0.0533 (0.0654)  loss_box_reg: 0.1202 (0.1488)  loss_objectness: 0.0048 (0.0056)  loss_rpn_box_reg: 0.0044 (0.0178)  time: 0.6474  data: 0.0327  max mem: 4960
# Epoch: [6]  [60/92]  eta: 0:00:21  lr: 0.000050  loss: 0.1982 (0.2319)  loss_classifier: 0.0556 (0.0638)  loss_box_reg: 0.1202 (0.1462)  loss_objectness: 0.0044 (0.0052)  loss_rpn_box_reg: 0.0077 (0.0168)  time: 0.6489  data: 0.0328  max mem: 4960
# Epoch: [6]  [70/92]  eta: 0:00:14  lr: 0.000050  loss: 0.1669 (0.2303)  loss_classifier: 0.0434 (0.0633)  loss_box_reg: 0.1104 (0.1463)  loss_objectness: 0.0015 (0.0049)  loss_rpn_box_reg: 0.0059 (0.0159)  time: 0.6499  data: 0.0330  max mem: 4960
# Epoch: [6]  [80/92]  eta: 0:00:07  lr: 0.000050  loss: 0.1843 (0.2313)  loss_classifier: 0.0517 (0.0632)  loss_box_reg: 0.1262 (0.1473)  loss_objectness: 0.0015 (0.0050)  loss_rpn_box_reg: 0.0059 (0.0159)  time: 0.6514  data: 0.0335  max mem: 4960
# Epoch: [6]  [90/92]  eta: 0:00:01  lr: 0.000050  loss: 0.2106 (0.2314)  loss_classifier: 0.0556 (0.0634)  loss_box_reg: 0.1414 (0.1465)  loss_objectness: 0.0035 (0.0053)  loss_rpn_box_reg: 0.0046 (0.0163)  time: 0.6432  data: 0.0308  max mem: 4960
# Epoch: [6]  [91/92]  eta: 0:00:00  lr: 0.000050  loss: 0.2106 (0.2326)  loss_classifier: 0.0556 (0.0637)  loss_box_reg: 0.1414 (0.1472)  loss_objectness: 0.0042 (0.0053)  loss_rpn_box_reg: 0.0074 (0.0164)  time: 0.6433  data: 0.0309  max mem: 4960
# Epoch: [6] Total time: 0:01:00 (0.6594 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2737 (0.2737)  evaluator_time: 0.0237 (0.0237)  time: 0.9597  data: 0.6167  max mem: 4960
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2537 (0.2546)  evaluator_time: 0.0279 (0.0335)  time: 0.3736  data: 0.0569  max mem: 4960
# Test: Total time: 0:00:07 (0.3754 s / it)
# Averaged stats: model_time: 0.2537 (0.2546)  evaluator_time: 0.0279 (0.0335)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.576
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.133
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
# Epoch: [7]  [ 0/92]  eta: 0:03:28  lr: 0.000050  loss: 0.2419 (0.2419)  loss_classifier: 0.0553 (0.0553)  loss_box_reg: 0.1804 (0.1804)  loss_objectness: 0.0025 (0.0025)  loss_rpn_box_reg: 0.0037 (0.0037)  time: 2.2695  data: 1.5853  max mem: 4960
# Epoch: [7]  [10/92]  eta: 0:01:05  lr: 0.000050  loss: 0.2286 (0.2324)  loss_classifier: 0.0568 (0.0595)  loss_box_reg: 0.1605 (0.1531)  loss_objectness: 0.0027 (0.0039)  loss_rpn_box_reg: 0.0051 (0.0160)  time: 0.8010  data: 0.1733  max mem: 4960
# Epoch: [7]  [20/92]  eta: 0:00:52  lr: 0.000050  loss: 0.2286 (0.2614)  loss_classifier: 0.0650 (0.0700)  loss_box_reg: 0.1605 (0.1680)  loss_objectness: 0.0032 (0.0055)  loss_rpn_box_reg: 0.0056 (0.0179)  time: 0.6513  data: 0.0331  max mem: 4960
# Epoch: [7]  [30/92]  eta: 0:00:43  lr: 0.000050  loss: 0.2802 (0.2620)  loss_classifier: 0.0663 (0.0711)  loss_box_reg: 0.1608 (0.1657)  loss_objectness: 0.0069 (0.0066)  loss_rpn_box_reg: 0.0088 (0.0187)  time: 0.6482  data: 0.0342  max mem: 4960
# Epoch: [7]  [40/92]  eta: 0:00:35  lr: 0.000050  loss: 0.1957 (0.2497)  loss_classifier: 0.0539 (0.0671)  loss_box_reg: 0.1326 (0.1585)  loss_objectness: 0.0062 (0.0067)  loss_rpn_box_reg: 0.0066 (0.0174)  time: 0.6487  data: 0.0326  max mem: 4960
# Epoch: [7]  [50/92]  eta: 0:00:28  lr: 0.000050  loss: 0.1451 (0.2319)  loss_classifier: 0.0413 (0.0623)  loss_box_reg: 0.1033 (0.1489)  loss_objectness: 0.0024 (0.0058)  loss_rpn_box_reg: 0.0036 (0.0150)  time: 0.6508  data: 0.0329  max mem: 4960
# Epoch: [7]  [60/92]  eta: 0:00:21  lr: 0.000050  loss: 0.1437 (0.2199)  loss_classifier: 0.0391 (0.0594)  loss_box_reg: 0.0988 (0.1419)  loss_objectness: 0.0015 (0.0052)  loss_rpn_box_reg: 0.0035 (0.0134)  time: 0.6486  data: 0.0338  max mem: 4960
# Epoch: [7]  [70/92]  eta: 0:00:14  lr: 0.000050  loss: 0.1636 (0.2193)  loss_classifier: 0.0456 (0.0590)  loss_box_reg: 0.1092 (0.1417)  loss_objectness: 0.0023 (0.0053)  loss_rpn_box_reg: 0.0048 (0.0133)  time: 0.6428  data: 0.0323  max mem: 4960
# Epoch: [7]  [80/92]  eta: 0:00:08  lr: 0.000050  loss: 0.1995 (0.2260)  loss_classifier: 0.0535 (0.0613)  loss_box_reg: 0.1331 (0.1446)  loss_objectness: 0.0040 (0.0055)  loss_rpn_box_reg: 0.0080 (0.0146)  time: 0.6434  data: 0.0328  max mem: 4960
# Epoch: [7]  [90/92]  eta: 0:00:01  lr: 0.000050  loss: 0.2535 (0.2286)  loss_classifier: 0.0646 (0.0620)  loss_box_reg: 0.1733 (0.1461)  loss_objectness: 0.0030 (0.0054)  loss_rpn_box_reg: 0.0099 (0.0152)  time: 0.6398  data: 0.0311  max mem: 4960
# Epoch: [7]  [91/92]  eta: 0:00:00  lr: 0.000050  loss: 0.2755 (0.2291)  loss_classifier: 0.0680 (0.0620)  loss_box_reg: 0.1733 (0.1461)  loss_objectness: 0.0040 (0.0054)  loss_rpn_box_reg: 0.0176 (0.0155)  time: 0.6397  data: 0.0311  max mem: 4960
# Epoch: [7] Total time: 0:01:01 (0.6644 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:17  model_time: 0.2821 (0.2821)  evaluator_time: 0.0208 (0.0208)  time: 0.8644  data: 0.5283  max mem: 4960
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2545 (0.2565)  evaluator_time: 0.0262 (0.0329)  time: 0.3736  data: 0.0540  max mem: 4960
# Test: Total time: 0:00:07 (0.3753 s / it)
# Averaged stats: model_time: 0.2545 (0.2565)  evaluator_time: 0.0262 (0.0329)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.226
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.583
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.136
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.166
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.309
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.169
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
# Epoch: [8]  [ 0/92]  eta: 0:03:21  lr: 0.000050  loss: 0.1417 (0.1417)  loss_classifier: 0.0405 (0.0405)  loss_box_reg: 0.0947 (0.0947)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0059 (0.0059)  time: 2.1891  data: 1.5200  max mem: 4960
# Epoch: [8]  [10/92]  eta: 0:01:04  lr: 0.000050  loss: 0.1417 (0.1535)  loss_classifier: 0.0405 (0.0409)  loss_box_reg: 0.0896 (0.1020)  loss_objectness: 0.0006 (0.0032)  loss_rpn_box_reg: 0.0036 (0.0074)  time: 0.7925  data: 0.1704  max mem: 4960
# Epoch: [8]  [20/92]  eta: 0:00:51  lr: 0.000050  loss: 0.1712 (0.1979)  loss_classifier: 0.0477 (0.0538)  loss_box_reg: 0.0937 (0.1307)  loss_objectness: 0.0013 (0.0041)  loss_rpn_box_reg: 0.0036 (0.0093)  time: 0.6481  data: 0.0334  max mem: 4960
# Epoch: [8]  [30/92]  eta: 0:00:43  lr: 0.000050  loss: 0.2643 (0.2249)  loss_classifier: 0.0623 (0.0607)  loss_box_reg: 0.1761 (0.1438)  loss_objectness: 0.0026 (0.0050)  loss_rpn_box_reg: 0.0092 (0.0154)  time: 0.6489  data: 0.0337  max mem: 4960
# Epoch: [8]  [40/92]  eta: 0:00:35  lr: 0.000050  loss: 0.2251 (0.2277)  loss_classifier: 0.0617 (0.0624)  loss_box_reg: 0.1444 (0.1454)  loss_objectness: 0.0026 (0.0047)  loss_rpn_box_reg: 0.0065 (0.0152)  time: 0.6549  data: 0.0353  max mem: 4960
# Epoch: [8]  [50/92]  eta: 0:00:28  lr: 0.000050  loss: 0.1744 (0.2226)  loss_classifier: 0.0534 (0.0601)  loss_box_reg: 0.1200 (0.1440)  loss_objectness: 0.0013 (0.0048)  loss_rpn_box_reg: 0.0042 (0.0138)  time: 0.6528  data: 0.0336  max mem: 4960
# Epoch: [8]  [60/92]  eta: 0:00:21  lr: 0.000050  loss: 0.1744 (0.2282)  loss_classifier: 0.0547 (0.0621)  loss_box_reg: 0.1200 (0.1461)  loss_objectness: 0.0041 (0.0051)  loss_rpn_box_reg: 0.0068 (0.0149)  time: 0.6507  data: 0.0336  max mem: 4960
# Epoch: [8]  [70/92]  eta: 0:00:14  lr: 0.000050  loss: 0.2190 (0.2270)  loss_classifier: 0.0555 (0.0615)  loss_box_reg: 0.1503 (0.1472)  loss_objectness: 0.0040 (0.0048)  loss_rpn_box_reg: 0.0062 (0.0135)  time: 0.6495  data: 0.0344  max mem: 4960
# Epoch: [8]  [80/92]  eta: 0:00:08  lr: 0.000050  loss: 0.1872 (0.2243)  loss_classifier: 0.0512 (0.0610)  loss_box_reg: 0.1275 (0.1451)  loss_objectness: 0.0022 (0.0047)  loss_rpn_box_reg: 0.0034 (0.0135)  time: 0.6504  data: 0.0346  max mem: 4960
# Epoch: [8]  [90/92]  eta: 0:00:01  lr: 0.000050  loss: 0.1927 (0.2309)  loss_classifier: 0.0512 (0.0625)  loss_box_reg: 0.1371 (0.1482)  loss_objectness: 0.0032 (0.0050)  loss_rpn_box_reg: 0.0088 (0.0152)  time: 0.6435  data: 0.0313  max mem: 4960
# Epoch: [8]  [91/92]  eta: 0:00:00  lr: 0.000050  loss: 0.1927 (0.2322)  loss_classifier: 0.0512 (0.0627)  loss_box_reg: 0.1371 (0.1485)  loss_objectness: 0.0032 (0.0050)  loss_rpn_box_reg: 0.0088 (0.0159)  time: 0.6416  data: 0.0309  max mem: 4960
# Epoch: [8] Total time: 0:01:01 (0.6662 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2988 (0.2988)  evaluator_time: 0.0212 (0.0212)  time: 0.9505  data: 0.5476  max mem: 4960
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2540 (0.2562)  evaluator_time: 0.0270 (0.0323)  time: 0.3732  data: 0.0542  max mem: 4960
# Test: Total time: 0:00:07 (0.3753 s / it)
# Averaged stats: model_time: 0.2540 (0.2562)  evaluator_time: 0.0270 (0.0323)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.573
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.135
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.056
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.309
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.442
# Epoch: [9]  [ 0/92]  eta: 0:02:53  lr: 0.000005  loss: 0.0996 (0.0996)  loss_classifier: 0.0237 (0.0237)  loss_box_reg: 0.0707 (0.0707)  loss_objectness: 0.0039 (0.0039)  loss_rpn_box_reg: 0.0012 (0.0012)  time: 1.8881  data: 1.1670  max mem: 4960
# Epoch: [9]  [10/92]  eta: 0:01:03  lr: 0.000005  loss: 0.2181 (0.2254)  loss_classifier: 0.0472 (0.0616)  loss_box_reg: 0.1229 (0.1416)  loss_objectness: 0.0038 (0.0065)  loss_rpn_box_reg: 0.0086 (0.0157)  time: 0.7771  data: 0.1430  max mem: 4960
# Epoch: [9]  [20/92]  eta: 0:00:51  lr: 0.000005  loss: 0.2181 (0.2293)  loss_classifier: 0.0580 (0.0632)  loss_box_reg: 0.1357 (0.1459)  loss_objectness: 0.0030 (0.0050)  loss_rpn_box_reg: 0.0086 (0.0151)  time: 0.6587  data: 0.0381  max mem: 4960
# Epoch: [9]  [30/92]  eta: 0:00:43  lr: 0.000005  loss: 0.2027 (0.2340)  loss_classifier: 0.0580 (0.0635)  loss_box_reg: 0.1476 (0.1477)  loss_objectness: 0.0033 (0.0058)  loss_rpn_box_reg: 0.0095 (0.0170)  time: 0.6489  data: 0.0347  max mem: 4960
# Epoch: [9]  [40/92]  eta: 0:00:35  lr: 0.000005  loss: 0.2007 (0.2370)  loss_classifier: 0.0584 (0.0666)  loss_box_reg: 0.1476 (0.1498)  loss_objectness: 0.0035 (0.0053)  loss_rpn_box_reg: 0.0057 (0.0153)  time: 0.6430  data: 0.0324  max mem: 4960
# Epoch: [9]  [50/92]  eta: 0:00:28  lr: 0.000005  loss: 0.1975 (0.2357)  loss_classifier: 0.0584 (0.0657)  loss_box_reg: 0.1496 (0.1506)  loss_objectness: 0.0019 (0.0051)  loss_rpn_box_reg: 0.0043 (0.0143)  time: 0.6470  data: 0.0318  max mem: 4960
# Epoch: [9]  [60/92]  eta: 0:00:21  lr: 0.000005  loss: 0.1975 (0.2322)  loss_classifier: 0.0554 (0.0643)  loss_box_reg: 0.1222 (0.1481)  loss_objectness: 0.0023 (0.0050)  loss_rpn_box_reg: 0.0039 (0.0148)  time: 0.6502  data: 0.0322  max mem: 4960
# Epoch: [9]  [70/92]  eta: 0:00:14  lr: 0.000005  loss: 0.1736 (0.2309)  loss_classifier: 0.0460 (0.0635)  loss_box_reg: 0.1173 (0.1476)  loss_objectness: 0.0029 (0.0053)  loss_rpn_box_reg: 0.0038 (0.0144)  time: 0.6446  data: 0.0325  max mem: 4960
# Epoch: [9]  [80/92]  eta: 0:00:07  lr: 0.000005  loss: 0.1806 (0.2299)  loss_classifier: 0.0508 (0.0633)  loss_box_reg: 0.1275 (0.1469)  loss_objectness: 0.0025 (0.0052)  loss_rpn_box_reg: 0.0041 (0.0146)  time: 0.6482  data: 0.0345  max mem: 4960
# Epoch: [9]  [90/92]  eta: 0:00:01  lr: 0.000005  loss: 0.1818 (0.2312)  loss_classifier: 0.0498 (0.0634)  loss_box_reg: 0.1266 (0.1464)  loss_objectness: 0.0026 (0.0053)  loss_rpn_box_reg: 0.0062 (0.0161)  time: 0.6459  data: 0.0331  max mem: 4960
# Epoch: [9]  [91/92]  eta: 0:00:00  lr: 0.000005  loss: 0.1818 (0.2300)  loss_classifier: 0.0486 (0.0631)  loss_box_reg: 0.1266 (0.1458)  loss_objectness: 0.0025 (0.0053)  loss_rpn_box_reg: 0.0052 (0.0159)  time: 0.6451  data: 0.0327  max mem: 4960
# Epoch: [9] Total time: 0:01:00 (0.6626 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.2832 (0.2832)  evaluator_time: 0.0221 (0.0221)  time: 1.0280  data: 0.6909  max mem: 4960
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2531 (0.2547)  evaluator_time: 0.0281 (0.0324)  time: 0.3766  data: 0.0611  max mem: 4960
# Test: Total time: 0:00:07 (0.3783 s / it)
# Averaged stats: model_time: 0.2531 (0.2547)  evaluator_time: 0.0281 (0.0324)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.573
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.135
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.341
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.309
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.442
