# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Download TorchVision repo to use some files from
# references/detection
# !pip install pycocotools --quiet
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 531476, done.
# remote: Counting objects: 100% (45086/45086), done.
# remote: Compressing objects: 100% (2078/2078), done.
# remote: Total 531476 (delta 43040), reused 44913 (delta 42935), pack-reused 486390
# Receiving objects: 100% (531476/531476), 1023.04 MiB | 25.79 MiB/s, done.
# Resolving deltas: 100% (496287/496287), done.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
# defining the files directory and testing directory
train_dir = '/kaggle/input/kitti-train-test-selection/Train_Test_Selection/Train'
test_dir  = '/kaggle/input/kitti-train-test-selection/Train_Test_Selection/Test'

# %%
#for txt-annotatation dataset
class KittiDataset(torch.utils.data.Dataset):
    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
        self.imgs = [image for image in sorted(os.listdir(files_dir)) if image.endswith(('.png', '.jpg'))]
        self.classes = ['background', 'Pedestrian']

    def __getitem__(self, idx):
        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # Reading the images and converting them to correct size and color
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        img_res /= 255.0

        # Annotation file
        annot_filename = img_name[:-4] + '.txt'
        annot_file_path = os.path.join(self.files_dir, annot_filename)

        boxes = []
        labels = []

           # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        # Read annotation data from text file
        with open(annot_file_path, 'r') as file:
            for line in file:
                parts = line.strip().split(' ')
                label_text = parts[0].lower()

                if label_text in ['pedestrian', 'person']:
                    labels.append(self.classes.index('Pedestrian'))

                    # Bounding box coordinates
                    xmin = float(parts[4])
                    ymin = float(parts[5])
                    xmax = float(parts[6])
                    ymax = float(parts[7])

                    # Normalize coordinates
                    xmin_corr = (xmin/wt)*self.width
                    xmax_corr = (xmax/wt)*self.width
                    ymin_corr = (ymin/ht)*self.height
                    ymax_corr = (ymax/ht)*self.height

                    boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])

        # Convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        #print("boxes shape: ", boxes.size(), "at index",idx, img_name)
       
      
           

        # Calculate areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # Suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)

        labels = torch.as_tensor(labels, dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd

        # image_id
        #image_id = torch.tensor([idx])
        image_id = idx
        target["image_id"] = image_id

        if self.transforms:
            sample = self.transforms(image=img_res, bboxes=target['boxes'], labels=labels)
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
        return img_res, target
    
    

    def __len__(self):
        return len(self.imgs)

# %%
def get_object_detection_model(num_classes):

    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 

    return model

# %%
# Send train=True fro training transforms and False for val/test transforms
def get_transform(train):
    
    if train:
        return A.Compose([
            A.HorizontalFlip(0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
            A.Rotate(limit=15, p=0.5),
            ToTensorV2(p=1.0)
        ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['labels']))
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
# use our dataset and defined transformations
train_dataset = KittiDataset(train_dir, 1920, 1080, transforms= get_transform(train=True))
test_dataset = KittiDataset(test_dir, 1920, 1080, transforms= get_transform(train=False))

# define training and validation data loaders
data_loader_train = torch.utils.data.DataLoader(
    train_dataset, batch_size=4, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    test_dataset, batch_size=4, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')


num_classes = 2

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:02<00:00, 71.5MB/s]

# %%
# training for 10 epochs
num_epochs = 10
for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, data_loader_train, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [ 0/75]  eta: 0:05:49  lr: 0.000073  loss: 1.1125 (1.1125)  loss_classifier: 0.8318 (0.8318)  loss_box_reg: 0.2160 (0.2160)  loss_objectness: 0.0280 (0.0280)  loss_rpn_box_reg: 0.0367 (0.0367)  time: 4.6650  data: 1.5693  max mem: 4799
# Epoch: [0]  [10/75]  eta: 0:01:05  lr: 0.000748  loss: 0.7035 (0.7280)  loss_classifier: 0.5204 (0.4883)  loss_box_reg: 0.1411 (0.1417)  loss_objectness: 0.0333 (0.0608)  loss_rpn_box_reg: 0.0310 (0.0372)  time: 1.0061  data: 0.1655  max mem: 4958
# Epoch: [0]  [20/75]  eta: 0:00:45  lr: 0.001423  loss: 0.4542 (0.5611)  loss_classifier: 0.1947 (0.3385)  loss_box_reg: 0.1221 (0.1361)  loss_objectness: 0.0333 (0.0557)  loss_rpn_box_reg: 0.0238 (0.0307)  time: 0.6407  data: 0.0268  max mem: 4959
# Epoch: [0]  [30/75]  eta: 0:00:34  lr: 0.002098  loss: 0.2574 (0.4961)  loss_classifier: 0.1272 (0.2711)  loss_box_reg: 0.0969 (0.1307)  loss_objectness: 0.0341 (0.0600)  loss_rpn_box_reg: 0.0210 (0.0341)  time: 0.6427  data: 0.0285  max mem: 4959
# Epoch: [0]  [40/75]  eta: 0:00:25  lr: 0.002773  loss: 0.3084 (0.4813)  loss_classifier: 0.1074 (0.2356)  loss_box_reg: 0.1501 (0.1443)  loss_objectness: 0.0442 (0.0674)  loss_rpn_box_reg: 0.0210 (0.0339)  time: 0.6449  data: 0.0298  max mem: 4959
# Epoch: [0]  [50/75]  eta: 0:00:18  lr: 0.003448  loss: 0.3182 (0.4479)  loss_classifier: 0.1048 (0.2075)  loss_box_reg: 0.1635 (0.1483)  loss_objectness: 0.0291 (0.0600)  loss_rpn_box_reg: 0.0204 (0.0320)  time: 0.6481  data: 0.0319  max mem: 4959
# Epoch: [0]  [60/75]  eta: 0:00:10  lr: 0.004123  loss: 0.2673 (0.4264)  loss_classifier: 0.0813 (0.1876)  loss_box_reg: 0.1393 (0.1516)  loss_objectness: 0.0288 (0.0555)  loss_rpn_box_reg: 0.0196 (0.0317)  time: 0.6508  data: 0.0314  max mem: 4959
# Epoch: [0]  [70/75]  eta: 0:00:03  lr: 0.004798  loss: 0.3008 (0.4134)  loss_classifier: 0.0851 (0.1737)  loss_box_reg: 0.1244 (0.1502)  loss_objectness: 0.0345 (0.0552)  loss_rpn_box_reg: 0.0257 (0.0343)  time: 0.6469  data: 0.0300  max mem: 4959
# Epoch: [0]  [74/75]  eta: 0:00:00  lr: 0.005000  loss: 0.2880 (0.4104)  loss_classifier: 0.0851 (0.1700)  loss_box_reg: 0.1244 (0.1523)  loss_objectness: 0.0355 (0.0541)  loss_rpn_box_reg: 0.0324 (0.0341)  time: 0.6425  data: 0.0294  max mem: 4959
# Epoch: [0] Total time: 0:00:52 (0.6982 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.2957 (0.2957)  evaluator_time: 0.0169 (0.0169)  time: 1.0168  data: 0.6397  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2528 (0.2552)  evaluator_time: 0.0279 (0.0322)  time: 0.3754  data: 0.0583  max mem: 4959
# Test: Total time: 0:00:07 (0.3770 s / it)
# Averaged stats: model_time: 0.2528 (0.2552)  evaluator_time: 0.0279 (0.0322)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.309
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.669
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.265
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.161
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.404
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.527
# Epoch: [1]  [ 0/75]  eta: 0:02:24  lr: 0.005000  loss: 0.2796 (0.2796)  loss_classifier: 0.0719 (0.0719)  loss_box_reg: 0.1438 (0.1438)  loss_objectness: 0.0153 (0.0153)  loss_rpn_box_reg: 0.0487 (0.0487)  time: 1.9224  data: 1.2354  max mem: 4959
# Epoch: [1]  [10/75]  eta: 0:00:51  lr: 0.005000  loss: 0.2274 (0.2247)  loss_classifier: 0.0606 (0.0648)  loss_box_reg: 0.1104 (0.1203)  loss_objectness: 0.0153 (0.0171)  loss_rpn_box_reg: 0.0186 (0.0225)  time: 0.7940  data: 0.1493  max mem: 4959
# Epoch: [1]  [20/75]  eta: 0:00:39  lr: 0.005000  loss: 0.1975 (0.2269)  loss_classifier: 0.0602 (0.0679)  loss_box_reg: 0.0998 (0.1198)  loss_objectness: 0.0139 (0.0183)  loss_rpn_box_reg: 0.0179 (0.0209)  time: 0.6635  data: 0.0366  max mem: 4959
# Epoch: [1]  [30/75]  eta: 0:00:31  lr: 0.005000  loss: 0.1902 (0.2378)  loss_classifier: 0.0586 (0.0644)  loss_box_reg: 0.0891 (0.1116)  loss_objectness: 0.0160 (0.0287)  loss_rpn_box_reg: 0.0179 (0.0332)  time: 0.6483  data: 0.0328  max mem: 4959
# Epoch: [1]  [40/75]  eta: 0:00:23  lr: 0.005000  loss: 0.2167 (0.2439)  loss_classifier: 0.0692 (0.0692)  loss_box_reg: 0.0922 (0.1125)  loss_objectness: 0.0290 (0.0305)  loss_rpn_box_reg: 0.0179 (0.0316)  time: 0.6458  data: 0.0316  max mem: 4959
# Epoch: [1]  [50/75]  eta: 0:00:16  lr: 0.005000  loss: 0.2304 (0.2476)  loss_classifier: 0.0692 (0.0676)  loss_box_reg: 0.0952 (0.1081)  loss_objectness: 0.0355 (0.0397)  loss_rpn_box_reg: 0.0212 (0.0322)  time: 0.6426  data: 0.0306  max mem: 4959
# Epoch: [1]  [60/75]  eta: 0:00:10  lr: 0.005000  loss: 0.2304 (0.2510)  loss_classifier: 0.0596 (0.0702)  loss_box_reg: 0.0818 (0.1087)  loss_objectness: 0.0357 (0.0412)  loss_rpn_box_reg: 0.0180 (0.0310)  time: 0.6466  data: 0.0324  max mem: 4959
# Epoch: [1]  [70/75]  eta: 0:00:03  lr: 0.005000  loss: 0.2605 (0.2595)  loss_classifier: 0.0892 (0.0724)  loss_box_reg: 0.1098 (0.1150)  loss_objectness: 0.0352 (0.0407)  loss_rpn_box_reg: 0.0180 (0.0314)  time: 0.6478  data: 0.0324  max mem: 4959
# Epoch: [1]  [74/75]  eta: 0:00:00  lr: 0.005000  loss: 0.2598 (0.2571)  loss_classifier: 0.0795 (0.0727)  loss_box_reg: 0.0942 (0.1137)  loss_objectness: 0.0352 (0.0398)  loss_rpn_box_reg: 0.0173 (0.0309)  time: 0.6445  data: 0.0311  max mem: 4959
# Epoch: [1] Total time: 0:00:50 (0.6677 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.2752 (0.2752)  evaluator_time: 0.0061 (0.0061)  time: 1.0322  data: 0.6995  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2528 (0.2540)  evaluator_time: 0.0090 (0.0106)  time: 0.3545  data: 0.0609  max mem: 4959
# Test: Total time: 0:00:07 (0.3564 s / it)
# Averaged stats: model_time: 0.2528 (0.2540)  evaluator_time: 0.0090 (0.0106)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.676
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.376
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.480
# Epoch: [2]  [ 0/75]  eta: 0:02:46  lr: 0.005000  loss: 0.1953 (0.1953)  loss_classifier: 0.0756 (0.0756)  loss_box_reg: 0.0864 (0.0864)  loss_objectness: 0.0172 (0.0172)  loss_rpn_box_reg: 0.0161 (0.0161)  time: 2.2179  data: 1.5490  max mem: 4959
# Epoch: [2]  [10/75]  eta: 0:00:51  lr: 0.005000  loss: 0.2441 (0.2778)  loss_classifier: 0.0756 (0.0763)  loss_box_reg: 0.0929 (0.1232)  loss_objectness: 0.0201 (0.0206)  loss_rpn_box_reg: 0.0216 (0.0576)  time: 0.7922  data: 0.1684  max mem: 4959
# Epoch: [2]  [20/75]  eta: 0:00:39  lr: 0.005000  loss: 0.2052 (0.2459)  loss_classifier: 0.0578 (0.0715)  loss_box_reg: 0.0929 (0.1144)  loss_objectness: 0.0143 (0.0171)  loss_rpn_box_reg: 0.0245 (0.0429)  time: 0.6487  data: 0.0315  max mem: 4959
# Epoch: [2]  [30/75]  eta: 0:00:31  lr: 0.005000  loss: 0.1762 (0.2234)  loss_classifier: 0.0578 (0.0669)  loss_box_reg: 0.0793 (0.1066)  loss_objectness: 0.0108 (0.0152)  loss_rpn_box_reg: 0.0176 (0.0348)  time: 0.6461  data: 0.0326  max mem: 4959
# Epoch: [2]  [40/75]  eta: 0:00:24  lr: 0.005000  loss: 0.1895 (0.2198)  loss_classifier: 0.0623 (0.0666)  loss_box_reg: 0.0793 (0.1081)  loss_objectness: 0.0099 (0.0149)  loss_rpn_box_reg: 0.0137 (0.0302)  time: 0.6474  data: 0.0333  max mem: 4959
# Epoch: [2]  [50/75]  eta: 0:00:16  lr: 0.005000  loss: 0.1895 (0.2175)  loss_classifier: 0.0623 (0.0677)  loss_box_reg: 0.0983 (0.1064)  loss_objectness: 0.0109 (0.0155)  loss_rpn_box_reg: 0.0137 (0.0279)  time: 0.6468  data: 0.0333  max mem: 4959
# Epoch: [2]  [60/75]  eta: 0:00:10  lr: 0.005000  loss: 0.2359 (0.2289)  loss_classifier: 0.0774 (0.0697)  loss_box_reg: 0.1163 (0.1119)  loss_objectness: 0.0128 (0.0172)  loss_rpn_box_reg: 0.0223 (0.0300)  time: 0.6526  data: 0.0342  max mem: 4959
# Epoch: [2]  [70/75]  eta: 0:00:03  lr: 0.005000  loss: 0.2398 (0.2244)  loss_classifier: 0.0672 (0.0677)  loss_box_reg: 0.1168 (0.1116)  loss_objectness: 0.0131 (0.0166)  loss_rpn_box_reg: 0.0245 (0.0285)  time: 0.6509  data: 0.0327  max mem: 4959
# Epoch: [2]  [74/75]  eta: 0:00:00  lr: 0.005000  loss: 0.1557 (0.2243)  loss_classifier: 0.0480 (0.0673)  loss_box_reg: 0.0854 (0.1115)  loss_objectness: 0.0131 (0.0167)  loss_rpn_box_reg: 0.0176 (0.0288)  time: 0.6453  data: 0.0308  max mem: 4959
# Epoch: [2] Total time: 0:00:50 (0.6689 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2752 (0.2752)  evaluator_time: 0.0089 (0.0089)  time: 0.9923  data: 0.6409  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2536 (0.2552)  evaluator_time: 0.0104 (0.0150)  time: 0.3562  data: 0.0567  max mem: 4959
# Test: Total time: 0:00:07 (0.3581 s / it)
# Averaged stats: model_time: 0.2536 (0.2552)  evaluator_time: 0.0104 (0.0150)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.341
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.711
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.255
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.438
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.417
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.541
# Epoch: [3]  [ 0/75]  eta: 0:02:03  lr: 0.000500  loss: 0.0895 (0.0895)  loss_classifier: 0.0389 (0.0389)  loss_box_reg: 0.0351 (0.0351)  loss_objectness: 0.0018 (0.0018)  loss_rpn_box_reg: 0.0137 (0.0137)  time: 1.6481  data: 0.9604  max mem: 4959
# Epoch: [3]  [10/75]  eta: 0:00:47  lr: 0.000500  loss: 0.1341 (0.1741)  loss_classifier: 0.0417 (0.0482)  loss_box_reg: 0.0710 (0.0829)  loss_objectness: 0.0095 (0.0150)  loss_rpn_box_reg: 0.0150 (0.0280)  time: 0.7362  data: 0.1181  max mem: 4959
# Epoch: [3]  [20/75]  eta: 0:00:38  lr: 0.000500  loss: 0.1677 (0.1776)  loss_classifier: 0.0500 (0.0513)  loss_box_reg: 0.0741 (0.0881)  loss_objectness: 0.0100 (0.0135)  loss_rpn_box_reg: 0.0161 (0.0246)  time: 0.6456  data: 0.0328  max mem: 4959
# Epoch: [3]  [30/75]  eta: 0:00:30  lr: 0.000500  loss: 0.1709 (0.1835)  loss_classifier: 0.0571 (0.0532)  loss_box_reg: 0.0992 (0.0954)  loss_objectness: 0.0100 (0.0120)  loss_rpn_box_reg: 0.0176 (0.0229)  time: 0.6464  data: 0.0316  max mem: 4959
# Epoch: [3]  [40/75]  eta: 0:00:23  lr: 0.000500  loss: 0.1776 (0.1828)  loss_classifier: 0.0546 (0.0535)  loss_box_reg: 0.1011 (0.0966)  loss_objectness: 0.0064 (0.0110)  loss_rpn_box_reg: 0.0125 (0.0218)  time: 0.6460  data: 0.0322  max mem: 4959
# Epoch: [3]  [50/75]  eta: 0:00:16  lr: 0.000500  loss: 0.1706 (0.1801)  loss_classifier: 0.0546 (0.0538)  loss_box_reg: 0.0892 (0.0945)  loss_objectness: 0.0072 (0.0109)  loss_rpn_box_reg: 0.0125 (0.0210)  time: 0.6425  data: 0.0316  max mem: 4959
# Epoch: [3]  [60/75]  eta: 0:00:09  lr: 0.000500  loss: 0.1913 (0.1878)  loss_classifier: 0.0569 (0.0562)  loss_box_reg: 0.0821 (0.0995)  loss_objectness: 0.0072 (0.0108)  loss_rpn_box_reg: 0.0147 (0.0214)  time: 0.6399  data: 0.0299  max mem: 4959
# Epoch: [3]  [70/75]  eta: 0:00:03  lr: 0.000500  loss: 0.1854 (0.1865)  loss_classifier: 0.0601 (0.0557)  loss_box_reg: 0.0963 (0.0996)  loss_objectness: 0.0072 (0.0103)  loss_rpn_box_reg: 0.0147 (0.0208)  time: 0.6410  data: 0.0300  max mem: 4959
# Epoch: [3]  [74/75]  eta: 0:00:00  lr: 0.000500  loss: 0.1942 (0.1878)  loss_classifier: 0.0601 (0.0562)  loss_box_reg: 0.1084 (0.1005)  loss_objectness: 0.0073 (0.0103)  loss_rpn_box_reg: 0.0155 (0.0209)  time: 0.6399  data: 0.0300  max mem: 4959
# Epoch: [3] Total time: 0:00:49 (0.6570 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2711 (0.2711)  evaluator_time: 0.0088 (0.0088)  time: 0.9812  data: 0.6161  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2529 (0.2543)  evaluator_time: 0.0104 (0.0119)  time: 0.3525  data: 0.0560  max mem: 4959
# Test: Total time: 0:00:07 (0.3541 s / it)
# Averaged stats: model_time: 0.2529 (0.2543)  evaluator_time: 0.0104 (0.0119)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.348
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.735
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.175
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.446
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.450
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.328
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.531
# Epoch: [4]  [ 0/75]  eta: 0:02:29  lr: 0.000500  loss: 0.1280 (0.1280)  loss_classifier: 0.0612 (0.0612)  loss_box_reg: 0.0540 (0.0540)  loss_objectness: 0.0089 (0.0089)  loss_rpn_box_reg: 0.0039 (0.0039)  time: 1.9945  data: 1.2760  max mem: 4959
# Epoch: [4]  [10/75]  eta: 0:00:50  lr: 0.000500  loss: 0.1794 (0.2050)  loss_classifier: 0.0630 (0.0706)  loss_box_reg: 0.0717 (0.1012)  loss_objectness: 0.0069 (0.0156)  loss_rpn_box_reg: 0.0138 (0.0176)  time: 0.7706  data: 0.1449  max mem: 4959
# Epoch: [4]  [20/75]  eta: 0:00:39  lr: 0.000500  loss: 0.1794 (0.2013)  loss_classifier: 0.0630 (0.0655)  loss_box_reg: 0.0717 (0.1017)  loss_objectness: 0.0069 (0.0130)  loss_rpn_box_reg: 0.0138 (0.0211)  time: 0.6468  data: 0.0318  max mem: 4959
# Epoch: [4]  [30/75]  eta: 0:00:31  lr: 0.000500  loss: 0.2269 (0.2024)  loss_classifier: 0.0667 (0.0642)  loss_box_reg: 0.1189 (0.1057)  loss_objectness: 0.0080 (0.0118)  loss_rpn_box_reg: 0.0166 (0.0207)  time: 0.6463  data: 0.0314  max mem: 4959
# Epoch: [4]  [40/75]  eta: 0:00:23  lr: 0.000500  loss: 0.1734 (0.1952)  loss_classifier: 0.0564 (0.0595)  loss_box_reg: 0.0950 (0.0998)  loss_objectness: 0.0080 (0.0111)  loss_rpn_box_reg: 0.0156 (0.0248)  time: 0.6458  data: 0.0310  max mem: 4959
# Epoch: [4]  [50/75]  eta: 0:00:16  lr: 0.000500  loss: 0.1438 (0.1903)  loss_classifier: 0.0448 (0.0582)  loss_box_reg: 0.0743 (0.0983)  loss_objectness: 0.0069 (0.0103)  loss_rpn_box_reg: 0.0118 (0.0234)  time: 0.6417  data: 0.0305  max mem: 4959
# Epoch: [4]  [60/75]  eta: 0:00:09  lr: 0.000500  loss: 0.1469 (0.1886)  loss_classifier: 0.0533 (0.0579)  loss_box_reg: 0.0743 (0.0981)  loss_objectness: 0.0071 (0.0099)  loss_rpn_box_reg: 0.0142 (0.0227)  time: 0.6404  data: 0.0292  max mem: 4959
# Epoch: [4]  [70/75]  eta: 0:00:03  lr: 0.000500  loss: 0.1914 (0.1965)  loss_classifier: 0.0565 (0.0595)  loss_box_reg: 0.0811 (0.1031)  loss_objectness: 0.0079 (0.0103)  loss_rpn_box_reg: 0.0169 (0.0237)  time: 0.6394  data: 0.0284  max mem: 4959
# Epoch: [4]  [74/75]  eta: 0:00:00  lr: 0.000500  loss: 0.1674 (0.1955)  loss_classifier: 0.0565 (0.0594)  loss_box_reg: 0.0811 (0.1029)  loss_objectness: 0.0083 (0.0102)  loss_rpn_box_reg: 0.0158 (0.0231)  time: 0.6378  data: 0.0283  max mem: 4959
# Epoch: [4] Total time: 0:00:49 (0.6616 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2718 (0.2718)  evaluator_time: 0.0069 (0.0069)  time: 0.9845  data: 0.6652  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2531 (0.2540)  evaluator_time: 0.0097 (0.0113)  time: 0.3525  data: 0.0579  max mem: 4959
# Test: Total time: 0:00:07 (0.3543 s / it)
# Averaged stats: model_time: 0.2531 (0.2540)  evaluator_time: 0.0097 (0.0113)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.362
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.744
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.228
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.431
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.337
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.555
# Epoch: [5]  [ 0/75]  eta: 0:02:20  lr: 0.000500  loss: 0.2439 (0.2439)  loss_classifier: 0.0603 (0.0603)  loss_box_reg: 0.1286 (0.1286)  loss_objectness: 0.0196 (0.0196)  loss_rpn_box_reg: 0.0354 (0.0354)  time: 1.8717  data: 1.1616  max mem: 4959
# Epoch: [5]  [10/75]  eta: 0:00:49  lr: 0.000500  loss: 0.1981 (0.1695)  loss_classifier: 0.0558 (0.0511)  loss_box_reg: 0.0999 (0.0934)  loss_objectness: 0.0056 (0.0072)  loss_rpn_box_reg: 0.0177 (0.0178)  time: 0.7627  data: 0.1346  max mem: 4959
# Epoch: [5]  [20/75]  eta: 0:00:38  lr: 0.000500  loss: 0.1710 (0.1866)  loss_classifier: 0.0504 (0.0575)  loss_box_reg: 0.0921 (0.1021)  loss_objectness: 0.0058 (0.0074)  loss_rpn_box_reg: 0.0128 (0.0196)  time: 0.6500  data: 0.0321  max mem: 4959
# Epoch: [5]  [30/75]  eta: 0:00:30  lr: 0.000500  loss: 0.2441 (0.2126)  loss_classifier: 0.0636 (0.0636)  loss_box_reg: 0.0954 (0.1118)  loss_objectness: 0.0082 (0.0094)  loss_rpn_box_reg: 0.0239 (0.0279)  time: 0.6453  data: 0.0320  max mem: 4959
# Epoch: [5]  [40/75]  eta: 0:00:23  lr: 0.000500  loss: 0.2399 (0.2069)  loss_classifier: 0.0675 (0.0618)  loss_box_reg: 0.0954 (0.1107)  loss_objectness: 0.0077 (0.0090)  loss_rpn_box_reg: 0.0251 (0.0254)  time: 0.6477  data: 0.0325  max mem: 4959
# Epoch: [5]  [50/75]  eta: 0:00:16  lr: 0.000500  loss: 0.1413 (0.1994)  loss_classifier: 0.0474 (0.0597)  loss_box_reg: 0.0890 (0.1086)  loss_objectness: 0.0052 (0.0086)  loss_rpn_box_reg: 0.0074 (0.0225)  time: 0.6524  data: 0.0335  max mem: 4959
# Epoch: [5]  [60/75]  eta: 0:00:10  lr: 0.000500  loss: 0.1341 (0.1932)  loss_classifier: 0.0489 (0.0584)  loss_box_reg: 0.0749 (0.1056)  loss_objectness: 0.0040 (0.0081)  loss_rpn_box_reg: 0.0088 (0.0211)  time: 0.6486  data: 0.0324  max mem: 4959
# Epoch: [5]  [70/75]  eta: 0:00:03  lr: 0.000500  loss: 0.1482 (0.1905)  loss_classifier: 0.0499 (0.0578)  loss_box_reg: 0.0822 (0.1042)  loss_objectness: 0.0055 (0.0081)  loss_rpn_box_reg: 0.0119 (0.0204)  time: 0.6405  data: 0.0297  max mem: 4959
# Epoch: [5]  [74/75]  eta: 0:00:00  lr: 0.000500  loss: 0.1482 (0.1903)  loss_classifier: 0.0492 (0.0577)  loss_box_reg: 0.0822 (0.1046)  loss_objectness: 0.0069 (0.0080)  loss_rpn_box_reg: 0.0091 (0.0199)  time: 0.6367  data: 0.0289  max mem: 4959
# Epoch: [5] Total time: 0:00:49 (0.6629 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:20  model_time: 0.2888 (0.2888)  evaluator_time: 0.0077 (0.0077)  time: 1.0281  data: 0.6654  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2530 (0.2553)  evaluator_time: 0.0091 (0.0116)  time: 0.3581  data: 0.0609  max mem: 4959
# Test: Total time: 0:00:07 (0.3598 s / it)
# Averaged stats: model_time: 0.2530 (0.2553)  evaluator_time: 0.0091 (0.0116)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.365
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.743
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.330
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.463
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.227
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.354
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.544
# Epoch: [6]  [ 0/75]  eta: 0:02:38  lr: 0.000050  loss: 0.1923 (0.1923)  loss_classifier: 0.0688 (0.0688)  loss_box_reg: 0.1086 (0.1086)  loss_objectness: 0.0019 (0.0019)  loss_rpn_box_reg: 0.0130 (0.0130)  time: 2.1179  data: 1.4737  max mem: 4959
# Epoch: [6]  [10/75]  eta: 0:00:50  lr: 0.000050  loss: 0.1923 (0.1723)  loss_classifier: 0.0423 (0.0499)  loss_box_reg: 0.1016 (0.0986)  loss_objectness: 0.0043 (0.0064)  loss_rpn_box_reg: 0.0117 (0.0174)  time: 0.7826  data: 0.1605  max mem: 4959
# Epoch: [6]  [20/75]  eta: 0:00:39  lr: 0.000050  loss: 0.1769 (0.1733)  loss_classifier: 0.0501 (0.0518)  loss_box_reg: 0.1016 (0.0984)  loss_objectness: 0.0054 (0.0071)  loss_rpn_box_reg: 0.0117 (0.0160)  time: 0.6470  data: 0.0297  max mem: 4959
# Epoch: [6]  [30/75]  eta: 0:00:31  lr: 0.000050  loss: 0.1779 (0.1818)  loss_classifier: 0.0612 (0.0553)  loss_box_reg: 0.0955 (0.1014)  loss_objectness: 0.0071 (0.0075)  loss_rpn_box_reg: 0.0145 (0.0176)  time: 0.6452  data: 0.0306  max mem: 4959
# Epoch: [6]  [40/75]  eta: 0:00:23  lr: 0.000050  loss: 0.1586 (0.1776)  loss_classifier: 0.0500 (0.0554)  loss_box_reg: 0.0858 (0.0984)  loss_objectness: 0.0055 (0.0078)  loss_rpn_box_reg: 0.0081 (0.0160)  time: 0.6463  data: 0.0315  max mem: 4959
# Epoch: [6]  [50/75]  eta: 0:00:16  lr: 0.000050  loss: 0.1474 (0.1865)  loss_classifier: 0.0500 (0.0578)  loss_box_reg: 0.0849 (0.1034)  loss_objectness: 0.0059 (0.0085)  loss_rpn_box_reg: 0.0102 (0.0168)  time: 0.6429  data: 0.0305  max mem: 4959
# Epoch: [6]  [60/75]  eta: 0:00:10  lr: 0.000050  loss: 0.1668 (0.1821)  loss_classifier: 0.0459 (0.0558)  loss_box_reg: 0.0787 (0.1004)  loss_objectness: 0.0085 (0.0087)  loss_rpn_box_reg: 0.0155 (0.0172)  time: 0.6423  data: 0.0301  max mem: 4959
# Epoch: [6]  [70/75]  eta: 0:00:03  lr: 0.000050  loss: 0.1488 (0.1835)  loss_classifier: 0.0452 (0.0564)  loss_box_reg: 0.0712 (0.1014)  loss_objectness: 0.0095 (0.0086)  loss_rpn_box_reg: 0.0089 (0.0172)  time: 0.6398  data: 0.0293  max mem: 4959
# Epoch: [6]  [74/75]  eta: 0:00:00  lr: 0.000050  loss: 0.1548 (0.1876)  loss_classifier: 0.0452 (0.0574)  loss_box_reg: 0.0787 (0.1034)  loss_objectness: 0.0073 (0.0087)  loss_rpn_box_reg: 0.0133 (0.0180)  time: 0.6346  data: 0.0277  max mem: 4959
# Epoch: [6] Total time: 0:00:49 (0.6630 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:17  model_time: 0.2878 (0.2878)  evaluator_time: 0.0105 (0.0105)  time: 0.8905  data: 0.5082  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2540 (0.2558)  evaluator_time: 0.0098 (0.0231)  time: 0.3647  data: 0.0538  max mem: 4959
# Test: Total time: 0:00:07 (0.3665 s / it)
# Averaged stats: model_time: 0.2540 (0.2558)  evaluator_time: 0.0098 (0.0231)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.744
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.436
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.472
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.549
# Epoch: [7]  [ 0/75]  eta: 0:02:39  lr: 0.000050  loss: 0.1620 (0.1620)  loss_classifier: 0.0638 (0.0638)  loss_box_reg: 0.0845 (0.0845)  loss_objectness: 0.0052 (0.0052)  loss_rpn_box_reg: 0.0085 (0.0085)  time: 2.1321  data: 1.4067  max mem: 4959
# Epoch: [7]  [10/75]  eta: 0:00:50  lr: 0.000050  loss: 0.1937 (0.2153)  loss_classifier: 0.0657 (0.0743)  loss_box_reg: 0.0870 (0.1155)  loss_objectness: 0.0070 (0.0081)  loss_rpn_box_reg: 0.0085 (0.0173)  time: 0.7821  data: 0.1557  max mem: 4959
# Epoch: [7]  [20/75]  eta: 0:00:39  lr: 0.000050  loss: 0.1561 (0.1949)  loss_classifier: 0.0607 (0.0655)  loss_box_reg: 0.0856 (0.1063)  loss_objectness: 0.0056 (0.0071)  loss_rpn_box_reg: 0.0099 (0.0160)  time: 0.6442  data: 0.0302  max mem: 4959
# Epoch: [7]  [30/75]  eta: 0:00:31  lr: 0.000050  loss: 0.1560 (0.1920)  loss_classifier: 0.0461 (0.0626)  loss_box_reg: 0.0797 (0.1058)  loss_objectness: 0.0054 (0.0069)  loss_rpn_box_reg: 0.0118 (0.0167)  time: 0.6455  data: 0.0315  max mem: 4959
# Epoch: [7]  [40/75]  eta: 0:00:23  lr: 0.000050  loss: 0.1611 (0.1941)  loss_classifier: 0.0497 (0.0616)  loss_box_reg: 0.0797 (0.1088)  loss_objectness: 0.0062 (0.0069)  loss_rpn_box_reg: 0.0118 (0.0168)  time: 0.6466  data: 0.0324  max mem: 4959
# Epoch: [7]  [50/75]  eta: 0:00:16  lr: 0.000050  loss: 0.1611 (0.1966)  loss_classifier: 0.0497 (0.0623)  loss_box_reg: 0.0890 (0.1100)  loss_objectness: 0.0074 (0.0076)  loss_rpn_box_reg: 0.0116 (0.0167)  time: 0.6422  data: 0.0310  max mem: 4959
# Epoch: [7]  [60/75]  eta: 0:00:10  lr: 0.000050  loss: 0.1735 (0.1934)  loss_classifier: 0.0546 (0.0610)  loss_box_reg: 0.0895 (0.1077)  loss_objectness: 0.0064 (0.0077)  loss_rpn_box_reg: 0.0116 (0.0171)  time: 0.6434  data: 0.0316  max mem: 4959
# Epoch: [7]  [70/75]  eta: 0:00:03  lr: 0.000050  loss: 0.2002 (0.1970)  loss_classifier: 0.0561 (0.0616)  loss_box_reg: 0.1092 (0.1100)  loss_objectness: 0.0064 (0.0076)  loss_rpn_box_reg: 0.0127 (0.0177)  time: 0.6425  data: 0.0310  max mem: 4959
# Epoch: [7]  [74/75]  eta: 0:00:00  lr: 0.000050  loss: 0.1935 (0.1930)  loss_classifier: 0.0556 (0.0606)  loss_box_reg: 0.1029 (0.1077)  loss_objectness: 0.0058 (0.0075)  loss_rpn_box_reg: 0.0123 (0.0172)  time: 0.6384  data: 0.0298  max mem: 4959
# Epoch: [7] Total time: 0:00:49 (0.6637 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:17  model_time: 0.2783 (0.2783)  evaluator_time: 0.0112 (0.0112)  time: 0.8565  data: 0.5317  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2534 (0.2548)  evaluator_time: 0.0099 (0.0119)  time: 0.3482  data: 0.0536  max mem: 4959
# Test: Total time: 0:00:06 (0.3499 s / it)
# Averaged stats: model_time: 0.2534 (0.2548)  evaluator_time: 0.0099 (0.0119)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.365
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.744
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.194
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.437
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.473
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554
# Epoch: [8]  [ 0/75]  eta: 0:02:08  lr: 0.000050  loss: 0.1207 (0.1207)  loss_classifier: 0.0451 (0.0451)  loss_box_reg: 0.0621 (0.0621)  loss_objectness: 0.0067 (0.0067)  loss_rpn_box_reg: 0.0069 (0.0069)  time: 1.7112  data: 1.0551  max mem: 4959
# Epoch: [8]  [10/75]  eta: 0:00:50  lr: 0.000050  loss: 0.1589 (0.2209)  loss_classifier: 0.0465 (0.0602)  loss_box_reg: 0.0672 (0.1140)  loss_objectness: 0.0065 (0.0078)  loss_rpn_box_reg: 0.0240 (0.0390)  time: 0.7724  data: 0.1357  max mem: 4959
# Epoch: [8]  [20/75]  eta: 0:00:39  lr: 0.000050  loss: 0.1313 (0.1844)  loss_classifier: 0.0439 (0.0526)  loss_box_reg: 0.0672 (0.0973)  loss_objectness: 0.0051 (0.0070)  loss_rpn_box_reg: 0.0146 (0.0274)  time: 0.6597  data: 0.0370  max mem: 4959
# Epoch: [8]  [30/75]  eta: 0:00:31  lr: 0.000050  loss: 0.1212 (0.1749)  loss_classifier: 0.0391 (0.0516)  loss_box_reg: 0.0681 (0.0952)  loss_objectness: 0.0038 (0.0062)  loss_rpn_box_reg: 0.0057 (0.0219)  time: 0.6473  data: 0.0320  max mem: 4959
# Epoch: [8]  [40/75]  eta: 0:00:23  lr: 0.000050  loss: 0.1250 (0.1767)  loss_classifier: 0.0391 (0.0520)  loss_box_reg: 0.0692 (0.0986)  loss_objectness: 0.0033 (0.0065)  loss_rpn_box_reg: 0.0077 (0.0196)  time: 0.6485  data: 0.0319  max mem: 4959
# Epoch: [8]  [50/75]  eta: 0:00:16  lr: 0.000050  loss: 0.1541 (0.1783)  loss_classifier: 0.0482 (0.0536)  loss_box_reg: 0.0825 (0.0986)  loss_objectness: 0.0042 (0.0064)  loss_rpn_box_reg: 0.0108 (0.0197)  time: 0.6387  data: 0.0287  max mem: 4959
# Epoch: [8]  [60/75]  eta: 0:00:10  lr: 0.000050  loss: 0.1478 (0.1785)  loss_classifier: 0.0512 (0.0546)  loss_box_reg: 0.0832 (0.0972)  loss_objectness: 0.0071 (0.0069)  loss_rpn_box_reg: 0.0141 (0.0199)  time: 0.6434  data: 0.0309  max mem: 4959
# Epoch: [8]  [70/75]  eta: 0:00:03  lr: 0.000050  loss: 0.1366 (0.1807)  loss_classifier: 0.0507 (0.0547)  loss_box_reg: 0.0795 (0.1000)  loss_objectness: 0.0054 (0.0068)  loss_rpn_box_reg: 0.0117 (0.0192)  time: 0.6452  data: 0.0316  max mem: 4959
# Epoch: [8]  [74/75]  eta: 0:00:00  lr: 0.000050  loss: 0.1522 (0.1851)  loss_classifier: 0.0512 (0.0560)  loss_box_reg: 0.0895 (0.1029)  loss_objectness: 0.0070 (0.0068)  loss_rpn_box_reg: 0.0129 (0.0193)  time: 0.6393  data: 0.0298  max mem: 4959
# Epoch: [8] Total time: 0:00:49 (0.6626 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2888 (0.2888)  evaluator_time: 0.0073 (0.0073)  time: 0.9709  data: 0.5896  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2535 (0.2557)  evaluator_time: 0.0085 (0.0118)  time: 0.3547  data: 0.0562  max mem: 4959
# Test: Total time: 0:00:07 (0.3565 s / it)
# Averaged stats: model_time: 0.2535 (0.2557)  evaluator_time: 0.0085 (0.0118)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.364
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.745
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.343
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.472
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554
# Epoch: [9]  [ 0/75]  eta: 0:01:41  lr: 0.000005  loss: 0.1283 (0.1283)  loss_classifier: 0.0573 (0.0573)  loss_box_reg: 0.0513 (0.0513)  loss_objectness: 0.0113 (0.0113)  loss_rpn_box_reg: 0.0084 (0.0084)  time: 1.3538  data: 0.7062  max mem: 4959
# Epoch: [9]  [10/75]  eta: 0:00:46  lr: 0.000005  loss: 0.1487 (0.1508)  loss_classifier: 0.0416 (0.0451)  loss_box_reg: 0.0775 (0.0806)  loss_objectness: 0.0080 (0.0077)  loss_rpn_box_reg: 0.0152 (0.0175)  time: 0.7165  data: 0.0967  max mem: 4959
# Epoch: [9]  [20/75]  eta: 0:00:37  lr: 0.000005  loss: 0.1380 (0.1705)  loss_classifier: 0.0391 (0.0506)  loss_box_reg: 0.0748 (0.0926)  loss_objectness: 0.0060 (0.0089)  loss_rpn_box_reg: 0.0150 (0.0184)  time: 0.6508  data: 0.0341  max mem: 4959
# Epoch: [9]  [30/75]  eta: 0:00:30  lr: 0.000005  loss: 0.1561 (0.1844)  loss_classifier: 0.0470 (0.0537)  loss_box_reg: 0.0882 (0.1010)  loss_objectness: 0.0042 (0.0085)  loss_rpn_box_reg: 0.0150 (0.0211)  time: 0.6437  data: 0.0311  max mem: 4959
# Epoch: [9]  [40/75]  eta: 0:00:23  lr: 0.000005  loss: 0.1963 (0.1887)  loss_classifier: 0.0560 (0.0568)  loss_box_reg: 0.0890 (0.1051)  loss_objectness: 0.0054 (0.0078)  loss_rpn_box_reg: 0.0125 (0.0190)  time: 0.6401  data: 0.0297  max mem: 4959
# Epoch: [9]  [50/75]  eta: 0:00:16  lr: 0.000005  loss: 0.1536 (0.1857)  loss_classifier: 0.0545 (0.0562)  loss_box_reg: 0.0821 (0.1021)  loss_objectness: 0.0080 (0.0081)  loss_rpn_box_reg: 0.0121 (0.0194)  time: 0.6443  data: 0.0314  max mem: 4959
# Epoch: [9]  [60/75]  eta: 0:00:09  lr: 0.000005  loss: 0.1692 (0.1833)  loss_classifier: 0.0525 (0.0560)  loss_box_reg: 0.0839 (0.1012)  loss_objectness: 0.0076 (0.0076)  loss_rpn_box_reg: 0.0110 (0.0185)  time: 0.6477  data: 0.0333  max mem: 4959
# Epoch: [9]  [70/75]  eta: 0:00:03  lr: 0.000005  loss: 0.1704 (0.1866)  loss_classifier: 0.0546 (0.0571)  loss_box_reg: 0.0951 (0.1027)  loss_objectness: 0.0055 (0.0078)  loss_rpn_box_reg: 0.0133 (0.0190)  time: 0.6467  data: 0.0326  max mem: 4959
# Epoch: [9]  [74/75]  eta: 0:00:00  lr: 0.000005  loss: 0.1748 (0.1872)  loss_classifier: 0.0546 (0.0575)  loss_box_reg: 0.0956 (0.1027)  loss_objectness: 0.0051 (0.0077)  loss_rpn_box_reg: 0.0144 (0.0193)  time: 0.6438  data: 0.0313  max mem: 4959
# Epoch: [9] Total time: 0:00:49 (0.6554 s / it)
# creating index...
# index created!
# Test:  [ 0/20]  eta: 0:00:19  model_time: 0.2669 (0.2669)  evaluator_time: 0.0070 (0.0070)  time: 0.9658  data: 0.6512  max mem: 4959
# Test:  [19/20]  eta: 0:00:00  model_time: 0.2534 (0.2545)  evaluator_time: 0.0086 (0.0114)  time: 0.3519  data: 0.0575  max mem: 4959
# Test: Total time: 0:00:07 (0.3538 s / it)
# Averaged stats: model_time: 0.2534 (0.2545)  evaluator_time: 0.0086 (0.0114)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.365
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.744
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.343
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.435
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.472
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.555
